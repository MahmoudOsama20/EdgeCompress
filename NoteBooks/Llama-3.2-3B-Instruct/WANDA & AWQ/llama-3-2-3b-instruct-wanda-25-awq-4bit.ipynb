# %% [markdown]
# # Libraries

# %%
# !pip install -q -U llmcompressor datasets accelerate transformers huggingface_hub
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.5/295.5 kB 13.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.5/196.5 kB 18.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 520.7/520.7 kB 29.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 85.0 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 34.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 563.6/563.6 kB 37.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 MB 43.8 MB/s eta 0:00:00:00:0100:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.31.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# google-adk 1.21.0 requires google-cloud-bigquery-storage>=2.0.0, which is not installed.

# %%
import random
import numpy as np
import torch

from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    set_seed,
)

from llmcompressor import oneshot
from llmcompressor.modifiers.awq import AWQModifier

from huggingface_hub import (
    login,
    create_repo,
    upload_folder,
)

from kaggle_secrets import UserSecretsClient
from datasets import load_dataset
# Out:
# 2026-03-21 14:01:35.281952: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774101695.464161      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774101695.515928      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774101695.944894      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774101695.944934      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774101695.944937      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774101695.944939      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %% [markdown]
# # Global Variables

# %%
BASE_ID = "meta-llama/Llama-3.2-3B-Instruct"
MODEL_ID = "EdgeCompress01/Llama-3.2-3B-Instruct-WANDA"
OUTPUT_DIR = "/kaggle/working/Llama-3.2-3B-Instruct-WANDA-AWQ-4bit"
REPO_ID = f"EdgeCompress01/Llama-3.2-3B-Instruct-WANDA-AWQ-4bit"
SEED = 42

# %% [markdown]
# # Functions

# %%
# --- 2. REPRODUCIBILITY ---
def set_reproducibility(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    set_seed(seed)
    # Ensure deterministic behavior in CuDNN
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    print(f"Global seed set to {seed}")

def format_chat(batch):
    texts = [
        tokenizer.apply_chat_template(
            messages,
            tokenize=False,
            add_generation_prompt=False
        )
        for messages in batch["messages"]
    ]
    return {"text": texts}

# %% [markdown]
# # Set Seed

# %%
set_reproducibility(SEED)
# Out:
# Global seed set to 42

# %% [markdown]
# # Huggingface Login

# %%
# --- 3. HUGGING FACE AUTHENTICATION ---
user_secrets = UserSecretsClient()
hf_token = user_secrets.get_secret("HF_TOKEN")
login(token=hf_token)
print("Logged in")
# Out:
# Logged in

# %% [markdown]
# # Load Model & Tokenizer

# %%
#Model
model = AutoModelForCausalLM.from_pretrained(
    MODEL_ID,
    subfolder="Models/25",
    device_map="auto",
    dtype=torch.bfloat16
)

#Tokenizer
tokenizer = AutoTokenizer.from_pretrained(BASE_ID)
# Out:
# config.json:   0%|          | 0.00/947 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Models/25/model-00002-of-00002.safetenso(…):   0%|          | 0.00/1.46G [00:00<?, ?B/s]
# Models/25/model-00001-of-00002.safetenso(…):   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/184 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/296 [00:00<?, ?B/s]

# %% [markdown]
# # AWQ Quantization

# %% [markdown]
# **Configurations**

# %%
recipe = [
    AWQModifier(
        ignore=["lm_head", "embed_tokens"], 
        scheme="W4A16",
        targets=["Linear"]
    )
]

# %% [markdown]
# **Calibration Dataset**

# %%
dataset = load_dataset("HuggingFaceH4/ultrachat_200k", split="train_sft").shuffle(seed=SEED).select(range(64))

formatted_dataset = dataset.map(
    format_chat,
    batched=True,
    remove_columns=dataset.column_names  # keep only "text"
)
# Out:
# README.md: 0.00B [00:00, ?B/s]
# data/train_sft-00000-of-00003-a3ecf92756(…):   0%|          | 0.00/244M [00:00<?, ?B/s]
# data/train_sft-00001-of-00003-0a1804bcb6(…):   0%|          | 0.00/244M [00:00<?, ?B/s]
# data/train_sft-00002-of-00003-ee46ed25cf(…):   0%|          | 0.00/244M [00:00<?, ?B/s]
# data/test_sft-00000-of-00001-f7dfac4afe5(…):   0%|          | 0.00/81.2M [00:00<?, ?B/s]
# data/train_gen-00000-of-00003-a6c9fb894b(…):   0%|          | 0.00/244M [00:00<?, ?B/s]
# data/train_gen-00001-of-00003-d6a0402e41(…):   0%|          | 0.00/243M [00:00<?, ?B/s]
# data/train_gen-00002-of-00003-c0db75b92a(…):   0%|          | 0.00/243M [00:00<?, ?B/s]
# data/test_gen-00000-of-00001-3d4cd830914(…):   0%|          | 0.00/80.4M [00:00<?, ?B/s]
# Generating train_sft split:   0%|          | 0/207865 [00:00<?, ? examples/s]
# Generating test_sft split:   0%|          | 0/23110 [00:00<?, ? examples/s]
# Generating train_gen split:   0%|          | 0/256032 [00:00<?, ? examples/s]
# Generating test_gen split:   0%|          | 0/28304 [00:00<?, ? examples/s]
# Map:   0%|          | 0/64 [00:00<?, ? examples/s]

# %% [markdown]
# **Apply quantization**

# %%
oneshot(
    model=model,
    tokenizer=tokenizer,
    dataset=formatted_dataset,
    text_column="text",
    recipe=recipe,
    max_seq_length=512
)
# Out:
# 2026-03-21T14:03:20.696805+0000 | __init__ | WARNING - Disabling tokenizer parallelism due to threading conflict between FastTokenizer and Datasets. Set TOKENIZERS_PARALLELISM=false to suppress this warning.
# Tokenizing:   0%|          | 0/64 [00:00<?, ? examples/s]
# 2026-03-21T14:03:21.175328+0000 | _make_sampler | WARNING - Requested 512 samples but the provided dataset only has 64 samples.
# 2026-03-21T14:03:21.176614+0000 | reset | INFO - Compression lifecycle reset
# 2026-03-21T14:03:21.179102+0000 | from_modifiers | INFO - Creating recipe from modifiers
# 2026-03-21T14:03:21.251088+0000 | on_initialize | INFO - No AWQModifier.mappings provided, inferring from model...
# 2026-03-21T14:03:21.261294+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.0.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-21T14:03:21.262194+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.1.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-21T14:03:21.264271+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.2.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-21T14:03:21.265114+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.3.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-21T14:03:21.265867+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.4.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-21T14:03:21.266847+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.5.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-21T14:03:21.267675+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.6.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-21T14:03:21.269132+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.7.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-21T14:03:21.269837+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.8.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-21T14:03:21.270753+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.9.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-21T14:03:21.271519+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.10.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-21T14:03:21.272416+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.11.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-21T14:03:21.273169+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.12.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-21T14:03:21.273905+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.13.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-21T14:03:21.274727+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.14.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-21T14:03:21.275469+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.15.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-21T14:03:21.276230+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.16.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-21T14:03:21.277106+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.17.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-21T14:03:21.277836+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.18.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-21T14:03:21.278720+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.19.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-21T14:03:21.279572+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.20.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-21T14:03:21.280407+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.21.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-21T14:03:21.282410+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.22.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-21T14:03:21.283106+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.23.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-21T14:03:21.283884+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.24.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-21T14:03:21.284744+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.25.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-21T14:03:21.285477+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.26.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-21T14:03:21.286198+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.27.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-21T14:03:21.295032+0000 | initialize | INFO - Compression lifecycle initialized for 1 modifiers
# 2026-03-21T14:03:21.296333+0000 | IndependentPipeline | INFO - Inferred `SequentialPipeline` for `AWQModifier`
# W0321 14:03:21.349000 55 torch/fx/_symbolic_trace.py:52] is_fx_tracing will return true for both fx.symbolic_trace and torch.export. Please use is_fx_tracing_symbolic_tracing() for specifically fx.symbolic_trace or torch.compiler.is_compiling() for specifically torch.export/compile.
# Preparing cache: 100%|██████████| 64/64 [00:00<00:00, 1169.24it/s]
# (1/29): Calibrating: 100%|██████████| 64/64 [00:02<00:00, 31.66it/s]
# Smoothing:   0%|          | 0/3 [00:00<?, ?it/s]
# Grid search for model.layers.0.input_layernorm:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.0.input_layernorm:   0%|          | 0/20 [00:00<?, ?it/s, best_error=1.103e-05]
# Grid search for model.layers.0.input_layernorm:   5%|▌         | 1/20 [00:00<00:10,  1.75it/s, best_error=1.103e-05]
# Grid search for model.layers.0.input_layernorm:   5%|▌         | 1/20 [00:00<00:10,  1.75it/s, best_error=7.510e-06]
# Grid search for model.layers.0.input_layernorm:  10%|█         | 2/20 [00:00<00:08,  2.06it/s, best_error=7.510e-06]
# Grid search for model.layers.0.input_layernorm:  10%|█         | 2/20 [00:01<00:08,  2.06it/s, best_error=5.394e-06]
# Grid search for model.layers.0.input_layernorm:  15%|█▌        | 3/20 [00:01<00:07,  2.18it/s, best_error=5.394e-06]
# Grid search for model.layers.0.input_layernorm:  15%|█▌        | 3/20 [00:01<00:07,  2.18it/s, best_error=4.739e-06]
# Grid search for model.layers.0.input_layernorm:  20%|██        | 4/20 [00:01<00:07,  2.23it/s, best_error=4.739e-06]
# Grid search for model.layers.0.input_layernorm:  20%|██        | 4/20 [00:02<00:07,  2.23it/s, best_error=3.457e-06]
# Grid search for model.layers.0.input_layernorm:  25%|██▌       | 5/20 [00:02<00:06,  2.27it/s, best_error=3.457e-06]
# Grid search for model.layers.0.input_layernorm:  25%|██▌       | 5/20 [00:02<00:06,  2.27it/s, best_error=2.697e-06]
# Grid search for model.layers.0.input_layernorm:  30%|███       | 6/20 [00:02<00:06,  2.29it/s, best_error=2.697e-06]
# Grid search for model.layers.0.input_layernorm:  30%|███       | 6/20 [00:03<00:06,  2.29it/s, best_error=2.369e-06]
# Grid search for model.layers.0.input_layernorm:  35%|███▌      | 7/20 [00:03<00:05,  2.30it/s, best_error=2.369e-06]
# Grid search for model.layers.0.input_layernorm:  35%|███▌      | 7/20 [00:03<00:05,  2.30it/s, best_error=1.900e-06]
# Grid search for model.layers.0.input_layernorm:  40%|████      | 8/20 [00:03<00:05,  2.31it/s, best_error=1.900e-06]
# Grid search for model.layers.0.input_layernorm:  40%|████      | 8/20 [00:03<00:05,  2.31it/s, best_error=1.729e-06]
# Grid search for model.layers.0.input_layernorm:  45%|████▌     | 9/20 [00:03<00:04,  2.32it/s, best_error=1.729e-06]
# Grid search for model.layers.0.input_layernorm:  45%|████▌     | 9/20 [00:04<00:04,  2.32it/s, best_error=1.580e-06]
# Grid search for model.layers.0.input_layernorm:  50%|█████     | 10/20 [00:04<00:04,  2.32it/s, best_error=1.580e-06]
# Grid search for model.layers.0.input_layernorm:  50%|█████     | 10/20 [00:04<00:04,  2.32it/s, best_error=1.311e-06]
# Grid search for model.layers.0.input_layernorm:  55%|█████▌    | 11/20 [00:04<00:03,  2.33it/s, best_error=1.311e-06]
# Grid search for model.layers.0.input_layernorm:  55%|█████▌    | 11/20 [00:05<00:03,  2.33it/s, best_error=1.252e-06]
# Grid search for model.layers.0.input_layernorm:  60%|██████    | 12/20 [00:05<00:03,  2.33it/s, best_error=1.252e-06]
# Grid search for model.layers.0.input_layernorm:  60%|██████    | 12/20 [00:05<00:03,  2.33it/s, best_error=1.200e-06]
# Grid search for model.layers.0.input_layernorm:  65%|██████▌   | 13/20 [00:05<00:03,  2.33it/s, best_error=1.200e-06]
# Grid search for model.layers.0.input_layernorm:  65%|██████▌   | 13/20 [00:06<00:03,  2.33it/s, best_error=1.200e-06]
# Grid search for model.layers.0.input_layernorm:  70%|███████   | 14/20 [00:06<00:02,  2.33it/s, best_error=1.200e-06]
# Grid search for model.layers.0.input_layernorm:  70%|███████   | 14/20 [00:06<00:02,  2.33it/s, best_error=1.200e-06]
# Grid search for model.layers.0.input_layernorm:  75%|███████▌  | 15/20 [00:06<00:02,  2.34it/s, best_error=1.200e-06]
# Grid search for model.layers.0.input_layernorm:  75%|███████▌  | 15/20 [00:06<00:02,  2.34it/s, best_error=1.200e-06]
# Grid search for model.layers.0.input_layernorm:  80%|████████  | 16/20 [00:06<00:01,  2.33it/s, best_error=1.200e-06]
# Grid search for model.layers.0.input_layernorm:  80%|████████  | 16/20 [00:07<00:01,  2.33it/s, best_error=1.200e-06]
# Grid search for model.layers.0.input_layernorm:  85%|████████▌ | 17/20 [00:07<00:01,  2.34it/s, best_error=1.200e-06]
# Grid search for model.layers.0.input_layernorm:  85%|████████▌ | 17/20 [00:07<00:01,  2.34it/s, best_error=1.200e-06]
# Grid search for model.layers.0.input_layernorm:  90%|█████████ | 18/20 [00:07<00:00,  2.34it/s, best_error=1.200e-06]
# Grid search for model.layers.0.input_layernorm:  90%|█████████ | 18/20 [00:08<00:00,  2.34it/s, best_error=1.200e-06]
# Grid search for model.layers.0.input_layernorm:  95%|█████████▌| 19/20 [00:08<00:00,  2.34it/s, best_error=1.200e-06]
# Grid search for model.layers.0.input_layernorm:  95%|█████████▌| 19/20 [00:08<00:00,  2.34it/s, best_error=1.200e-06]
# Grid search for model.layers.0.input_layernorm: 100%|██████████| 20/20 [00:08<00:00,  2.34it/s, best_error=1.200e-06]
# Smoothing:  33%|███▎      | 1/3 [00:09<00:18,  9.17s/it]
# Grid search for model.layers.0.post_attention_layernorm:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.0.post_attention_layernorm:   0%|          | 0/20 [00:00<?, ?it/s, best_error=3.353e-06]
# Grid search for model.layers.0.post_attention_layernorm:   5%|▌         | 1/20 [00:00<00:17,  1.11it/s, best_error=3.353e-06]
# Grid search for model.layers.0.post_attention_layernorm:   5%|▌         | 1/20 [00:01<00:17,  1.11it/s, best_error=3.278e-06]
# Grid search for model.layers.0.post_attention_layernorm:  10%|█         | 2/20 [00:01<00:16,  1.11it/s, best_error=3.278e-06]
# Grid search for model.layers.0.post_attention_layernorm:  10%|█         | 2/20 [00:02<00:16,  1.11it/s, best_error=3.159e-06]
# Grid search for model.layers.0.post_attention_layernorm:  15%|█▌        | 3/20 [00:02<00:15,  1.11it/s, best_error=3.159e-06]
# Grid search for model.layers.0.post_attention_layernorm:  15%|█▌        | 3/20 [00:03<00:15,  1.11it/s, best_error=3.159e-06]
# Grid search for model.layers.0.post_attention_layernorm:  20%|██        | 4/20 [00:03<00:14,  1.11it/s, best_error=3.159e-06]
# Grid search for model.layers.0.post_attention_layernorm:  20%|██        | 4/20 [00:04<00:14,  1.11it/s, best_error=3.159e-06]
# Grid search for model.layers.0.post_attention_layernorm:  25%|██▌       | 5/20 [00:04<00:13,  1.11it/s, best_error=3.159e-06]
# Grid search for model.layers.0.post_attention_layernorm:  25%|██▌       | 5/20 [00:05<00:13,  1.11it/s, best_error=3.159e-06]
# Grid search for model.layers.0.post_attention_layernorm:  30%|███       | 6/20 [00:05<00:12,  1.11it/s, best_error=3.159e-06]
# Grid search for model.layers.0.post_attention_layernorm:  30%|███       | 6/20 [00:06<00:12,  1.11it/s, best_error=3.159e-06]
# Grid search for model.layers.0.post_attention_layernorm:  35%|███▌      | 7/20 [00:06<00:11,  1.11it/s, best_error=3.159e-06]
# Grid search for model.layers.0.post_attention_layernorm:  35%|███▌      | 7/20 [00:07<00:11,  1.11it/s, best_error=3.159e-06]
# Grid search for model.layers.0.post_attention_layernorm:  40%|████      | 8/20 [00:07<00:10,  1.11it/s, best_error=3.159e-06]
# Grid search for model.layers.0.post_attention_layernorm:  40%|████      | 8/20 [00:08<00:10,  1.11it/s, best_error=3.159e-06]
# Grid search for model.layers.0.post_attention_layernorm:  45%|████▌     | 9/20 [00:08<00:09,  1.11it/s, best_error=3.159e-06]
# Grid search for model.layers.0.post_attention_layernorm:  45%|████▌     | 9/20 [00:09<00:09,  1.11it/s, best_error=3.159e-06]
# Grid search for model.layers.0.post_attention_layernorm:  50%|█████     | 10/20 [00:09<00:09,  1.11it/s, best_error=3.159e-06]
# Grid search for model.layers.0.post_attention_layernorm:  50%|█████     | 10/20 [00:09<00:09,  1.11it/s, best_error=3.159e-06]
# Grid search for model.layers.0.post_attention_layernorm:  55%|█████▌    | 11/20 [00:09<00:08,  1.11it/s, best_error=3.159e-06]
# Grid search for model.layers.0.post_attention_layernorm:  55%|█████▌    | 11/20 [00:10<00:08,  1.11it/s, best_error=3.159e-06]
# Grid search for model.layers.0.post_attention_layernorm:  60%|██████    | 12/20 [00:10<00:07,  1.11it/s, best_error=3.159e-06]
# Grid search for model.layers.0.post_attention_layernorm:  60%|██████    | 12/20 [00:11<00:07,  1.11it/s, best_error=3.159e-06]
# Grid search for model.layers.0.post_attention_layernorm:  65%|██████▌   | 13/20 [00:11<00:06,  1.11it/s, best_error=3.159e-06]
# Grid search for model.layers.0.post_attention_layernorm:  65%|██████▌   | 13/20 [00:12<00:06,  1.11it/s, best_error=3.159e-06]
# Grid search for model.layers.0.post_attention_layernorm:  70%|███████   | 14/20 [00:12<00:05,  1.11it/s, best_error=3.159e-06]
# Grid search for model.layers.0.post_attention_layernorm:  70%|███████   | 14/20 [00:13<00:05,  1.11it/s, best_error=3.159e-06]
# Grid search for model.layers.0.post_attention_layernorm:  75%|███████▌  | 15/20 [00:13<00:04,  1.11it/s, best_error=3.159e-06]
# Grid search for model.layers.0.post_attention_layernorm:  75%|███████▌  | 15/20 [00:14<00:04,  1.11it/s, best_error=3.159e-06]
# Grid search for model.layers.0.post_attention_layernorm:  80%|████████  | 16/20 [00:14<00:03,  1.11it/s, best_error=3.159e-06]
# Grid search for model.layers.0.post_attention_layernorm:  80%|████████  | 16/20 [00:15<00:03,  1.11it/s, best_error=3.159e-06]
# Grid search for model.layers.0.post_attention_layernorm:  85%|████████▌ | 17/20 [00:15<00:02,  1.11it/s, best_error=3.159e-06]
# Grid search for model.layers.0.post_attention_layernorm:  85%|████████▌ | 17/20 [00:16<00:02,  1.11it/s, best_error=3.159e-06]
# Grid search for model.layers.0.post_attention_layernorm:  90%|█████████ | 18/20 [00:16<00:01,  1.11it/s, best_error=3.159e-06]
# Grid search for model.layers.0.post_attention_layernorm:  90%|█████████ | 18/20 [00:17<00:01,  1.11it/s, best_error=3.159e-06]
# Grid search for model.layers.0.post_attention_layernorm:  95%|█████████▌| 19/20 [00:17<00:00,  1.11it/s, best_error=3.159e-06]
# Grid search for model.layers.0.post_attention_layernorm:  95%|█████████▌| 19/20 [00:18<00:00,  1.11it/s, best_error=3.159e-06]
# Grid search for model.layers.0.post_attention_layernorm: 100%|██████████| 20/20 [00:18<00:00,  1.11it/s, best_error=3.159e-06]
# Smoothing:  67%|██████▋   | 2/3 [00:28<00:14, 14.94s/it]
# Grid search for model.layers.0.mlp.up_proj:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.0.mlp.up_proj:   0%|          | 0/20 [00:00<?, ?it/s, best_error=7.153e-06]
# Grid search for model.layers.0.mlp.up_proj:   5%|▌         | 1/20 [00:00<00:06,  3.16it/s, best_error=7.153e-06]
# Grid search for model.layers.0.mlp.up_proj:   5%|▌         | 1/20 [00:00<00:06,  3.16it/s, best_error=7.153e-06]
# Grid search for model.layers.0.mlp.up_proj:  10%|█         | 2/20 [00:00<00:05,  3.14it/s, best_error=7.153e-06]
# Grid search for model.layers.0.mlp.up_proj:  10%|█         | 2/20 [00:00<00:05,  3.14it/s, best_error=7.123e-06]
# Grid search for model.layers.0.mlp.up_proj:  15%|█▌        | 3/20 [00:00<00:05,  3.13it/s, best_error=7.123e-06]
# Grid search for model.layers.0.mlp.up_proj:  15%|█▌        | 3/20 [00:01<00:05,  3.13it/s, best_error=7.123e-06]
# Grid search for model.layers.0.mlp.up_proj:  20%|██        | 4/20 [00:01<00:05,  3.13it/s, best_error=7.123e-06]
# Grid search for model.layers.0.mlp.up_proj:  20%|██        | 4/20 [00:01<00:05,  3.13it/s, best_error=7.123e-06]
# Grid search for model.layers.0.mlp.up_proj:  25%|██▌       | 5/20 [00:01<00:04,  3.13it/s, best_error=7.123e-06]
# Grid search for model.layers.0.mlp.up_proj:  25%|██▌       | 5/20 [00:01<00:04,  3.13it/s, best_error=7.123e-06]
# Grid search for model.layers.0.mlp.up_proj:  30%|███       | 6/20 [00:01<00:04,  3.14it/s, best_error=7.123e-06]
# Grid search for model.layers.0.mlp.up_proj:  30%|███       | 6/20 [00:02<00:04,  3.14it/s, best_error=7.063e-06]
# Grid search for model.layers.0.mlp.up_proj:  35%|███▌      | 7/20 [00:02<00:04,  3.13it/s, best_error=7.063e-06]
# Grid search for model.layers.0.mlp.up_proj:  35%|███▌      | 7/20 [00:02<00:04,  3.13it/s, best_error=7.063e-06]
# Grid search for model.layers.0.mlp.up_proj:  40%|████      | 8/20 [00:02<00:03,  3.13it/s, best_error=7.063e-06]
# Grid search for model.layers.0.mlp.up_proj:  40%|████      | 8/20 [00:02<00:03,  3.13it/s, best_error=7.063e-06]
# Grid search for model.layers.0.mlp.up_proj:  45%|████▌     | 9/20 [00:02<00:03,  3.13it/s, best_error=7.063e-06]
# Grid search for model.layers.0.mlp.up_proj:  45%|████▌     | 9/20 [00:03<00:03,  3.13it/s, best_error=7.063e-06]
# Grid search for model.layers.0.mlp.up_proj:  50%|█████     | 10/20 [00:03<00:03,  3.13it/s, best_error=7.063e-06]
# Grid search for model.layers.0.mlp.up_proj:  50%|█████     | 10/20 [00:03<00:03,  3.13it/s, best_error=7.063e-06]
# Grid search for model.layers.0.mlp.up_proj:  55%|█████▌    | 11/20 [00:03<00:02,  3.13it/s, best_error=7.063e-06]
# Grid search for model.layers.0.mlp.up_proj:  55%|█████▌    | 11/20 [00:03<00:02,  3.13it/s, best_error=7.063e-06]
# Grid search for model.layers.0.mlp.up_proj:  60%|██████    | 12/20 [00:03<00:02,  3.13it/s, best_error=7.063e-06]
# Grid search for model.layers.0.mlp.up_proj:  60%|██████    | 12/20 [00:04<00:02,  3.13it/s, best_error=7.063e-06]
# Grid search for model.layers.0.mlp.up_proj:  65%|██████▌   | 13/20 [00:04<00:02,  3.13it/s, best_error=7.063e-06]
# Grid search for model.layers.0.mlp.up_proj:  65%|██████▌   | 13/20 [00:04<00:02,  3.13it/s, best_error=7.063e-06]
# Grid search for model.layers.0.mlp.up_proj:  70%|███████   | 14/20 [00:04<00:01,  3.13it/s, best_error=7.063e-06]
# Grid search for model.layers.0.mlp.up_proj:  70%|███████   | 14/20 [00:04<00:01,  3.13it/s, best_error=7.063e-06]
# Grid search for model.layers.0.mlp.up_proj:  75%|███████▌  | 15/20 [00:04<00:01,  3.13it/s, best_error=7.063e-06]
# Grid search for model.layers.0.mlp.up_proj:  75%|███████▌  | 15/20 [00:05<00:01,  3.13it/s, best_error=7.063e-06]
# Grid search for model.layers.0.mlp.up_proj:  80%|████████  | 16/20 [00:05<00:01,  3.13it/s, best_error=7.063e-06]
# Grid search for model.layers.0.mlp.up_proj:  80%|████████  | 16/20 [00:05<00:01,  3.13it/s, best_error=7.063e-06]
# Grid search for model.layers.0.mlp.up_proj:  85%|████████▌ | 17/20 [00:05<00:00,  3.14it/s, best_error=7.063e-06]
# Grid search for model.layers.0.mlp.up_proj:  85%|████████▌ | 17/20 [00:05<00:00,  3.14it/s, best_error=7.063e-06]
# Grid search for model.layers.0.mlp.up_proj:  90%|█████████ | 18/20 [00:05<00:00,  3.13it/s, best_error=7.063e-06]
# Grid search for model.layers.0.mlp.up_proj:  90%|█████████ | 18/20 [00:06<00:00,  3.13it/s, best_error=7.063e-06]
# Grid search for model.layers.0.mlp.up_proj:  95%|█████████▌| 19/20 [00:06<00:00,  3.14it/s, best_error=7.063e-06]
# Grid search for model.layers.0.mlp.up_proj:  95%|█████████▌| 19/20 [00:06<00:00,  3.14it/s, best_error=7.063e-06]
# Grid search for model.layers.0.mlp.up_proj: 100%|██████████| 20/20 [00:06<00:00,  3.13it/s, best_error=7.063e-06]
# Smoothing: 100%|██████████| 3/3 [00:34<00:00, 11.62s/it]
# (1/29): Propagating: 100%|██████████| 64/64 [00:01<00:00, 38.64it/s]
# (2/29): Calibrating: 100%|██████████| 64/64 [00:01<00:00, 43.04it/s]
# Smoothing:   0%|          | 0/3 [00:00<?, ?it/s]
# Grid search for model.layers.1.input_layernorm:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.1.input_layernorm:   0%|          | 0/20 [00:00<?, ?it/s, best_error=6.586e-06]
# Grid search for model.layers.1.input_layernorm:   5%|▌         | 1/20 [00:00<00:08,  2.35it/s, best_error=6.586e-06]
# Grid search for model.layers.1.input_layernorm:   5%|▌         | 1/20 [00:00<00:08,  2.35it/s, best_error=5.156e-06]
# Grid search for model.layers.1.input_layernorm:  10%|█         | 2/20 [00:00<00:07,  2.34it/s, best_error=5.156e-06]
# Grid search for model.layers.1.input_layernorm:  10%|█         | 2/20 [00:01<00:07,  2.34it/s, best_error=4.411e-06]
# Grid search for model.layers.1.input_layernorm:  15%|█▌        | 3/20 [00:01<00:07,  2.34it/s, best_error=4.411e-06]
# Grid search for model.layers.1.input_layernorm:  15%|█▌        | 3/20 [00:01<00:07,  2.34it/s, best_error=3.502e-06]
# Grid search for model.layers.1.input_layernorm:  20%|██        | 4/20 [00:01<00:06,  2.34it/s, best_error=3.502e-06]
# Grid search for model.layers.1.input_layernorm:  20%|██        | 4/20 [00:02<00:06,  2.34it/s, best_error=2.965e-06]
# Grid search for model.layers.1.input_layernorm:  25%|██▌       | 5/20 [00:02<00:06,  2.33it/s, best_error=2.965e-06]
# Grid search for model.layers.1.input_layernorm:  25%|██▌       | 5/20 [00:02<00:06,  2.33it/s, best_error=2.623e-06]
# Grid search for model.layers.1.input_layernorm:  30%|███       | 6/20 [00:02<00:05,  2.33it/s, best_error=2.623e-06]
# Grid search for model.layers.1.input_layernorm:  30%|███       | 6/20 [00:02<00:05,  2.33it/s, best_error=2.623e-06]
# Grid search for model.layers.1.input_layernorm:  35%|███▌      | 7/20 [00:02<00:05,  2.33it/s, best_error=2.623e-06]
# Grid search for model.layers.1.input_layernorm:  35%|███▌      | 7/20 [00:03<00:05,  2.33it/s, best_error=2.369e-06]
# Grid search for model.layers.1.input_layernorm:  40%|████      | 8/20 [00:03<00:05,  2.33it/s, best_error=2.369e-06]
# Grid search for model.layers.1.input_layernorm:  40%|████      | 8/20 [00:03<00:05,  2.33it/s, best_error=2.161e-06]
# Grid search for model.layers.1.input_layernorm:  45%|████▌     | 9/20 [00:03<00:04,  2.34it/s, best_error=2.161e-06]
# Grid search for model.layers.1.input_layernorm:  45%|████▌     | 9/20 [00:04<00:04,  2.34it/s, best_error=2.161e-06]
# Grid search for model.layers.1.input_layernorm:  50%|█████     | 10/20 [00:04<00:04,  2.33it/s, best_error=2.161e-06]
# Grid search for model.layers.1.input_layernorm:  50%|█████     | 10/20 [00:04<00:04,  2.33it/s, best_error=2.161e-06]
# Grid search for model.layers.1.input_layernorm:  55%|█████▌    | 11/20 [00:04<00:03,  2.33it/s, best_error=2.161e-06]
# Grid search for model.layers.1.input_layernorm:  55%|█████▌    | 11/20 [00:05<00:03,  2.33it/s, best_error=2.161e-06]
# Grid search for model.layers.1.input_layernorm:  60%|██████    | 12/20 [00:05<00:03,  2.34it/s, best_error=2.161e-06]
# Grid search for model.layers.1.input_layernorm:  60%|██████    | 12/20 [00:05<00:03,  2.34it/s, best_error=2.161e-06]
# Grid search for model.layers.1.input_layernorm:  65%|██████▌   | 13/20 [00:05<00:02,  2.34it/s, best_error=2.161e-06]
# Grid search for model.layers.1.input_layernorm:  65%|██████▌   | 13/20 [00:05<00:02,  2.34it/s, best_error=2.161e-06]
# Grid search for model.layers.1.input_layernorm:  70%|███████   | 14/20 [00:05<00:02,  2.34it/s, best_error=2.161e-06]
# Grid search for model.layers.1.input_layernorm:  70%|███████   | 14/20 [00:06<00:02,  2.34it/s, best_error=2.161e-06]
# Grid search for model.layers.1.input_layernorm:  75%|███████▌  | 15/20 [00:06<00:02,  2.34it/s, best_error=2.161e-06]
# Grid search for model.layers.1.input_layernorm:  75%|███████▌  | 15/20 [00:06<00:02,  2.34it/s, best_error=2.161e-06]
# Grid search for model.layers.1.input_layernorm:  80%|████████  | 16/20 [00:06<00:01,  2.34it/s, best_error=2.161e-06]
# Grid search for model.layers.1.input_layernorm:  80%|████████  | 16/20 [00:07<00:01,  2.34it/s, best_error=2.161e-06]
# Grid search for model.layers.1.input_layernorm:  85%|████████▌ | 17/20 [00:07<00:01,  2.34it/s, best_error=2.161e-06]
# Grid search for model.layers.1.input_layernorm:  85%|████████▌ | 17/20 [00:07<00:01,  2.34it/s, best_error=2.161e-06]
# Grid search for model.layers.1.input_layernorm:  90%|█████████ | 18/20 [00:07<00:00,  2.34it/s, best_error=2.161e-06]
# Grid search for model.layers.1.input_layernorm:  90%|█████████ | 18/20 [00:08<00:00,  2.34it/s, best_error=2.161e-06]
# Grid search for model.layers.1.input_layernorm:  95%|█████████▌| 19/20 [00:08<00:00,  2.34it/s, best_error=2.161e-06]
# Grid search for model.layers.1.input_layernorm:  95%|█████████▌| 19/20 [00:08<00:00,  2.34it/s, best_error=2.161e-06]
# Grid search for model.layers.1.input_layernorm: 100%|██████████| 20/20 [00:08<00:00,  2.34it/s, best_error=2.161e-06]
# Smoothing:  33%|███▎      | 1/3 [00:08<00:17,  8.99s/it]
# Grid search for model.layers.1.post_attention_layernorm:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.1.post_attention_layernorm:   0%|          | 0/20 [00:00<?, ?it/s, best_error=1.060e-03]
# Grid search for model.layers.1.post_attention_layernorm:   5%|▌         | 1/20 [00:00<00:17,  1.11it/s, best_error=1.060e-03]
# Grid search for model.layers.1.post_attention_layernorm:   5%|▌         | 1/20 [00:01<00:17,  1.11it/s, best_error=1.060e-03]
# Grid search for model.layers.1.post_attention_layernorm:  10%|█         | 2/20 [00:01<00:16,  1.11it/s, best_error=1.060e-03]
# Grid search for model.layers.1.post_attention_layernorm:  10%|█         | 2/20 [00:02<00:16,  1.11it/s, best_error=1.640e-04]
# Grid search for model.layers.1.post_attention_layernorm:  15%|█▌        | 3/20 [00:02<00:15,  1.11it/s, best_error=1.640e-04]
# Grid search for model.layers.1.post_attention_layernorm:  15%|█▌        | 3/20 [00:03<00:15,  1.11it/s, best_error=1.640e-04]
# Grid search for model.layers.1.post_attention_layernorm:  20%|██        | 4/20 [00:03<00:14,  1.11it/s, best_error=1.640e-04]
# Grid search for model.layers.1.post_attention_layernorm:  20%|██        | 4/20 [00:04<00:14,  1.11it/s, best_error=1.640e-04]
# Grid search for model.layers.1.post_attention_layernorm:  25%|██▌       | 5/20 [00:04<00:13,  1.11it/s, best_error=1.640e-04]
# Grid search for model.layers.1.post_attention_layernorm:  25%|██▌       | 5/20 [00:05<00:13,  1.11it/s, best_error=1.640e-04]
# Grid search for model.layers.1.post_attention_layernorm:  30%|███       | 6/20 [00:05<00:12,  1.11it/s, best_error=1.640e-04]
# Grid search for model.layers.1.post_attention_layernorm:  30%|███       | 6/20 [00:06<00:12,  1.11it/s, best_error=1.640e-04]
# Grid search for model.layers.1.post_attention_layernorm:  35%|███▌      | 7/20 [00:06<00:11,  1.11it/s, best_error=1.640e-04]
# Grid search for model.layers.1.post_attention_layernorm:  35%|███▌      | 7/20 [00:07<00:11,  1.11it/s, best_error=1.640e-04]
# Grid search for model.layers.1.post_attention_layernorm:  40%|████      | 8/20 [00:07<00:10,  1.11it/s, best_error=1.640e-04]
# Grid search for model.layers.1.post_attention_layernorm:  40%|████      | 8/20 [00:08<00:10,  1.11it/s, best_error=1.640e-04]
# Grid search for model.layers.1.post_attention_layernorm:  45%|████▌     | 9/20 [00:08<00:09,  1.11it/s, best_error=1.640e-04]
# Grid search for model.layers.1.post_attention_layernorm:  45%|████▌     | 9/20 [00:09<00:09,  1.11it/s, best_error=1.640e-04]
# Grid search for model.layers.1.post_attention_layernorm:  50%|█████     | 10/20 [00:09<00:09,  1.11it/s, best_error=1.640e-04]
# Grid search for model.layers.1.post_attention_layernorm:  50%|█████     | 10/20 [00:09<00:09,  1.11it/s, best_error=1.640e-04]
# Grid search for model.layers.1.post_attention_layernorm:  55%|█████▌    | 11/20 [00:09<00:08,  1.11it/s, best_error=1.640e-04]
# Grid search for model.layers.1.post_attention_layernorm:  55%|█████▌    | 11/20 [00:10<00:08,  1.11it/s, best_error=1.640e-04]
# Grid search for model.layers.1.post_attention_layernorm:  60%|██████    | 12/20 [00:10<00:07,  1.11it/s, best_error=1.640e-04]
# Grid search for model.layers.1.post_attention_layernorm:  60%|██████    | 12/20 [00:11<00:07,  1.11it/s, best_error=1.640e-04]
# Grid search for model.layers.1.post_attention_layernorm:  65%|██████▌   | 13/20 [00:11<00:06,  1.11it/s, best_error=1.640e-04]
# Grid search for model.layers.1.post_attention_layernorm:  65%|██████▌   | 13/20 [00:12<00:06,  1.11it/s, best_error=1.640e-04]
# Grid search for model.layers.1.post_attention_layernorm:  70%|███████   | 14/20 [00:12<00:05,  1.11it/s, best_error=1.640e-04]
# Grid search for model.layers.1.post_attention_layernorm:  70%|███████   | 14/20 [00:13<00:05,  1.11it/s, best_error=1.640e-04]
# Grid search for model.layers.1.post_attention_layernorm:  75%|███████▌  | 15/20 [00:13<00:04,  1.11it/s, best_error=1.640e-04]
# Grid search for model.layers.1.post_attention_layernorm:  75%|███████▌  | 15/20 [00:14<00:04,  1.11it/s, best_error=1.640e-04]
# Grid search for model.layers.1.post_attention_layernorm:  80%|████████  | 16/20 [00:14<00:03,  1.11it/s, best_error=1.640e-04]
# Grid search for model.layers.1.post_attention_layernorm:  80%|████████  | 16/20 [00:15<00:03,  1.11it/s, best_error=1.640e-04]
# Grid search for model.layers.1.post_attention_layernorm:  85%|████████▌ | 17/20 [00:15<00:02,  1.11it/s, best_error=1.640e-04]
# Grid search for model.layers.1.post_attention_layernorm:  85%|████████▌ | 17/20 [00:16<00:02,  1.11it/s, best_error=1.640e-04]
# Grid search for model.layers.1.post_attention_layernorm:  90%|█████████ | 18/20 [00:16<00:01,  1.11it/s, best_error=1.640e-04]
# Grid search for model.layers.1.post_attention_layernorm:  90%|█████████ | 18/20 [00:17<00:01,  1.11it/s, best_error=1.640e-04]
# Grid search for model.layers.1.post_attention_layernorm:  95%|█████████▌| 19/20 [00:17<00:00,  1.11it/s, best_error=1.640e-04]
# Grid search for model.layers.1.post_attention_layernorm:  95%|█████████▌| 19/20 [00:18<00:00,  1.11it/s, best_error=1.640e-04]
# Grid search for model.layers.1.post_attention_layernorm: 100%|██████████| 20/20 [00:18<00:00,  1.11it/s, best_error=1.640e-04]
# Smoothing:  67%|██████▋   | 2/3 [00:27<00:14, 14.87s/it]
# Grid search for model.layers.1.mlp.up_proj:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.1.mlp.up_proj:   0%|          | 0/20 [00:00<?, ?it/s, best_error=3.418e-03]
# Grid search for model.layers.1.mlp.up_proj:   5%|▌         | 1/20 [00:00<00:06,  3.16it/s, best_error=3.418e-03]
# Grid search for model.layers.1.mlp.up_proj:   5%|▌         | 1/20 [00:00<00:06,  3.16it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  10%|█         | 2/20 [00:00<00:05,  3.14it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  10%|█         | 2/20 [00:00<00:05,  3.14it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  15%|█▌        | 3/20 [00:00<00:05,  3.14it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  15%|█▌        | 3/20 [00:01<00:05,  3.14it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  20%|██        | 4/20 [00:01<00:05,  3.14it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  20%|██        | 4/20 [00:01<00:05,  3.14it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  25%|██▌       | 5/20 [00:01<00:04,  3.14it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  25%|██▌       | 5/20 [00:01<00:04,  3.14it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  30%|███       | 6/20 [00:01<00:04,  3.14it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  30%|███       | 6/20 [00:02<00:04,  3.14it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  35%|███▌      | 7/20 [00:02<00:04,  3.14it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  35%|███▌      | 7/20 [00:02<00:04,  3.14it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  40%|████      | 8/20 [00:02<00:03,  3.14it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  40%|████      | 8/20 [00:02<00:03,  3.14it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  45%|████▌     | 9/20 [00:02<00:03,  3.14it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  45%|████▌     | 9/20 [00:03<00:03,  3.14it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  50%|█████     | 10/20 [00:03<00:03,  3.13it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  50%|█████     | 10/20 [00:03<00:03,  3.13it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  55%|█████▌    | 11/20 [00:03<00:02,  3.13it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  55%|█████▌    | 11/20 [00:03<00:02,  3.13it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  60%|██████    | 12/20 [00:03<00:02,  3.14it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  60%|██████    | 12/20 [00:04<00:02,  3.14it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  65%|██████▌   | 13/20 [00:04<00:02,  3.13it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  65%|██████▌   | 13/20 [00:04<00:02,  3.13it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  70%|███████   | 14/20 [00:04<00:01,  3.13it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  70%|███████   | 14/20 [00:04<00:01,  3.13it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  75%|███████▌  | 15/20 [00:04<00:01,  3.13it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  75%|███████▌  | 15/20 [00:05<00:01,  3.13it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  80%|████████  | 16/20 [00:05<00:01,  3.13it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  80%|████████  | 16/20 [00:05<00:01,  3.13it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  85%|████████▌ | 17/20 [00:05<00:00,  3.13it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  85%|████████▌ | 17/20 [00:05<00:00,  3.13it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  90%|█████████ | 18/20 [00:05<00:00,  3.13it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  90%|█████████ | 18/20 [00:06<00:00,  3.13it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  95%|█████████▌| 19/20 [00:06<00:00,  3.13it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  95%|█████████▌| 19/20 [00:06<00:00,  3.13it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj: 100%|██████████| 20/20 [00:06<00:00,  3.13it/s, best_error=2.747e-03]
# Smoothing: 100%|██████████| 3/3 [00:34<00:00, 11.56s/it]
# (2/29): Propagating: 100%|██████████| 64/64 [00:01<00:00, 42.52it/s]
# (3/29): Calibrating: 100%|██████████| 64/64 [00:01<00:00, 42.97it/s]
# Smoothing:   0%|          | 0/3 [00:00<?, ?it/s]
# Grid search for model.layers.2.input_layernorm:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.2.input_layernorm:   0%|          | 0/20 [00:00<?, ?it/s, best_error=4.977e-06]
# Grid search for model.layers.2.input_layernorm:   5%|▌         | 1/20 [00:00<00:08,  2.34it/s, best_error=4.977e-06]
# Grid search for model.layers.2.input_layernorm:   5%|▌         | 1/20 [00:00<00:08,  2.34it/s, best_error=4.619e-06]
# Grid search for model.layers.2.input_layernorm:  10%|█         | 2/20 [00:00<00:07,  2.35it/s, best_error=4.619e-06]
# Grid search for model.layers.2.input_layernorm:  10%|█         | 2/20 [00:01<00:07,  2.35it/s, best_error=4.619e-06]
# Grid search for model.layers.2.input_layernorm:  15%|█▌        | 3/20 [00:01<00:07,  2.34it/s, best_error=4.619e-06]
# Grid search for model.layers.2.input_layernorm:  15%|█▌        | 3/20 [00:01<00:07,  2.34it/s, best_error=4.381e-06]
# Grid search for model.layers.2.input_layernorm:  20%|██        | 4/20 [00:01<00:06,  2.34it/s, best_error=4.381e-06]
# Grid search for model.layers.2.input_layernorm:  20%|██        | 4/20 [00:02<00:06,  2.34it/s, best_error=4.232e-06]
# Grid search for model.layers.2.input_layernorm:  25%|██▌       | 5/20 [00:02<00:06,  2.34it/s, best_error=4.232e-06]
# Grid search for model.layers.2.input_layernorm:  25%|██▌       | 5/20 [00:02<00:06,  2.34it/s, best_error=4.232e-06]
# Grid search for model.layers.2.input_layernorm:  30%|███       | 6/20 [00:02<00:05,  2.34it/s, best_error=4.232e-06]
# Grid search for model.layers.2.input_layernorm:  30%|███       | 6/20 [00:02<00:05,  2.34it/s, best_error=4.143e-06]
# Grid search for model.layers.2.input_layernorm:  35%|███▌      | 7/20 [00:02<00:05,  2.34it/s, best_error=4.143e-06]
# Grid search for model.layers.2.input_layernorm:  35%|███▌      | 7/20 [00:03<00:05,  2.34it/s, best_error=4.143e-06]
# Grid search for model.layers.2.input_layernorm:  40%|████      | 8/20 [00:03<00:05,  2.34it/s, best_error=4.143e-06]
# Grid search for model.layers.2.input_layernorm:  40%|████      | 8/20 [00:03<00:05,  2.34it/s, best_error=4.143e-06]
# Grid search for model.layers.2.input_layernorm:  45%|████▌     | 9/20 [00:03<00:04,  2.34it/s, best_error=4.143e-06]
# Grid search for model.layers.2.input_layernorm:  45%|████▌     | 9/20 [00:04<00:04,  2.34it/s, best_error=4.143e-06]
# Grid search for model.layers.2.input_layernorm:  50%|█████     | 10/20 [00:04<00:04,  2.34it/s, best_error=4.143e-06]
# Grid search for model.layers.2.input_layernorm:  50%|█████     | 10/20 [00:04<00:04,  2.34it/s, best_error=4.143e-06]
# Grid search for model.layers.2.input_layernorm:  55%|█████▌    | 11/20 [00:04<00:03,  2.34it/s, best_error=4.143e-06]
# Grid search for model.layers.2.input_layernorm:  55%|█████▌    | 11/20 [00:05<00:03,  2.34it/s, best_error=4.143e-06]
# Grid search for model.layers.2.input_layernorm:  60%|██████    | 12/20 [00:05<00:03,  2.33it/s, best_error=4.143e-06]
# Grid search for model.layers.2.input_layernorm:  60%|██████    | 12/20 [00:05<00:03,  2.33it/s, best_error=4.143e-06]
# Grid search for model.layers.2.input_layernorm:  65%|██████▌   | 13/20 [00:05<00:02,  2.33it/s, best_error=4.143e-06]
# Grid search for model.layers.2.input_layernorm:  65%|██████▌   | 13/20 [00:05<00:02,  2.33it/s, best_error=4.143e-06]
# Grid search for model.layers.2.input_layernorm:  70%|███████   | 14/20 [00:05<00:02,  2.33it/s, best_error=4.143e-06]
# Grid search for model.layers.2.input_layernorm:  70%|███████   | 14/20 [00:06<00:02,  2.33it/s, best_error=4.143e-06]
# Grid search for model.layers.2.input_layernorm:  75%|███████▌  | 15/20 [00:06<00:02,  2.34it/s, best_error=4.143e-06]
# Grid search for model.layers.2.input_layernorm:  75%|███████▌  | 15/20 [00:06<00:02,  2.34it/s, best_error=4.143e-06]
# Grid search for model.layers.2.input_layernorm:  80%|████████  | 16/20 [00:06<00:01,  2.33it/s, best_error=4.143e-06]
# Grid search for model.layers.2.input_layernorm:  80%|████████  | 16/20 [00:07<00:01,  2.33it/s, best_error=4.143e-06]
# Grid search for model.layers.2.input_layernorm:  85%|████████▌ | 17/20 [00:07<00:01,  2.34it/s, best_error=4.143e-06]
# Grid search for model.layers.2.input_layernorm:  85%|████████▌ | 17/20 [00:07<00:01,  2.34it/s, best_error=4.143e-06]
# Grid search for model.layers.2.input_layernorm:  90%|█████████ | 18/20 [00:07<00:00,  2.34it/s, best_error=4.143e-06]
# Grid search for model.layers.2.input_layernorm:  90%|█████████ | 18/20 [00:08<00:00,  2.34it/s, best_error=4.143e-06]
# Grid search for model.layers.2.input_layernorm:  95%|█████████▌| 19/20 [00:08<00:00,  2.34it/s, best_error=4.143e-06]
# Grid search for model.layers.2.input_layernorm:  95%|█████████▌| 19/20 [00:08<00:00,  2.34it/s, best_error=4.143e-06]
# Grid search for model.layers.2.input_layernorm: 100%|██████████| 20/20 [00:08<00:00,  2.34it/s, best_error=4.143e-06]
# Smoothing:  33%|███▎      | 1/3 [00:08<00:17,  8.99s/it]
# Grid search for model.layers.2.post_attention_layernorm:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.2.post_attention_layernorm:   0%|          | 0/20 [00:00<?, ?it/s, best_error=1.049e-05]
# Grid search for model.layers.2.post_attention_layernorm:   5%|▌         | 1/20 [00:00<00:17,  1.11it/s, best_error=1.049e-05]
# Grid search for model.layers.2.post_attention_layernorm:   5%|▌         | 1/20 [00:01<00:17,  1.11it/s, best_error=1.049e-05]
# Grid search for model.layers.2.post_attention_layernorm:  10%|█         | 2/20 [00:01<00:16,  1.11it/s, best_error=1.049e-05]
# Grid search for model.layers.2.post_attention_layernorm:  10%|█         | 2/20 [00:02<00:16,  1.11it/s, best_error=1.043e-05]
# Grid search for model.layers.2.post_attention_layernorm:  15%|█▌        | 3/20 [00:02<00:15,  1.11it/s, best_error=1.043e-05]
# Grid search for model.layers.2.post_attention_layernorm:  15%|█▌        | 3/20 [00:03<00:15,  1.11it/s, best_error=1.043e-05]
# Grid search for model.layers.2.post_attention_layernorm:  20%|██        | 4/20 [00:03<00:14,  1.11it/s, best_error=1.043e-05]
# Grid search for model.layers.2.post_attention_layernorm:  20%|██        | 4/20 [00:04<00:14,  1.11it/s, best_error=1.043e-05]
# Grid search for model.layers.2.post_attention_layernorm:  25%|██▌       | 5/20 [00:04<00:13,  1.11it/s, best_error=1.043e-05]
# Grid search for model.layers.2.post_attention_layernorm:  25%|██▌       | 5/20 [00:05<00:13,  1.11it/s, best_error=1.031e-05]
# Grid search for model.layers.2.post_attention_layernorm:  30%|███       | 6/20 [00:05<00:12,  1.11it/s, best_error=1.031e-05]
# Grid search for model.layers.2.post_attention_layernorm:  30%|███       | 6/20 [00:06<00:12,  1.11it/s, best_error=1.031e-05]
# Grid search for model.layers.2.post_attention_layernorm:  35%|███▌      | 7/20 [00:06<00:11,  1.11it/s, best_error=1.031e-05]
# Grid search for model.layers.2.post_attention_layernorm:  35%|███▌      | 7/20 [00:07<00:11,  1.11it/s, best_error=1.031e-05]
# Grid search for model.layers.2.post_attention_layernorm:  40%|████      | 8/20 [00:07<00:10,  1.11it/s, best_error=1.031e-05]
# Grid search for model.layers.2.post_attention_layernorm:  40%|████      | 8/20 [00:08<00:10,  1.11it/s, best_error=1.031e-05]
# Grid search for model.layers.2.post_attention_layernorm:  45%|████▌     | 9/20 [00:08<00:09,  1.11it/s, best_error=1.031e-05]
# Grid search for model.layers.2.post_attention_layernorm:  45%|████▌     | 9/20 [00:09<00:09,  1.11it/s, best_error=1.031e-05]
# Grid search for model.layers.2.post_attention_layernorm:  50%|█████     | 10/20 [00:09<00:09,  1.11it/s, best_error=1.031e-05]
# Grid search for model.layers.2.post_attention_layernorm:  50%|█████     | 10/20 [00:09<00:09,  1.11it/s, best_error=1.031e-05]
# Grid search for model.layers.2.post_attention_layernorm:  55%|█████▌    | 11/20 [00:09<00:08,  1.11it/s, best_error=1.031e-05]
# Grid search for model.layers.2.post_attention_layernorm:  55%|█████▌    | 11/20 [00:10<00:08,  1.11it/s, best_error=1.031e-05]
# Grid search for model.layers.2.post_attention_layernorm:  60%|██████    | 12/20 [00:10<00:07,  1.11it/s, best_error=1.031e-05]
# Grid search for model.layers.2.post_attention_layernorm:  60%|██████    | 12/20 [00:11<00:07,  1.11it/s, best_error=1.031e-05]
# Grid search for model.layers.2.post_attention_layernorm:  65%|██████▌   | 13/20 [00:11<00:06,  1.11it/s, best_error=1.031e-05]
# Grid search for model.layers.2.post_attention_layernorm:  65%|██████▌   | 13/20 [00:12<00:06,  1.11it/s, best_error=1.031e-05]
# Grid search for model.layers.2.post_attention_layernorm:  70%|███████   | 14/20 [00:12<00:05,  1.11it/s, best_error=1.031e-05]
# Grid search for model.layers.2.post_attention_layernorm:  70%|███████   | 14/20 [00:13<00:05,  1.11it/s, best_error=1.031e-05]
# ...
# Grid search for model.layers.27.input_layernorm:  20%|██        | 4/20 [00:01<00:06,  2.34it/s, best_error=4.406e-04]
# Grid search for model.layers.27.input_layernorm:  20%|██        | 4/20 [00:02<00:06,  2.34it/s, best_error=4.368e-04]
# Grid search for model.layers.27.input_layernorm:  25%|██▌       | 5/20 [00:02<00:06,  2.34it/s, best_error=4.368e-04]
# Grid search for model.layers.27.input_layernorm:  25%|██▌       | 5/20 [00:02<00:06,  2.34it/s, best_error=4.368e-04]
# Grid search for model.layers.27.input_layernorm:  30%|███       | 6/20 [00:02<00:05,  2.34it/s, best_error=4.368e-04]
# Grid search for model.layers.27.input_layernorm:  30%|███       | 6/20 [00:02<00:05,  2.34it/s, best_error=4.368e-04]
# Grid search for model.layers.27.input_layernorm:  35%|███▌      | 7/20 [00:02<00:05,  2.34it/s, best_error=4.368e-04]
# Grid search for model.layers.27.input_layernorm:  35%|███▌      | 7/20 [00:03<00:05,  2.34it/s, best_error=4.368e-04]
# Grid search for model.layers.27.input_layernorm:  40%|████      | 8/20 [00:03<00:05,  2.34it/s, best_error=4.368e-04]
# Grid search for model.layers.27.input_layernorm:  40%|████      | 8/20 [00:03<00:05,  2.34it/s, best_error=4.368e-04]
# Grid search for model.layers.27.input_layernorm:  45%|████▌     | 9/20 [00:03<00:04,  2.34it/s, best_error=4.368e-04]
# Grid search for model.layers.27.input_layernorm:  45%|████▌     | 9/20 [00:04<00:04,  2.34it/s, best_error=4.368e-04]
# Grid search for model.layers.27.input_layernorm:  50%|█████     | 10/20 [00:04<00:04,  2.34it/s, best_error=4.368e-04]
# Grid search for model.layers.27.input_layernorm:  50%|█████     | 10/20 [00:04<00:04,  2.34it/s, best_error=4.368e-04]
# Grid search for model.layers.27.input_layernorm:  55%|█████▌    | 11/20 [00:04<00:03,  2.34it/s, best_error=4.368e-04]
# Grid search for model.layers.27.input_layernorm:  55%|█████▌    | 11/20 [00:05<00:03,  2.34it/s, best_error=4.368e-04]
# Grid search for model.layers.27.input_layernorm:  60%|██████    | 12/20 [00:05<00:03,  2.34it/s, best_error=4.368e-04]
# Grid search for model.layers.27.input_layernorm:  60%|██████    | 12/20 [00:05<00:03,  2.34it/s, best_error=4.368e-04]
# Grid search for model.layers.27.input_layernorm:  65%|██████▌   | 13/20 [00:05<00:02,  2.34it/s, best_error=4.368e-04]
# Grid search for model.layers.27.input_layernorm:  65%|██████▌   | 13/20 [00:05<00:02,  2.34it/s, best_error=4.368e-04]
# Grid search for model.layers.27.input_layernorm:  70%|███████   | 14/20 [00:05<00:02,  2.34it/s, best_error=4.368e-04]
# Grid search for model.layers.27.input_layernorm:  70%|███████   | 14/20 [00:06<00:02,  2.34it/s, best_error=4.368e-04]
# Grid search for model.layers.27.input_layernorm:  75%|███████▌  | 15/20 [00:06<00:02,  2.34it/s, best_error=4.368e-04]
# Grid search for model.layers.27.input_layernorm:  75%|███████▌  | 15/20 [00:06<00:02,  2.34it/s, best_error=4.368e-04]
# Grid search for model.layers.27.input_layernorm:  80%|████████  | 16/20 [00:06<00:01,  2.34it/s, best_error=4.368e-04]
# Grid search for model.layers.27.input_layernorm:  80%|████████  | 16/20 [00:07<00:01,  2.34it/s, best_error=4.368e-04]
# Grid search for model.layers.27.input_layernorm:  85%|████████▌ | 17/20 [00:07<00:01,  2.34it/s, best_error=4.368e-04]
# Grid search for model.layers.27.input_layernorm:  85%|████████▌ | 17/20 [00:07<00:01,  2.34it/s, best_error=4.368e-04]
# Grid search for model.layers.27.input_layernorm:  90%|█████████ | 18/20 [00:07<00:00,  2.34it/s, best_error=4.368e-04]
# Grid search for model.layers.27.input_layernorm:  90%|█████████ | 18/20 [00:08<00:00,  2.34it/s, best_error=4.368e-04]
# Grid search for model.layers.27.input_layernorm:  95%|█████████▌| 19/20 [00:08<00:00,  2.34it/s, best_error=4.368e-04]
# Grid search for model.layers.27.input_layernorm:  95%|█████████▌| 19/20 [00:08<00:00,  2.34it/s, best_error=4.368e-04]
# Grid search for model.layers.27.input_layernorm: 100%|██████████| 20/20 [00:08<00:00,  2.34it/s, best_error=4.368e-04]
# Smoothing:  33%|███▎      | 1/3 [00:08<00:17,  8.98s/it]
# Grid search for model.layers.27.post_attention_layernorm:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.27.post_attention_layernorm:   0%|          | 0/20 [00:00<?, ?it/s, best_error=1.289e-03]
# Grid search for model.layers.27.post_attention_layernorm:   5%|▌         | 1/20 [00:00<00:17,  1.11it/s, best_error=1.289e-03]
# Grid search for model.layers.27.post_attention_layernorm:   5%|▌         | 1/20 [00:01<00:17,  1.11it/s, best_error=1.289e-03]
# Grid search for model.layers.27.post_attention_layernorm:  10%|█         | 2/20 [00:01<00:16,  1.11it/s, best_error=1.289e-03]
# Grid search for model.layers.27.post_attention_layernorm:  10%|█         | 2/20 [00:02<00:16,  1.11it/s, best_error=1.289e-03]
# Grid search for model.layers.27.post_attention_layernorm:  15%|█▌        | 3/20 [00:02<00:15,  1.11it/s, best_error=1.289e-03]
# Grid search for model.layers.27.post_attention_layernorm:  15%|█▌        | 3/20 [00:03<00:15,  1.11it/s, best_error=1.289e-03]
# Grid search for model.layers.27.post_attention_layernorm:  20%|██        | 4/20 [00:03<00:14,  1.11it/s, best_error=1.289e-03]
# Grid search for model.layers.27.post_attention_layernorm:  20%|██        | 4/20 [00:04<00:14,  1.11it/s, best_error=1.289e-03]
# Grid search for model.layers.27.post_attention_layernorm:  25%|██▌       | 5/20 [00:04<00:13,  1.11it/s, best_error=1.289e-03]
# Grid search for model.layers.27.post_attention_layernorm:  25%|██▌       | 5/20 [00:05<00:13,  1.11it/s, best_error=1.289e-03]
# Grid search for model.layers.27.post_attention_layernorm:  30%|███       | 6/20 [00:05<00:12,  1.11it/s, best_error=1.289e-03]
# Grid search for model.layers.27.post_attention_layernorm:  30%|███       | 6/20 [00:06<00:12,  1.11it/s, best_error=1.289e-03]
# Grid search for model.layers.27.post_attention_layernorm:  35%|███▌      | 7/20 [00:06<00:11,  1.11it/s, best_error=1.289e-03]
# Grid search for model.layers.27.post_attention_layernorm:  35%|███▌      | 7/20 [00:07<00:11,  1.11it/s, best_error=1.289e-03]
# Grid search for model.layers.27.post_attention_layernorm:  40%|████      | 8/20 [00:07<00:10,  1.11it/s, best_error=1.289e-03]
# Grid search for model.layers.27.post_attention_layernorm:  40%|████      | 8/20 [00:08<00:10,  1.11it/s, best_error=1.289e-03]
# Grid search for model.layers.27.post_attention_layernorm:  45%|████▌     | 9/20 [00:08<00:09,  1.11it/s, best_error=1.289e-03]
# Grid search for model.layers.27.post_attention_layernorm:  45%|████▌     | 9/20 [00:09<00:09,  1.11it/s, best_error=1.289e-03]
# Grid search for model.layers.27.post_attention_layernorm:  50%|█████     | 10/20 [00:09<00:09,  1.11it/s, best_error=1.289e-03]
# Grid search for model.layers.27.post_attention_layernorm:  50%|█████     | 10/20 [00:09<00:09,  1.11it/s, best_error=1.289e-03]
# Grid search for model.layers.27.post_attention_layernorm:  55%|█████▌    | 11/20 [00:09<00:08,  1.11it/s, best_error=1.289e-03]
# Grid search for model.layers.27.post_attention_layernorm:  55%|█████▌    | 11/20 [00:10<00:08,  1.11it/s, best_error=1.289e-03]
# Grid search for model.layers.27.post_attention_layernorm:  60%|██████    | 12/20 [00:10<00:07,  1.11it/s, best_error=1.289e-03]
# Grid search for model.layers.27.post_attention_layernorm:  60%|██████    | 12/20 [00:11<00:07,  1.11it/s, best_error=1.289e-03]
# Grid search for model.layers.27.post_attention_layernorm:  65%|██████▌   | 13/20 [00:11<00:06,  1.11it/s, best_error=1.289e-03]
# Grid search for model.layers.27.post_attention_layernorm:  65%|██████▌   | 13/20 [00:12<00:06,  1.11it/s, best_error=1.289e-03]
# Grid search for model.layers.27.post_attention_layernorm:  70%|███████   | 14/20 [00:12<00:05,  1.11it/s, best_error=1.289e-03]
# Grid search for model.layers.27.post_attention_layernorm:  70%|███████   | 14/20 [00:13<00:05,  1.11it/s, best_error=1.289e-03]
# Grid search for model.layers.27.post_attention_layernorm:  75%|███████▌  | 15/20 [00:13<00:04,  1.11it/s, best_error=1.289e-03]
# Grid search for model.layers.27.post_attention_layernorm:  75%|███████▌  | 15/20 [00:14<00:04,  1.11it/s, best_error=1.289e-03]
# Grid search for model.layers.27.post_attention_layernorm:  80%|████████  | 16/20 [00:14<00:03,  1.11it/s, best_error=1.289e-03]
# Grid search for model.layers.27.post_attention_layernorm:  80%|████████  | 16/20 [00:15<00:03,  1.11it/s, best_error=1.289e-03]
# Grid search for model.layers.27.post_attention_layernorm:  85%|████████▌ | 17/20 [00:15<00:02,  1.11it/s, best_error=1.289e-03]
# Grid search for model.layers.27.post_attention_layernorm:  85%|████████▌ | 17/20 [00:16<00:02,  1.11it/s, best_error=1.289e-03]
# Grid search for model.layers.27.post_attention_layernorm:  90%|█████████ | 18/20 [00:16<00:01,  1.11it/s, best_error=1.289e-03]
# Grid search for model.layers.27.post_attention_layernorm:  90%|█████████ | 18/20 [00:17<00:01,  1.11it/s, best_error=1.289e-03]
# Grid search for model.layers.27.post_attention_layernorm:  95%|█████████▌| 19/20 [00:17<00:00,  1.11it/s, best_error=1.289e-03]
# Grid search for model.layers.27.post_attention_layernorm:  95%|█████████▌| 19/20 [00:18<00:00,  1.11it/s, best_error=1.289e-03]
# Grid search for model.layers.27.post_attention_layernorm: 100%|██████████| 20/20 [00:18<00:00,  1.11it/s, best_error=1.289e-03]
# Smoothing:  67%|██████▋   | 2/3 [00:27<00:14, 14.85s/it]
# Grid search for model.layers.27.mlp.up_proj:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.27.mlp.up_proj:   0%|          | 0/20 [00:00<?, ?it/s, best_error=2.625e-03]
# Grid search for model.layers.27.mlp.up_proj:   5%|▌         | 1/20 [00:00<00:06,  3.17it/s, best_error=2.625e-03]
# Grid search for model.layers.27.mlp.up_proj:   5%|▌         | 1/20 [00:00<00:06,  3.17it/s, best_error=2.396e-03]
# Grid search for model.layers.27.mlp.up_proj:  10%|█         | 2/20 [00:00<00:05,  3.15it/s, best_error=2.396e-03]
# Grid search for model.layers.27.mlp.up_proj:  10%|█         | 2/20 [00:00<00:05,  3.15it/s, best_error=2.396e-03]
# Grid search for model.layers.27.mlp.up_proj:  15%|█▌        | 3/20 [00:00<00:05,  3.15it/s, best_error=2.396e-03]
# Grid search for model.layers.27.mlp.up_proj:  15%|█▌        | 3/20 [00:01<00:05,  3.15it/s, best_error=2.243e-03]
# Grid search for model.layers.27.mlp.up_proj:  20%|██        | 4/20 [00:01<00:05,  3.14it/s, best_error=2.243e-03]
# Grid search for model.layers.27.mlp.up_proj:  20%|██        | 4/20 [00:01<00:05,  3.14it/s, best_error=2.121e-03]
# Grid search for model.layers.27.mlp.up_proj:  25%|██▌       | 5/20 [00:01<00:04,  3.14it/s, best_error=2.121e-03]
# Grid search for model.layers.27.mlp.up_proj:  25%|██▌       | 5/20 [00:01<00:04,  3.14it/s, best_error=2.121e-03]
# Grid search for model.layers.27.mlp.up_proj:  30%|███       | 6/20 [00:01<00:04,  3.14it/s, best_error=2.121e-03]
# Grid search for model.layers.27.mlp.up_proj:  30%|███       | 6/20 [00:02<00:04,  3.14it/s, best_error=2.121e-03]
# Grid search for model.layers.27.mlp.up_proj:  35%|███▌      | 7/20 [00:02<00:04,  3.14it/s, best_error=2.121e-03]
# Grid search for model.layers.27.mlp.up_proj:  35%|███▌      | 7/20 [00:02<00:04,  3.14it/s, best_error=2.121e-03]
# Grid search for model.layers.27.mlp.up_proj:  40%|████      | 8/20 [00:02<00:03,  3.14it/s, best_error=2.121e-03]
# Grid search for model.layers.27.mlp.up_proj:  40%|████      | 8/20 [00:02<00:03,  3.14it/s, best_error=2.121e-03]
# Grid search for model.layers.27.mlp.up_proj:  45%|████▌     | 9/20 [00:02<00:03,  3.14it/s, best_error=2.121e-03]
# Grid search for model.layers.27.mlp.up_proj:  45%|████▌     | 9/20 [00:03<00:03,  3.14it/s, best_error=2.121e-03]
# Grid search for model.layers.27.mlp.up_proj:  50%|█████     | 10/20 [00:03<00:03,  3.14it/s, best_error=2.121e-03]
# Grid search for model.layers.27.mlp.up_proj:  50%|█████     | 10/20 [00:03<00:03,  3.14it/s, best_error=2.121e-03]
# Grid search for model.layers.27.mlp.up_proj:  55%|█████▌    | 11/20 [00:03<00:02,  3.14it/s, best_error=2.121e-03]
# Grid search for model.layers.27.mlp.up_proj:  55%|█████▌    | 11/20 [00:03<00:02,  3.14it/s, best_error=2.121e-03]
# Grid search for model.layers.27.mlp.up_proj:  60%|██████    | 12/20 [00:03<00:02,  3.14it/s, best_error=2.121e-03]
# Grid search for model.layers.27.mlp.up_proj:  60%|██████    | 12/20 [00:04<00:02,  3.14it/s, best_error=2.121e-03]
# Grid search for model.layers.27.mlp.up_proj:  65%|██████▌   | 13/20 [00:04<00:02,  3.14it/s, best_error=2.121e-03]
# Grid search for model.layers.27.mlp.up_proj:  65%|██████▌   | 13/20 [00:04<00:02,  3.14it/s, best_error=2.121e-03]
# Grid search for model.layers.27.mlp.up_proj:  70%|███████   | 14/20 [00:04<00:01,  3.14it/s, best_error=2.121e-03]
# Grid search for model.layers.27.mlp.up_proj:  70%|███████   | 14/20 [00:04<00:01,  3.14it/s, best_error=2.121e-03]
# Grid search for model.layers.27.mlp.up_proj:  75%|███████▌  | 15/20 [00:04<00:01,  3.14it/s, best_error=2.121e-03]
# Grid search for model.layers.27.mlp.up_proj:  75%|███████▌  | 15/20 [00:05<00:01,  3.14it/s, best_error=2.121e-03]
# Grid search for model.layers.27.mlp.up_proj:  80%|████████  | 16/20 [00:05<00:01,  3.14it/s, best_error=2.121e-03]
# Grid search for model.layers.27.mlp.up_proj:  80%|████████  | 16/20 [00:05<00:01,  3.14it/s, best_error=2.121e-03]
# Grid search for model.layers.27.mlp.up_proj:  85%|████████▌ | 17/20 [00:05<00:00,  3.14it/s, best_error=2.121e-03]
# Grid search for model.layers.27.mlp.up_proj:  85%|████████▌ | 17/20 [00:05<00:00,  3.14it/s, best_error=2.121e-03]
# Grid search for model.layers.27.mlp.up_proj:  90%|█████████ | 18/20 [00:05<00:00,  3.14it/s, best_error=2.121e-03]
# Grid search for model.layers.27.mlp.up_proj:  90%|█████████ | 18/20 [00:06<00:00,  3.14it/s, best_error=2.121e-03]
# Grid search for model.layers.27.mlp.up_proj:  95%|█████████▌| 19/20 [00:06<00:00,  3.14it/s, best_error=2.121e-03]
# Grid search for model.layers.27.mlp.up_proj:  95%|█████████▌| 19/20 [00:06<00:00,  3.14it/s, best_error=2.121e-03]
# Grid search for model.layers.27.mlp.up_proj: 100%|██████████| 20/20 [00:06<00:00,  3.14it/s, best_error=2.121e-03]
# Smoothing: 100%|██████████| 3/3 [00:34<00:00, 11.54s/it]
# (28/29): Propagating: 100%|██████████| 64/64 [00:01<00:00, 43.32it/s]
# (29/29): Calibrating: 100%|██████████| 64/64 [00:00<00:00, 847.45it/s]
# Smoothing: 0it [00:00, ?it/s]
# (29/29): Propagating: 100%|██████████| 64/64 [00:00<00:00, 860.84it/s]
# Smoothing: 0it [00:00, ?it/s]
# Updating global scales: 100%|██████████| 196/196 [00:00<00:00, 292140.58it/s]
# Fusing global scales: 567it [00:00, 344962.34it/s]
# Calibrating weights: 100%|██████████| 196/196 [00:00<00:00, 813.06it/s]
# 2026-03-21T14:20:56.093108+0000 | finalize | INFO - Compression lifecycle finalized for 1 modifiers
# 2026-03-21T14:20:56.093819+0000 | post_process | WARNING - Optimized model is not saved. To save, please provide`output_dir` as input arg.Ex. `oneshot(..., output_dir=...)`
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(128256, 3072)
#     (layers): ModuleList(
#       (0-27): 28 x LlamaDecoderLayer(
#         (self_attn): LlamaAttention(
#           (q_proj): Linear(in_features=3072, out_features=3072, bias=False)
#           (k_proj): Linear(in_features=3072, out_features=1024, bias=False)
#           (v_proj): Linear(in_features=3072, out_features=1024, bias=False)
#           (o_proj): Linear(in_features=3072, out_features=3072, bias=False)
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear(in_features=3072, out_features=8192, bias=False)
#           (up_proj): Linear(in_features=3072, out_features=8192, bias=False)
#           (down_proj): Linear(in_features=8192, out_features=3072, bias=False)
#           (act_fn): SiLUActivation()
#         )
#         (input_layernorm): LlamaRMSNorm((3072,), eps=1e-05)
#         (post_attention_layernorm): LlamaRMSNorm((3072,), eps=1e-05)
#       )
#     )
#     (norm): LlamaRMSNorm((3072,), eps=1e-05)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=3072, out_features=128256, bias=False)
# )

# %% [markdown]
# **Saving**

# %%
model.config._name_or_path = ""

model.save_pretrained(OUTPUT_DIR,skip_sparsity_compression_stats=False)#VERY IMPORTANT
tokenizer.save_pretrained(OUTPUT_DIR)

print("Model saved successfully")
# Out:
# Calculating model sparsity: 100%|██████████| 647/647 [00:16<00:00, 38.32it/s]
# Checking whether model follows 2:4 sparsity structure: 100%|██████████| 197/197 [00:17<00:00, 11.00it/s]
# Compressing model: 196it [00:28,  6.93it/s]
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py:3970: UserWarning: Attempting to save a model with offloaded modules. Ensure that unallocated cpu memory exceeds the `shard_size` (5GB default)
#   warnings.warn(
# Saving checkpoint shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Model saved successfully

# %% [markdown]
# # PUSH TO HUGGING FACE

# %%
create_repo(REPO_ID, repo_type="model", exist_ok=True)

upload_folder(
    folder_path=OUTPUT_DIR,
    repo_id=REPO_ID,
    path_in_repo="Sparsity/25"
)
# Out:
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# CommitInfo(commit_url='https://huggingface.co/EdgeCompress01/Llama-3.2-3B-Instruct-WANDA-AWQ-4bit/commit/3d7b29548343beb8e91effe9e810c9d6311a57b5', commit_message='Upload folder using huggingface_hub', commit_description='', oid='3d7b29548343beb8e91effe9e810c9d6311a57b5', pr_url=None, repo_url=RepoUrl('https://huggingface.co/EdgeCompress01/Llama-3.2-3B-Instruct-WANDA-AWQ-4bit', endpoint='https://huggingface.co', repo_type='model', repo_id='EdgeCompress01/Llama-3.2-3B-Instruct-WANDA-AWQ-4bit'), pr_revision=None, pr_num=None)
