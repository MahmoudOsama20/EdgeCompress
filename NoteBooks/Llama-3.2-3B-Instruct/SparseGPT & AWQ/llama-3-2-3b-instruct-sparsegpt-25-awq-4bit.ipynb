# %% [markdown]
# # Libraries

# %%
# !pip install -q -U llmcompressor datasets accelerate transformers huggingface_hub
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.5/295.5 kB 18.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.5/196.5 kB 14.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 520.7/520.7 kB 25.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 80.5 MB/s eta 0:00:00:00:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 34.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 563.6/563.6 kB 33.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 MB 42.7 MB/s eta 0:00:00:00:0100:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.31.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# google-adk 1.21.0 requires google-cloud-bigquery-storage>=2.0.0, which is not installed.

# %%
import random
import numpy as np
import torch

from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    set_seed,
)

from llmcompressor import oneshot
from llmcompressor.modifiers.awq import AWQModifier

from huggingface_hub import (
    login,
    create_repo,
    upload_folder,
)

from kaggle_secrets import UserSecretsClient
from datasets import load_dataset
# Out:
# 2026-03-27 09:51:33.453978: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774605093.839225      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774605094.002007      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774605094.944412      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774605094.944451      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774605094.944454      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774605094.944456      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %% [markdown]
# # Global Variables

# %%
BASE_ID = "meta-llama/Llama-3.2-3B-Instruct"
MODEL_ID = "EdgeCompress01/Llama-3.2-3B-Instruct-SparseGPT"
OUTPUT_DIR = "/kaggle/working/Llama-3.2-3B-Instruct-SparseGPT-AWQ-4bit"
REPO_ID = f"EdgeCompress01/Llama-3.2-3B-Instruct-SparseGPT-AWQ-4bit"
SEED = 42

# %% [markdown]
# # Functions

# %%
# --- 2. REPRODUCIBILITY ---
def set_reproducibility(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    set_seed(seed)
    # Ensure deterministic behavior in CuDNN
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    print(f"Global seed set to {seed}")

def format_chat(batch):
    texts = [
        tokenizer.apply_chat_template(
            messages,
            tokenize=False,
            add_generation_prompt=False
        )
        for messages in batch["messages"]
    ]
    return {"text": texts}

# %% [markdown]
# # Set Seed

# %%
set_reproducibility(SEED)
# Out:
# Global seed set to 42

# %% [markdown]
# # Huggingface Login

# %%
# --- 3. HUGGING FACE AUTHENTICATION ---
user_secrets = UserSecretsClient()
hf_token = user_secrets.get_secret("HF_TOKEN")
login(token=hf_token)
print("Logged in")
# Out:
# Logged in

# %% [markdown]
# # Load Model & Tokenizer

# %%
#Model
model = AutoModelForCausalLM.from_pretrained(
    MODEL_ID,
    subfolder="Models/25",
    device_map="auto",
    dtype=torch.bfloat16
)

#Tokenizer
tokenizer = AutoTokenizer.from_pretrained(BASE_ID)
# Out:
# config.json:   0%|          | 0.00/927 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Models/25/model-00001-of-00002.safetenso(…):   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# Models/25/model-00002-of-00002.safetenso(…):   0%|          | 0.00/1.46G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/184 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/296 [00:00<?, ?B/s]

# %% [markdown]
# # AWQ Quantization

# %% [markdown]
# **Configurations**

# %%
recipe = [
    AWQModifier(
        ignore=["lm_head", "embed_tokens"], 
        scheme="W4A16",
        targets=["Linear"]
    )
]

# %% [markdown]
# **Calibration Dataset**

# %%
dataset = load_dataset("HuggingFaceH4/ultrachat_200k", split="train_sft").shuffle(seed=SEED).select(range(64))

formatted_dataset = dataset.map(
    format_chat,
    batched=True,
    remove_columns=dataset.column_names  # keep only "text"
)
# Out:
# README.md: 0.00B [00:00, ?B/s]
# data/train_sft-00000-of-00003-a3ecf92756(…):   0%|          | 0.00/244M [00:00<?, ?B/s]
# data/train_sft-00001-of-00003-0a1804bcb6(…):   0%|          | 0.00/244M [00:00<?, ?B/s]
# data/train_sft-00002-of-00003-ee46ed25cf(…):   0%|          | 0.00/244M [00:00<?, ?B/s]
# data/test_sft-00000-of-00001-f7dfac4afe5(…):   0%|          | 0.00/81.2M [00:00<?, ?B/s]
# data/train_gen-00000-of-00003-a6c9fb894b(…):   0%|          | 0.00/244M [00:00<?, ?B/s]
# data/train_gen-00001-of-00003-d6a0402e41(…):   0%|          | 0.00/243M [00:00<?, ?B/s]
# data/train_gen-00002-of-00003-c0db75b92a(…):   0%|          | 0.00/243M [00:00<?, ?B/s]
# data/test_gen-00000-of-00001-3d4cd830914(…):   0%|          | 0.00/80.4M [00:00<?, ?B/s]
# Generating train_sft split:   0%|          | 0/207865 [00:00<?, ? examples/s]
# Generating test_sft split:   0%|          | 0/23110 [00:00<?, ? examples/s]
# Generating train_gen split:   0%|          | 0/256032 [00:00<?, ? examples/s]
# Generating test_gen split:   0%|          | 0/28304 [00:00<?, ? examples/s]
# Map:   0%|          | 0/64 [00:00<?, ? examples/s]

# %% [markdown]
# **Apply quantization**

# %%
oneshot(
    model=model,
    tokenizer=tokenizer,
    dataset=formatted_dataset,
    text_column="text",
    recipe=recipe,
    max_seq_length=512
)
# Out:
# 2026-03-27T09:53:33.294339+0000 | __init__ | WARNING - Disabling tokenizer parallelism due to threading conflict between FastTokenizer and Datasets. Set TOKENIZERS_PARALLELISM=false to suppress this warning.
# Tokenizing:   0%|          | 0/64 [00:00<?, ? examples/s]
# 2026-03-27T09:53:33.694175+0000 | _make_sampler | WARNING - Requested 512 samples but the provided dataset only has 64 samples.
# 2026-03-27T09:53:33.695447+0000 | reset | INFO - Compression lifecycle reset
# 2026-03-27T09:53:33.697436+0000 | from_modifiers | INFO - Creating recipe from modifiers
# 2026-03-27T09:53:33.766774+0000 | on_initialize | INFO - No AWQModifier.mappings provided, inferring from model...
# 2026-03-27T09:53:33.775919+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.0.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-27T09:53:33.776959+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.1.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-27T09:53:33.778111+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.2.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-27T09:53:33.778778+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.3.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-27T09:53:33.779566+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.4.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-27T09:53:33.781074+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.5.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-27T09:53:33.781790+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.6.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-27T09:53:33.782624+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.7.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-27T09:53:33.783835+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.8.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-27T09:53:33.784523+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.9.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-27T09:53:33.785245+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.10.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-27T09:53:33.786157+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.11.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-27T09:53:33.787222+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.12.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-27T09:53:33.787944+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.13.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-27T09:53:33.788824+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.14.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-27T09:53:33.789704+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.15.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-27T09:53:33.790527+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.16.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-27T09:53:33.791310+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.17.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-27T09:53:33.792228+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.18.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-27T09:53:33.792977+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.19.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-27T09:53:33.794469+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.20.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-27T09:53:33.795256+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.21.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-27T09:53:33.795960+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.22.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-27T09:53:33.796855+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.23.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-27T09:53:33.797608+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.24.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-27T09:53:33.798422+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.25.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-27T09:53:33.799214+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.26.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-27T09:53:33.800051+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.27.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-27T09:53:33.808297+0000 | initialize | INFO - Compression lifecycle initialized for 1 modifiers
# 2026-03-27T09:53:33.809006+0000 | IndependentPipeline | INFO - Inferred `SequentialPipeline` for `AWQModifier`
# W0327 09:53:33.859000 55 torch/fx/_symbolic_trace.py:52] is_fx_tracing will return true for both fx.symbolic_trace and torch.export. Please use is_fx_tracing_symbolic_tracing() for specifically fx.symbolic_trace or torch.compiler.is_compiling() for specifically torch.export/compile.
# Preparing cache: 100%|██████████| 64/64 [00:00<00:00, 1290.46it/s]
# (1/29): Calibrating: 100%|██████████| 64/64 [00:02<00:00, 23.20it/s]
# Smoothing:   0%|          | 0/3 [00:00<?, ?it/s]
# Grid search for model.layers.0.input_layernorm:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.0.input_layernorm:   0%|          | 0/20 [00:00<?, ?it/s, best_error=8.011e-05]
# Grid search for model.layers.0.input_layernorm:   5%|▌         | 1/20 [00:00<00:11,  1.59it/s, best_error=8.011e-05]
# Grid search for model.layers.0.input_layernorm:   5%|▌         | 1/20 [00:01<00:11,  1.59it/s, best_error=7.772e-05]
# Grid search for model.layers.0.input_layernorm:  10%|█         | 2/20 [00:01<00:09,  1.95it/s, best_error=7.772e-05]
# Grid search for model.layers.0.input_layernorm:  10%|█         | 2/20 [00:01<00:09,  1.95it/s, best_error=4.482e-05]
# Grid search for model.layers.0.input_layernorm:  15%|█▌        | 3/20 [00:01<00:08,  2.11it/s, best_error=4.482e-05]
# Grid search for model.layers.0.input_layernorm:  15%|█▌        | 3/20 [00:01<00:08,  2.11it/s, best_error=1.043e-05]
# Grid search for model.layers.0.input_layernorm:  20%|██        | 4/20 [00:01<00:07,  2.19it/s, best_error=1.043e-05]
# Grid search for model.layers.0.input_layernorm:  20%|██        | 4/20 [00:02<00:07,  2.19it/s, best_error=5.335e-06]
# Grid search for model.layers.0.input_layernorm:  25%|██▌       | 5/20 [00:02<00:06,  2.24it/s, best_error=5.335e-06]
# Grid search for model.layers.0.input_layernorm:  25%|██▌       | 5/20 [00:02<00:06,  2.24it/s, best_error=3.621e-06]
# Grid search for model.layers.0.input_layernorm:  30%|███       | 6/20 [00:02<00:06,  2.27it/s, best_error=3.621e-06]
# Grid search for model.layers.0.input_layernorm:  30%|███       | 6/20 [00:03<00:06,  2.27it/s, best_error=2.369e-06]
# Grid search for model.layers.0.input_layernorm:  35%|███▌      | 7/20 [00:03<00:05,  2.29it/s, best_error=2.369e-06]
# Grid search for model.layers.0.input_layernorm:  35%|███▌      | 7/20 [00:03<00:05,  2.29it/s, best_error=1.632e-06]
# Grid search for model.layers.0.input_layernorm:  40%|████      | 8/20 [00:03<00:05,  2.30it/s, best_error=1.632e-06]
# Grid search for model.layers.0.input_layernorm:  40%|████      | 8/20 [00:04<00:05,  2.30it/s, best_error=1.349e-06]
# Grid search for model.layers.0.input_layernorm:  45%|████▌     | 9/20 [00:04<00:04,  2.32it/s, best_error=1.349e-06]
# Grid search for model.layers.0.input_layernorm:  45%|████▌     | 9/20 [00:04<00:04,  2.32it/s, best_error=1.304e-06]
# Grid search for model.layers.0.input_layernorm:  50%|█████     | 10/20 [00:04<00:04,  2.32it/s, best_error=1.304e-06]
# Grid search for model.layers.0.input_layernorm:  50%|█████     | 10/20 [00:04<00:04,  2.32it/s, best_error=1.118e-06]
# Grid search for model.layers.0.input_layernorm:  55%|█████▌    | 11/20 [00:04<00:03,  2.33it/s, best_error=1.118e-06]
# Grid search for model.layers.0.input_layernorm:  55%|█████▌    | 11/20 [00:05<00:03,  2.33it/s, best_error=1.118e-06]
# Grid search for model.layers.0.input_layernorm:  60%|██████    | 12/20 [00:05<00:03,  2.33it/s, best_error=1.118e-06]
# Grid search for model.layers.0.input_layernorm:  60%|██████    | 12/20 [00:05<00:03,  2.33it/s, best_error=1.036e-06]
# Grid search for model.layers.0.input_layernorm:  65%|██████▌   | 13/20 [00:05<00:03,  2.33it/s, best_error=1.036e-06]
# Grid search for model.layers.0.input_layernorm:  65%|██████▌   | 13/20 [00:06<00:03,  2.33it/s, best_error=1.036e-06]
# Grid search for model.layers.0.input_layernorm:  70%|███████   | 14/20 [00:06<00:02,  2.33it/s, best_error=1.036e-06]
# Grid search for model.layers.0.input_layernorm:  70%|███████   | 14/20 [00:06<00:02,  2.33it/s, best_error=1.036e-06]
# Grid search for model.layers.0.input_layernorm:  75%|███████▌  | 15/20 [00:06<00:02,  2.33it/s, best_error=1.036e-06]
# Grid search for model.layers.0.input_layernorm:  75%|███████▌  | 15/20 [00:07<00:02,  2.33it/s, best_error=1.036e-06]
# Grid search for model.layers.0.input_layernorm:  80%|████████  | 16/20 [00:07<00:01,  2.30it/s, best_error=1.036e-06]
# Grid search for model.layers.0.input_layernorm:  80%|████████  | 16/20 [00:07<00:01,  2.30it/s, best_error=1.036e-06]
# Grid search for model.layers.0.input_layernorm:  85%|████████▌ | 17/20 [00:07<00:01,  2.31it/s, best_error=1.036e-06]
# Grid search for model.layers.0.input_layernorm:  85%|████████▌ | 17/20 [00:07<00:01,  2.31it/s, best_error=1.036e-06]
# Grid search for model.layers.0.input_layernorm:  90%|█████████ | 18/20 [00:07<00:00,  2.31it/s, best_error=1.036e-06]
# Grid search for model.layers.0.input_layernorm:  90%|█████████ | 18/20 [00:08<00:00,  2.31it/s, best_error=1.036e-06]
# Grid search for model.layers.0.input_layernorm:  95%|█████████▌| 19/20 [00:08<00:00,  2.29it/s, best_error=1.036e-06]
# Grid search for model.layers.0.input_layernorm:  95%|█████████▌| 19/20 [00:08<00:00,  2.29it/s, best_error=1.036e-06]
# Grid search for model.layers.0.input_layernorm: 100%|██████████| 20/20 [00:08<00:00,  2.30it/s, best_error=1.036e-06]
# Smoothing:  33%|███▎      | 1/3 [00:09<00:18,  9.29s/it]
# Grid search for model.layers.0.post_attention_layernorm:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.0.post_attention_layernorm:   0%|          | 0/20 [00:00<?, ?it/s, best_error=3.174e-06]
# Grid search for model.layers.0.post_attention_layernorm:   5%|▌         | 1/20 [00:00<00:17,  1.11it/s, best_error=3.174e-06]
# Grid search for model.layers.0.post_attention_layernorm:   5%|▌         | 1/20 [00:01<00:17,  1.11it/s, best_error=3.174e-06]
# Grid search for model.layers.0.post_attention_layernorm:  10%|█         | 2/20 [00:01<00:16,  1.11it/s, best_error=3.174e-06]
# Grid search for model.layers.0.post_attention_layernorm:  10%|█         | 2/20 [00:02<00:16,  1.11it/s, best_error=3.174e-06]
# Grid search for model.layers.0.post_attention_layernorm:  15%|█▌        | 3/20 [00:02<00:15,  1.10it/s, best_error=3.174e-06]
# Grid search for model.layers.0.post_attention_layernorm:  15%|█▌        | 3/20 [00:03<00:15,  1.10it/s, best_error=3.144e-06]
# Grid search for model.layers.0.post_attention_layernorm:  20%|██        | 4/20 [00:03<00:15,  1.03it/s, best_error=3.144e-06]
# Grid search for model.layers.0.post_attention_layernorm:  20%|██        | 4/20 [00:04<00:15,  1.03it/s, best_error=3.144e-06]
# Grid search for model.layers.0.post_attention_layernorm:  25%|██▌       | 5/20 [00:04<00:14,  1.06it/s, best_error=3.144e-06]
# Grid search for model.layers.0.post_attention_layernorm:  25%|██▌       | 5/20 [00:05<00:14,  1.06it/s, best_error=3.144e-06]
# Grid search for model.layers.0.post_attention_layernorm:  30%|███       | 6/20 [00:05<00:13,  1.07it/s, best_error=3.144e-06]
# Grid search for model.layers.0.post_attention_layernorm:  30%|███       | 6/20 [00:06<00:13,  1.07it/s, best_error=3.144e-06]
# Grid search for model.layers.0.post_attention_layernorm:  35%|███▌      | 7/20 [00:06<00:12,  1.08it/s, best_error=3.144e-06]
# Grid search for model.layers.0.post_attention_layernorm:  35%|███▌      | 7/20 [00:07<00:12,  1.08it/s, best_error=3.144e-06]
# Grid search for model.layers.0.post_attention_layernorm:  40%|████      | 8/20 [00:07<00:11,  1.09it/s, best_error=3.144e-06]
# Grid search for model.layers.0.post_attention_layernorm:  40%|████      | 8/20 [00:08<00:11,  1.09it/s, best_error=3.144e-06]
# Grid search for model.layers.0.post_attention_layernorm:  45%|████▌     | 9/20 [00:08<00:10,  1.10it/s, best_error=3.144e-06]
# Grid search for model.layers.0.post_attention_layernorm:  45%|████▌     | 9/20 [00:09<00:10,  1.10it/s, best_error=3.144e-06]
# Grid search for model.layers.0.post_attention_layernorm:  50%|█████     | 10/20 [00:09<00:09,  1.10it/s, best_error=3.144e-06]
# Grid search for model.layers.0.post_attention_layernorm:  50%|█████     | 10/20 [00:10<00:09,  1.10it/s, best_error=3.144e-06]
# Grid search for model.layers.0.post_attention_layernorm:  55%|█████▌    | 11/20 [00:10<00:08,  1.10it/s, best_error=3.144e-06]
# Grid search for model.layers.0.post_attention_layernorm:  55%|█████▌    | 11/20 [00:11<00:08,  1.10it/s, best_error=3.144e-06]
# Grid search for model.layers.0.post_attention_layernorm:  60%|██████    | 12/20 [00:11<00:07,  1.10it/s, best_error=3.144e-06]
# Grid search for model.layers.0.post_attention_layernorm:  60%|██████    | 12/20 [00:11<00:07,  1.10it/s, best_error=3.144e-06]
# Grid search for model.layers.0.post_attention_layernorm:  65%|██████▌   | 13/20 [00:11<00:06,  1.10it/s, best_error=3.144e-06]
# Grid search for model.layers.0.post_attention_layernorm:  65%|██████▌   | 13/20 [00:12<00:06,  1.10it/s, best_error=3.144e-06]
# Grid search for model.layers.0.post_attention_layernorm:  70%|███████   | 14/20 [00:12<00:05,  1.08it/s, best_error=3.144e-06]
# Grid search for model.layers.0.post_attention_layernorm:  70%|███████   | 14/20 [00:13<00:05,  1.08it/s, best_error=3.144e-06]
# Grid search for model.layers.0.post_attention_layernorm:  75%|███████▌  | 15/20 [00:13<00:04,  1.06it/s, best_error=3.144e-06]
# Grid search for model.layers.0.post_attention_layernorm:  75%|███████▌  | 15/20 [00:14<00:04,  1.06it/s, best_error=3.144e-06]
# Grid search for model.layers.0.post_attention_layernorm:  80%|████████  | 16/20 [00:14<00:03,  1.07it/s, best_error=3.144e-06]
# Grid search for model.layers.0.post_attention_layernorm:  80%|████████  | 16/20 [00:15<00:03,  1.07it/s, best_error=3.144e-06]
# Grid search for model.layers.0.post_attention_layernorm:  85%|████████▌ | 17/20 [00:15<00:02,  1.04it/s, best_error=3.144e-06]
# Grid search for model.layers.0.post_attention_layernorm:  85%|████████▌ | 17/20 [00:16<00:02,  1.04it/s, best_error=3.144e-06]
# Grid search for model.layers.0.post_attention_layernorm:  90%|█████████ | 18/20 [00:16<00:01,  1.06it/s, best_error=3.144e-06]
# Grid search for model.layers.0.post_attention_layernorm:  90%|█████████ | 18/20 [00:17<00:01,  1.06it/s, best_error=3.144e-06]
# Grid search for model.layers.0.post_attention_layernorm:  95%|█████████▌| 19/20 [00:17<00:00,  1.07it/s, best_error=3.144e-06]
# Grid search for model.layers.0.post_attention_layernorm:  95%|█████████▌| 19/20 [00:18<00:00,  1.07it/s, best_error=3.144e-06]
# Grid search for model.layers.0.post_attention_layernorm: 100%|██████████| 20/20 [00:18<00:00,  1.07it/s, best_error=3.144e-06]
# Smoothing:  67%|██████▋   | 2/3 [00:28<00:15, 15.28s/it]
# Grid search for model.layers.0.mlp.up_proj:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.0.mlp.up_proj:   0%|          | 0/20 [00:00<?, ?it/s, best_error=6.706e-06]
# Grid search for model.layers.0.mlp.up_proj:   5%|▌         | 1/20 [00:00<00:06,  3.16it/s, best_error=6.706e-06]
# Grid search for model.layers.0.mlp.up_proj:   5%|▌         | 1/20 [00:00<00:06,  3.16it/s, best_error=6.706e-06]
# Grid search for model.layers.0.mlp.up_proj:  10%|█         | 2/20 [00:00<00:05,  3.14it/s, best_error=6.706e-06]
# Grid search for model.layers.0.mlp.up_proj:  10%|█         | 2/20 [00:01<00:05,  3.14it/s, best_error=6.706e-06]
# Grid search for model.layers.0.mlp.up_proj:  15%|█▌        | 3/20 [00:01<00:06,  2.72it/s, best_error=6.706e-06]
# Grid search for model.layers.0.mlp.up_proj:  15%|█▌        | 3/20 [00:01<00:06,  2.72it/s, best_error=6.646e-06]
# Grid search for model.layers.0.mlp.up_proj:  20%|██        | 4/20 [00:01<00:05,  2.87it/s, best_error=6.646e-06]
# Grid search for model.layers.0.mlp.up_proj:  20%|██        | 4/20 [00:01<00:05,  2.87it/s, best_error=6.646e-06]
# Grid search for model.layers.0.mlp.up_proj:  25%|██▌       | 5/20 [00:01<00:05,  2.96it/s, best_error=6.646e-06]
# Grid search for model.layers.0.mlp.up_proj:  25%|██▌       | 5/20 [00:02<00:05,  2.96it/s, best_error=6.646e-06]
# Grid search for model.layers.0.mlp.up_proj:  30%|███       | 6/20 [00:02<00:04,  3.02it/s, best_error=6.646e-06]
# Grid search for model.layers.0.mlp.up_proj:  30%|███       | 6/20 [00:02<00:04,  3.02it/s, best_error=6.646e-06]
# Grid search for model.layers.0.mlp.up_proj:  35%|███▌      | 7/20 [00:02<00:04,  3.03it/s, best_error=6.646e-06]
# Grid search for model.layers.0.mlp.up_proj:  35%|███▌      | 7/20 [00:02<00:04,  3.03it/s, best_error=6.646e-06]
# Grid search for model.layers.0.mlp.up_proj:  40%|████      | 8/20 [00:02<00:03,  3.05it/s, best_error=6.646e-06]
# Grid search for model.layers.0.mlp.up_proj:  40%|████      | 8/20 [00:02<00:03,  3.05it/s, best_error=6.646e-06]
# Grid search for model.layers.0.mlp.up_proj:  45%|████▌     | 9/20 [00:02<00:03,  3.07it/s, best_error=6.646e-06]
# Grid search for model.layers.0.mlp.up_proj:  45%|████▌     | 9/20 [00:03<00:03,  3.07it/s, best_error=6.646e-06]
# Grid search for model.layers.0.mlp.up_proj:  50%|█████     | 10/20 [00:03<00:03,  3.09it/s, best_error=6.646e-06]
# Grid search for model.layers.0.mlp.up_proj:  50%|█████     | 10/20 [00:03<00:03,  3.09it/s, best_error=6.646e-06]
# Grid search for model.layers.0.mlp.up_proj:  55%|█████▌    | 11/20 [00:03<00:02,  3.11it/s, best_error=6.646e-06]
# Grid search for model.layers.0.mlp.up_proj:  55%|█████▌    | 11/20 [00:04<00:02,  3.11it/s, best_error=6.646e-06]
# Grid search for model.layers.0.mlp.up_proj:  60%|██████    | 12/20 [00:04<00:02,  2.81it/s, best_error=6.646e-06]
# Grid search for model.layers.0.mlp.up_proj:  60%|██████    | 12/20 [00:04<00:02,  2.81it/s, best_error=6.646e-06]
# Grid search for model.layers.0.mlp.up_proj:  65%|██████▌   | 13/20 [00:04<00:02,  2.91it/s, best_error=6.646e-06]
# Grid search for model.layers.0.mlp.up_proj:  65%|██████▌   | 13/20 [00:04<00:02,  2.91it/s, best_error=6.646e-06]
# Grid search for model.layers.0.mlp.up_proj:  70%|███████   | 14/20 [00:04<00:02,  2.97it/s, best_error=6.646e-06]
# Grid search for model.layers.0.mlp.up_proj:  70%|███████   | 14/20 [00:05<00:02,  2.97it/s, best_error=6.646e-06]
# Grid search for model.layers.0.mlp.up_proj:  75%|███████▌  | 15/20 [00:05<00:01,  3.02it/s, best_error=6.646e-06]
# Grid search for model.layers.0.mlp.up_proj:  75%|███████▌  | 15/20 [00:05<00:01,  3.02it/s, best_error=6.646e-06]
# Grid search for model.layers.0.mlp.up_proj:  80%|████████  | 16/20 [00:05<00:01,  3.01it/s, best_error=6.646e-06]
# Grid search for model.layers.0.mlp.up_proj:  80%|████████  | 16/20 [00:05<00:01,  3.01it/s, best_error=6.646e-06]
# Grid search for model.layers.0.mlp.up_proj:  85%|████████▌ | 17/20 [00:05<00:01,  2.67it/s, best_error=6.646e-06]
# Grid search for model.layers.0.mlp.up_proj:  85%|████████▌ | 17/20 [00:06<00:01,  2.67it/s, best_error=6.646e-06]
# Grid search for model.layers.0.mlp.up_proj:  90%|█████████ | 18/20 [00:06<00:00,  2.79it/s, best_error=6.646e-06]
# Grid search for model.layers.0.mlp.up_proj:  90%|█████████ | 18/20 [00:06<00:00,  2.79it/s, best_error=6.646e-06]
# Grid search for model.layers.0.mlp.up_proj:  95%|█████████▌| 19/20 [00:06<00:00,  2.88it/s, best_error=6.646e-06]
# Grid search for model.layers.0.mlp.up_proj:  95%|█████████▌| 19/20 [00:06<00:00,  2.88it/s, best_error=6.646e-06]
# Grid search for model.layers.0.mlp.up_proj: 100%|██████████| 20/20 [00:06<00:00,  2.96it/s, best_error=6.646e-06]
# Smoothing: 100%|██████████| 3/3 [00:36<00:00, 12.02s/it]
# (1/29): Propagating: 100%|██████████| 64/64 [00:01<00:00, 35.74it/s]
# (2/29): Calibrating: 100%|██████████| 64/64 [00:02<00:00, 31.98it/s]
# Smoothing:   0%|          | 0/3 [00:00<?, ?it/s]
# Grid search for model.layers.1.input_layernorm:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.1.input_layernorm:   0%|          | 0/20 [00:00<?, ?it/s, best_error=2.539e-05]
# Grid search for model.layers.1.input_layernorm:   5%|▌         | 1/20 [00:00<00:08,  2.36it/s, best_error=2.539e-05]
# Grid search for model.layers.1.input_layernorm:   5%|▌         | 1/20 [00:00<00:08,  2.36it/s, best_error=1.979e-05]
# Grid search for model.layers.1.input_layernorm:  10%|█         | 2/20 [00:00<00:07,  2.29it/s, best_error=1.979e-05]
# Grid search for model.layers.1.input_layernorm:  10%|█         | 2/20 [00:01<00:07,  2.29it/s, best_error=9.000e-06]
# Grid search for model.layers.1.input_layernorm:  15%|█▌        | 3/20 [00:01<00:07,  2.31it/s, best_error=9.000e-06]
# Grid search for model.layers.1.input_layernorm:  15%|█▌        | 3/20 [00:01<00:07,  2.31it/s, best_error=3.442e-06]
# Grid search for model.layers.1.input_layernorm:  20%|██        | 4/20 [00:01<00:06,  2.32it/s, best_error=3.442e-06]
# Grid search for model.layers.1.input_layernorm:  20%|██        | 4/20 [00:02<00:06,  2.32it/s, best_error=2.503e-06]
# Grid search for model.layers.1.input_layernorm:  25%|██▌       | 5/20 [00:02<00:06,  2.32it/s, best_error=2.503e-06]
# Grid search for model.layers.1.input_layernorm:  25%|██▌       | 5/20 [00:02<00:06,  2.32it/s, best_error=2.101e-06]
# Grid search for model.layers.1.input_layernorm:  30%|███       | 6/20 [00:02<00:06,  2.33it/s, best_error=2.101e-06]
# Grid search for model.layers.1.input_layernorm:  30%|███       | 6/20 [00:03<00:06,  2.33it/s, best_error=1.922e-06]
# Grid search for model.layers.1.input_layernorm:  35%|███▌      | 7/20 [00:03<00:05,  2.33it/s, best_error=1.922e-06]
# Grid search for model.layers.1.input_layernorm:  35%|███▌      | 7/20 [00:03<00:05,  2.33it/s, best_error=1.818e-06]
# Grid search for model.layers.1.input_layernorm:  40%|████      | 8/20 [00:03<00:05,  2.33it/s, best_error=1.818e-06]
# Grid search for model.layers.1.input_layernorm:  40%|████      | 8/20 [00:03<00:05,  2.33it/s, best_error=1.796e-06]
# Grid search for model.layers.1.input_layernorm:  45%|████▌     | 9/20 [00:03<00:04,  2.33it/s, best_error=1.796e-06]
# Grid search for model.layers.1.input_layernorm:  45%|████▌     | 9/20 [00:04<00:04,  2.33it/s, best_error=1.796e-06]
# Grid search for model.layers.1.input_layernorm:  50%|█████     | 10/20 [00:04<00:04,  2.33it/s, best_error=1.796e-06]
# Grid search for model.layers.1.input_layernorm:  50%|█████     | 10/20 [00:04<00:04,  2.33it/s, best_error=1.796e-06]
# Grid search for model.layers.1.input_layernorm:  55%|█████▌    | 11/20 [00:04<00:03,  2.33it/s, best_error=1.796e-06]
# Grid search for model.layers.1.input_layernorm:  55%|█████▌    | 11/20 [00:05<00:03,  2.33it/s, best_error=1.796e-06]
# Grid search for model.layers.1.input_layernorm:  60%|██████    | 12/20 [00:05<00:03,  2.13it/s, best_error=1.796e-06]
# Grid search for model.layers.1.input_layernorm:  60%|██████    | 12/20 [00:05<00:03,  2.13it/s, best_error=1.796e-06]
# Grid search for model.layers.1.input_layernorm:  65%|██████▌   | 13/20 [00:05<00:03,  2.19it/s, best_error=1.796e-06]
# Grid search for model.layers.1.input_layernorm:  65%|██████▌   | 13/20 [00:06<00:03,  2.19it/s, best_error=1.796e-06]
# Grid search for model.layers.1.input_layernorm:  70%|███████   | 14/20 [00:06<00:02,  2.23it/s, best_error=1.796e-06]
# Grid search for model.layers.1.input_layernorm:  70%|███████   | 14/20 [00:06<00:02,  2.23it/s, best_error=1.796e-06]
# Grid search for model.layers.1.input_layernorm:  75%|███████▌  | 15/20 [00:06<00:02,  2.26it/s, best_error=1.796e-06]
# Grid search for model.layers.1.input_layernorm:  75%|███████▌  | 15/20 [00:07<00:02,  2.26it/s, best_error=1.796e-06]
# Grid search for model.layers.1.input_layernorm:  80%|████████  | 16/20 [00:07<00:01,  2.28it/s, best_error=1.796e-06]
# Grid search for model.layers.1.input_layernorm:  80%|████████  | 16/20 [00:07<00:01,  2.28it/s, best_error=1.796e-06]
# Grid search for model.layers.1.input_layernorm:  85%|████████▌ | 17/20 [00:07<00:01,  2.30it/s, best_error=1.796e-06]
# Grid search for model.layers.1.input_layernorm:  85%|████████▌ | 17/20 [00:07<00:01,  2.30it/s, best_error=1.796e-06]
# Grid search for model.layers.1.input_layernorm:  90%|█████████ | 18/20 [00:07<00:00,  2.30it/s, best_error=1.796e-06]
# Grid search for model.layers.1.input_layernorm:  90%|█████████ | 18/20 [00:08<00:00,  2.30it/s, best_error=1.796e-06]
# Grid search for model.layers.1.input_layernorm:  95%|█████████▌| 19/20 [00:08<00:00,  2.08it/s, best_error=1.796e-06]
# Grid search for model.layers.1.input_layernorm:  95%|█████████▌| 19/20 [00:08<00:00,  2.08it/s, best_error=1.796e-06]
# Grid search for model.layers.1.input_layernorm: 100%|██████████| 20/20 [00:08<00:00,  2.15it/s, best_error=1.796e-06]
# Smoothing:  33%|███▎      | 1/3 [00:09<00:18,  9.32s/it]
# Grid search for model.layers.1.post_attention_layernorm:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.1.post_attention_layernorm:   0%|          | 0/20 [00:00<?, ?it/s, best_error=8.812e-04]
# Grid search for model.layers.1.post_attention_layernorm:   5%|▌         | 1/20 [00:00<00:17,  1.07it/s, best_error=8.812e-04]
# Grid search for model.layers.1.post_attention_layernorm:   5%|▌         | 1/20 [00:01<00:17,  1.07it/s, best_error=2.613e-04]
# Grid search for model.layers.1.post_attention_layernorm:  10%|█         | 2/20 [00:01<00:16,  1.09it/s, best_error=2.613e-04]
# Grid search for model.layers.1.post_attention_layernorm:  10%|█         | 2/20 [00:02<00:16,  1.09it/s, best_error=2.375e-04]
# Grid search for model.layers.1.post_attention_layernorm:  15%|█▌        | 3/20 [00:02<00:15,  1.10it/s, best_error=2.375e-04]
# Grid search for model.layers.1.post_attention_layernorm:  15%|█▌        | 3/20 [00:03<00:15,  1.10it/s, best_error=2.375e-04]
# Grid search for model.layers.1.post_attention_layernorm:  20%|██        | 4/20 [00:03<00:14,  1.10it/s, best_error=2.375e-04]
# Grid search for model.layers.1.post_attention_layernorm:  20%|██        | 4/20 [00:04<00:14,  1.10it/s, best_error=2.375e-04]
# Grid search for model.layers.1.post_attention_layernorm:  25%|██▌       | 5/20 [00:04<00:13,  1.10it/s, best_error=2.375e-04]
# Grid search for model.layers.1.post_attention_layernorm:  25%|██▌       | 5/20 [00:05<00:13,  1.10it/s, best_error=2.375e-04]
# Grid search for model.layers.1.post_attention_layernorm:  30%|███       | 6/20 [00:05<00:12,  1.09it/s, best_error=2.375e-04]
# Grid search for model.layers.1.post_attention_layernorm:  30%|███       | 6/20 [00:06<00:12,  1.09it/s, best_error=2.375e-04]
# Grid search for model.layers.1.post_attention_layernorm:  35%|███▌      | 7/20 [00:06<00:11,  1.10it/s, best_error=2.375e-04]
# Grid search for model.layers.1.post_attention_layernorm:  35%|███▌      | 7/20 [00:07<00:11,  1.10it/s, best_error=2.375e-04]
# Grid search for model.layers.1.post_attention_layernorm:  40%|████      | 8/20 [00:07<00:10,  1.10it/s, best_error=2.375e-04]
# Grid search for model.layers.1.post_attention_layernorm:  40%|████      | 8/20 [00:08<00:10,  1.10it/s, best_error=2.375e-04]
# Grid search for model.layers.1.post_attention_layernorm:  45%|████▌     | 9/20 [00:08<00:09,  1.10it/s, best_error=2.375e-04]
# Grid search for model.layers.1.post_attention_layernorm:  45%|████▌     | 9/20 [00:09<00:09,  1.10it/s, best_error=2.375e-04]
# Grid search for model.layers.1.post_attention_layernorm:  50%|█████     | 10/20 [00:09<00:09,  1.10it/s, best_error=2.375e-04]
# Grid search for model.layers.1.post_attention_layernorm:  50%|█████     | 10/20 [00:10<00:09,  1.10it/s, best_error=2.375e-04]
# Grid search for model.layers.1.post_attention_layernorm:  55%|█████▌    | 11/20 [00:10<00:08,  1.10it/s, best_error=2.375e-04]
# Grid search for model.layers.1.post_attention_layernorm:  55%|█████▌    | 11/20 [00:10<00:08,  1.10it/s, best_error=2.375e-04]
# Grid search for model.layers.1.post_attention_layernorm:  60%|██████    | 12/20 [00:10<00:07,  1.10it/s, best_error=2.375e-04]
# Grid search for model.layers.1.post_attention_layernorm:  60%|██████    | 12/20 [00:11<00:07,  1.10it/s, best_error=2.375e-04]
# Grid search for model.layers.1.post_attention_layernorm:  65%|██████▌   | 13/20 [00:11<00:06,  1.10it/s, best_error=2.375e-04]
# Grid search for model.layers.1.post_attention_layernorm:  65%|██████▌   | 13/20 [00:12<00:06,  1.10it/s, best_error=2.375e-04]
# Grid search for model.layers.1.post_attention_layernorm:  70%|███████   | 14/20 [00:12<00:05,  1.05it/s, best_error=2.375e-04]
# Grid search for model.layers.1.post_attention_layernorm:  70%|███████   | 14/20 [00:13<00:05,  1.05it/s, best_error=2.375e-04]
# Grid search for model.layers.1.post_attention_layernorm:  75%|███████▌  | 15/20 [00:13<00:04,  1.07it/s, best_error=2.375e-04]
# Grid search for model.layers.1.post_attention_layernorm:  75%|███████▌  | 15/20 [00:14<00:04,  1.07it/s, best_error=2.375e-04]
# Grid search for model.layers.1.post_attention_layernorm:  80%|████████  | 16/20 [00:14<00:03,  1.08it/s, best_error=2.375e-04]
# Grid search for model.layers.1.post_attention_layernorm:  80%|████████  | 16/20 [00:15<00:03,  1.08it/s, best_error=2.375e-04]
# Grid search for model.layers.1.post_attention_layernorm:  85%|████████▌ | 17/20 [00:15<00:02,  1.09it/s, best_error=2.375e-04]
# Grid search for model.layers.1.post_attention_layernorm:  85%|████████▌ | 17/20 [00:16<00:02,  1.09it/s, best_error=2.375e-04]
# Grid search for model.layers.1.post_attention_layernorm:  90%|█████████ | 18/20 [00:16<00:01,  1.09it/s, best_error=2.375e-04]
# Grid search for model.layers.1.post_attention_layernorm:  90%|█████████ | 18/20 [00:17<00:01,  1.09it/s, best_error=2.375e-04]
# Grid search for model.layers.1.post_attention_layernorm:  95%|█████████▌| 19/20 [00:17<00:00,  1.09it/s, best_error=2.375e-04]
# Grid search for model.layers.1.post_attention_layernorm:  95%|█████████▌| 19/20 [00:18<00:00,  1.09it/s, best_error=2.375e-04]
# Grid search for model.layers.1.post_attention_layernorm: 100%|██████████| 20/20 [00:18<00:00,  1.10it/s, best_error=2.375e-04]
# Smoothing:  67%|██████▋   | 2/3 [00:28<00:15, 15.23s/it]
# Grid search for model.layers.1.mlp.up_proj:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.1.mlp.up_proj:   0%|          | 0/20 [00:00<?, ?it/s, best_error=3.418e-03]
# Grid search for model.layers.1.mlp.up_proj:   5%|▌         | 1/20 [00:00<00:06,  3.16it/s, best_error=3.418e-03]
# Grid search for model.layers.1.mlp.up_proj:   5%|▌         | 1/20 [00:00<00:06,  3.16it/s, best_error=3.418e-03]
# Grid search for model.layers.1.mlp.up_proj:  10%|█         | 2/20 [00:00<00:05,  3.15it/s, best_error=3.418e-03]
# Grid search for model.layers.1.mlp.up_proj:  10%|█         | 2/20 [00:00<00:05,  3.15it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  15%|█▌        | 3/20 [00:00<00:05,  3.14it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  15%|█▌        | 3/20 [00:01<00:05,  3.14it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  20%|██        | 4/20 [00:01<00:05,  3.11it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  20%|██        | 4/20 [00:01<00:05,  3.11it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  25%|██▌       | 5/20 [00:01<00:05,  2.70it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  25%|██▌       | 5/20 [00:02<00:05,  2.70it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  30%|███       | 6/20 [00:02<00:04,  2.84it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  30%|███       | 6/20 [00:02<00:04,  2.84it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  35%|███▌      | 7/20 [00:02<00:04,  2.92it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  35%|███▌      | 7/20 [00:02<00:04,  2.92it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  40%|████      | 8/20 [00:02<00:04,  2.99it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  40%|████      | 8/20 [00:03<00:04,  2.99it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  45%|████▌     | 9/20 [00:03<00:03,  2.97it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  45%|████▌     | 9/20 [00:03<00:03,  2.97it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  50%|█████     | 10/20 [00:03<00:03,  2.66it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  50%|█████     | 10/20 [00:03<00:03,  2.66it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  55%|█████▌    | 11/20 [00:03<00:03,  2.79it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  55%|█████▌    | 11/20 [00:04<00:03,  2.79it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  60%|██████    | 12/20 [00:04<00:02,  2.88it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  60%|██████    | 12/20 [00:04<00:02,  2.88it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  65%|██████▌   | 13/20 [00:04<00:02,  2.95it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  65%|██████▌   | 13/20 [00:04<00:02,  2.95it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  70%|███████   | 14/20 [00:04<00:02,  3.00it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  70%|███████   | 14/20 [00:05<00:02,  3.00it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  75%|███████▌  | 15/20 [00:05<00:01,  3.04it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  75%|███████▌  | 15/20 [00:05<00:01,  3.04it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  80%|████████  | 16/20 [00:05<00:01,  3.07it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  80%|████████  | 16/20 [00:05<00:01,  3.07it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  85%|████████▌ | 17/20 [00:05<00:00,  3.09it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  85%|████████▌ | 17/20 [00:06<00:00,  3.09it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  90%|█████████ | 18/20 [00:06<00:00,  2.85it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  90%|█████████ | 18/20 [00:06<00:00,  2.85it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  95%|█████████▌| 19/20 [00:06<00:00,  2.93it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj:  95%|█████████▌| 19/20 [00:06<00:00,  2.93it/s, best_error=2.747e-03]
# Grid search for model.layers.1.mlp.up_proj: 100%|██████████| 20/20 [00:06<00:00,  2.99it/s, best_error=2.747e-03]
# Smoothing: 100%|██████████| 3/3 [00:35<00:00, 11.93s/it]
# (2/29): Propagating: 100%|██████████| 64/64 [00:01<00:00, 35.97it/s]
# (3/29): Calibrating: 100%|██████████| 64/64 [00:01<00:00, 38.84it/s]
# Smoothing:   0%|          | 0/3 [00:00<?, ?it/s]
# Grid search for model.layers.2.input_layernorm:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.2.input_layernorm:   0%|          | 0/20 [00:00<?, ?it/s, best_error=4.798e-06]
# Grid search for model.layers.2.input_layernorm:   5%|▌         | 1/20 [00:00<00:08,  2.27it/s, best_error=4.798e-06]
# Grid search for model.layers.2.input_layernorm:   5%|▌         | 1/20 [00:00<00:08,  2.27it/s, best_error=4.262e-06]
# Grid search for model.layers.2.input_layernorm:  10%|█         | 2/20 [00:00<00:07,  2.31it/s, best_error=4.262e-06]
# Grid search for model.layers.2.input_layernorm:  10%|█         | 2/20 [00:01<00:07,  2.31it/s, best_error=4.262e-06]
# Grid search for model.layers.2.input_layernorm:  15%|█▌        | 3/20 [00:01<00:07,  2.32it/s, best_error=4.262e-06]
# Grid search for model.layers.2.input_layernorm:  15%|█▌        | 3/20 [00:01<00:07,  2.32it/s, best_error=3.874e-06]
# Grid search for model.layers.2.input_layernorm:  20%|██        | 4/20 [00:01<00:06,  2.30it/s, best_error=3.874e-06]
# Grid search for model.layers.2.input_layernorm:  20%|██        | 4/20 [00:02<00:06,  2.30it/s, best_error=3.874e-06]
# Grid search for model.layers.2.input_layernorm:  25%|██▌       | 5/20 [00:02<00:06,  2.31it/s, best_error=3.874e-06]
# Grid search for model.layers.2.input_layernorm:  25%|██▌       | 5/20 [00:02<00:06,  2.31it/s, best_error=3.844e-06]
# Grid search for model.layers.2.input_layernorm:  30%|███       | 6/20 [00:02<00:06,  2.31it/s, best_error=3.844e-06]
# Grid search for model.layers.2.input_layernorm:  30%|███       | 6/20 [00:03<00:06,  2.31it/s, best_error=3.770e-06]
# Grid search for model.layers.2.input_layernorm:  35%|███▌      | 7/20 [00:03<00:05,  2.31it/s, best_error=3.770e-06]
# Grid search for model.layers.2.input_layernorm:  35%|███▌      | 7/20 [00:03<00:05,  2.31it/s, best_error=3.770e-06]
# Grid search for model.layers.2.input_layernorm:  40%|████      | 8/20 [00:03<00:05,  2.11it/s, best_error=3.770e-06]
# Grid search for model.layers.2.input_layernorm:  40%|████      | 8/20 [00:04<00:05,  2.11it/s, best_error=3.770e-06]
# Grid search for model.layers.2.input_layernorm:  45%|████▌     | 9/20 [00:04<00:05,  2.16it/s, best_error=3.770e-06]
# Grid search for model.layers.2.input_layernorm:  45%|████▌     | 9/20 [00:04<00:05,  2.16it/s, best_error=3.770e-06]
# Grid search for model.layers.2.input_layernorm:  50%|█████     | 10/20 [00:04<00:04,  2.21it/s, best_error=3.770e-06]
# Grid search for model.layers.2.input_layernorm:  50%|█████     | 10/20 [00:04<00:04,  2.21it/s, best_error=3.770e-06]
# Grid search for model.layers.2.input_layernorm:  55%|█████▌    | 11/20 [00:04<00:03,  2.25it/s, best_error=3.770e-06]
# Grid search for model.layers.2.input_layernorm:  55%|█████▌    | 11/20 [00:05<00:03,  2.25it/s, best_error=3.770e-06]
# Grid search for model.layers.2.input_layernorm:  60%|██████    | 12/20 [00:05<00:03,  2.28it/s, best_error=3.770e-06]
# Grid search for model.layers.2.input_layernorm:  60%|██████    | 12/20 [00:05<00:03,  2.28it/s, best_error=3.770e-06]
# Grid search for model.layers.2.input_layernorm:  65%|██████▌   | 13/20 [00:05<00:03,  2.29it/s, best_error=3.770e-06]
# Grid search for model.layers.2.input_layernorm:  65%|██████▌   | 13/20 [00:06<00:03,  2.29it/s, best_error=3.770e-06]
# Grid search for model.layers.2.input_layernorm:  70%|███████   | 14/20 [00:06<00:02,  2.30it/s, best_error=3.770e-06]
# Grid search for model.layers.2.input_layernorm:  70%|███████   | 14/20 [00:06<00:02,  2.30it/s, best_error=3.770e-06]
# Grid search for model.layers.2.input_layernorm:  75%|███████▌  | 15/20 [00:06<00:02,  2.31it/s, best_error=3.770e-06]
# Grid search for model.layers.2.input_layernorm:  75%|███████▌  | 15/20 [00:07<00:02,  2.31it/s, best_error=3.770e-06]
# Grid search for model.layers.2.input_layernorm:  80%|████████  | 16/20 [00:07<00:01,  2.31it/s, best_error=3.770e-06]
# Grid search for model.layers.2.input_layernorm:  80%|████████  | 16/20 [00:07<00:01,  2.31it/s, best_error=3.770e-06]
# Grid search for model.layers.2.input_layernorm:  85%|████████▌ | 17/20 [00:07<00:01,  2.32it/s, best_error=3.770e-06]
# Grid search for model.layers.2.input_layernorm:  85%|████████▌ | 17/20 [00:07<00:01,  2.32it/s, best_error=3.770e-06]
# Grid search for model.layers.2.input_layernorm:  90%|█████████ | 18/20 [00:07<00:00,  2.32it/s, best_error=3.770e-06]
# Grid search for model.layers.2.input_layernorm:  90%|█████████ | 18/20 [00:08<00:00,  2.32it/s, best_error=3.770e-06]
# Grid search for model.layers.2.input_layernorm:  95%|█████████▌| 19/20 [00:08<00:00,  2.32it/s, best_error=3.770e-06]
# Grid search for model.layers.2.input_layernorm:  95%|█████████▌| 19/20 [00:08<00:00,  2.32it/s, best_error=3.770e-06]
# Grid search for model.layers.2.input_layernorm: 100%|██████████| 20/20 [00:08<00:00,  2.33it/s, best_error=3.770e-06]
# Smoothing:  33%|███▎      | 1/3 [00:09<00:18,  9.18s/it]
# Grid search for model.layers.2.post_attention_layernorm:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.2.post_attention_layernorm:   0%|          | 0/20 [00:00<?, ?it/s, best_error=1.436e-05]
# Grid search for model.layers.2.post_attention_layernorm:   5%|▌         | 1/20 [00:00<00:17,  1.11it/s, best_error=1.436e-05]
# Grid search for model.layers.2.post_attention_layernorm:   5%|▌         | 1/20 [00:01<00:17,  1.11it/s, best_error=1.383e-05]
# Grid search for model.layers.2.post_attention_layernorm:  10%|█         | 2/20 [00:01<00:16,  1.11it/s, best_error=1.383e-05]
# Grid search for model.layers.2.post_attention_layernorm:  10%|█         | 2/20 [00:02<00:16,  1.11it/s, best_error=1.365e-05]
# Grid search for model.layers.2.post_attention_layernorm:  15%|█▌        | 3/20 [00:02<00:15,  1.07it/s, best_error=1.365e-05]
# Grid search for model.layers.2.post_attention_layernorm:  15%|█▌        | 3/20 [00:03<00:15,  1.07it/s, best_error=1.305e-05]
# Grid search for model.layers.2.post_attention_layernorm:  20%|██        | 4/20 [00:03<00:14,  1.09it/s, best_error=1.305e-05]
# Grid search for model.layers.2.post_attention_layernorm:  20%|██        | 4/20 [00:04<00:14,  1.09it/s, best_error=1.281e-05]
# Grid search for model.layers.2.post_attention_layernorm:  25%|██▌       | 5/20 [00:04<00:13,  1.09it/s, best_error=1.281e-05]
# Grid search for model.layers.2.post_attention_layernorm:  25%|██▌       | 5/20 [00:05<00:13,  1.09it/s, best_error=1.246e-05]
# Grid search for model.layers.2.post_attention_layernorm:  30%|███       | 6/20 [00:05<00:13,  1.08it/s, best_error=1.246e-05]
# Grid search for model.layers.2.post_attention_layernorm:  30%|███       | 6/20 [00:06<00:13,  1.08it/s, best_error=1.222e-05]
# Grid search for model.layers.2.post_attention_layernorm:  35%|███▌      | 7/20 [00:06<00:11,  1.09it/s, best_error=1.222e-05]
# Grid search for model.layers.2.post_attention_layernorm:  35%|███▌      | 7/20 [00:07<00:11,  1.09it/s, best_error=1.198e-05]
# Grid search for model.layers.2.post_attention_layernorm:  40%|████      | 8/20 [00:07<00:10,  1.09it/s, best_error=1.198e-05]
# Grid search for model.layers.2.post_attention_layernorm:  40%|████      | 8/20 [00:08<00:10,  1.09it/s, best_error=1.192e-05]
# Grid search for model.layers.2.post_attention_layernorm:  45%|████▌     | 9/20 [00:08<00:10,  1.07it/s, best_error=1.192e-05]
# Grid search for model.layers.2.post_attention_layernorm:  45%|████▌     | 9/20 [00:09<00:10,  1.07it/s, best_error=1.192e-05]
# Grid search for model.layers.2.post_attention_layernorm:  50%|█████     | 10/20 [00:09<00:09,  1.08it/s, best_error=1.192e-05]
# Grid search for model.layers.2.post_attention_layernorm:  50%|█████     | 10/20 [00:10<00:09,  1.08it/s, best_error=1.168e-05]
# Grid search for model.layers.2.post_attention_layernorm:  55%|█████▌    | 11/20 [00:10<00:08,  1.09it/s, best_error=1.168e-05]
# Grid search for model.layers.2.post_attention_layernorm:  55%|█████▌    | 11/20 [00:11<00:08,  1.09it/s, best_error=1.168e-05]
# Grid search for model.layers.2.post_attention_layernorm:  60%|██████    | 12/20 [00:11<00:07,  1.09it/s, best_error=1.168e-05]
# Grid search for model.layers.2.post_attention_layernorm:  60%|██████    | 12/20 [00:11<00:07,  1.09it/s, best_error=1.168e-05]
# Grid search for model.layers.2.post_attention_layernorm:  65%|██████▌   | 13/20 [00:11<00:06,  1.09it/s, best_error=1.168e-05]
# Grid search for model.layers.2.post_attention_layernorm:  65%|██████▌   | 13/20 [00:12<00:06,  1.09it/s, best_error=1.168e-05]
# Grid search for model.layers.2.post_attention_layernorm:  70%|███████   | 14/20 [00:12<00:05,  1.10it/s, best_error=1.168e-05]
# Grid search for model.layers.2.post_attention_layernorm:  70%|███████   | 14/20 [00:13<00:05,  1.10it/s, best_error=1.168e-05]
# ...
# Grid search for model.layers.8.mlp.up_proj:  50%|█████     | 10/20 [00:03<00:03,  3.09it/s, best_error=4.506e-05]
# Grid search for model.layers.8.mlp.up_proj:  50%|█████     | 10/20 [00:03<00:03,  3.09it/s, best_error=4.506e-05]
# Grid search for model.layers.8.mlp.up_proj:  55%|█████▌    | 11/20 [00:03<00:02,  3.10it/s, best_error=4.506e-05]
# Grid search for model.layers.8.mlp.up_proj:  55%|█████▌    | 11/20 [00:03<00:02,  3.10it/s, best_error=4.506e-05]
# Grid search for model.layers.8.mlp.up_proj:  60%|██████    | 12/20 [00:03<00:02,  3.03it/s, best_error=4.506e-05]
# Grid search for model.layers.8.mlp.up_proj:  60%|██████    | 12/20 [00:04<00:02,  3.03it/s, best_error=4.506e-05]
# Grid search for model.layers.8.mlp.up_proj:  65%|██████▌   | 13/20 [00:04<00:02,  3.07it/s, best_error=4.506e-05]
# Grid search for model.layers.8.mlp.up_proj:  65%|██████▌   | 13/20 [00:04<00:02,  3.07it/s, best_error=4.506e-05]
# Grid search for model.layers.8.mlp.up_proj:  70%|███████   | 14/20 [00:04<00:01,  3.09it/s, best_error=4.506e-05]
# Grid search for model.layers.8.mlp.up_proj:  70%|███████   | 14/20 [00:04<00:01,  3.09it/s, best_error=4.506e-05]
# Grid search for model.layers.8.mlp.up_proj:  75%|███████▌  | 15/20 [00:04<00:01,  3.11it/s, best_error=4.506e-05]
# Grid search for model.layers.8.mlp.up_proj:  75%|███████▌  | 15/20 [00:05<00:01,  3.11it/s, best_error=4.506e-05]
# Grid search for model.layers.8.mlp.up_proj:  80%|████████  | 16/20 [00:05<00:01,  3.08it/s, best_error=4.506e-05]
# Grid search for model.layers.8.mlp.up_proj:  80%|████████  | 16/20 [00:05<00:01,  3.08it/s, best_error=4.506e-05]
# Grid search for model.layers.8.mlp.up_proj:  85%|████████▌ | 17/20 [00:05<00:01,  2.83it/s, best_error=4.506e-05]
# Grid search for model.layers.8.mlp.up_proj:  85%|████████▌ | 17/20 [00:05<00:01,  2.83it/s, best_error=4.506e-05]
# Grid search for model.layers.8.mlp.up_proj:  90%|█████████ | 18/20 [00:05<00:00,  2.87it/s, best_error=4.506e-05]
# Grid search for model.layers.8.mlp.up_proj:  90%|█████████ | 18/20 [00:06<00:00,  2.87it/s, best_error=4.506e-05]
# Grid search for model.layers.8.mlp.up_proj:  95%|█████████▌| 19/20 [00:06<00:00,  2.95it/s, best_error=4.506e-05]
# Grid search for model.layers.8.mlp.up_proj:  95%|█████████▌| 19/20 [00:06<00:00,  2.95it/s, best_error=4.506e-05]
# Grid search for model.layers.8.mlp.up_proj: 100%|██████████| 20/20 [00:06<00:00,  3.00it/s, best_error=4.506e-05]
# Smoothing: 100%|██████████| 3/3 [00:35<00:00, 11.73s/it]
# (9/29): Propagating: 100%|██████████| 64/64 [00:01<00:00, 39.46it/s]
# (10/29): Calibrating: 100%|██████████| 64/64 [00:01<00:00, 35.75it/s]
# Smoothing:   0%|          | 0/3 [00:00<?, ?it/s]
# Grid search for model.layers.9.input_layernorm:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.9.input_layernorm:   0%|          | 0/20 [00:00<?, ?it/s, best_error=3.266e-05]
# Grid search for model.layers.9.input_layernorm:   5%|▌         | 1/20 [00:00<00:08,  2.35it/s, best_error=3.266e-05]
# Grid search for model.layers.9.input_layernorm:   5%|▌         | 1/20 [00:00<00:08,  2.35it/s, best_error=3.123e-05]
# Grid search for model.layers.9.input_layernorm:  10%|█         | 2/20 [00:00<00:07,  2.34it/s, best_error=3.123e-05]
# Grid search for model.layers.9.input_layernorm:  10%|█         | 2/20 [00:01<00:07,  2.34it/s, best_error=3.123e-05]
# Grid search for model.layers.9.input_layernorm:  15%|█▌        | 3/20 [00:01<00:07,  2.34it/s, best_error=3.123e-05]
# Grid search for model.layers.9.input_layernorm:  15%|█▌        | 3/20 [00:01<00:07,  2.34it/s, best_error=3.123e-05]
# Grid search for model.layers.9.input_layernorm:  20%|██        | 4/20 [00:01<00:06,  2.34it/s, best_error=3.123e-05]
# Grid search for model.layers.9.input_layernorm:  20%|██        | 4/20 [00:02<00:06,  2.34it/s, best_error=3.123e-05]
# Grid search for model.layers.9.input_layernorm:  25%|██▌       | 5/20 [00:02<00:06,  2.34it/s, best_error=3.123e-05]
# Grid search for model.layers.9.input_layernorm:  25%|██▌       | 5/20 [00:02<00:06,  2.34it/s, best_error=3.099e-05]
# Grid search for model.layers.9.input_layernorm:  30%|███       | 6/20 [00:02<00:05,  2.34it/s, best_error=3.099e-05]
# Grid search for model.layers.9.input_layernorm:  30%|███       | 6/20 [00:02<00:05,  2.34it/s, best_error=3.099e-05]
# Grid search for model.layers.9.input_layernorm:  35%|███▌      | 7/20 [00:02<00:05,  2.33it/s, best_error=3.099e-05]
# Grid search for model.layers.9.input_layernorm:  35%|███▌      | 7/20 [00:03<00:05,  2.33it/s, best_error=3.099e-05]
# Grid search for model.layers.9.input_layernorm:  40%|████      | 8/20 [00:03<00:05,  2.33it/s, best_error=3.099e-05]
# Grid search for model.layers.9.input_layernorm:  40%|████      | 8/20 [00:03<00:05,  2.33it/s, best_error=3.099e-05]
# Grid search for model.layers.9.input_layernorm:  45%|████▌     | 9/20 [00:03<00:04,  2.33it/s, best_error=3.099e-05]
# Grid search for model.layers.9.input_layernorm:  45%|████▌     | 9/20 [00:04<00:04,  2.33it/s, best_error=3.099e-05]
# Grid search for model.layers.9.input_layernorm:  50%|█████     | 10/20 [00:04<00:04,  2.33it/s, best_error=3.099e-05]
# Grid search for model.layers.9.input_layernorm:  50%|█████     | 10/20 [00:04<00:04,  2.33it/s, best_error=3.099e-05]
# Grid search for model.layers.9.input_layernorm:  55%|█████▌    | 11/20 [00:04<00:03,  2.34it/s, best_error=3.099e-05]
# Grid search for model.layers.9.input_layernorm:  55%|█████▌    | 11/20 [00:05<00:03,  2.34it/s, best_error=3.099e-05]
# Grid search for model.layers.9.input_layernorm:  60%|██████    | 12/20 [00:05<00:03,  2.34it/s, best_error=3.099e-05]
# Grid search for model.layers.9.input_layernorm:  60%|██████    | 12/20 [00:05<00:03,  2.34it/s, best_error=3.099e-05]
# Grid search for model.layers.9.input_layernorm:  65%|██████▌   | 13/20 [00:05<00:02,  2.34it/s, best_error=3.099e-05]
# Grid search for model.layers.9.input_layernorm:  65%|██████▌   | 13/20 [00:05<00:02,  2.34it/s, best_error=3.099e-05]
# Grid search for model.layers.9.input_layernorm:  70%|███████   | 14/20 [00:06<00:02,  2.32it/s, best_error=3.099e-05]
# Grid search for model.layers.9.input_layernorm:  70%|███████   | 14/20 [00:06<00:02,  2.32it/s, best_error=3.099e-05]
# Grid search for model.layers.9.input_layernorm:  75%|███████▌  | 15/20 [00:06<00:02,  2.33it/s, best_error=3.099e-05]
# Grid search for model.layers.9.input_layernorm:  75%|███████▌  | 15/20 [00:06<00:02,  2.33it/s, best_error=3.099e-05]
# Grid search for model.layers.9.input_layernorm:  80%|████████  | 16/20 [00:06<00:01,  2.33it/s, best_error=3.099e-05]
# Grid search for model.layers.9.input_layernorm:  80%|████████  | 16/20 [00:07<00:01,  2.33it/s, best_error=3.099e-05]
# Grid search for model.layers.9.input_layernorm:  85%|████████▌ | 17/20 [00:07<00:01,  2.33it/s, best_error=3.099e-05]
# Grid search for model.layers.9.input_layernorm:  85%|████████▌ | 17/20 [00:07<00:01,  2.33it/s, best_error=3.099e-05]
# Grid search for model.layers.9.input_layernorm:  90%|█████████ | 18/20 [00:07<00:00,  2.33it/s, best_error=3.099e-05]
# Grid search for model.layers.9.input_layernorm:  90%|█████████ | 18/20 [00:08<00:00,  2.33it/s, best_error=3.099e-05]
# Grid search for model.layers.9.input_layernorm:  95%|█████████▌| 19/20 [00:08<00:00,  2.34it/s, best_error=3.099e-05]
# Grid search for model.layers.9.input_layernorm:  95%|█████████▌| 19/20 [00:08<00:00,  2.34it/s, best_error=3.099e-05]
# Grid search for model.layers.9.input_layernorm: 100%|██████████| 20/20 [00:08<00:00,  2.34it/s, best_error=3.099e-05]
# Smoothing:  33%|███▎      | 1/3 [00:09<00:18,  9.01s/it]
# Grid search for model.layers.9.post_attention_layernorm:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.9.post_attention_layernorm:   0%|          | 0/20 [00:00<?, ?it/s, best_error=5.507e-05]
# Grid search for model.layers.9.post_attention_layernorm:   5%|▌         | 1/20 [00:00<00:17,  1.08it/s, best_error=5.507e-05]
# Grid search for model.layers.9.post_attention_layernorm:   5%|▌         | 1/20 [00:01<00:17,  1.08it/s, best_error=5.436e-05]
# Grid search for model.layers.9.post_attention_layernorm:  10%|█         | 2/20 [00:01<00:16,  1.07it/s, best_error=5.436e-05]
# Grid search for model.layers.9.post_attention_layernorm:  10%|█         | 2/20 [00:02<00:16,  1.07it/s, best_error=5.436e-05]
# Grid search for model.layers.9.post_attention_layernorm:  15%|█▌        | 3/20 [00:02<00:15,  1.08it/s, best_error=5.436e-05]
# Grid search for model.layers.9.post_attention_layernorm:  15%|█▌        | 3/20 [00:03<00:15,  1.08it/s, best_error=5.436e-05]
# Grid search for model.layers.9.post_attention_layernorm:  20%|██        | 4/20 [00:03<00:14,  1.09it/s, best_error=5.436e-05]
# Grid search for model.layers.9.post_attention_layernorm:  20%|██        | 4/20 [00:04<00:14,  1.09it/s, best_error=5.436e-05]
# Grid search for model.layers.9.post_attention_layernorm:  25%|██▌       | 5/20 [00:04<00:14,  1.04it/s, best_error=5.436e-05]
# Grid search for model.layers.9.post_attention_layernorm:  25%|██▌       | 5/20 [00:05<00:14,  1.04it/s, best_error=5.436e-05]
# Grid search for model.layers.9.post_attention_layernorm:  30%|███       | 6/20 [00:05<00:13,  1.06it/s, best_error=5.436e-05]
# Grid search for model.layers.9.post_attention_layernorm:  30%|███       | 6/20 [00:06<00:13,  1.06it/s, best_error=5.436e-05]
# Grid search for model.layers.9.post_attention_layernorm:  35%|███▌      | 7/20 [00:06<00:12,  1.07it/s, best_error=5.436e-05]
# Grid search for model.layers.9.post_attention_layernorm:  35%|███▌      | 7/20 [00:07<00:12,  1.07it/s, best_error=5.436e-05]
# Grid search for model.layers.9.post_attention_layernorm:  40%|████      | 8/20 [00:07<00:11,  1.08it/s, best_error=5.436e-05]
# Grid search for model.layers.9.post_attention_layernorm:  40%|████      | 8/20 [00:08<00:11,  1.08it/s, best_error=5.436e-05]
# Grid search for model.layers.9.post_attention_layernorm:  45%|████▌     | 9/20 [00:08<00:10,  1.09it/s, best_error=5.436e-05]
# Grid search for model.layers.9.post_attention_layernorm:  45%|████▌     | 9/20 [00:09<00:10,  1.09it/s, best_error=5.436e-05]
# Grid search for model.layers.9.post_attention_layernorm:  50%|█████     | 10/20 [00:09<00:09,  1.09it/s, best_error=5.436e-05]
# Grid search for model.layers.9.post_attention_layernorm:  50%|█████     | 10/20 [00:10<00:09,  1.09it/s, best_error=5.436e-05]
# Grid search for model.layers.9.post_attention_layernorm:  55%|█████▌    | 11/20 [00:10<00:08,  1.10it/s, best_error=5.436e-05]
# Grid search for model.layers.9.post_attention_layernorm:  55%|█████▌    | 11/20 [00:11<00:08,  1.10it/s, best_error=5.436e-05]
# Grid search for model.layers.9.post_attention_layernorm:  60%|██████    | 12/20 [00:11<00:07,  1.10it/s, best_error=5.436e-05]
# Grid search for model.layers.9.post_attention_layernorm:  60%|██████    | 12/20 [00:11<00:07,  1.10it/s, best_error=5.436e-05]
# Grid search for model.layers.9.post_attention_layernorm:  65%|██████▌   | 13/20 [00:11<00:06,  1.10it/s, best_error=5.436e-05]
# Grid search for model.layers.9.post_attention_layernorm:  65%|██████▌   | 13/20 [00:12<00:06,  1.10it/s, best_error=5.436e-05]
# Grid search for model.layers.9.post_attention_layernorm:  70%|███████   | 14/20 [00:12<00:05,  1.10it/s, best_error=5.436e-05]
# Grid search for model.layers.9.post_attention_layernorm:  70%|███████   | 14/20 [00:13<00:05,  1.10it/s, best_error=5.436e-05]
# Grid search for model.layers.9.post_attention_layernorm:  75%|███████▌  | 15/20 [00:13<00:04,  1.10it/s, best_error=5.436e-05]
# Grid search for model.layers.9.post_attention_layernorm:  75%|███████▌  | 15/20 [00:14<00:04,  1.10it/s, best_error=5.436e-05]
# Grid search for model.layers.9.post_attention_layernorm:  80%|████████  | 16/20 [00:14<00:03,  1.11it/s, best_error=5.436e-05]
# Grid search for model.layers.9.post_attention_layernorm:  80%|████████  | 16/20 [00:15<00:03,  1.11it/s, best_error=5.436e-05]
# Grid search for model.layers.9.post_attention_layernorm:  85%|████████▌ | 17/20 [00:15<00:02,  1.10it/s, best_error=5.436e-05]
# Grid search for model.layers.9.post_attention_layernorm:  85%|████████▌ | 17/20 [00:16<00:02,  1.10it/s, best_error=5.436e-05]
# Grid search for model.layers.9.post_attention_layernorm:  90%|█████████ | 18/20 [00:16<00:01,  1.10it/s, best_error=5.436e-05]
# Grid search for model.layers.9.post_attention_layernorm:  90%|█████████ | 18/20 [00:17<00:01,  1.10it/s, best_error=5.436e-05]
# Grid search for model.layers.9.post_attention_layernorm:  95%|█████████▌| 19/20 [00:17<00:00,  1.09it/s, best_error=5.436e-05]
# Grid search for model.layers.9.post_attention_layernorm:  95%|█████████▌| 19/20 [00:18<00:00,  1.09it/s, best_error=5.436e-05]
# Grid search for model.layers.9.post_attention_layernorm: 100%|██████████| 20/20 [00:18<00:00,  1.09it/s, best_error=5.436e-05]
# Smoothing:  67%|██████▋   | 2/3 [00:28<00:15, 15.04s/it]
# Grid search for model.layers.9.mlp.up_proj:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.9.mlp.up_proj:   0%|          | 0/20 [00:00<?, ?it/s, best_error=4.864e-05]
# Grid search for model.layers.9.mlp.up_proj:   5%|▌         | 1/20 [00:00<00:06,  3.16it/s, best_error=4.864e-05]
# Grid search for model.layers.9.mlp.up_proj:   5%|▌         | 1/20 [00:00<00:06,  3.16it/s, best_error=4.792e-05]
# Grid search for model.layers.9.mlp.up_proj:  10%|█         | 2/20 [00:00<00:05,  3.15it/s, best_error=4.792e-05]
# Grid search for model.layers.9.mlp.up_proj:  10%|█         | 2/20 [00:00<00:05,  3.15it/s, best_error=4.768e-05]
# Grid search for model.layers.9.mlp.up_proj:  15%|█▌        | 3/20 [00:00<00:05,  3.15it/s, best_error=4.768e-05]
# Grid search for model.layers.9.mlp.up_proj:  15%|█▌        | 3/20 [00:01<00:05,  3.15it/s, best_error=4.697e-05]
# Grid search for model.layers.9.mlp.up_proj:  20%|██        | 4/20 [00:01<00:05,  3.14it/s, best_error=4.697e-05]
# Grid search for model.layers.9.mlp.up_proj:  20%|██        | 4/20 [00:01<00:05,  3.14it/s, best_error=4.673e-05]
# Grid search for model.layers.9.mlp.up_proj:  25%|██▌       | 5/20 [00:01<00:04,  3.14it/s, best_error=4.673e-05]
# Grid search for model.layers.9.mlp.up_proj:  25%|██▌       | 5/20 [00:01<00:04,  3.14it/s, best_error=4.673e-05]
# Grid search for model.layers.9.mlp.up_proj:  30%|███       | 6/20 [00:01<00:04,  3.14it/s, best_error=4.673e-05]
# Grid search for model.layers.9.mlp.up_proj:  30%|███       | 6/20 [00:02<00:04,  3.14it/s, best_error=4.673e-05]
# Grid search for model.layers.9.mlp.up_proj:  35%|███▌      | 7/20 [00:02<00:04,  3.13it/s, best_error=4.673e-05]
# Grid search for model.layers.9.mlp.up_proj:  35%|███▌      | 7/20 [00:02<00:04,  3.13it/s, best_error=4.673e-05]
# Grid search for model.layers.9.mlp.up_proj:  40%|████      | 8/20 [00:02<00:03,  3.10it/s, best_error=4.673e-05]
# Grid search for model.layers.9.mlp.up_proj:  40%|████      | 8/20 [00:02<00:03,  3.10it/s, best_error=4.673e-05]
# Grid search for model.layers.9.mlp.up_proj:  45%|████▌     | 9/20 [00:02<00:03,  3.11it/s, best_error=4.673e-05]
# Grid search for model.layers.9.mlp.up_proj:  45%|████▌     | 9/20 [00:03<00:03,  3.11it/s, best_error=4.673e-05]
# Grid search for model.layers.9.mlp.up_proj:  50%|█████     | 10/20 [00:03<00:03,  3.12it/s, best_error=4.673e-05]
# Grid search for model.layers.9.mlp.up_proj:  50%|█████     | 10/20 [00:03<00:03,  3.12it/s, best_error=4.673e-05]
# Grid search for model.layers.9.mlp.up_proj:  55%|█████▌    | 11/20 [00:03<00:03,  2.81it/s, best_error=4.673e-05]
# Grid search for model.layers.9.mlp.up_proj:  55%|█████▌    | 11/20 [00:03<00:03,  2.81it/s, best_error=4.673e-05]
# Grid search for model.layers.9.mlp.up_proj:  60%|██████    | 12/20 [00:03<00:02,  2.91it/s, best_error=4.673e-05]
# Grid search for model.layers.9.mlp.up_proj:  60%|██████    | 12/20 [00:04<00:02,  2.91it/s, best_error=4.673e-05]
# Grid search for model.layers.9.mlp.up_proj:  65%|██████▌   | 13/20 [00:04<00:02,  2.97it/s, best_error=4.673e-05]

# %% [markdown]
# **Saving**

# %%
model.config._name_or_path = ""

model.save_pretrained(OUTPUT_DIR,skip_sparsity_compression_stats=False)#VERY IMPORTANT
tokenizer.save_pretrained(OUTPUT_DIR)

print("Model saved successfully")

# %% [markdown]
# # PUSH TO HUGGING FACE

# %%
create_repo(REPO_ID, repo_type="model", exist_ok=True)

upload_folder(
    folder_path=OUTPUT_DIR,
    repo_id=REPO_ID,
    path_in_repo="Sparsity/25"
)
