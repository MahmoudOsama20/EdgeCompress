# %% [markdown]
# # Libraries

# %%
# !pip install -q -U llmcompressor datasets accelerate transformers huggingface_hub
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.5/295.5 kB 13.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.5/196.5 kB 15.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 520.7/520.7 kB 27.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 70.2 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 34.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 563.6/563.6 kB 20.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 MB 38.1 MB/s eta 0:00:00:00:0100:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.31.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# google-adk 1.21.0 requires google-cloud-bigquery-storage>=2.0.0, which is not installed.

# %%
import random
import numpy as np
import torch

from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    set_seed,
)

from llmcompressor import oneshot
from llmcompressor.modifiers.awq import AWQModifier

from huggingface_hub import (
    login,
    create_repo,
    upload_folder,
)

from kaggle_secrets import UserSecretsClient
from datasets import load_dataset
# Out:
# 2026-03-19 03:54:37.869176: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773892478.046941      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773892478.101256      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773892478.522827      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773892478.522864      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773892478.522866      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773892478.522868      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %% [markdown]
# # Global Variables

# %%
MODEL_ID = "Qwen/Qwen3-4B"
OUTPUT_DIR = "/kaggle/working/Qwen3-4B-AWQ-4bit"
REPO_ID = f"EdgeCompress01/Qwen3-4B-AWQ-4bit"
SEED = 42

# %% [markdown]
# # Functions

# %%
# --- 2. REPRODUCIBILITY ---
def set_reproducibility(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    set_seed(seed)
    # Ensure deterministic behavior in CuDNN
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    print(f"Global seed set to {seed}")

def format_chat(batch):
    texts = [
        tokenizer.apply_chat_template(
            messages,
            tokenize=False,
            add_generation_prompt=False
        )
        for messages in batch["messages"]
    ]
    return {"text": texts}

# %% [markdown]
# # Set Seed

# %%
set_reproducibility(SEED)
# Out:
# Global seed set to 42

# %% [markdown]
# # Huggingface Login

# %%
# --- 3. HUGGING FACE AUTHENTICATION ---
print("Logging into Hugging Face...")
user_secrets = UserSecretsClient()
hf_token = user_secrets.get_secret("HF_TOKEN")
login(token=hf_token)
# Out:
# Logging into Hugging Face...

# %% [markdown]
# # Load Model & Tokenizer

# %%
#Model
model = AutoModelForCausalLM.from_pretrained(
    MODEL_ID,
    device_map="auto",
    dtype=torch.bfloat16
)

#Tokenizer
tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen3-4B")
# Out:
# config.json:   0%|          | 0.00/726 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/3.99G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/3.96G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/99.6M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]

# %% [markdown]
# # AWQ Quantization

# %% [markdown]
# **Configurations**

# %%
recipe = [
    AWQModifier(
        ignore=["lm_head", "embed_tokens"], 
        scheme="W4A16",
        targets=["Linear"]
    )
]

# %% [markdown]
# **Calibration Dataset**

# %%
dataset = load_dataset("HuggingFaceH4/ultrachat_200k", split="train_sft").shuffle(seed=SEED).select(range(64))

formatted_dataset = dataset.map(
    format_chat,
    batched=True,
    remove_columns=dataset.column_names  # keep only "text"
)
# Out:
# README.md: 0.00B [00:00, ?B/s]
# data/train_sft-00000-of-00003-a3ecf92756(…):   0%|          | 0.00/244M [00:00<?, ?B/s]
# data/train_sft-00001-of-00003-0a1804bcb6(…):   0%|          | 0.00/244M [00:00<?, ?B/s]
# data/train_sft-00002-of-00003-ee46ed25cf(…):   0%|          | 0.00/244M [00:00<?, ?B/s]
# data/test_sft-00000-of-00001-f7dfac4afe5(…):   0%|          | 0.00/81.2M [00:00<?, ?B/s]
# data/train_gen-00000-of-00003-a6c9fb894b(…):   0%|          | 0.00/244M [00:00<?, ?B/s]
# data/train_gen-00001-of-00003-d6a0402e41(…):   0%|          | 0.00/243M [00:00<?, ?B/s]
# data/train_gen-00002-of-00003-c0db75b92a(…):   0%|          | 0.00/243M [00:00<?, ?B/s]
# data/test_gen-00000-of-00001-3d4cd830914(…):   0%|          | 0.00/80.4M [00:00<?, ?B/s]
# Generating train_sft split:   0%|          | 0/207865 [00:00<?, ? examples/s]
# Generating test_sft split:   0%|          | 0/23110 [00:00<?, ? examples/s]
# Generating train_gen split:   0%|          | 0/256032 [00:00<?, ? examples/s]
# Generating test_gen split:   0%|          | 0/28304 [00:00<?, ? examples/s]
# Map:   0%|          | 0/64 [00:00<?, ? examples/s]

# %% [markdown]
# **Apply quantization**

# %%
oneshot(
    model=model,
    tokenizer=tokenizer,
    dataset=formatted_dataset,
    text_column="text",
    recipe=recipe,
    max_seq_length=512
)
# Out:
# 2026-03-19T03:56:30.984247+0000 | __init__ | WARNING - Disabling tokenizer parallelism due to threading conflict between FastTokenizer and Datasets. Set TOKENIZERS_PARALLELISM=false to suppress this warning.
# Tokenizing:   0%|          | 0/64 [00:00<?, ? examples/s]
# 2026-03-19T03:56:31.386399+0000 | _make_sampler | WARNING - Requested 512 samples but the provided dataset only has 64 samples.
# 2026-03-19T03:56:31.387496+0000 | reset | INFO - Compression lifecycle reset
# 2026-03-19T03:56:31.389898+0000 | from_modifiers | INFO - Creating recipe from modifiers
# 2026-03-19T03:56:31.469325+0000 | on_initialize | INFO - No AWQModifier.mappings provided, inferring from model...
# 2026-03-19T03:56:31.482146+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.0.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-19T03:56:31.482826+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.1.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-19T03:56:31.483579+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.2.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-19T03:56:31.484402+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.3.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-19T03:56:31.485249+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.4.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-19T03:56:31.486213+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.5.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-19T03:56:31.486984+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.6.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-19T03:56:31.487795+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.7.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-19T03:56:31.488628+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.8.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-19T03:56:31.489425+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.9.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-19T03:56:31.490226+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.10.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-19T03:56:31.491035+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.11.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-19T03:56:31.491845+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.12.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-19T03:56:31.492555+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.13.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-19T03:56:31.493351+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.14.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-19T03:56:31.493991+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.15.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-19T03:56:31.494805+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.16.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-19T03:56:31.495592+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.17.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-19T03:56:31.496292+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.18.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-19T03:56:31.497147+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.19.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-19T03:56:31.497993+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.20.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-19T03:56:31.498771+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.21.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-19T03:56:31.499536+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.22.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-19T03:56:31.500375+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.23.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-19T03:56:31.501129+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.24.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-19T03:56:31.502025+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.25.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-19T03:56:31.502811+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.26.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-19T03:56:31.503668+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.27.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-19T03:56:31.504447+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.28.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-19T03:56:31.505227+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.29.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-19T03:56:31.506029+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.30.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-19T03:56:31.506878+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.31.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-19T03:56:31.507654+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.32.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-19T03:56:31.508447+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.33.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-19T03:56:31.509238+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.34.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-19T03:56:31.510032+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.35.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-19T03:56:31.521274+0000 | initialize | INFO - Compression lifecycle initialized for 1 modifiers
# 2026-03-19T03:56:31.521935+0000 | IndependentPipeline | INFO - Inferred `SequentialPipeline` for `AWQModifier`
# W0319 03:56:31.572000 55 torch/fx/_symbolic_trace.py:52] is_fx_tracing will return true for both fx.symbolic_trace and torch.export. Please use is_fx_tracing_symbolic_tracing() for specifically fx.symbolic_trace or torch.compiler.is_compiling() for specifically torch.export/compile.
# Preparing cache: 100%|██████████| 64/64 [00:00<00:00, 1298.96it/s]
# (1/37): Calibrating: 100%|██████████| 64/64 [00:02<00:00, 30.31it/s]
# Smoothing:   0%|          | 0/3 [00:00<?, ?it/s]
# Grid search for model.layers.0.input_layernorm:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.0.input_layernorm:   0%|          | 0/20 [00:00<?, ?it/s, best_error=1.740e-05]
# Grid search for model.layers.0.input_layernorm:   5%|▌         | 1/20 [00:00<00:11,  1.59it/s, best_error=1.740e-05]
# Grid search for model.layers.0.input_layernorm:   5%|▌         | 1/20 [00:01<00:11,  1.59it/s, best_error=1.657e-05]
# Grid search for model.layers.0.input_layernorm:  10%|█         | 2/20 [00:01<00:09,  1.83it/s, best_error=1.657e-05]
# Grid search for model.layers.0.input_layernorm:  10%|█         | 2/20 [00:01<00:09,  1.83it/s, best_error=1.657e-05]
# Grid search for model.layers.0.input_layernorm:  15%|█▌        | 3/20 [00:01<00:08,  1.92it/s, best_error=1.657e-05]
# Grid search for model.layers.0.input_layernorm:  15%|█▌        | 3/20 [00:02<00:08,  1.92it/s, best_error=1.538e-05]
# Grid search for model.layers.0.input_layernorm:  20%|██        | 4/20 [00:02<00:08,  1.96it/s, best_error=1.538e-05]
# Grid search for model.layers.0.input_layernorm:  20%|██        | 4/20 [00:02<00:08,  1.96it/s, best_error=1.538e-05]
# Grid search for model.layers.0.input_layernorm:  25%|██▌       | 5/20 [00:02<00:07,  1.99it/s, best_error=1.538e-05]
# Grid search for model.layers.0.input_layernorm:  25%|██▌       | 5/20 [00:03<00:07,  1.99it/s, best_error=1.448e-05]
# Grid search for model.layers.0.input_layernorm:  30%|███       | 6/20 [00:03<00:06,  2.00it/s, best_error=1.448e-05]
# Grid search for model.layers.0.input_layernorm:  30%|███       | 6/20 [00:03<00:06,  2.00it/s, best_error=1.448e-05]
# Grid search for model.layers.0.input_layernorm:  35%|███▌      | 7/20 [00:03<00:06,  2.01it/s, best_error=1.448e-05]
# Grid search for model.layers.0.input_layernorm:  35%|███▌      | 7/20 [00:04<00:06,  2.01it/s, best_error=1.448e-05]
# Grid search for model.layers.0.input_layernorm:  40%|████      | 8/20 [00:04<00:05,  2.02it/s, best_error=1.448e-05]
# Grid search for model.layers.0.input_layernorm:  40%|████      | 8/20 [00:04<00:05,  2.02it/s, best_error=1.448e-05]
# Grid search for model.layers.0.input_layernorm:  45%|████▌     | 9/20 [00:04<00:05,  2.03it/s, best_error=1.448e-05]
# Grid search for model.layers.0.input_layernorm:  45%|████▌     | 9/20 [00:05<00:05,  2.03it/s, best_error=1.448e-05]
# Grid search for model.layers.0.input_layernorm:  50%|█████     | 10/20 [00:05<00:04,  2.03it/s, best_error=1.448e-05]
# Grid search for model.layers.0.input_layernorm:  50%|█████     | 10/20 [00:05<00:04,  2.03it/s, best_error=1.448e-05]
# Grid search for model.layers.0.input_layernorm:  55%|█████▌    | 11/20 [00:05<00:04,  2.03it/s, best_error=1.448e-05]
# Grid search for model.layers.0.input_layernorm:  55%|█████▌    | 11/20 [00:06<00:04,  2.03it/s, best_error=1.448e-05]
# Grid search for model.layers.0.input_layernorm:  60%|██████    | 12/20 [00:06<00:03,  2.03it/s, best_error=1.448e-05]
# Grid search for model.layers.0.input_layernorm:  60%|██████    | 12/20 [00:06<00:03,  2.03it/s, best_error=1.448e-05]
# Grid search for model.layers.0.input_layernorm:  65%|██████▌   | 13/20 [00:06<00:03,  2.04it/s, best_error=1.448e-05]
# Grid search for model.layers.0.input_layernorm:  65%|██████▌   | 13/20 [00:07<00:03,  2.04it/s, best_error=1.448e-05]
# Grid search for model.layers.0.input_layernorm:  70%|███████   | 14/20 [00:07<00:02,  2.04it/s, best_error=1.448e-05]
# Grid search for model.layers.0.input_layernorm:  70%|███████   | 14/20 [00:07<00:02,  2.04it/s, best_error=1.448e-05]
# Grid search for model.layers.0.input_layernorm:  75%|███████▌  | 15/20 [00:07<00:02,  2.03it/s, best_error=1.448e-05]
# Grid search for model.layers.0.input_layernorm:  75%|███████▌  | 15/20 [00:07<00:02,  2.03it/s, best_error=1.448e-05]
# Grid search for model.layers.0.input_layernorm:  80%|████████  | 16/20 [00:07<00:01,  2.03it/s, best_error=1.448e-05]
# Grid search for model.layers.0.input_layernorm:  80%|████████  | 16/20 [00:08<00:01,  2.03it/s, best_error=1.448e-05]
# Grid search for model.layers.0.input_layernorm:  85%|████████▌ | 17/20 [00:08<00:01,  2.04it/s, best_error=1.448e-05]
# Grid search for model.layers.0.input_layernorm:  85%|████████▌ | 17/20 [00:08<00:01,  2.04it/s, best_error=1.448e-05]
# Grid search for model.layers.0.input_layernorm:  90%|█████████ | 18/20 [00:08<00:00,  2.04it/s, best_error=1.448e-05]
# Grid search for model.layers.0.input_layernorm:  90%|█████████ | 18/20 [00:09<00:00,  2.04it/s, best_error=1.448e-05]
# Grid search for model.layers.0.input_layernorm:  95%|█████████▌| 19/20 [00:09<00:00,  2.04it/s, best_error=1.448e-05]
# Grid search for model.layers.0.input_layernorm:  95%|█████████▌| 19/20 [00:09<00:00,  2.04it/s, best_error=1.448e-05]
# Grid search for model.layers.0.input_layernorm: 100%|██████████| 20/20 [00:09<00:00,  2.04it/s, best_error=1.448e-05]
# Smoothing:  33%|███▎      | 1/3 [00:10<00:20, 10.48s/it]
# Grid search for model.layers.0.post_attention_layernorm:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.0.post_attention_layernorm:   0%|          | 0/20 [00:00<?, ?it/s, best_error=3.719e-05]
# Grid search for model.layers.0.post_attention_layernorm:   5%|▌         | 1/20 [00:00<00:17,  1.09it/s, best_error=3.719e-05]
# Grid search for model.layers.0.post_attention_layernorm:   5%|▌         | 1/20 [00:01<00:17,  1.09it/s, best_error=3.695e-05]
# Grid search for model.layers.0.post_attention_layernorm:  10%|█         | 2/20 [00:01<00:16,  1.09it/s, best_error=3.695e-05]
# Grid search for model.layers.0.post_attention_layernorm:  10%|█         | 2/20 [00:02<00:16,  1.09it/s, best_error=3.672e-05]
# Grid search for model.layers.0.post_attention_layernorm:  15%|█▌        | 3/20 [00:02<00:15,  1.09it/s, best_error=3.672e-05]
# Grid search for model.layers.0.post_attention_layernorm:  15%|█▌        | 3/20 [00:03<00:15,  1.09it/s, best_error=3.672e-05]
# Grid search for model.layers.0.post_attention_layernorm:  20%|██        | 4/20 [00:03<00:14,  1.09it/s, best_error=3.672e-05]
# Grid search for model.layers.0.post_attention_layernorm:  20%|██        | 4/20 [00:04<00:14,  1.09it/s, best_error=3.648e-05]
# Grid search for model.layers.0.post_attention_layernorm:  25%|██▌       | 5/20 [00:04<00:13,  1.09it/s, best_error=3.648e-05]
# Grid search for model.layers.0.post_attention_layernorm:  25%|██▌       | 5/20 [00:05<00:13,  1.09it/s, best_error=3.624e-05]
# Grid search for model.layers.0.post_attention_layernorm:  30%|███       | 6/20 [00:05<00:12,  1.09it/s, best_error=3.624e-05]
# Grid search for model.layers.0.post_attention_layernorm:  30%|███       | 6/20 [00:06<00:12,  1.09it/s, best_error=3.624e-05]
# Grid search for model.layers.0.post_attention_layernorm:  35%|███▌      | 7/20 [00:06<00:11,  1.09it/s, best_error=3.624e-05]
# Grid search for model.layers.0.post_attention_layernorm:  35%|███▌      | 7/20 [00:07<00:11,  1.09it/s, best_error=3.624e-05]
# Grid search for model.layers.0.post_attention_layernorm:  40%|████      | 8/20 [00:07<00:11,  1.09it/s, best_error=3.624e-05]
# Grid search for model.layers.0.post_attention_layernorm:  40%|████      | 8/20 [00:08<00:11,  1.09it/s, best_error=3.624e-05]
# Grid search for model.layers.0.post_attention_layernorm:  45%|████▌     | 9/20 [00:08<00:10,  1.09it/s, best_error=3.624e-05]
# Grid search for model.layers.0.post_attention_layernorm:  45%|████▌     | 9/20 [00:09<00:10,  1.09it/s, best_error=3.624e-05]
# Grid search for model.layers.0.post_attention_layernorm:  50%|█████     | 10/20 [00:09<00:09,  1.09it/s, best_error=3.624e-05]
# Grid search for model.layers.0.post_attention_layernorm:  50%|█████     | 10/20 [00:10<00:09,  1.09it/s, best_error=3.624e-05]
# Grid search for model.layers.0.post_attention_layernorm:  55%|█████▌    | 11/20 [00:10<00:08,  1.09it/s, best_error=3.624e-05]
# Grid search for model.layers.0.post_attention_layernorm:  55%|█████▌    | 11/20 [00:11<00:08,  1.09it/s, best_error=3.624e-05]
# Grid search for model.layers.0.post_attention_layernorm:  60%|██████    | 12/20 [00:11<00:07,  1.09it/s, best_error=3.624e-05]
# Grid search for model.layers.0.post_attention_layernorm:  60%|██████    | 12/20 [00:11<00:07,  1.09it/s, best_error=3.624e-05]
# Grid search for model.layers.0.post_attention_layernorm:  65%|██████▌   | 13/20 [00:11<00:06,  1.09it/s, best_error=3.624e-05]
# Grid search for model.layers.0.post_attention_layernorm:  65%|██████▌   | 13/20 [00:12<00:06,  1.09it/s, best_error=3.624e-05]
# Grid search for model.layers.0.post_attention_layernorm:  70%|███████   | 14/20 [00:12<00:05,  1.09it/s, best_error=3.624e-05]
# Grid search for model.layers.0.post_attention_layernorm:  70%|███████   | 14/20 [00:13<00:05,  1.09it/s, best_error=3.624e-05]
# Grid search for model.layers.0.post_attention_layernorm:  75%|███████▌  | 15/20 [00:13<00:04,  1.09it/s, best_error=3.624e-05]
# Grid search for model.layers.0.post_attention_layernorm:  75%|███████▌  | 15/20 [00:14<00:04,  1.09it/s, best_error=3.624e-05]
# Grid search for model.layers.0.post_attention_layernorm:  80%|████████  | 16/20 [00:14<00:03,  1.09it/s, best_error=3.624e-05]
# Grid search for model.layers.0.post_attention_layernorm:  80%|████████  | 16/20 [00:15<00:03,  1.09it/s, best_error=3.624e-05]
# Grid search for model.layers.0.post_attention_layernorm:  85%|████████▌ | 17/20 [00:15<00:02,  1.09it/s, best_error=3.624e-05]
# Grid search for model.layers.0.post_attention_layernorm:  85%|████████▌ | 17/20 [00:16<00:02,  1.09it/s, best_error=3.624e-05]
# Grid search for model.layers.0.post_attention_layernorm:  90%|█████████ | 18/20 [00:16<00:01,  1.09it/s, best_error=3.624e-05]
# Grid search for model.layers.0.post_attention_layernorm:  90%|█████████ | 18/20 [00:17<00:01,  1.09it/s, best_error=3.624e-05]
# Grid search for model.layers.0.post_attention_layernorm:  95%|█████████▌| 19/20 [00:17<00:00,  1.09it/s, best_error=3.624e-05]
# Grid search for model.layers.0.post_attention_layernorm:  95%|█████████▌| 19/20 [00:18<00:00,  1.09it/s, best_error=3.624e-05]
# Grid search for model.layers.0.post_attention_layernorm: 100%|██████████| 20/20 [00:18<00:00,  1.09it/s, best_error=3.624e-05]
# Smoothing:  67%|██████▋   | 2/3 [00:29<00:15, 15.66s/it]
# Grid search for model.layers.0.mlp.up_proj:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.0.mlp.up_proj:   0%|          | 0/20 [00:00<?, ?it/s, best_error=1.316e-04]
# Grid search for model.layers.0.mlp.up_proj:   5%|▌         | 1/20 [00:00<00:06,  2.96it/s, best_error=1.316e-04]
# Grid search for model.layers.0.mlp.up_proj:   5%|▌         | 1/20 [00:00<00:06,  2.96it/s, best_error=1.278e-04]
# Grid search for model.layers.0.mlp.up_proj:  10%|█         | 2/20 [00:00<00:06,  2.94it/s, best_error=1.278e-04]
# Grid search for model.layers.0.mlp.up_proj:  10%|█         | 2/20 [00:01<00:06,  2.94it/s, best_error=1.240e-04]
# Grid search for model.layers.0.mlp.up_proj:  15%|█▌        | 3/20 [00:01<00:05,  2.95it/s, best_error=1.240e-04]
# Grid search for model.layers.0.mlp.up_proj:  15%|█▌        | 3/20 [00:01<00:05,  2.95it/s, best_error=1.240e-04]
# Grid search for model.layers.0.mlp.up_proj:  20%|██        | 4/20 [00:01<00:05,  2.95it/s, best_error=1.240e-04]
# Grid search for model.layers.0.mlp.up_proj:  20%|██        | 4/20 [00:01<00:05,  2.95it/s, best_error=1.221e-04]
# Grid search for model.layers.0.mlp.up_proj:  25%|██▌       | 5/20 [00:01<00:05,  2.95it/s, best_error=1.221e-04]
# Grid search for model.layers.0.mlp.up_proj:  25%|██▌       | 5/20 [00:02<00:05,  2.95it/s, best_error=1.211e-04]
# Grid search for model.layers.0.mlp.up_proj:  30%|███       | 6/20 [00:02<00:04,  2.95it/s, best_error=1.211e-04]
# Grid search for model.layers.0.mlp.up_proj:  30%|███       | 6/20 [00:02<00:04,  2.95it/s, best_error=1.206e-04]
# Grid search for model.layers.0.mlp.up_proj:  35%|███▌      | 7/20 [00:02<00:04,  2.94it/s, best_error=1.206e-04]
# Grid search for model.layers.0.mlp.up_proj:  35%|███▌      | 7/20 [00:02<00:04,  2.94it/s, best_error=1.206e-04]
# Grid search for model.layers.0.mlp.up_proj:  40%|████      | 8/20 [00:02<00:04,  2.94it/s, best_error=1.206e-04]
# Grid search for model.layers.0.mlp.up_proj:  40%|████      | 8/20 [00:03<00:04,  2.94it/s, best_error=1.206e-04]
# Grid search for model.layers.0.mlp.up_proj:  45%|████▌     | 9/20 [00:03<00:03,  2.94it/s, best_error=1.206e-04]
# Grid search for model.layers.0.mlp.up_proj:  45%|████▌     | 9/20 [00:03<00:03,  2.94it/s, best_error=1.206e-04]
# Grid search for model.layers.0.mlp.up_proj:  50%|█████     | 10/20 [00:03<00:03,  2.94it/s, best_error=1.206e-04]
# Grid search for model.layers.0.mlp.up_proj:  50%|█████     | 10/20 [00:03<00:03,  2.94it/s, best_error=1.206e-04]
# Grid search for model.layers.0.mlp.up_proj:  55%|█████▌    | 11/20 [00:03<00:03,  2.94it/s, best_error=1.206e-04]
# Grid search for model.layers.0.mlp.up_proj:  55%|█████▌    | 11/20 [00:04<00:03,  2.94it/s, best_error=1.206e-04]
# Grid search for model.layers.0.mlp.up_proj:  60%|██████    | 12/20 [00:04<00:02,  2.94it/s, best_error=1.206e-04]
# Grid search for model.layers.0.mlp.up_proj:  60%|██████    | 12/20 [00:04<00:02,  2.94it/s, best_error=1.206e-04]
# Grid search for model.layers.0.mlp.up_proj:  65%|██████▌   | 13/20 [00:04<00:02,  2.94it/s, best_error=1.206e-04]
# Grid search for model.layers.0.mlp.up_proj:  65%|██████▌   | 13/20 [00:04<00:02,  2.94it/s, best_error=1.206e-04]
# Grid search for model.layers.0.mlp.up_proj:  70%|███████   | 14/20 [00:04<00:02,  2.94it/s, best_error=1.206e-04]
# Grid search for model.layers.0.mlp.up_proj:  70%|███████   | 14/20 [00:05<00:02,  2.94it/s, best_error=1.206e-04]
# Grid search for model.layers.0.mlp.up_proj:  75%|███████▌  | 15/20 [00:05<00:01,  2.94it/s, best_error=1.206e-04]
# Grid search for model.layers.0.mlp.up_proj:  75%|███████▌  | 15/20 [00:05<00:01,  2.94it/s, best_error=1.206e-04]
# Grid search for model.layers.0.mlp.up_proj:  80%|████████  | 16/20 [00:05<00:01,  2.94it/s, best_error=1.206e-04]
# Grid search for model.layers.0.mlp.up_proj:  80%|████████  | 16/20 [00:05<00:01,  2.94it/s, best_error=1.206e-04]
# Grid search for model.layers.0.mlp.up_proj:  85%|████████▌ | 17/20 [00:05<00:01,  2.94it/s, best_error=1.206e-04]
# Grid search for model.layers.0.mlp.up_proj:  85%|████████▌ | 17/20 [00:06<00:01,  2.94it/s, best_error=1.206e-04]
# Grid search for model.layers.0.mlp.up_proj:  90%|█████████ | 18/20 [00:06<00:00,  2.94it/s, best_error=1.206e-04]
# Grid search for model.layers.0.mlp.up_proj:  90%|█████████ | 18/20 [00:06<00:00,  2.94it/s, best_error=1.206e-04]
# Grid search for model.layers.0.mlp.up_proj:  95%|█████████▌| 19/20 [00:06<00:00,  2.94it/s, best_error=1.206e-04]
# Grid search for model.layers.0.mlp.up_proj:  95%|█████████▌| 19/20 [00:06<00:00,  2.94it/s, best_error=1.206e-04]
# Grid search for model.layers.0.mlp.up_proj: 100%|██████████| 20/20 [00:06<00:00,  2.94it/s, best_error=1.206e-04]
# Smoothing: 100%|██████████| 3/3 [00:36<00:00, 12.30s/it]
# (1/37): Propagating: 100%|██████████| 64/64 [00:01<00:00, 38.35it/s]
# (2/37): Calibrating: 100%|██████████| 64/64 [00:01<00:00, 41.90it/s]
# Smoothing:   0%|          | 0/3 [00:00<?, ?it/s]
# Grid search for model.layers.1.input_layernorm:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.1.input_layernorm:   0%|          | 0/20 [00:00<?, ?it/s, best_error=1.884e-05]
# Grid search for model.layers.1.input_layernorm:   5%|▌         | 1/20 [00:00<00:09,  2.04it/s, best_error=1.884e-05]
# Grid search for model.layers.1.input_layernorm:   5%|▌         | 1/20 [00:00<00:09,  2.04it/s, best_error=1.764e-05]
# Grid search for model.layers.1.input_layernorm:  10%|█         | 2/20 [00:00<00:08,  2.04it/s, best_error=1.764e-05]
# Grid search for model.layers.1.input_layernorm:  10%|█         | 2/20 [00:01<00:08,  2.04it/s, best_error=1.752e-05]
# Grid search for model.layers.1.input_layernorm:  15%|█▌        | 3/20 [00:01<00:08,  2.04it/s, best_error=1.752e-05]
# Grid search for model.layers.1.input_layernorm:  15%|█▌        | 3/20 [00:01<00:08,  2.04it/s, best_error=1.562e-05]
# Grid search for model.layers.1.input_layernorm:  20%|██        | 4/20 [00:01<00:07,  2.04it/s, best_error=1.562e-05]
# Grid search for model.layers.1.input_layernorm:  20%|██        | 4/20 [00:02<00:07,  2.04it/s, best_error=1.562e-05]
# Grid search for model.layers.1.input_layernorm:  25%|██▌       | 5/20 [00:02<00:07,  2.04it/s, best_error=1.562e-05]
# Grid search for model.layers.1.input_layernorm:  25%|██▌       | 5/20 [00:02<00:07,  2.04it/s, best_error=1.562e-05]
# Grid search for model.layers.1.input_layernorm:  30%|███       | 6/20 [00:02<00:06,  2.04it/s, best_error=1.562e-05]
# Grid search for model.layers.1.input_layernorm:  30%|███       | 6/20 [00:03<00:06,  2.04it/s, best_error=1.562e-05]
# Grid search for model.layers.1.input_layernorm:  35%|███▌      | 7/20 [00:03<00:06,  2.04it/s, best_error=1.562e-05]
# Grid search for model.layers.1.input_layernorm:  35%|███▌      | 7/20 [00:03<00:06,  2.04it/s, best_error=1.562e-05]
# Grid search for model.layers.1.input_layernorm:  40%|████      | 8/20 [00:03<00:05,  2.03it/s, best_error=1.562e-05]
# Grid search for model.layers.1.input_layernorm:  40%|████      | 8/20 [00:04<00:05,  2.03it/s, best_error=1.496e-05]
# Grid search for model.layers.1.input_layernorm:  45%|████▌     | 9/20 [00:04<00:05,  2.03it/s, best_error=1.496e-05]
# Grid search for model.layers.1.input_layernorm:  45%|████▌     | 9/20 [00:04<00:05,  2.03it/s, best_error=1.496e-05]
# Grid search for model.layers.1.input_layernorm:  50%|█████     | 10/20 [00:04<00:04,  2.04it/s, best_error=1.496e-05]
# Grid search for model.layers.1.input_layernorm:  50%|█████     | 10/20 [00:05<00:04,  2.04it/s, best_error=1.496e-05]
# Grid search for model.layers.1.input_layernorm:  55%|█████▌    | 11/20 [00:05<00:04,  2.03it/s, best_error=1.496e-05]
# Grid search for model.layers.1.input_layernorm:  55%|█████▌    | 11/20 [00:05<00:04,  2.03it/s, best_error=1.496e-05]
# Grid search for model.layers.1.input_layernorm:  60%|██████    | 12/20 [00:05<00:03,  2.04it/s, best_error=1.496e-05]
# Grid search for model.layers.1.input_layernorm:  60%|██████    | 12/20 [00:06<00:03,  2.04it/s, best_error=1.496e-05]
# Grid search for model.layers.1.input_layernorm:  65%|██████▌   | 13/20 [00:06<00:03,  2.04it/s, best_error=1.496e-05]
# Grid search for model.layers.1.input_layernorm:  65%|██████▌   | 13/20 [00:06<00:03,  2.04it/s, best_error=1.496e-05]
# Grid search for model.layers.1.input_layernorm:  70%|███████   | 14/20 [00:06<00:02,  2.04it/s, best_error=1.496e-05]
# Grid search for model.layers.1.input_layernorm:  70%|███████   | 14/20 [00:07<00:02,  2.04it/s, best_error=1.496e-05]
# Grid search for model.layers.1.input_layernorm:  75%|███████▌  | 15/20 [00:07<00:02,  2.04it/s, best_error=1.496e-05]
# Grid search for model.layers.1.input_layernorm:  75%|███████▌  | 15/20 [00:07<00:02,  2.04it/s, best_error=1.496e-05]
# Grid search for model.layers.1.input_layernorm:  80%|████████  | 16/20 [00:07<00:01,  2.04it/s, best_error=1.496e-05]
# Grid search for model.layers.1.input_layernorm:  80%|████████  | 16/20 [00:08<00:01,  2.04it/s, best_error=1.496e-05]
# Grid search for model.layers.1.input_layernorm:  85%|████████▌ | 17/20 [00:08<00:01,  2.04it/s, best_error=1.496e-05]
# Grid search for model.layers.1.input_layernorm:  85%|████████▌ | 17/20 [00:08<00:01,  2.04it/s, best_error=1.496e-05]
# Grid search for model.layers.1.input_layernorm:  90%|█████████ | 18/20 [00:08<00:00,  2.04it/s, best_error=1.496e-05]
# Grid search for model.layers.1.input_layernorm:  90%|█████████ | 18/20 [00:09<00:00,  2.04it/s, best_error=1.496e-05]
# Grid search for model.layers.1.input_layernorm:  95%|█████████▌| 19/20 [00:09<00:00,  2.03it/s, best_error=1.496e-05]
# Grid search for model.layers.1.input_layernorm:  95%|█████████▌| 19/20 [00:09<00:00,  2.03it/s, best_error=1.496e-05]
# Grid search for model.layers.1.input_layernorm: 100%|██████████| 20/20 [00:09<00:00,  2.04it/s, best_error=1.496e-05]
# Smoothing:  33%|███▎      | 1/3 [00:10<00:20, 10.32s/it]
# Grid search for model.layers.1.post_attention_layernorm:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.1.post_attention_layernorm:   0%|          | 0/20 [00:00<?, ?it/s, best_error=2.365e-03]
# Grid search for model.layers.1.post_attention_layernorm:   5%|▌         | 1/20 [00:00<00:17,  1.09it/s, best_error=2.365e-03]
# Grid search for model.layers.1.post_attention_layernorm:   5%|▌         | 1/20 [00:01<00:17,  1.09it/s, best_error=1.343e-03]
# Grid search for model.layers.1.post_attention_layernorm:  10%|█         | 2/20 [00:01<00:16,  1.09it/s, best_error=1.343e-03]
# Grid search for model.layers.1.post_attention_layernorm:  10%|█         | 2/20 [00:02<00:16,  1.09it/s, best_error=3.281e-04]
# Grid search for model.layers.1.post_attention_layernorm:  15%|█▌        | 3/20 [00:02<00:15,  1.09it/s, best_error=3.281e-04]
# Grid search for model.layers.1.post_attention_layernorm:  15%|█▌        | 3/20 [00:03<00:15,  1.09it/s, best_error=2.899e-04]
# Grid search for model.layers.1.post_attention_layernorm:  20%|██        | 4/20 [00:03<00:14,  1.09it/s, best_error=2.899e-04]
# Grid search for model.layers.1.post_attention_layernorm:  20%|██        | 4/20 [00:04<00:14,  1.09it/s, best_error=2.632e-04]
# Grid search for model.layers.1.post_attention_layernorm:  25%|██▌       | 5/20 [00:04<00:13,  1.09it/s, best_error=2.632e-04]
# Grid search for model.layers.1.post_attention_layernorm:  25%|██▌       | 5/20 [00:05<00:13,  1.09it/s, best_error=9.251e-05]
# Grid search for model.layers.1.post_attention_layernorm:  30%|███       | 6/20 [00:05<00:12,  1.09it/s, best_error=9.251e-05]
# Grid search for model.layers.1.post_attention_layernorm:  30%|███       | 6/20 [00:06<00:12,  1.09it/s, best_error=9.251e-05]
# Grid search for model.layers.1.post_attention_layernorm:  35%|███▌      | 7/20 [00:06<00:11,  1.09it/s, best_error=9.251e-05]
# Grid search for model.layers.1.post_attention_layernorm:  35%|███▌      | 7/20 [00:07<00:11,  1.09it/s, best_error=9.251e-05]
# Grid search for model.layers.1.post_attention_layernorm:  40%|████      | 8/20 [00:07<00:11,  1.09it/s, best_error=9.251e-05]
# Grid search for model.layers.1.post_attention_layernorm:  40%|████      | 8/20 [00:08<00:11,  1.09it/s, best_error=9.251e-05]
# Grid search for model.layers.1.post_attention_layernorm:  45%|████▌     | 9/20 [00:08<00:10,  1.09it/s, best_error=9.251e-05]
# Grid search for model.layers.1.post_attention_layernorm:  45%|████▌     | 9/20 [00:09<00:10,  1.09it/s, best_error=7.296e-05]
# Grid search for model.layers.1.post_attention_layernorm:  50%|█████     | 10/20 [00:09<00:09,  1.09it/s, best_error=7.296e-05]
# Grid search for model.layers.1.post_attention_layernorm:  50%|█████     | 10/20 [00:10<00:09,  1.09it/s, best_error=7.296e-05]
# Grid search for model.layers.1.post_attention_layernorm:  55%|█████▌    | 11/20 [00:10<00:08,  1.09it/s, best_error=7.296e-05]
# Grid search for model.layers.1.post_attention_layernorm:  55%|█████▌    | 11/20 [00:11<00:08,  1.09it/s, best_error=7.296e-05]
# Grid search for model.layers.1.post_attention_layernorm:  60%|██████    | 12/20 [00:11<00:07,  1.09it/s, best_error=7.296e-05]
# Grid search for model.layers.1.post_attention_layernorm:  60%|██████    | 12/20 [00:11<00:07,  1.09it/s, best_error=7.296e-05]
# Grid search for model.layers.1.post_attention_layernorm:  65%|██████▌   | 13/20 [00:11<00:06,  1.09it/s, best_error=7.296e-05]
# Grid search for model.layers.1.post_attention_layernorm:  65%|██████▌   | 13/20 [00:12<00:06,  1.09it/s, best_error=7.296e-05]
# Grid search for model.layers.1.post_attention_layernorm:  70%|███████   | 14/20 [00:12<00:05,  1.09it/s, best_error=7.296e-05]
# Grid search for model.layers.1.post_attention_layernorm:  70%|███████   | 14/20 [00:13<00:05,  1.09it/s, best_error=7.296e-05]
# Grid search for model.layers.1.post_attention_layernorm:  75%|███████▌  | 15/20 [00:13<00:04,  1.09it/s, best_error=7.296e-05]
# Grid search for model.layers.1.post_attention_layernorm:  75%|███████▌  | 15/20 [00:14<00:04,  1.09it/s, best_error=7.296e-05]
# Grid search for model.layers.1.post_attention_layernorm:  80%|████████  | 16/20 [00:14<00:03,  1.09it/s, best_error=7.296e-05]
# Grid search for model.layers.1.post_attention_layernorm:  80%|████████  | 16/20 [00:15<00:03,  1.09it/s, best_error=7.296e-05]
# Grid search for model.layers.1.post_attention_layernorm:  85%|████████▌ | 17/20 [00:15<00:02,  1.09it/s, best_error=7.296e-05]
# Grid search for model.layers.1.post_attention_layernorm:  85%|████████▌ | 17/20 [00:16<00:02,  1.09it/s, best_error=7.296e-05]
# Grid search for model.layers.1.post_attention_layernorm:  90%|█████████ | 18/20 [00:16<00:01,  1.09it/s, best_error=7.296e-05]
# Grid search for model.layers.1.post_attention_layernorm:  90%|█████████ | 18/20 [00:17<00:01,  1.09it/s, best_error=7.296e-05]
# Grid search for model.layers.1.post_attention_layernorm:  95%|█████████▌| 19/20 [00:17<00:00,  1.09it/s, best_error=7.296e-05]
# Grid search for model.layers.1.post_attention_layernorm:  95%|█████████▌| 19/20 [00:18<00:00,  1.09it/s, best_error=7.296e-05]
# Grid search for model.layers.1.post_attention_layernorm: 100%|██████████| 20/20 [00:18<00:00,  1.09it/s, best_error=7.296e-05]
# Smoothing:  67%|██████▋   | 2/3 [00:29<00:15, 15.60s/it]
# Grid search for model.layers.1.mlp.up_proj:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.1.mlp.up_proj:   0%|          | 0/20 [00:00<?, ?it/s, best_error=1.240e-04]
# Grid search for model.layers.1.mlp.up_proj:   5%|▌         | 1/20 [00:00<00:06,  2.96it/s, best_error=1.240e-04]
# Grid search for model.layers.1.mlp.up_proj:   5%|▌         | 1/20 [00:00<00:06,  2.96it/s, best_error=1.240e-04]
# Grid search for model.layers.1.mlp.up_proj:  10%|█         | 2/20 [00:00<00:06,  2.95it/s, best_error=1.240e-04]
# Grid search for model.layers.1.mlp.up_proj:  10%|█         | 2/20 [00:01<00:06,  2.95it/s, best_error=1.240e-04]
# Grid search for model.layers.1.mlp.up_proj:  15%|█▌        | 3/20 [00:01<00:05,  2.95it/s, best_error=1.240e-04]
# Grid search for model.layers.1.mlp.up_proj:  15%|█▌        | 3/20 [00:01<00:05,  2.95it/s, best_error=1.240e-04]
# Grid search for model.layers.1.mlp.up_proj:  20%|██        | 4/20 [00:01<00:05,  2.94it/s, best_error=1.240e-04]
# Grid search for model.layers.1.mlp.up_proj:  20%|██        | 4/20 [00:01<00:05,  2.94it/s, best_error=1.240e-04]
# Grid search for model.layers.1.mlp.up_proj:  25%|██▌       | 5/20 [00:01<00:05,  2.94it/s, best_error=1.240e-04]
# Grid search for model.layers.1.mlp.up_proj:  25%|██▌       | 5/20 [00:02<00:05,  2.94it/s, best_error=1.211e-04]
# Grid search for model.layers.1.mlp.up_proj:  30%|███       | 6/20 [00:02<00:04,  2.94it/s, best_error=1.211e-04]
# Grid search for model.layers.1.mlp.up_proj:  30%|███       | 6/20 [00:02<00:04,  2.94it/s, best_error=1.211e-04]
# Grid search for model.layers.1.mlp.up_proj:  35%|███▌      | 7/20 [00:02<00:04,  2.95it/s, best_error=1.211e-04]
# Grid search for model.layers.1.mlp.up_proj:  35%|███▌      | 7/20 [00:02<00:04,  2.95it/s, best_error=1.192e-04]
# Grid search for model.layers.1.mlp.up_proj:  40%|████      | 8/20 [00:02<00:04,  2.94it/s, best_error=1.192e-04]
# Grid search for model.layers.1.mlp.up_proj:  40%|████      | 8/20 [00:03<00:04,  2.94it/s, best_error=1.192e-04]
# Grid search for model.layers.1.mlp.up_proj:  45%|████▌     | 9/20 [00:03<00:03,  2.94it/s, best_error=1.192e-04]
# Grid search for model.layers.1.mlp.up_proj:  45%|████▌     | 9/20 [00:03<00:03,  2.94it/s, best_error=1.192e-04]
# Grid search for model.layers.1.mlp.up_proj:  50%|█████     | 10/20 [00:03<00:03,  2.94it/s, best_error=1.192e-04]
# Grid search for model.layers.1.mlp.up_proj:  50%|█████     | 10/20 [00:03<00:03,  2.94it/s, best_error=1.159e-04]
# Grid search for model.layers.1.mlp.up_proj:  55%|█████▌    | 11/20 [00:03<00:03,  2.94it/s, best_error=1.159e-04]
# Grid search for model.layers.1.mlp.up_proj:  55%|█████▌    | 11/20 [00:04<00:03,  2.94it/s, best_error=1.130e-04]
# Grid search for model.layers.1.mlp.up_proj:  60%|██████    | 12/20 [00:04<00:02,  2.94it/s, best_error=1.130e-04]
# Grid search for model.layers.1.mlp.up_proj:  60%|██████    | 12/20 [00:04<00:02,  2.94it/s, best_error=1.130e-04]
# Grid search for model.layers.1.mlp.up_proj:  65%|██████▌   | 13/20 [00:04<00:02,  2.95it/s, best_error=1.130e-04]
# Grid search for model.layers.1.mlp.up_proj:  65%|██████▌   | 13/20 [00:04<00:02,  2.95it/s, best_error=1.130e-04]
# Grid search for model.layers.1.mlp.up_proj:  70%|███████   | 14/20 [00:04<00:02,  2.94it/s, best_error=1.130e-04]
# Grid search for model.layers.1.mlp.up_proj:  70%|███████   | 14/20 [00:05<00:02,  2.94it/s, best_error=1.130e-04]
# Grid search for model.layers.1.mlp.up_proj:  75%|███████▌  | 15/20 [00:05<00:01,  2.94it/s, best_error=1.130e-04]
# Grid search for model.layers.1.mlp.up_proj:  75%|███████▌  | 15/20 [00:05<00:01,  2.94it/s, best_error=1.130e-04]
# Grid search for model.layers.1.mlp.up_proj:  80%|████████  | 16/20 [00:05<00:01,  2.94it/s, best_error=1.130e-04]
# Grid search for model.layers.1.mlp.up_proj:  80%|████████  | 16/20 [00:05<00:01,  2.94it/s, best_error=1.130e-04]
# Grid search for model.layers.1.mlp.up_proj:  85%|████████▌ | 17/20 [00:05<00:01,  2.94it/s, best_error=1.130e-04]
# Grid search for model.layers.1.mlp.up_proj:  85%|████████▌ | 17/20 [00:06<00:01,  2.94it/s, best_error=1.130e-04]
# Grid search for model.layers.1.mlp.up_proj:  90%|█████████ | 18/20 [00:06<00:00,  2.94it/s, best_error=1.130e-04]
# Grid search for model.layers.1.mlp.up_proj:  90%|█████████ | 18/20 [00:06<00:00,  2.94it/s, best_error=1.130e-04]
# Grid search for model.layers.1.mlp.up_proj:  95%|█████████▌| 19/20 [00:06<00:00,  2.94it/s, best_error=1.130e-04]
# Grid search for model.layers.1.mlp.up_proj:  95%|█████████▌| 19/20 [00:06<00:00,  2.94it/s, best_error=1.130e-04]
# Grid search for model.layers.1.mlp.up_proj: 100%|██████████| 20/20 [00:06<00:00,  2.94it/s, best_error=1.130e-04]
# Smoothing: 100%|██████████| 3/3 [00:36<00:00, 12.25s/it]
# (2/37): Propagating: 100%|██████████| 64/64 [00:01<00:00, 40.26it/s]
# (3/37): Calibrating: 100%|██████████| 64/64 [00:01<00:00, 41.94it/s]
# Smoothing:   0%|          | 0/3 [00:00<?, ?it/s]
# Grid search for model.layers.2.input_layernorm:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.2.input_layernorm:   0%|          | 0/20 [00:00<?, ?it/s, best_error=2.933e-05]
# Grid search for model.layers.2.input_layernorm:   5%|▌         | 1/20 [00:00<00:09,  2.05it/s, best_error=2.933e-05]
# Grid search for model.layers.2.input_layernorm:   5%|▌         | 1/20 [00:00<00:09,  2.05it/s, best_error=2.897e-05]
# Grid search for model.layers.2.input_layernorm:  10%|█         | 2/20 [00:00<00:08,  2.04it/s, best_error=2.897e-05]
# Grid search for model.layers.2.input_layernorm:  10%|█         | 2/20 [00:01<00:08,  2.04it/s, best_error=2.861e-05]
# Grid search for model.layers.2.input_layernorm:  15%|█▌        | 3/20 [00:01<00:08,  2.05it/s, best_error=2.861e-05]
# Grid search for model.layers.2.input_layernorm:  15%|█▌        | 3/20 [00:01<00:08,  2.05it/s, best_error=2.801e-05]
# Grid search for model.layers.2.input_layernorm:  20%|██        | 4/20 [00:01<00:07,  2.04it/s, best_error=2.801e-05]
# Grid search for model.layers.2.input_layernorm:  20%|██        | 4/20 [00:02<00:07,  2.04it/s, best_error=2.742e-05]
# Grid search for model.layers.2.input_layernorm:  25%|██▌       | 5/20 [00:02<00:07,  2.04it/s, best_error=2.742e-05]
# Grid search for model.layers.2.input_layernorm:  25%|██▌       | 5/20 [00:02<00:07,  2.04it/s, best_error=2.742e-05]
# Grid search for model.layers.2.input_layernorm:  30%|███       | 6/20 [00:02<00:06,  2.04it/s, best_error=2.742e-05]
# Grid search for model.layers.2.input_layernorm:  30%|███       | 6/20 [00:03<00:06,  2.04it/s, best_error=2.742e-05]
# Grid search for model.layers.2.input_layernorm:  35%|███▌      | 7/20 [00:03<00:06,  2.04it/s, best_error=2.742e-05]
# Grid search for model.layers.2.input_layernorm:  35%|███▌      | 7/20 [00:03<00:06,  2.04it/s, best_error=2.742e-05]
# Grid search for model.layers.2.input_layernorm:  40%|████      | 8/20 [00:03<00:05,  2.04it/s, best_error=2.742e-05]
# Grid search for model.layers.2.input_layernorm:  40%|████      | 8/20 [00:04<00:05,  2.04it/s, best_error=2.742e-05]
# Grid search for model.layers.2.input_layernorm:  45%|████▌     | 9/20 [00:04<00:05,  2.04it/s, best_error=2.742e-05]
# Grid search for model.layers.2.input_layernorm:  45%|████▌     | 9/20 [00:04<00:05,  2.04it/s, best_error=2.742e-05]
# Grid search for model.layers.2.input_layernorm:  50%|█████     | 10/20 [00:04<00:04,  2.04it/s, best_error=2.742e-05]
# Grid search for model.layers.2.input_layernorm:  50%|█████     | 10/20 [00:05<00:04,  2.04it/s, best_error=2.742e-05]
# Grid search for model.layers.2.input_layernorm:  55%|█████▌    | 11/20 [00:05<00:04,  2.04it/s, best_error=2.742e-05]
# Grid search for model.layers.2.input_layernorm:  55%|█████▌    | 11/20 [00:05<00:04,  2.04it/s, best_error=2.742e-05]
# Grid search for model.layers.2.input_layernorm:  60%|██████    | 12/20 [00:05<00:03,  2.04it/s, best_error=2.742e-05]
# Grid search for model.layers.2.input_layernorm:  60%|██████    | 12/20 [00:06<00:03,  2.04it/s, best_error=2.742e-05]
# Grid search for model.layers.2.input_layernorm:  65%|██████▌   | 13/20 [00:06<00:03,  2.04it/s, best_error=2.742e-05]
# Grid search for model.layers.2.input_layernorm:  65%|██████▌   | 13/20 [00:06<00:03,  2.04it/s, best_error=2.742e-05]
# Grid search for model.layers.2.input_layernorm:  70%|███████   | 14/20 [00:06<00:02,  2.04it/s, best_error=2.742e-05]
# Grid search for model.layers.2.input_layernorm:  70%|███████   | 14/20 [00:07<00:02,  2.04it/s, best_error=2.742e-05]
# Grid search for model.layers.2.input_layernorm:  75%|███████▌  | 15/20 [00:07<00:02,  2.04it/s, best_error=2.742e-05]
# Grid search for model.layers.2.input_layernorm:  75%|███████▌  | 15/20 [00:07<00:02,  2.04it/s, best_error=2.742e-05]
# Grid search for model.layers.2.input_layernorm:  80%|████████  | 16/20 [00:07<00:01,  2.04it/s, best_error=2.742e-05]
# Grid search for model.layers.2.input_layernorm:  80%|████████  | 16/20 [00:08<00:01,  2.04it/s, best_error=2.742e-05]
# Grid search for model.layers.2.input_layernorm:  85%|████████▌ | 17/20 [00:08<00:01,  2.04it/s, best_error=2.742e-05]
# Grid search for model.layers.2.input_layernorm:  85%|████████▌ | 17/20 [00:08<00:01,  2.04it/s, best_error=2.742e-05]
# Grid search for model.layers.2.input_layernorm:  90%|█████████ | 18/20 [00:08<00:00,  2.04it/s, best_error=2.742e-05]
# Grid search for model.layers.2.input_layernorm:  90%|█████████ | 18/20 [00:09<00:00,  2.04it/s, best_error=2.742e-05]
# Grid search for model.layers.2.input_layernorm:  95%|█████████▌| 19/20 [00:09<00:00,  2.04it/s, best_error=2.742e-05]
# Grid search for model.layers.2.input_layernorm:  95%|█████████▌| 19/20 [00:09<00:00,  2.04it/s, best_error=2.742e-05]
# Grid search for model.layers.2.input_layernorm: 100%|██████████| 20/20 [00:09<00:00,  2.04it/s, best_error=2.742e-05]
# Smoothing:  33%|███▎      | 1/3 [00:10<00:20, 10.30s/it]
# Grid search for model.layers.2.post_attention_layernorm:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.2.post_attention_layernorm:   0%|          | 0/20 [00:00<?, ?it/s, best_error=3.693e-03]
# Grid search for model.layers.2.post_attention_layernorm:   5%|▌         | 1/20 [00:00<00:17,  1.09it/s, best_error=3.693e-03]
# Grid search for model.layers.2.post_attention_layernorm:   5%|▌         | 1/20 [00:01<00:17,  1.09it/s, best_error=1.358e-03]
# Grid search for model.layers.2.post_attention_layernorm:  10%|█         | 2/20 [00:01<00:16,  1.09it/s, best_error=1.358e-03]
# Grid search for model.layers.2.post_attention_layernorm:  10%|█         | 2/20 [00:02<00:16,  1.09it/s, best_error=7.401e-04]
# Grid search for model.layers.2.post_attention_layernorm:  15%|█▌        | 3/20 [00:02<00:15,  1.09it/s, best_error=7.401e-04]
# Grid search for model.layers.2.post_attention_layernorm:  15%|█▌        | 3/20 [00:03<00:15,  1.09it/s, best_error=4.330e-04]
# Grid search for model.layers.2.post_attention_layernorm:  20%|██        | 4/20 [00:03<00:14,  1.09it/s, best_error=4.330e-04]
# Grid search for model.layers.2.post_attention_layernorm:  20%|██        | 4/20 [00:04<00:14,  1.09it/s, best_error=2.785e-04]
# Grid search for model.layers.2.post_attention_layernorm:  25%|██▌       | 5/20 [00:04<00:13,  1.09it/s, best_error=2.785e-04]
# Grid search for model.layers.2.post_attention_layernorm:  25%|██▌       | 5/20 [00:05<00:13,  1.09it/s, best_error=2.003e-04]
# Grid search for model.layers.2.post_attention_layernorm:  30%|███       | 6/20 [00:05<00:12,  1.09it/s, best_error=2.003e-04]
# ...
# Grid search for model.layers.35.input_layernorm:  20%|██        | 4/20 [00:02<00:07,  2.03it/s, best_error=7.422e-02]
# Grid search for model.layers.35.input_layernorm:  25%|██▌       | 5/20 [00:02<00:07,  2.03it/s, best_error=7.422e-02]
# Grid search for model.layers.35.input_layernorm:  25%|██▌       | 5/20 [00:02<00:07,  2.03it/s, best_error=7.422e-02]
# Grid search for model.layers.35.input_layernorm:  30%|███       | 6/20 [00:02<00:06,  2.03it/s, best_error=7.422e-02]
# Grid search for model.layers.35.input_layernorm:  30%|███       | 6/20 [00:03<00:06,  2.03it/s, best_error=7.422e-02]
# Grid search for model.layers.35.input_layernorm:  35%|███▌      | 7/20 [00:03<00:06,  2.03it/s, best_error=7.422e-02]
# Grid search for model.layers.35.input_layernorm:  35%|███▌      | 7/20 [00:03<00:06,  2.03it/s, best_error=7.422e-02]
# Grid search for model.layers.35.input_layernorm:  40%|████      | 8/20 [00:03<00:05,  2.03it/s, best_error=7.422e-02]
# Grid search for model.layers.35.input_layernorm:  40%|████      | 8/20 [00:04<00:05,  2.03it/s, best_error=7.422e-02]
# Grid search for model.layers.35.input_layernorm:  45%|████▌     | 9/20 [00:04<00:05,  2.03it/s, best_error=7.422e-02]
# Grid search for model.layers.35.input_layernorm:  45%|████▌     | 9/20 [00:04<00:05,  2.03it/s, best_error=7.422e-02]
# Grid search for model.layers.35.input_layernorm:  50%|█████     | 10/20 [00:04<00:04,  2.03it/s, best_error=7.422e-02]
# Grid search for model.layers.35.input_layernorm:  50%|█████     | 10/20 [00:05<00:04,  2.03it/s, best_error=7.422e-02]
# Grid search for model.layers.35.input_layernorm:  55%|█████▌    | 11/20 [00:05<00:04,  2.03it/s, best_error=7.422e-02]
# Grid search for model.layers.35.input_layernorm:  55%|█████▌    | 11/20 [00:05<00:04,  2.03it/s, best_error=7.422e-02]
# Grid search for model.layers.35.input_layernorm:  60%|██████    | 12/20 [00:05<00:03,  2.03it/s, best_error=7.422e-02]
# Grid search for model.layers.35.input_layernorm:  60%|██████    | 12/20 [00:06<00:03,  2.03it/s, best_error=7.422e-02]
# Grid search for model.layers.35.input_layernorm:  65%|██████▌   | 13/20 [00:06<00:03,  2.03it/s, best_error=7.422e-02]
# Grid search for model.layers.35.input_layernorm:  65%|██████▌   | 13/20 [00:06<00:03,  2.03it/s, best_error=7.422e-02]
# Grid search for model.layers.35.input_layernorm:  70%|███████   | 14/20 [00:06<00:02,  2.03it/s, best_error=7.422e-02]
# Grid search for model.layers.35.input_layernorm:  70%|███████   | 14/20 [00:07<00:02,  2.03it/s, best_error=7.422e-02]
# Grid search for model.layers.35.input_layernorm:  75%|███████▌  | 15/20 [00:07<00:02,  2.03it/s, best_error=7.422e-02]
# Grid search for model.layers.35.input_layernorm:  75%|███████▌  | 15/20 [00:07<00:02,  2.03it/s, best_error=7.422e-02]
# Grid search for model.layers.35.input_layernorm:  80%|████████  | 16/20 [00:07<00:01,  2.03it/s, best_error=7.422e-02]
# Grid search for model.layers.35.input_layernorm:  80%|████████  | 16/20 [00:08<00:01,  2.03it/s, best_error=7.422e-02]
# Grid search for model.layers.35.input_layernorm:  85%|████████▌ | 17/20 [00:08<00:01,  2.03it/s, best_error=7.422e-02]
# Grid search for model.layers.35.input_layernorm:  85%|████████▌ | 17/20 [00:08<00:01,  2.03it/s, best_error=7.422e-02]
# Grid search for model.layers.35.input_layernorm:  90%|█████████ | 18/20 [00:08<00:00,  2.03it/s, best_error=7.422e-02]
# Grid search for model.layers.35.input_layernorm:  90%|█████████ | 18/20 [00:09<00:00,  2.03it/s, best_error=7.422e-02]
# Grid search for model.layers.35.input_layernorm:  95%|█████████▌| 19/20 [00:09<00:00,  2.03it/s, best_error=7.422e-02]
# Grid search for model.layers.35.input_layernorm:  95%|█████████▌| 19/20 [00:09<00:00,  2.03it/s, best_error=7.422e-02]
# Grid search for model.layers.35.input_layernorm: 100%|██████████| 20/20 [00:09<00:00,  2.03it/s, best_error=7.422e-02]
# Smoothing:  33%|███▎      | 1/3 [00:10<00:20, 10.33s/it]
# Grid search for model.layers.35.post_attention_layernorm:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.35.post_attention_layernorm:   0%|          | 0/20 [00:00<?, ?it/s, best_error=1.019e+01]
# Grid search for model.layers.35.post_attention_layernorm:   5%|▌         | 1/20 [00:00<00:17,  1.09it/s, best_error=1.019e+01]
# Grid search for model.layers.35.post_attention_layernorm:   5%|▌         | 1/20 [00:01<00:17,  1.09it/s, best_error=1.019e+01]
# Grid search for model.layers.35.post_attention_layernorm:  10%|█         | 2/20 [00:01<00:16,  1.09it/s, best_error=1.019e+01]
# Grid search for model.layers.35.post_attention_layernorm:  10%|█         | 2/20 [00:02<00:16,  1.09it/s, best_error=1.019e+01]
# Grid search for model.layers.35.post_attention_layernorm:  15%|█▌        | 3/20 [00:02<00:15,  1.09it/s, best_error=1.019e+01]
# Grid search for model.layers.35.post_attention_layernorm:  15%|█▌        | 3/20 [00:03<00:15,  1.09it/s, best_error=1.019e+01]
# Grid search for model.layers.35.post_attention_layernorm:  20%|██        | 4/20 [00:03<00:14,  1.09it/s, best_error=1.019e+01]
# Grid search for model.layers.35.post_attention_layernorm:  20%|██        | 4/20 [00:04<00:14,  1.09it/s, best_error=9.812e+00]
# Grid search for model.layers.35.post_attention_layernorm:  25%|██▌       | 5/20 [00:04<00:13,  1.09it/s, best_error=9.812e+00]
# Grid search for model.layers.35.post_attention_layernorm:  25%|██▌       | 5/20 [00:05<00:13,  1.09it/s, best_error=9.688e+00]
# Grid search for model.layers.35.post_attention_layernorm:  30%|███       | 6/20 [00:05<00:12,  1.09it/s, best_error=9.688e+00]
# Grid search for model.layers.35.post_attention_layernorm:  30%|███       | 6/20 [00:06<00:12,  1.09it/s, best_error=9.688e+00]
# Grid search for model.layers.35.post_attention_layernorm:  35%|███▌      | 7/20 [00:06<00:11,  1.09it/s, best_error=9.688e+00]
# Grid search for model.layers.35.post_attention_layernorm:  35%|███▌      | 7/20 [00:07<00:11,  1.09it/s, best_error=9.688e+00]
# Grid search for model.layers.35.post_attention_layernorm:  40%|████      | 8/20 [00:07<00:11,  1.09it/s, best_error=9.688e+00]
# Grid search for model.layers.35.post_attention_layernorm:  40%|████      | 8/20 [00:08<00:11,  1.09it/s, best_error=9.688e+00]
# Grid search for model.layers.35.post_attention_layernorm:  45%|████▌     | 9/20 [00:08<00:10,  1.09it/s, best_error=9.688e+00]
# Grid search for model.layers.35.post_attention_layernorm:  45%|████▌     | 9/20 [00:09<00:10,  1.09it/s, best_error=9.688e+00]
# Grid search for model.layers.35.post_attention_layernorm:  50%|█████     | 10/20 [00:09<00:09,  1.09it/s, best_error=9.688e+00]
# Grid search for model.layers.35.post_attention_layernorm:  50%|█████     | 10/20 [00:10<00:09,  1.09it/s, best_error=9.625e+00]
# Grid search for model.layers.35.post_attention_layernorm:  55%|█████▌    | 11/20 [00:10<00:08,  1.09it/s, best_error=9.625e+00]
# Grid search for model.layers.35.post_attention_layernorm:  55%|█████▌    | 11/20 [00:11<00:08,  1.09it/s, best_error=9.625e+00]
# Grid search for model.layers.35.post_attention_layernorm:  60%|██████    | 12/20 [00:11<00:07,  1.09it/s, best_error=9.625e+00]
# Grid search for model.layers.35.post_attention_layernorm:  60%|██████    | 12/20 [00:11<00:07,  1.09it/s, best_error=9.625e+00]
# Grid search for model.layers.35.post_attention_layernorm:  65%|██████▌   | 13/20 [00:11<00:06,  1.09it/s, best_error=9.625e+00]
# Grid search for model.layers.35.post_attention_layernorm:  65%|██████▌   | 13/20 [00:12<00:06,  1.09it/s, best_error=9.625e+00]
# Grid search for model.layers.35.post_attention_layernorm:  70%|███████   | 14/20 [00:12<00:05,  1.09it/s, best_error=9.625e+00]
# Grid search for model.layers.35.post_attention_layernorm:  70%|███████   | 14/20 [00:13<00:05,  1.09it/s, best_error=9.625e+00]
# Grid search for model.layers.35.post_attention_layernorm:  75%|███████▌  | 15/20 [00:13<00:04,  1.09it/s, best_error=9.625e+00]
# Grid search for model.layers.35.post_attention_layernorm:  75%|███████▌  | 15/20 [00:14<00:04,  1.09it/s, best_error=9.625e+00]
# Grid search for model.layers.35.post_attention_layernorm:  80%|████████  | 16/20 [00:14<00:03,  1.09it/s, best_error=9.625e+00]
# Grid search for model.layers.35.post_attention_layernorm:  80%|████████  | 16/20 [00:15<00:03,  1.09it/s, best_error=9.625e+00]
# Grid search for model.layers.35.post_attention_layernorm:  85%|████████▌ | 17/20 [00:15<00:02,  1.09it/s, best_error=9.625e+00]
# Grid search for model.layers.35.post_attention_layernorm:  85%|████████▌ | 17/20 [00:16<00:02,  1.09it/s, best_error=9.625e+00]
# Grid search for model.layers.35.post_attention_layernorm:  90%|█████████ | 18/20 [00:16<00:01,  1.09it/s, best_error=9.625e+00]
# Grid search for model.layers.35.post_attention_layernorm:  90%|█████████ | 18/20 [00:17<00:01,  1.09it/s, best_error=9.625e+00]
# Grid search for model.layers.35.post_attention_layernorm:  95%|█████████▌| 19/20 [00:17<00:00,  1.09it/s, best_error=9.625e+00]
# Grid search for model.layers.35.post_attention_layernorm:  95%|█████████▌| 19/20 [00:18<00:00,  1.09it/s, best_error=9.625e+00]
# Grid search for model.layers.35.post_attention_layernorm: 100%|██████████| 20/20 [00:18<00:00,  1.09it/s, best_error=9.625e+00]
# Smoothing:  67%|██████▋   | 2/3 [00:29<00:15, 15.61s/it]
# Grid search for model.layers.35.mlp.up_proj:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.35.mlp.up_proj:   0%|          | 0/20 [00:00<?, ?it/s, best_error=2.266e-01]
# Grid search for model.layers.35.mlp.up_proj:   5%|▌         | 1/20 [00:00<00:06,  2.95it/s, best_error=2.266e-01]
# Grid search for model.layers.35.mlp.up_proj:   5%|▌         | 1/20 [00:00<00:06,  2.95it/s, best_error=2.266e-01]
# Grid search for model.layers.35.mlp.up_proj:  10%|█         | 2/20 [00:00<00:06,  2.96it/s, best_error=2.266e-01]
# Grid search for model.layers.35.mlp.up_proj:  10%|█         | 2/20 [00:01<00:06,  2.96it/s, best_error=2.266e-01]
# Grid search for model.layers.35.mlp.up_proj:  15%|█▌        | 3/20 [00:01<00:05,  2.96it/s, best_error=2.266e-01]
# Grid search for model.layers.35.mlp.up_proj:  15%|█▌        | 3/20 [00:01<00:05,  2.96it/s, best_error=1.875e-01]
# Grid search for model.layers.35.mlp.up_proj:  20%|██        | 4/20 [00:01<00:05,  2.95it/s, best_error=1.875e-01]
# Grid search for model.layers.35.mlp.up_proj:  20%|██        | 4/20 [00:01<00:05,  2.95it/s, best_error=1.875e-01]
# Grid search for model.layers.35.mlp.up_proj:  25%|██▌       | 5/20 [00:01<00:05,  2.94it/s, best_error=1.875e-01]
# Grid search for model.layers.35.mlp.up_proj:  25%|██▌       | 5/20 [00:02<00:05,  2.94it/s, best_error=1.875e-01]
# Grid search for model.layers.35.mlp.up_proj:  30%|███       | 6/20 [00:02<00:04,  2.94it/s, best_error=1.875e-01]
# Grid search for model.layers.35.mlp.up_proj:  30%|███       | 6/20 [00:02<00:04,  2.94it/s, best_error=1.875e-01]
# Grid search for model.layers.35.mlp.up_proj:  35%|███▌      | 7/20 [00:02<00:04,  2.93it/s, best_error=1.875e-01]
# Grid search for model.layers.35.mlp.up_proj:  35%|███▌      | 7/20 [00:02<00:04,  2.93it/s, best_error=1.875e-01]
# Grid search for model.layers.35.mlp.up_proj:  40%|████      | 8/20 [00:02<00:04,  2.93it/s, best_error=1.875e-01]
# Grid search for model.layers.35.mlp.up_proj:  40%|████      | 8/20 [00:03<00:04,  2.93it/s, best_error=1.875e-01]
# Grid search for model.layers.35.mlp.up_proj:  45%|████▌     | 9/20 [00:03<00:03,  2.93it/s, best_error=1.875e-01]
# Grid search for model.layers.35.mlp.up_proj:  45%|████▌     | 9/20 [00:03<00:03,  2.93it/s, best_error=1.875e-01]
# Grid search for model.layers.35.mlp.up_proj:  50%|█████     | 10/20 [00:03<00:03,  2.93it/s, best_error=1.875e-01]
# Grid search for model.layers.35.mlp.up_proj:  50%|█████     | 10/20 [00:03<00:03,  2.93it/s, best_error=1.875e-01]
# Grid search for model.layers.35.mlp.up_proj:  55%|█████▌    | 11/20 [00:03<00:03,  2.93it/s, best_error=1.875e-01]
# Grid search for model.layers.35.mlp.up_proj:  55%|█████▌    | 11/20 [00:04<00:03,  2.93it/s, best_error=1.875e-01]
# Grid search for model.layers.35.mlp.up_proj:  60%|██████    | 12/20 [00:04<00:02,  2.93it/s, best_error=1.875e-01]
# Grid search for model.layers.35.mlp.up_proj:  60%|██████    | 12/20 [00:04<00:02,  2.93it/s, best_error=1.875e-01]
# Grid search for model.layers.35.mlp.up_proj:  65%|██████▌   | 13/20 [00:04<00:02,  2.92it/s, best_error=1.875e-01]
# Grid search for model.layers.35.mlp.up_proj:  65%|██████▌   | 13/20 [00:04<00:02,  2.92it/s, best_error=1.875e-01]
# Grid search for model.layers.35.mlp.up_proj:  70%|███████   | 14/20 [00:04<00:02,  2.93it/s, best_error=1.875e-01]
# Grid search for model.layers.35.mlp.up_proj:  70%|███████   | 14/20 [00:05<00:02,  2.93it/s, best_error=1.875e-01]
# Grid search for model.layers.35.mlp.up_proj:  75%|███████▌  | 15/20 [00:05<00:01,  2.93it/s, best_error=1.875e-01]
# Grid search for model.layers.35.mlp.up_proj:  75%|███████▌  | 15/20 [00:05<00:01,  2.93it/s, best_error=1.875e-01]
# Grid search for model.layers.35.mlp.up_proj:  80%|████████  | 16/20 [00:05<00:01,  2.93it/s, best_error=1.875e-01]
# Grid search for model.layers.35.mlp.up_proj:  80%|████████  | 16/20 [00:05<00:01,  2.93it/s, best_error=1.875e-01]
# Grid search for model.layers.35.mlp.up_proj:  85%|████████▌ | 17/20 [00:05<00:01,  2.93it/s, best_error=1.875e-01]
# Grid search for model.layers.35.mlp.up_proj:  85%|████████▌ | 17/20 [00:06<00:01,  2.93it/s, best_error=1.875e-01]
# Grid search for model.layers.35.mlp.up_proj:  90%|█████████ | 18/20 [00:06<00:00,  2.93it/s, best_error=1.875e-01]
# Grid search for model.layers.35.mlp.up_proj:  90%|█████████ | 18/20 [00:06<00:00,  2.93it/s, best_error=1.875e-01]
# Grid search for model.layers.35.mlp.up_proj:  95%|█████████▌| 19/20 [00:06<00:00,  2.93it/s, best_error=1.875e-01]
# Grid search for model.layers.35.mlp.up_proj:  95%|█████████▌| 19/20 [00:06<00:00,  2.93it/s, best_error=1.875e-01]
# Grid search for model.layers.35.mlp.up_proj: 100%|██████████| 20/20 [00:06<00:00,  2.93it/s, best_error=1.875e-01]
# Smoothing: 100%|██████████| 3/3 [00:36<00:00, 12.27s/it]
# (36/37): Propagating: 100%|██████████| 64/64 [00:01<00:00, 41.45it/s]
# (37/37): Calibrating: 100%|██████████| 64/64 [00:00<00:00, 968.41it/s]
# Smoothing: 0it [00:00, ?it/s]
# (37/37): Propagating: 100%|██████████| 64/64 [00:00<00:00, 1036.73it/s]
# Smoothing: 0it [00:00, ?it/s]
# Updating global scales: 100%|██████████| 252/252 [00:00<00:00, 335331.41it/s]
# Fusing global scales: 799it [00:00, 401587.64it/s]
# Calibrating weights: 100%|██████████| 252/252 [00:00<00:00, 832.04it/s]
# 2026-03-19T04:20:27.504955+0000 | finalize | INFO - Compression lifecycle finalized for 1 modifiers
# 2026-03-19T04:20:27.505546+0000 | post_process | WARNING - Optimized model is not saved. To save, please provide`output_dir` as input arg.Ex. `oneshot(..., output_dir=...)`
# Qwen3ForCausalLM(
#   (model): Qwen3Model(
#     (embed_tokens): Embedding(151936, 2560)
#     (layers): ModuleList(
#       (0-35): 36 x Qwen3DecoderLayer(
#         (self_attn): Qwen3Attention(
#           (q_proj): Linear(in_features=2560, out_features=4096, bias=False)
#           (k_proj): Linear(in_features=2560, out_features=1024, bias=False)
#           (v_proj): Linear(in_features=2560, out_features=1024, bias=False)
#           (o_proj): Linear(in_features=4096, out_features=2560, bias=False)
#           (q_norm): Qwen3RMSNorm((128,), eps=1e-06)
#           (k_norm): Qwen3RMSNorm((128,), eps=1e-06)
#         )
#         (mlp): Qwen3MLP(
#           (gate_proj): Linear(in_features=2560, out_features=9728, bias=False)
#           (up_proj): Linear(in_features=2560, out_features=9728, bias=False)
#           (down_proj): Linear(in_features=9728, out_features=2560, bias=False)
#           (act_fn): SiLUActivation()
#         )
#         (input_layernorm): Qwen3RMSNorm((2560,), eps=1e-06)
#         (post_attention_layernorm): Qwen3RMSNorm((2560,), eps=1e-06)
#       )
#     )
#     (norm): Qwen3RMSNorm((2560,), eps=1e-06)
#     (rotary_emb): Qwen3RotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=2560, out_features=151936, bias=False)
# )

# %% [markdown]
# **Saving**

# %%
model.config._name_or_path = ""

model.save_pretrained(OUTPUT_DIR)#VERY IMPORTANT
tokenizer.save_pretrained(OUTPUT_DIR)

print("Model saved successfully")
# Out:
# 2026-03-19T04:20:34.983809+0000 | get_model_compressor | INFO - skip_sparsity_compression_stats set to True. Skipping sparsity compression statistic calculations. No sparsity compressor will be applied.
# Compressing model: 252it [00:31,  8.11it/s]
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py:3970: UserWarning: Attempting to save a model with offloaded modules. Ensure that unallocated cpu memory exceeds the `shard_size` (5GB default)
#   warnings.warn(
# Saving checkpoint shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Model saved successfully

# %% [markdown]
# # PUSH TO HUGGING FACE

# %%
# create repo in organization
create_repo(REPO_ID, repo_type="model", exist_ok=True)

# upload to organization repo
upload_folder(
    repo_id=REPO_ID,
    repo_type="model",
    folder_path=OUTPUT_DIR
)

print("Upload complete to organization!")
# Out:
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# Upload complete to organization!
