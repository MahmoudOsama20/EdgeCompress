# %% [markdown]
# # Libraries

# %%
# !pip install -q -U llmcompressor datasets accelerate transformers huggingface_hub
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.5/295.5 kB 8.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.5/196.5 kB 14.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 520.7/520.7 kB 32.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 94.9 MB/s eta 0:00:00:00:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 33.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 563.6/563.6 kB 36.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 MB 42.6 MB/s eta 0:00:00:00:0100:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.31.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# google-adk 1.21.0 requires google-cloud-bigquery-storage>=2.0.0, which is not installed.

# %%
import random
import numpy as np
import torch

from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    set_seed,
)

from llmcompressor import oneshot
from llmcompressor.modifiers.awq import AWQModifier

from huggingface_hub import (
    login,
    create_repo,
    upload_folder,
)

from kaggle_secrets import UserSecretsClient
from datasets import load_dataset
# Out:
# 2026-03-22 15:06:38.221024: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774191998.451997      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774191998.518725      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774191999.090061      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774191999.090105      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774191999.090108      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774191999.090111      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %% [markdown]
# # Global Variables

# %%
BASE_ID = "Qwen/Qwen3-4B"
MODEL_ID = "EdgeCompress01/Qwen3-4B-WANDA"
OUTPUT_DIR = "/kaggle/working/Qwen3-4B-WANDA-AWQ-4bit"
REPO_ID = f"EdgeCompress01/Qwen3-4B-WANDA-AWQ-4bit"
SEED = 42

# %% [markdown]
# # Functions

# %%
# --- 2. REPRODUCIBILITY ---
def set_reproducibility(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    set_seed(seed)
    # Ensure deterministic behavior in CuDNN
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    print(f"Global seed set to {seed}")

def format_chat(batch):
    texts = [
        tokenizer.apply_chat_template(
            messages,
            tokenize=False,
            add_generation_prompt=False
        )
        for messages in batch["messages"]
    ]
    return {"text": texts}

# %% [markdown]
# # Set Seed

# %%
set_reproducibility(SEED)
# Out:
# Global seed set to 42

# %% [markdown]
# # Huggingface Login

# %%
# --- 3. HUGGING FACE AUTHENTICATION ---
user_secrets = UserSecretsClient()
hf_token = user_secrets.get_secret("HF_TOKEN")
login(token=hf_token)
print("Logged in")
# Out:
# Logged in

# %% [markdown]
# # Load Model & Tokenizer

# %%
#Model
model = AutoModelForCausalLM.from_pretrained(
    MODEL_ID,
    subfolder="Models/25",
    device_map="auto",
    dtype=torch.bfloat16
)

#Tokenizer
tokenizer = AutoTokenizer.from_pretrained(BASE_ID)
# Out:
# config.json: 0.00B [00:00, ?B/s]
# Models/25/model.safetensors:   0%|          | 0.00/8.04G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/213 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]

# %% [markdown]
# # AWQ Quantization

# %% [markdown]
# **Configurations**

# %%
recipe = [
    AWQModifier(
        ignore=["lm_head", "embed_tokens"], 
        scheme="W4A16",
        targets=["Linear"]
    )
]

# %% [markdown]
# **Calibration Dataset**

# %%
dataset = load_dataset("HuggingFaceH4/ultrachat_200k", split="train_sft").shuffle(seed=SEED).select(range(64))

formatted_dataset = dataset.map(
    format_chat,
    batched=True,
    remove_columns=dataset.column_names  # keep only "text"
)
# Out:
# README.md: 0.00B [00:00, ?B/s]
# data/train_sft-00000-of-00003-a3ecf92756(…):   0%|          | 0.00/244M [00:00<?, ?B/s]
# data/train_sft-00001-of-00003-0a1804bcb6(…):   0%|          | 0.00/244M [00:00<?, ?B/s]
# data/train_sft-00002-of-00003-ee46ed25cf(…):   0%|          | 0.00/244M [00:00<?, ?B/s]
# data/test_sft-00000-of-00001-f7dfac4afe5(…):   0%|          | 0.00/81.2M [00:00<?, ?B/s]
# data/train_gen-00000-of-00003-a6c9fb894b(…):   0%|          | 0.00/244M [00:00<?, ?B/s]
# data/train_gen-00001-of-00003-d6a0402e41(…):   0%|          | 0.00/243M [00:00<?, ?B/s]
# data/train_gen-00002-of-00003-c0db75b92a(…):   0%|          | 0.00/243M [00:00<?, ?B/s]
# data/test_gen-00000-of-00001-3d4cd830914(…):   0%|          | 0.00/80.4M [00:00<?, ?B/s]
# Generating train_sft split:   0%|          | 0/207865 [00:00<?, ? examples/s]
# Generating test_sft split:   0%|          | 0/23110 [00:00<?, ? examples/s]
# Generating train_gen split:   0%|          | 0/256032 [00:00<?, ? examples/s]
# Generating test_gen split:   0%|          | 0/28304 [00:00<?, ? examples/s]
# Map:   0%|          | 0/64 [00:00<?, ? examples/s]

# %% [markdown]
# **Apply quantization**

# %%
oneshot(
    model=model,
    tokenizer=tokenizer,
    dataset=formatted_dataset,
    text_column="text",
    recipe=recipe,
    max_seq_length=512
)
# Out:
# 2026-03-22T15:08:36.150739+0000 | __init__ | WARNING - Disabling tokenizer parallelism due to threading conflict between FastTokenizer and Datasets. Set TOKENIZERS_PARALLELISM=false to suppress this warning.
# Tokenizing:   0%|          | 0/64 [00:00<?, ? examples/s]
# 2026-03-22T15:08:36.637783+0000 | _make_sampler | WARNING - Requested 512 samples but the provided dataset only has 64 samples.
# 2026-03-22T15:08:36.639268+0000 | reset | INFO - Compression lifecycle reset
# 2026-03-22T15:08:36.642028+0000 | from_modifiers | INFO - Creating recipe from modifiers
# 2026-03-22T15:08:36.724049+0000 | on_initialize | INFO - No AWQModifier.mappings provided, inferring from model...
# 2026-03-22T15:08:36.737705+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.0.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-22T15:08:36.738514+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.1.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-22T15:08:36.739586+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.2.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-22T15:08:36.740274+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.3.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-22T15:08:36.741144+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.4.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-22T15:08:36.742146+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.5.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-22T15:08:36.743851+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.6.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-22T15:08:36.744508+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.7.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-22T15:08:36.745391+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.8.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-22T15:08:36.746308+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.9.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-22T15:08:36.747512+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.10.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-22T15:08:36.748753+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.11.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-22T15:08:36.749918+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.12.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-22T15:08:36.751758+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.13.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-22T15:08:36.752667+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.14.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-22T15:08:36.753845+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.15.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-22T15:08:36.754956+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.16.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-22T15:08:36.755886+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.17.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-22T15:08:36.756841+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.18.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-22T15:08:36.757732+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.19.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-22T15:08:36.758650+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.20.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-22T15:08:36.759637+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.21.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-22T15:08:36.760498+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.22.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-22T15:08:36.761387+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.23.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-22T15:08:36.762238+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.24.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-22T15:08:36.763075+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.25.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-22T15:08:36.765444+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.26.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-22T15:08:36.766266+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.27.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-22T15:08:36.767033+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.28.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-22T15:08:36.768027+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.29.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-22T15:08:36.769022+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.30.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-22T15:08:36.769941+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.31.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-22T15:08:36.770768+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.32.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-22T15:08:36.771658+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.33.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-22T15:08:36.772645+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.34.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-22T15:08:36.773472+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.35.self_attn.v_proj for mapping AWQMapping(smooth_layer='re:.*v_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-03-22T15:08:36.786781+0000 | initialize | INFO - Compression lifecycle initialized for 1 modifiers
# 2026-03-22T15:08:36.787350+0000 | IndependentPipeline | INFO - Inferred `SequentialPipeline` for `AWQModifier`
# W0322 15:08:36.869000 55 torch/fx/_symbolic_trace.py:52] is_fx_tracing will return true for both fx.symbolic_trace and torch.export. Please use is_fx_tracing_symbolic_tracing() for specifically fx.symbolic_trace or torch.compiler.is_compiling() for specifically torch.export/compile.
# Preparing cache: 100%|██████████| 64/64 [00:00<00:00, 1145.03it/s]
# (1/37): Calibrating: 100%|██████████| 64/64 [00:02<00:00, 27.26it/s]
# Smoothing:   0%|          | 0/3 [00:00<?, ?it/s]
# Grid search for model.layers.0.input_layernorm:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.0.input_layernorm:   0%|          | 0/20 [00:00<?, ?it/s, best_error=1.931e-05]
# Grid search for model.layers.0.input_layernorm:   5%|▌         | 1/20 [00:00<00:12,  1.49it/s, best_error=1.931e-05]
# Grid search for model.layers.0.input_layernorm:   5%|▌         | 1/20 [00:01<00:12,  1.49it/s, best_error=1.800e-05]
# Grid search for model.layers.0.input_layernorm:  10%|█         | 2/20 [00:01<00:10,  1.77it/s, best_error=1.800e-05]
# Grid search for model.layers.0.input_layernorm:  10%|█         | 2/20 [00:01<00:10,  1.77it/s, best_error=1.800e-05]
# Grid search for model.layers.0.input_layernorm:  15%|█▌        | 3/20 [00:01<00:09,  1.88it/s, best_error=1.800e-05]
# Grid search for model.layers.0.input_layernorm:  15%|█▌        | 3/20 [00:02<00:09,  1.88it/s, best_error=1.693e-05]
# Grid search for model.layers.0.input_layernorm:  20%|██        | 4/20 [00:02<00:08,  1.93it/s, best_error=1.693e-05]
# Grid search for model.layers.0.input_layernorm:  20%|██        | 4/20 [00:02<00:08,  1.93it/s, best_error=1.693e-05]
# Grid search for model.layers.0.input_layernorm:  25%|██▌       | 5/20 [00:02<00:07,  1.97it/s, best_error=1.693e-05]
# Grid search for model.layers.0.input_layernorm:  25%|██▌       | 5/20 [00:03<00:07,  1.97it/s, best_error=1.681e-05]
# Grid search for model.layers.0.input_layernorm:  30%|███       | 6/20 [00:03<00:07,  1.99it/s, best_error=1.681e-05]
# Grid search for model.layers.0.input_layernorm:  30%|███       | 6/20 [00:03<00:07,  1.99it/s, best_error=1.681e-05]
# Grid search for model.layers.0.input_layernorm:  35%|███▌      | 7/20 [00:03<00:06,  2.00it/s, best_error=1.681e-05]
# Grid search for model.layers.0.input_layernorm:  35%|███▌      | 7/20 [00:04<00:06,  2.00it/s, best_error=1.681e-05]
# Grid search for model.layers.0.input_layernorm:  40%|████      | 8/20 [00:04<00:05,  2.01it/s, best_error=1.681e-05]
# Grid search for model.layers.0.input_layernorm:  40%|████      | 8/20 [00:04<00:05,  2.01it/s, best_error=1.621e-05]
# Grid search for model.layers.0.input_layernorm:  45%|████▌     | 9/20 [00:04<00:05,  2.01it/s, best_error=1.621e-05]
# Grid search for model.layers.0.input_layernorm:  45%|████▌     | 9/20 [00:05<00:05,  2.01it/s, best_error=1.621e-05]
# Grid search for model.layers.0.input_layernorm:  50%|█████     | 10/20 [00:05<00:04,  2.02it/s, best_error=1.621e-05]
# Grid search for model.layers.0.input_layernorm:  50%|█████     | 10/20 [00:05<00:04,  2.02it/s, best_error=1.621e-05]
# Grid search for model.layers.0.input_layernorm:  55%|█████▌    | 11/20 [00:05<00:04,  2.02it/s, best_error=1.621e-05]
# Grid search for model.layers.0.input_layernorm:  55%|█████▌    | 11/20 [00:06<00:04,  2.02it/s, best_error=1.621e-05]
# Grid search for model.layers.0.input_layernorm:  60%|██████    | 12/20 [00:06<00:03,  2.02it/s, best_error=1.621e-05]
# Grid search for model.layers.0.input_layernorm:  60%|██████    | 12/20 [00:06<00:03,  2.02it/s, best_error=1.621e-05]
# Grid search for model.layers.0.input_layernorm:  65%|██████▌   | 13/20 [00:06<00:03,  2.02it/s, best_error=1.621e-05]
# Grid search for model.layers.0.input_layernorm:  65%|██████▌   | 13/20 [00:07<00:03,  2.02it/s, best_error=1.621e-05]
# Grid search for model.layers.0.input_layernorm:  70%|███████   | 14/20 [00:07<00:02,  2.03it/s, best_error=1.621e-05]
# Grid search for model.layers.0.input_layernorm:  70%|███████   | 14/20 [00:07<00:02,  2.03it/s, best_error=1.621e-05]
# Grid search for model.layers.0.input_layernorm:  75%|███████▌  | 15/20 [00:07<00:02,  2.03it/s, best_error=1.621e-05]
# Grid search for model.layers.0.input_layernorm:  75%|███████▌  | 15/20 [00:08<00:02,  2.03it/s, best_error=1.621e-05]
# Grid search for model.layers.0.input_layernorm:  80%|████████  | 16/20 [00:08<00:01,  2.03it/s, best_error=1.621e-05]
# Grid search for model.layers.0.input_layernorm:  80%|████████  | 16/20 [00:08<00:01,  2.03it/s, best_error=1.621e-05]
# Grid search for model.layers.0.input_layernorm:  85%|████████▌ | 17/20 [00:08<00:01,  2.03it/s, best_error=1.621e-05]
# Grid search for model.layers.0.input_layernorm:  85%|████████▌ | 17/20 [00:09<00:01,  2.03it/s, best_error=1.621e-05]
# Grid search for model.layers.0.input_layernorm:  90%|█████████ | 18/20 [00:09<00:00,  2.03it/s, best_error=1.621e-05]
# Grid search for model.layers.0.input_layernorm:  90%|█████████ | 18/20 [00:09<00:00,  2.03it/s, best_error=1.621e-05]
# Grid search for model.layers.0.input_layernorm:  95%|█████████▌| 19/20 [00:09<00:00,  2.03it/s, best_error=1.621e-05]
# Grid search for model.layers.0.input_layernorm:  95%|█████████▌| 19/20 [00:10<00:00,  2.03it/s, best_error=1.621e-05]
# Grid search for model.layers.0.input_layernorm: 100%|██████████| 20/20 [00:10<00:00,  2.03it/s, best_error=1.621e-05]
# Smoothing:  33%|███▎      | 1/3 [00:10<00:21, 10.56s/it]
# Grid search for model.layers.0.post_attention_layernorm:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.0.post_attention_layernorm:   0%|          | 0/20 [00:00<?, ?it/s, best_error=4.792e-05]
# Grid search for model.layers.0.post_attention_layernorm:   5%|▌         | 1/20 [00:00<00:17,  1.09it/s, best_error=4.792e-05]
# Grid search for model.layers.0.post_attention_layernorm:   5%|▌         | 1/20 [00:01<00:17,  1.09it/s, best_error=4.506e-05]
# Grid search for model.layers.0.post_attention_layernorm:  10%|█         | 2/20 [00:01<00:16,  1.09it/s, best_error=4.506e-05]
# Grid search for model.layers.0.post_attention_layernorm:  10%|█         | 2/20 [00:02<00:16,  1.09it/s, best_error=4.053e-05]
# Grid search for model.layers.0.post_attention_layernorm:  15%|█▌        | 3/20 [00:02<00:15,  1.09it/s, best_error=4.053e-05]
# Grid search for model.layers.0.post_attention_layernorm:  15%|█▌        | 3/20 [00:03<00:15,  1.09it/s, best_error=3.743e-05]
# Grid search for model.layers.0.post_attention_layernorm:  20%|██        | 4/20 [00:03<00:14,  1.09it/s, best_error=3.743e-05]
# Grid search for model.layers.0.post_attention_layernorm:  20%|██        | 4/20 [00:04<00:14,  1.09it/s, best_error=3.505e-05]
# Grid search for model.layers.0.post_attention_layernorm:  25%|██▌       | 5/20 [00:04<00:13,  1.09it/s, best_error=3.505e-05]
# Grid search for model.layers.0.post_attention_layernorm:  25%|██▌       | 5/20 [00:05<00:13,  1.09it/s, best_error=3.386e-05]
# Grid search for model.layers.0.post_attention_layernorm:  30%|███       | 6/20 [00:05<00:12,  1.09it/s, best_error=3.386e-05]
# Grid search for model.layers.0.post_attention_layernorm:  30%|███       | 6/20 [00:06<00:12,  1.09it/s, best_error=3.290e-05]
# Grid search for model.layers.0.post_attention_layernorm:  35%|███▌      | 7/20 [00:06<00:11,  1.09it/s, best_error=3.290e-05]
# Grid search for model.layers.0.post_attention_layernorm:  35%|███▌      | 7/20 [00:07<00:11,  1.09it/s, best_error=3.266e-05]
# Grid search for model.layers.0.post_attention_layernorm:  40%|████      | 8/20 [00:07<00:11,  1.09it/s, best_error=3.266e-05]
# Grid search for model.layers.0.post_attention_layernorm:  40%|████      | 8/20 [00:08<00:11,  1.09it/s, best_error=3.242e-05]
# Grid search for model.layers.0.post_attention_layernorm:  45%|████▌     | 9/20 [00:08<00:10,  1.09it/s, best_error=3.242e-05]
# Grid search for model.layers.0.post_attention_layernorm:  45%|████▌     | 9/20 [00:09<00:10,  1.09it/s, best_error=3.242e-05]
# Grid search for model.layers.0.post_attention_layernorm:  50%|█████     | 10/20 [00:09<00:09,  1.09it/s, best_error=3.242e-05]
# Grid search for model.layers.0.post_attention_layernorm:  50%|█████     | 10/20 [00:10<00:09,  1.09it/s, best_error=3.242e-05]
# Grid search for model.layers.0.post_attention_layernorm:  55%|█████▌    | 11/20 [00:10<00:08,  1.09it/s, best_error=3.242e-05]
# Grid search for model.layers.0.post_attention_layernorm:  55%|█████▌    | 11/20 [00:11<00:08,  1.09it/s, best_error=3.242e-05]
# Grid search for model.layers.0.post_attention_layernorm:  60%|██████    | 12/20 [00:11<00:07,  1.09it/s, best_error=3.242e-05]
# Grid search for model.layers.0.post_attention_layernorm:  60%|██████    | 12/20 [00:11<00:07,  1.09it/s, best_error=3.242e-05]
# Grid search for model.layers.0.post_attention_layernorm:  65%|██████▌   | 13/20 [00:11<00:06,  1.09it/s, best_error=3.242e-05]
# Grid search for model.layers.0.post_attention_layernorm:  65%|██████▌   | 13/20 [00:12<00:06,  1.09it/s, best_error=3.242e-05]
# Grid search for model.layers.0.post_attention_layernorm:  70%|███████   | 14/20 [00:12<00:05,  1.09it/s, best_error=3.242e-05]
# Grid search for model.layers.0.post_attention_layernorm:  70%|███████   | 14/20 [00:13<00:05,  1.09it/s, best_error=3.242e-05]
# Grid search for model.layers.0.post_attention_layernorm:  75%|███████▌  | 15/20 [00:13<00:04,  1.09it/s, best_error=3.242e-05]
# Grid search for model.layers.0.post_attention_layernorm:  75%|███████▌  | 15/20 [00:14<00:04,  1.09it/s, best_error=3.242e-05]
# Grid search for model.layers.0.post_attention_layernorm:  80%|████████  | 16/20 [00:14<00:03,  1.09it/s, best_error=3.242e-05]
# Grid search for model.layers.0.post_attention_layernorm:  80%|████████  | 16/20 [00:15<00:03,  1.09it/s, best_error=3.242e-05]
# Grid search for model.layers.0.post_attention_layernorm:  85%|████████▌ | 17/20 [00:15<00:02,  1.09it/s, best_error=3.242e-05]
# Grid search for model.layers.0.post_attention_layernorm:  85%|████████▌ | 17/20 [00:16<00:02,  1.09it/s, best_error=3.242e-05]
# Grid search for model.layers.0.post_attention_layernorm:  90%|█████████ | 18/20 [00:16<00:01,  1.09it/s, best_error=3.242e-05]
# Grid search for model.layers.0.post_attention_layernorm:  90%|█████████ | 18/20 [00:17<00:01,  1.09it/s, best_error=3.242e-05]
# Grid search for model.layers.0.post_attention_layernorm:  95%|█████████▌| 19/20 [00:17<00:00,  1.09it/s, best_error=3.242e-05]
# Grid search for model.layers.0.post_attention_layernorm:  95%|█████████▌| 19/20 [00:18<00:00,  1.09it/s, best_error=3.242e-05]
# Grid search for model.layers.0.post_attention_layernorm: 100%|██████████| 20/20 [00:18<00:00,  1.09it/s, best_error=3.242e-05]
# Smoothing:  67%|██████▋   | 2/3 [00:29<00:15, 15.69s/it]
# Grid search for model.layers.0.mlp.up_proj:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.0.mlp.up_proj:   0%|          | 0/20 [00:00<?, ?it/s, best_error=1.383e-04]
# Grid search for model.layers.0.mlp.up_proj:   5%|▌         | 1/20 [00:00<00:06,  2.96it/s, best_error=1.383e-04]
# Grid search for model.layers.0.mlp.up_proj:   5%|▌         | 1/20 [00:00<00:06,  2.96it/s, best_error=1.326e-04]
# Grid search for model.layers.0.mlp.up_proj:  10%|█         | 2/20 [00:00<00:06,  2.95it/s, best_error=1.326e-04]
# Grid search for model.layers.0.mlp.up_proj:  10%|█         | 2/20 [00:01<00:06,  2.95it/s, best_error=1.287e-04]
# Grid search for model.layers.0.mlp.up_proj:  15%|█▌        | 3/20 [00:01<00:05,  2.96it/s, best_error=1.287e-04]
# Grid search for model.layers.0.mlp.up_proj:  15%|█▌        | 3/20 [00:01<00:05,  2.96it/s, best_error=1.249e-04]
# Grid search for model.layers.0.mlp.up_proj:  20%|██        | 4/20 [00:01<00:05,  2.96it/s, best_error=1.249e-04]
# Grid search for model.layers.0.mlp.up_proj:  20%|██        | 4/20 [00:01<00:05,  2.96it/s, best_error=1.206e-04]
# Grid search for model.layers.0.mlp.up_proj:  25%|██▌       | 5/20 [00:01<00:05,  2.96it/s, best_error=1.206e-04]
# Grid search for model.layers.0.mlp.up_proj:  25%|██▌       | 5/20 [00:02<00:05,  2.96it/s, best_error=1.183e-04]
# Grid search for model.layers.0.mlp.up_proj:  30%|███       | 6/20 [00:02<00:04,  2.95it/s, best_error=1.183e-04]
# Grid search for model.layers.0.mlp.up_proj:  30%|███       | 6/20 [00:02<00:04,  2.95it/s, best_error=1.159e-04]
# Grid search for model.layers.0.mlp.up_proj:  35%|███▌      | 7/20 [00:02<00:04,  2.95it/s, best_error=1.159e-04]
# Grid search for model.layers.0.mlp.up_proj:  35%|███▌      | 7/20 [00:02<00:04,  2.95it/s, best_error=1.144e-04]
# Grid search for model.layers.0.mlp.up_proj:  40%|████      | 8/20 [00:02<00:04,  2.94it/s, best_error=1.144e-04]
# Grid search for model.layers.0.mlp.up_proj:  40%|████      | 8/20 [00:03<00:04,  2.94it/s, best_error=1.135e-04]
# Grid search for model.layers.0.mlp.up_proj:  45%|████▌     | 9/20 [00:03<00:03,  2.94it/s, best_error=1.135e-04]
# Grid search for model.layers.0.mlp.up_proj:  45%|████▌     | 9/20 [00:03<00:03,  2.94it/s, best_error=1.135e-04]
# Grid search for model.layers.0.mlp.up_proj:  50%|█████     | 10/20 [00:03<00:03,  2.94it/s, best_error=1.135e-04]
# Grid search for model.layers.0.mlp.up_proj:  50%|█████     | 10/20 [00:03<00:03,  2.94it/s, best_error=1.130e-04]
# Grid search for model.layers.0.mlp.up_proj:  55%|█████▌    | 11/20 [00:03<00:03,  2.94it/s, best_error=1.130e-04]
# Grid search for model.layers.0.mlp.up_proj:  55%|█████▌    | 11/20 [00:04<00:03,  2.94it/s, best_error=1.130e-04]
# Grid search for model.layers.0.mlp.up_proj:  60%|██████    | 12/20 [00:04<00:02,  2.94it/s, best_error=1.130e-04]
# Grid search for model.layers.0.mlp.up_proj:  60%|██████    | 12/20 [00:04<00:02,  2.94it/s, best_error=1.130e-04]
# Grid search for model.layers.0.mlp.up_proj:  65%|██████▌   | 13/20 [00:04<00:02,  2.94it/s, best_error=1.130e-04]
# Grid search for model.layers.0.mlp.up_proj:  65%|██████▌   | 13/20 [00:04<00:02,  2.94it/s, best_error=1.130e-04]
# Grid search for model.layers.0.mlp.up_proj:  70%|███████   | 14/20 [00:04<00:02,  2.94it/s, best_error=1.130e-04]
# Grid search for model.layers.0.mlp.up_proj:  70%|███████   | 14/20 [00:05<00:02,  2.94it/s, best_error=1.130e-04]
# Grid search for model.layers.0.mlp.up_proj:  75%|███████▌  | 15/20 [00:05<00:01,  2.95it/s, best_error=1.130e-04]
# Grid search for model.layers.0.mlp.up_proj:  75%|███████▌  | 15/20 [00:05<00:01,  2.95it/s, best_error=1.130e-04]
# Grid search for model.layers.0.mlp.up_proj:  80%|████████  | 16/20 [00:05<00:01,  2.95it/s, best_error=1.130e-04]
# Grid search for model.layers.0.mlp.up_proj:  80%|████████  | 16/20 [00:05<00:01,  2.95it/s, best_error=1.130e-04]
# Grid search for model.layers.0.mlp.up_proj:  85%|████████▌ | 17/20 [00:05<00:01,  2.95it/s, best_error=1.130e-04]
# Grid search for model.layers.0.mlp.up_proj:  85%|████████▌ | 17/20 [00:06<00:01,  2.95it/s, best_error=1.130e-04]
# Grid search for model.layers.0.mlp.up_proj:  90%|█████████ | 18/20 [00:06<00:00,  2.94it/s, best_error=1.130e-04]
# Grid search for model.layers.0.mlp.up_proj:  90%|█████████ | 18/20 [00:06<00:00,  2.94it/s, best_error=1.130e-04]
# Grid search for model.layers.0.mlp.up_proj:  95%|█████████▌| 19/20 [00:06<00:00,  2.94it/s, best_error=1.130e-04]
# Grid search for model.layers.0.mlp.up_proj:  95%|█████████▌| 19/20 [00:06<00:00,  2.94it/s, best_error=1.130e-04]
# Grid search for model.layers.0.mlp.up_proj: 100%|██████████| 20/20 [00:06<00:00,  2.94it/s, best_error=1.130e-04]
# Smoothing: 100%|██████████| 3/3 [00:36<00:00, 12.32s/it]
# (1/37): Propagating: 100%|██████████| 64/64 [00:01<00:00, 37.70it/s]
# (2/37): Calibrating: 100%|██████████| 64/64 [00:01<00:00, 41.48it/s]
# Smoothing:   0%|          | 0/3 [00:00<?, ?it/s]
# Grid search for model.layers.1.input_layernorm:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.1.input_layernorm:   0%|          | 0/20 [00:00<?, ?it/s, best_error=2.635e-05]
# Grid search for model.layers.1.input_layernorm:   5%|▌         | 1/20 [00:00<00:09,  2.05it/s, best_error=2.635e-05]
# Grid search for model.layers.1.input_layernorm:   5%|▌         | 1/20 [00:00<00:09,  2.05it/s, best_error=2.408e-05]
# Grid search for model.layers.1.input_layernorm:  10%|█         | 2/20 [00:00<00:08,  2.04it/s, best_error=2.408e-05]
# Grid search for model.layers.1.input_layernorm:  10%|█         | 2/20 [00:01<00:08,  2.04it/s, best_error=2.182e-05]
# Grid search for model.layers.1.input_layernorm:  15%|█▌        | 3/20 [00:01<00:08,  2.04it/s, best_error=2.182e-05]
# Grid search for model.layers.1.input_layernorm:  15%|█▌        | 3/20 [00:01<00:08,  2.04it/s, best_error=1.931e-05]
# Grid search for model.layers.1.input_layernorm:  20%|██        | 4/20 [00:01<00:07,  2.03it/s, best_error=1.931e-05]
# Grid search for model.layers.1.input_layernorm:  20%|██        | 4/20 [00:02<00:07,  2.03it/s, best_error=1.931e-05]
# Grid search for model.layers.1.input_layernorm:  25%|██▌       | 5/20 [00:02<00:07,  2.03it/s, best_error=1.931e-05]
# Grid search for model.layers.1.input_layernorm:  25%|██▌       | 5/20 [00:02<00:07,  2.03it/s, best_error=1.931e-05]
# Grid search for model.layers.1.input_layernorm:  30%|███       | 6/20 [00:02<00:06,  2.03it/s, best_error=1.931e-05]
# Grid search for model.layers.1.input_layernorm:  30%|███       | 6/20 [00:03<00:06,  2.03it/s, best_error=1.931e-05]
# Grid search for model.layers.1.input_layernorm:  35%|███▌      | 7/20 [00:03<00:06,  2.03it/s, best_error=1.931e-05]
# Grid search for model.layers.1.input_layernorm:  35%|███▌      | 7/20 [00:03<00:06,  2.03it/s, best_error=1.895e-05]
# Grid search for model.layers.1.input_layernorm:  40%|████      | 8/20 [00:03<00:05,  2.03it/s, best_error=1.895e-05]
# Grid search for model.layers.1.input_layernorm:  40%|████      | 8/20 [00:04<00:05,  2.03it/s, best_error=1.836e-05]
# Grid search for model.layers.1.input_layernorm:  45%|████▌     | 9/20 [00:04<00:05,  2.03it/s, best_error=1.836e-05]
# Grid search for model.layers.1.input_layernorm:  45%|████▌     | 9/20 [00:04<00:05,  2.03it/s, best_error=1.836e-05]
# Grid search for model.layers.1.input_layernorm:  50%|█████     | 10/20 [00:04<00:04,  2.04it/s, best_error=1.836e-05]
# Grid search for model.layers.1.input_layernorm:  50%|█████     | 10/20 [00:05<00:04,  2.04it/s, best_error=1.836e-05]
# Grid search for model.layers.1.input_layernorm:  55%|█████▌    | 11/20 [00:05<00:04,  2.04it/s, best_error=1.836e-05]
# Grid search for model.layers.1.input_layernorm:  55%|█████▌    | 11/20 [00:05<00:04,  2.04it/s, best_error=1.836e-05]
# Grid search for model.layers.1.input_layernorm:  60%|██████    | 12/20 [00:05<00:03,  2.03it/s, best_error=1.836e-05]
# Grid search for model.layers.1.input_layernorm:  60%|██████    | 12/20 [00:06<00:03,  2.03it/s, best_error=1.836e-05]
# Grid search for model.layers.1.input_layernorm:  65%|██████▌   | 13/20 [00:06<00:03,  2.03it/s, best_error=1.836e-05]
# Grid search for model.layers.1.input_layernorm:  65%|██████▌   | 13/20 [00:06<00:03,  2.03it/s, best_error=1.836e-05]
# Grid search for model.layers.1.input_layernorm:  70%|███████   | 14/20 [00:06<00:02,  2.03it/s, best_error=1.836e-05]
# Grid search for model.layers.1.input_layernorm:  70%|███████   | 14/20 [00:07<00:02,  2.03it/s, best_error=1.836e-05]
# Grid search for model.layers.1.input_layernorm:  75%|███████▌  | 15/20 [00:07<00:02,  2.03it/s, best_error=1.836e-05]
# Grid search for model.layers.1.input_layernorm:  75%|███████▌  | 15/20 [00:07<00:02,  2.03it/s, best_error=1.836e-05]
# Grid search for model.layers.1.input_layernorm:  80%|████████  | 16/20 [00:07<00:01,  2.03it/s, best_error=1.836e-05]
# Grid search for model.layers.1.input_layernorm:  80%|████████  | 16/20 [00:08<00:01,  2.03it/s, best_error=1.836e-05]
# Grid search for model.layers.1.input_layernorm:  85%|████████▌ | 17/20 [00:08<00:01,  2.03it/s, best_error=1.836e-05]
# Grid search for model.layers.1.input_layernorm:  85%|████████▌ | 17/20 [00:08<00:01,  2.03it/s, best_error=1.836e-05]
# Grid search for model.layers.1.input_layernorm:  90%|█████████ | 18/20 [00:08<00:00,  2.03it/s, best_error=1.836e-05]
# Grid search for model.layers.1.input_layernorm:  90%|█████████ | 18/20 [00:09<00:00,  2.03it/s, best_error=1.836e-05]
# Grid search for model.layers.1.input_layernorm:  95%|█████████▌| 19/20 [00:09<00:00,  2.03it/s, best_error=1.836e-05]
# Grid search for model.layers.1.input_layernorm:  95%|█████████▌| 19/20 [00:09<00:00,  2.03it/s, best_error=1.836e-05]
# Grid search for model.layers.1.input_layernorm: 100%|██████████| 20/20 [00:09<00:00,  2.03it/s, best_error=1.836e-05]
# Smoothing:  33%|███▎      | 1/3 [00:10<00:20, 10.33s/it]
# Grid search for model.layers.1.post_attention_layernorm:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.1.post_attention_layernorm:   0%|          | 0/20 [00:00<?, ?it/s, best_error=1.808e-03]
# Grid search for model.layers.1.post_attention_layernorm:   5%|▌         | 1/20 [00:00<00:17,  1.10it/s, best_error=1.808e-03]
# Grid search for model.layers.1.post_attention_layernorm:   5%|▌         | 1/20 [00:01<00:17,  1.10it/s, best_error=1.022e-03]
# Grid search for model.layers.1.post_attention_layernorm:  10%|█         | 2/20 [00:01<00:16,  1.09it/s, best_error=1.022e-03]
# Grid search for model.layers.1.post_attention_layernorm:  10%|█         | 2/20 [00:02<00:16,  1.09it/s, best_error=5.379e-04]
# Grid search for model.layers.1.post_attention_layernorm:  15%|█▌        | 3/20 [00:02<00:15,  1.09it/s, best_error=5.379e-04]
# Grid search for model.layers.1.post_attention_layernorm:  15%|█▌        | 3/20 [00:03<00:15,  1.09it/s, best_error=4.616e-04]
# Grid search for model.layers.1.post_attention_layernorm:  20%|██        | 4/20 [00:03<00:14,  1.09it/s, best_error=4.616e-04]
# Grid search for model.layers.1.post_attention_layernorm:  20%|██        | 4/20 [00:04<00:14,  1.09it/s, best_error=3.452e-04]
# Grid search for model.layers.1.post_attention_layernorm:  25%|██▌       | 5/20 [00:04<00:13,  1.09it/s, best_error=3.452e-04]
# Grid search for model.layers.1.post_attention_layernorm:  25%|██▌       | 5/20 [00:05<00:13,  1.09it/s, best_error=1.383e-04]
# Grid search for model.layers.1.post_attention_layernorm:  30%|███       | 6/20 [00:05<00:12,  1.09it/s, best_error=1.383e-04]
# Grid search for model.layers.1.post_attention_layernorm:  30%|███       | 6/20 [00:06<00:12,  1.09it/s, best_error=1.383e-04]
# Grid search for model.layers.1.post_attention_layernorm:  35%|███▌      | 7/20 [00:06<00:11,  1.09it/s, best_error=1.383e-04]
# Grid search for model.layers.1.post_attention_layernorm:  35%|███▌      | 7/20 [00:07<00:11,  1.09it/s, best_error=1.383e-04]
# Grid search for model.layers.1.post_attention_layernorm:  40%|████      | 8/20 [00:07<00:11,  1.09it/s, best_error=1.383e-04]
# Grid search for model.layers.1.post_attention_layernorm:  40%|████      | 8/20 [00:08<00:11,  1.09it/s, best_error=1.383e-04]
# Grid search for model.layers.1.post_attention_layernorm:  45%|████▌     | 9/20 [00:08<00:10,  1.09it/s, best_error=1.383e-04]
# Grid search for model.layers.1.post_attention_layernorm:  45%|████▌     | 9/20 [00:09<00:10,  1.09it/s, best_error=1.287e-04]
# Grid search for model.layers.1.post_attention_layernorm:  50%|█████     | 10/20 [00:09<00:09,  1.09it/s, best_error=1.287e-04]
# Grid search for model.layers.1.post_attention_layernorm:  50%|█████     | 10/20 [00:10<00:09,  1.09it/s, best_error=1.287e-04]
# Grid search for model.layers.1.post_attention_layernorm:  55%|█████▌    | 11/20 [00:10<00:08,  1.09it/s, best_error=1.287e-04]
# Grid search for model.layers.1.post_attention_layernorm:  55%|█████▌    | 11/20 [00:11<00:08,  1.09it/s, best_error=1.287e-04]
# Grid search for model.layers.1.post_attention_layernorm:  60%|██████    | 12/20 [00:11<00:07,  1.09it/s, best_error=1.287e-04]
# Grid search for model.layers.1.post_attention_layernorm:  60%|██████    | 12/20 [00:11<00:07,  1.09it/s, best_error=1.287e-04]
# Grid search for model.layers.1.post_attention_layernorm:  65%|██████▌   | 13/20 [00:11<00:06,  1.09it/s, best_error=1.287e-04]
# Grid search for model.layers.1.post_attention_layernorm:  65%|██████▌   | 13/20 [00:12<00:06,  1.09it/s, best_error=1.287e-04]
# Grid search for model.layers.1.post_attention_layernorm:  70%|███████   | 14/20 [00:12<00:05,  1.09it/s, best_error=1.287e-04]
# Grid search for model.layers.1.post_attention_layernorm:  70%|███████   | 14/20 [00:13<00:05,  1.09it/s, best_error=1.287e-04]
# Grid search for model.layers.1.post_attention_layernorm:  75%|███████▌  | 15/20 [00:13<00:04,  1.09it/s, best_error=1.287e-04]
# Grid search for model.layers.1.post_attention_layernorm:  75%|███████▌  | 15/20 [00:14<00:04,  1.09it/s, best_error=1.287e-04]
# Grid search for model.layers.1.post_attention_layernorm:  80%|████████  | 16/20 [00:14<00:03,  1.09it/s, best_error=1.287e-04]
# Grid search for model.layers.1.post_attention_layernorm:  80%|████████  | 16/20 [00:15<00:03,  1.09it/s, best_error=1.287e-04]
# Grid search for model.layers.1.post_attention_layernorm:  85%|████████▌ | 17/20 [00:15<00:02,  1.09it/s, best_error=1.287e-04]
# Grid search for model.layers.1.post_attention_layernorm:  85%|████████▌ | 17/20 [00:16<00:02,  1.09it/s, best_error=1.287e-04]
# Grid search for model.layers.1.post_attention_layernorm:  90%|█████████ | 18/20 [00:16<00:01,  1.09it/s, best_error=1.287e-04]
# Grid search for model.layers.1.post_attention_layernorm:  90%|█████████ | 18/20 [00:17<00:01,  1.09it/s, best_error=1.287e-04]
# Grid search for model.layers.1.post_attention_layernorm:  95%|█████████▌| 19/20 [00:17<00:00,  1.09it/s, best_error=1.287e-04]
# Grid search for model.layers.1.post_attention_layernorm:  95%|█████████▌| 19/20 [00:18<00:00,  1.09it/s, best_error=1.287e-04]
# Grid search for model.layers.1.post_attention_layernorm: 100%|██████████| 20/20 [00:18<00:00,  1.09it/s, best_error=1.287e-04]
# Smoothing:  67%|██████▋   | 2/3 [00:29<00:15, 15.59s/it]
# Grid search for model.layers.1.mlp.up_proj:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.1.mlp.up_proj:   0%|          | 0/20 [00:00<?, ?it/s, best_error=1.732e-03]
# Grid search for model.layers.1.mlp.up_proj:   5%|▌         | 1/20 [00:00<00:06,  2.98it/s, best_error=1.732e-03]
# Grid search for model.layers.1.mlp.up_proj:   5%|▌         | 1/20 [00:00<00:06,  2.98it/s, best_error=3.624e-04]
# Grid search for model.layers.1.mlp.up_proj:  10%|█         | 2/20 [00:00<00:06,  2.95it/s, best_error=3.624e-04]
# Grid search for model.layers.1.mlp.up_proj:  10%|█         | 2/20 [00:01<00:06,  2.95it/s, best_error=2.861e-04]
# Grid search for model.layers.1.mlp.up_proj:  15%|█▌        | 3/20 [00:01<00:05,  2.96it/s, best_error=2.861e-04]
# Grid search for model.layers.1.mlp.up_proj:  15%|█▌        | 3/20 [00:01<00:05,  2.96it/s, best_error=2.861e-04]
# Grid search for model.layers.1.mlp.up_proj:  20%|██        | 4/20 [00:01<00:05,  2.95it/s, best_error=2.861e-04]
# Grid search for model.layers.1.mlp.up_proj:  20%|██        | 4/20 [00:01<00:05,  2.95it/s, best_error=2.613e-04]
# Grid search for model.layers.1.mlp.up_proj:  25%|██▌       | 5/20 [00:01<00:05,  2.95it/s, best_error=2.613e-04]
# Grid search for model.layers.1.mlp.up_proj:  25%|██▌       | 5/20 [00:02<00:05,  2.95it/s, best_error=2.260e-04]
# Grid search for model.layers.1.mlp.up_proj:  30%|███       | 6/20 [00:02<00:04,  2.95it/s, best_error=2.260e-04]
# Grid search for model.layers.1.mlp.up_proj:  30%|███       | 6/20 [00:02<00:04,  2.95it/s, best_error=2.041e-04]
# Grid search for model.layers.1.mlp.up_proj:  35%|███▌      | 7/20 [00:02<00:04,  2.95it/s, best_error=2.041e-04]
# Grid search for model.layers.1.mlp.up_proj:  35%|███▌      | 7/20 [00:02<00:04,  2.95it/s, best_error=1.955e-04]
# Grid search for model.layers.1.mlp.up_proj:  40%|████      | 8/20 [00:02<00:04,  2.95it/s, best_error=1.955e-04]
# Grid search for model.layers.1.mlp.up_proj:  40%|████      | 8/20 [00:03<00:04,  2.95it/s, best_error=1.678e-04]
# Grid search for model.layers.1.mlp.up_proj:  45%|████▌     | 9/20 [00:03<00:03,  2.95it/s, best_error=1.678e-04]
# Grid search for model.layers.1.mlp.up_proj:  45%|████▌     | 9/20 [00:03<00:03,  2.95it/s, best_error=1.564e-04]
# Grid search for model.layers.1.mlp.up_proj:  50%|█████     | 10/20 [00:03<00:03,  2.95it/s, best_error=1.564e-04]
# Grid search for model.layers.1.mlp.up_proj:  50%|█████     | 10/20 [00:03<00:03,  2.95it/s, best_error=1.564e-04]
# Grid search for model.layers.1.mlp.up_proj:  55%|█████▌    | 11/20 [00:03<00:03,  2.94it/s, best_error=1.564e-04]
# Grid search for model.layers.1.mlp.up_proj:  55%|█████▌    | 11/20 [00:04<00:03,  2.94it/s, best_error=1.564e-04]
# Grid search for model.layers.1.mlp.up_proj:  60%|██████    | 12/20 [00:04<00:02,  2.95it/s, best_error=1.564e-04]
# Grid search for model.layers.1.mlp.up_proj:  60%|██████    | 12/20 [00:04<00:02,  2.95it/s, best_error=1.564e-04]
# Grid search for model.layers.1.mlp.up_proj:  65%|██████▌   | 13/20 [00:04<00:02,  2.94it/s, best_error=1.564e-04]
# Grid search for model.layers.1.mlp.up_proj:  65%|██████▌   | 13/20 [00:04<00:02,  2.94it/s, best_error=1.564e-04]
# Grid search for model.layers.1.mlp.up_proj:  70%|███████   | 14/20 [00:04<00:02,  2.94it/s, best_error=1.564e-04]
# Grid search for model.layers.1.mlp.up_proj:  70%|███████   | 14/20 [00:05<00:02,  2.94it/s, best_error=1.564e-04]
# Grid search for model.layers.1.mlp.up_proj:  75%|███████▌  | 15/20 [00:05<00:01,  2.95it/s, best_error=1.564e-04]
# Grid search for model.layers.1.mlp.up_proj:  75%|███████▌  | 15/20 [00:05<00:01,  2.95it/s, best_error=1.564e-04]
# Grid search for model.layers.1.mlp.up_proj:  80%|████████  | 16/20 [00:05<00:01,  2.94it/s, best_error=1.564e-04]
# Grid search for model.layers.1.mlp.up_proj:  80%|████████  | 16/20 [00:05<00:01,  2.94it/s, best_error=1.564e-04]
# Grid search for model.layers.1.mlp.up_proj:  85%|████████▌ | 17/20 [00:05<00:01,  2.94it/s, best_error=1.564e-04]
# Grid search for model.layers.1.mlp.up_proj:  85%|████████▌ | 17/20 [00:06<00:01,  2.94it/s, best_error=1.564e-04]
# Grid search for model.layers.1.mlp.up_proj:  90%|█████████ | 18/20 [00:06<00:00,  2.94it/s, best_error=1.564e-04]
# Grid search for model.layers.1.mlp.up_proj:  90%|█████████ | 18/20 [00:06<00:00,  2.94it/s, best_error=1.564e-04]
# Grid search for model.layers.1.mlp.up_proj:  95%|█████████▌| 19/20 [00:06<00:00,  2.95it/s, best_error=1.564e-04]
# Grid search for model.layers.1.mlp.up_proj:  95%|█████████▌| 19/20 [00:06<00:00,  2.95it/s, best_error=1.564e-04]
# Grid search for model.layers.1.mlp.up_proj: 100%|██████████| 20/20 [00:06<00:00,  2.94it/s, best_error=1.564e-04]
# Smoothing: 100%|██████████| 3/3 [00:36<00:00, 12.25s/it]
# (2/37): Propagating: 100%|██████████| 64/64 [00:01<00:00, 41.33it/s]
# (3/37): Calibrating: 100%|██████████| 64/64 [00:01<00:00, 41.47it/s]
# Smoothing:   0%|          | 0/3 [00:00<?, ?it/s]
# Grid search for model.layers.2.input_layernorm:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.2.input_layernorm:   0%|          | 0/20 [00:00<?, ?it/s, best_error=3.600e-05]
# Grid search for model.layers.2.input_layernorm:   5%|▌         | 1/20 [00:00<00:09,  2.03it/s, best_error=3.600e-05]
# Grid search for model.layers.2.input_layernorm:   5%|▌         | 1/20 [00:00<00:09,  2.03it/s, best_error=3.552e-05]
# Grid search for model.layers.2.input_layernorm:  10%|█         | 2/20 [00:00<00:08,  2.02it/s, best_error=3.552e-05]
# Grid search for model.layers.2.input_layernorm:  10%|█         | 2/20 [00:01<00:08,  2.02it/s, best_error=3.481e-05]
# Grid search for model.layers.2.input_layernorm:  15%|█▌        | 3/20 [00:01<00:08,  2.03it/s, best_error=3.481e-05]
# Grid search for model.layers.2.input_layernorm:  15%|█▌        | 3/20 [00:01<00:08,  2.03it/s, best_error=3.338e-05]
# Grid search for model.layers.2.input_layernorm:  20%|██        | 4/20 [00:01<00:07,  2.03it/s, best_error=3.338e-05]
# Grid search for model.layers.2.input_layernorm:  20%|██        | 4/20 [00:02<00:07,  2.03it/s, best_error=3.338e-05]
# Grid search for model.layers.2.input_layernorm:  25%|██▌       | 5/20 [00:02<00:07,  2.03it/s, best_error=3.338e-05]
# Grid search for model.layers.2.input_layernorm:  25%|██▌       | 5/20 [00:02<00:07,  2.03it/s, best_error=3.338e-05]
# Grid search for model.layers.2.input_layernorm:  30%|███       | 6/20 [00:02<00:06,  2.03it/s, best_error=3.338e-05]
# Grid search for model.layers.2.input_layernorm:  30%|███       | 6/20 [00:03<00:06,  2.03it/s, best_error=3.338e-05]
# Grid search for model.layers.2.input_layernorm:  35%|███▌      | 7/20 [00:03<00:06,  2.03it/s, best_error=3.338e-05]
# Grid search for model.layers.2.input_layernorm:  35%|███▌      | 7/20 [00:03<00:06,  2.03it/s, best_error=3.338e-05]
# Grid search for model.layers.2.input_layernorm:  40%|████      | 8/20 [00:03<00:05,  2.03it/s, best_error=3.338e-05]
# Grid search for model.layers.2.input_layernorm:  40%|████      | 8/20 [00:04<00:05,  2.03it/s, best_error=3.338e-05]
# Grid search for model.layers.2.input_layernorm:  45%|████▌     | 9/20 [00:04<00:05,  2.03it/s, best_error=3.338e-05]
# Grid search for model.layers.2.input_layernorm:  45%|████▌     | 9/20 [00:04<00:05,  2.03it/s, best_error=3.338e-05]
# Grid search for model.layers.2.input_layernorm:  50%|█████     | 10/20 [00:04<00:04,  2.03it/s, best_error=3.338e-05]
# Grid search for model.layers.2.input_layernorm:  50%|█████     | 10/20 [00:05<00:04,  2.03it/s, best_error=3.338e-05]
# Grid search for model.layers.2.input_layernorm:  55%|█████▌    | 11/20 [00:05<00:04,  2.03it/s, best_error=3.338e-05]
# Grid search for model.layers.2.input_layernorm:  55%|█████▌    | 11/20 [00:05<00:04,  2.03it/s, best_error=3.338e-05]
# Grid search for model.layers.2.input_layernorm:  60%|██████    | 12/20 [00:05<00:03,  2.03it/s, best_error=3.338e-05]
# Grid search for model.layers.2.input_layernorm:  60%|██████    | 12/20 [00:06<00:03,  2.03it/s, best_error=3.338e-05]
# Grid search for model.layers.2.input_layernorm:  65%|██████▌   | 13/20 [00:06<00:03,  2.04it/s, best_error=3.338e-05]
# Grid search for model.layers.2.input_layernorm:  65%|██████▌   | 13/20 [00:06<00:03,  2.04it/s, best_error=3.338e-05]
# Grid search for model.layers.2.input_layernorm:  70%|███████   | 14/20 [00:06<00:02,  2.04it/s, best_error=3.338e-05]
# Grid search for model.layers.2.input_layernorm:  70%|███████   | 14/20 [00:07<00:02,  2.04it/s, best_error=3.338e-05]
# Grid search for model.layers.2.input_layernorm:  75%|███████▌  | 15/20 [00:07<00:02,  2.03it/s, best_error=3.338e-05]
# Grid search for model.layers.2.input_layernorm:  75%|███████▌  | 15/20 [00:07<00:02,  2.03it/s, best_error=3.338e-05]
# Grid search for model.layers.2.input_layernorm:  80%|████████  | 16/20 [00:07<00:01,  2.03it/s, best_error=3.338e-05]
# Grid search for model.layers.2.input_layernorm:  80%|████████  | 16/20 [00:08<00:01,  2.03it/s, best_error=3.338e-05]
# Grid search for model.layers.2.input_layernorm:  85%|████████▌ | 17/20 [00:08<00:01,  2.03it/s, best_error=3.338e-05]
# Grid search for model.layers.2.input_layernorm:  85%|████████▌ | 17/20 [00:08<00:01,  2.03it/s, best_error=3.338e-05]
# Grid search for model.layers.2.input_layernorm:  90%|█████████ | 18/20 [00:08<00:00,  2.03it/s, best_error=3.338e-05]
# Grid search for model.layers.2.input_layernorm:  90%|█████████ | 18/20 [00:09<00:00,  2.03it/s, best_error=3.338e-05]
# Grid search for model.layers.2.input_layernorm:  95%|█████████▌| 19/20 [00:09<00:00,  2.03it/s, best_error=3.338e-05]
# Grid search for model.layers.2.input_layernorm:  95%|█████████▌| 19/20 [00:09<00:00,  2.03it/s, best_error=3.338e-05]
# Grid search for model.layers.2.input_layernorm: 100%|██████████| 20/20 [00:09<00:00,  2.03it/s, best_error=3.338e-05]
# Smoothing:  33%|███▎      | 1/3 [00:10<00:20, 10.33s/it]
# Grid search for model.layers.2.post_attention_layernorm:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.2.post_attention_layernorm:   0%|          | 0/20 [00:00<?, ?it/s, best_error=4.852e-03]
# Grid search for model.layers.2.post_attention_layernorm:   5%|▌         | 1/20 [00:00<00:17,  1.09it/s, best_error=4.852e-03]
# Grid search for model.layers.2.post_attention_layernorm:   5%|▌         | 1/20 [00:01<00:17,  1.09it/s, best_error=1.671e-03]
# Grid search for model.layers.2.post_attention_layernorm:  10%|█         | 2/20 [00:01<00:16,  1.09it/s, best_error=1.671e-03]
# Grid search for model.layers.2.post_attention_layernorm:  10%|█         | 2/20 [00:02<00:16,  1.09it/s, best_error=1.022e-03]
# Grid search for model.layers.2.post_attention_layernorm:  15%|█▌        | 3/20 [00:02<00:15,  1.09it/s, best_error=1.022e-03]
# Grid search for model.layers.2.post_attention_layernorm:  15%|█▌        | 3/20 [00:03<00:15,  1.09it/s, best_error=5.264e-04]
# Grid search for model.layers.2.post_attention_layernorm:  20%|██        | 4/20 [00:03<00:14,  1.09it/s, best_error=5.264e-04]
# Grid search for model.layers.2.post_attention_layernorm:  20%|██        | 4/20 [00:04<00:14,  1.09it/s, best_error=3.853e-04]
# Grid search for model.layers.2.post_attention_layernorm:  25%|██▌       | 5/20 [00:04<00:13,  1.09it/s, best_error=3.853e-04]
# Grid search for model.layers.2.post_attention_layernorm:  25%|██▌       | 5/20 [00:05<00:13,  1.09it/s, best_error=2.413e-04]
# Grid search for model.layers.2.post_attention_layernorm:  30%|███       | 6/20 [00:05<00:12,  1.09it/s, best_error=2.413e-04]
# ...
# Grid search for model.layers.35.input_layernorm:  20%|██        | 4/20 [00:02<00:07,  2.03it/s, best_error=5.273e-02]
# Grid search for model.layers.35.input_layernorm:  25%|██▌       | 5/20 [00:02<00:07,  2.03it/s, best_error=5.273e-02]
# Grid search for model.layers.35.input_layernorm:  25%|██▌       | 5/20 [00:02<00:07,  2.03it/s, best_error=5.273e-02]
# Grid search for model.layers.35.input_layernorm:  30%|███       | 6/20 [00:02<00:06,  2.03it/s, best_error=5.273e-02]
# Grid search for model.layers.35.input_layernorm:  30%|███       | 6/20 [00:03<00:06,  2.03it/s, best_error=5.273e-02]
# Grid search for model.layers.35.input_layernorm:  35%|███▌      | 7/20 [00:03<00:06,  2.03it/s, best_error=5.273e-02]
# Grid search for model.layers.35.input_layernorm:  35%|███▌      | 7/20 [00:03<00:06,  2.03it/s, best_error=5.273e-02]
# Grid search for model.layers.35.input_layernorm:  40%|████      | 8/20 [00:03<00:05,  2.03it/s, best_error=5.273e-02]
# Grid search for model.layers.35.input_layernorm:  40%|████      | 8/20 [00:04<00:05,  2.03it/s, best_error=5.273e-02]
# Grid search for model.layers.35.input_layernorm:  45%|████▌     | 9/20 [00:04<00:05,  2.03it/s, best_error=5.273e-02]
# Grid search for model.layers.35.input_layernorm:  45%|████▌     | 9/20 [00:04<00:05,  2.03it/s, best_error=5.273e-02]
# Grid search for model.layers.35.input_layernorm:  50%|█████     | 10/20 [00:04<00:04,  2.03it/s, best_error=5.273e-02]
# Grid search for model.layers.35.input_layernorm:  50%|█████     | 10/20 [00:05<00:04,  2.03it/s, best_error=5.273e-02]
# Grid search for model.layers.35.input_layernorm:  55%|█████▌    | 11/20 [00:05<00:04,  2.03it/s, best_error=5.273e-02]
# Grid search for model.layers.35.input_layernorm:  55%|█████▌    | 11/20 [00:05<00:04,  2.03it/s, best_error=5.273e-02]
# Grid search for model.layers.35.input_layernorm:  60%|██████    | 12/20 [00:05<00:03,  2.03it/s, best_error=5.273e-02]
# Grid search for model.layers.35.input_layernorm:  60%|██████    | 12/20 [00:06<00:03,  2.03it/s, best_error=5.273e-02]
# Grid search for model.layers.35.input_layernorm:  65%|██████▌   | 13/20 [00:06<00:03,  2.03it/s, best_error=5.273e-02]
# Grid search for model.layers.35.input_layernorm:  65%|██████▌   | 13/20 [00:06<00:03,  2.03it/s, best_error=5.273e-02]
# Grid search for model.layers.35.input_layernorm:  70%|███████   | 14/20 [00:06<00:02,  2.03it/s, best_error=5.273e-02]
# Grid search for model.layers.35.input_layernorm:  70%|███████   | 14/20 [00:07<00:02,  2.03it/s, best_error=5.273e-02]
# Grid search for model.layers.35.input_layernorm:  75%|███████▌  | 15/20 [00:07<00:02,  2.03it/s, best_error=5.273e-02]
# Grid search for model.layers.35.input_layernorm:  75%|███████▌  | 15/20 [00:07<00:02,  2.03it/s, best_error=5.273e-02]
# Grid search for model.layers.35.input_layernorm:  80%|████████  | 16/20 [00:07<00:01,  2.03it/s, best_error=5.273e-02]
# Grid search for model.layers.35.input_layernorm:  80%|████████  | 16/20 [00:08<00:01,  2.03it/s, best_error=5.273e-02]
# Grid search for model.layers.35.input_layernorm:  85%|████████▌ | 17/20 [00:08<00:01,  2.03it/s, best_error=5.273e-02]
# Grid search for model.layers.35.input_layernorm:  85%|████████▌ | 17/20 [00:08<00:01,  2.03it/s, best_error=5.273e-02]
# Grid search for model.layers.35.input_layernorm:  90%|█████████ | 18/20 [00:08<00:00,  2.03it/s, best_error=5.273e-02]
# Grid search for model.layers.35.input_layernorm:  90%|█████████ | 18/20 [00:09<00:00,  2.03it/s, best_error=5.273e-02]
# Grid search for model.layers.35.input_layernorm:  95%|█████████▌| 19/20 [00:09<00:00,  2.03it/s, best_error=5.273e-02]
# Grid search for model.layers.35.input_layernorm:  95%|█████████▌| 19/20 [00:09<00:00,  2.03it/s, best_error=5.273e-02]
# Grid search for model.layers.35.input_layernorm: 100%|██████████| 20/20 [00:09<00:00,  2.03it/s, best_error=5.273e-02]
# Smoothing:  33%|███▎      | 1/3 [00:10<00:20, 10.36s/it]
# Grid search for model.layers.35.post_attention_layernorm:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.35.post_attention_layernorm:   0%|          | 0/20 [00:00<?, ?it/s, best_error=1.088e+01]
# Grid search for model.layers.35.post_attention_layernorm:   5%|▌         | 1/20 [00:00<00:17,  1.09it/s, best_error=1.088e+01]
# Grid search for model.layers.35.post_attention_layernorm:   5%|▌         | 1/20 [00:01<00:17,  1.09it/s, best_error=1.038e+01]
# Grid search for model.layers.35.post_attention_layernorm:  10%|█         | 2/20 [00:01<00:16,  1.09it/s, best_error=1.038e+01]
# Grid search for model.layers.35.post_attention_layernorm:  10%|█         | 2/20 [00:02<00:16,  1.09it/s, best_error=1.000e+01]
# Grid search for model.layers.35.post_attention_layernorm:  15%|█▌        | 3/20 [00:02<00:15,  1.09it/s, best_error=1.000e+01]
# Grid search for model.layers.35.post_attention_layernorm:  15%|█▌        | 3/20 [00:03<00:15,  1.09it/s, best_error=9.750e+00]
# Grid search for model.layers.35.post_attention_layernorm:  20%|██        | 4/20 [00:03<00:14,  1.09it/s, best_error=9.750e+00]
# Grid search for model.layers.35.post_attention_layernorm:  20%|██        | 4/20 [00:04<00:14,  1.09it/s, best_error=9.625e+00]
# Grid search for model.layers.35.post_attention_layernorm:  25%|██▌       | 5/20 [00:04<00:13,  1.09it/s, best_error=9.625e+00]
# Grid search for model.layers.35.post_attention_layernorm:  25%|██▌       | 5/20 [00:05<00:13,  1.09it/s, best_error=9.625e+00]
# Grid search for model.layers.35.post_attention_layernorm:  30%|███       | 6/20 [00:05<00:12,  1.09it/s, best_error=9.625e+00]
# Grid search for model.layers.35.post_attention_layernorm:  30%|███       | 6/20 [00:06<00:12,  1.09it/s, best_error=9.625e+00]
# Grid search for model.layers.35.post_attention_layernorm:  35%|███▌      | 7/20 [00:06<00:11,  1.09it/s, best_error=9.625e+00]
# Grid search for model.layers.35.post_attention_layernorm:  35%|███▌      | 7/20 [00:07<00:11,  1.09it/s, best_error=9.625e+00]
# Grid search for model.layers.35.post_attention_layernorm:  40%|████      | 8/20 [00:07<00:11,  1.09it/s, best_error=9.625e+00]
# Grid search for model.layers.35.post_attention_layernorm:  40%|████      | 8/20 [00:08<00:11,  1.09it/s, best_error=9.625e+00]
# Grid search for model.layers.35.post_attention_layernorm:  45%|████▌     | 9/20 [00:08<00:10,  1.09it/s, best_error=9.625e+00]
# Grid search for model.layers.35.post_attention_layernorm:  45%|████▌     | 9/20 [00:09<00:10,  1.09it/s, best_error=9.625e+00]
# Grid search for model.layers.35.post_attention_layernorm:  50%|█████     | 10/20 [00:09<00:09,  1.09it/s, best_error=9.625e+00]
# Grid search for model.layers.35.post_attention_layernorm:  50%|█████     | 10/20 [00:10<00:09,  1.09it/s, best_error=9.625e+00]
# Grid search for model.layers.35.post_attention_layernorm:  55%|█████▌    | 11/20 [00:10<00:08,  1.09it/s, best_error=9.625e+00]
# Grid search for model.layers.35.post_attention_layernorm:  55%|█████▌    | 11/20 [00:11<00:08,  1.09it/s, best_error=9.562e+00]
# Grid search for model.layers.35.post_attention_layernorm:  60%|██████    | 12/20 [00:11<00:07,  1.09it/s, best_error=9.562e+00]
# Grid search for model.layers.35.post_attention_layernorm:  60%|██████    | 12/20 [00:11<00:07,  1.09it/s, best_error=9.562e+00]
# Grid search for model.layers.35.post_attention_layernorm:  65%|██████▌   | 13/20 [00:11<00:06,  1.09it/s, best_error=9.562e+00]
# Grid search for model.layers.35.post_attention_layernorm:  65%|██████▌   | 13/20 [00:12<00:06,  1.09it/s, best_error=9.562e+00]
# Grid search for model.layers.35.post_attention_layernorm:  70%|███████   | 14/20 [00:12<00:05,  1.09it/s, best_error=9.562e+00]
# Grid search for model.layers.35.post_attention_layernorm:  70%|███████   | 14/20 [00:13<00:05,  1.09it/s, best_error=9.562e+00]
# Grid search for model.layers.35.post_attention_layernorm:  75%|███████▌  | 15/20 [00:13<00:04,  1.09it/s, best_error=9.562e+00]
# Grid search for model.layers.35.post_attention_layernorm:  75%|███████▌  | 15/20 [00:14<00:04,  1.09it/s, best_error=9.562e+00]
# Grid search for model.layers.35.post_attention_layernorm:  80%|████████  | 16/20 [00:14<00:03,  1.09it/s, best_error=9.562e+00]
# Grid search for model.layers.35.post_attention_layernorm:  80%|████████  | 16/20 [00:15<00:03,  1.09it/s, best_error=9.562e+00]
# Grid search for model.layers.35.post_attention_layernorm:  85%|████████▌ | 17/20 [00:15<00:02,  1.09it/s, best_error=9.562e+00]
# Grid search for model.layers.35.post_attention_layernorm:  85%|████████▌ | 17/20 [00:16<00:02,  1.09it/s, best_error=9.562e+00]
# Grid search for model.layers.35.post_attention_layernorm:  90%|█████████ | 18/20 [00:16<00:01,  1.09it/s, best_error=9.562e+00]
# Grid search for model.layers.35.post_attention_layernorm:  90%|█████████ | 18/20 [00:17<00:01,  1.09it/s, best_error=9.562e+00]
# Grid search for model.layers.35.post_attention_layernorm:  95%|█████████▌| 19/20 [00:17<00:00,  1.09it/s, best_error=9.562e+00]
# Grid search for model.layers.35.post_attention_layernorm:  95%|█████████▌| 19/20 [00:18<00:00,  1.09it/s, best_error=9.562e+00]
# Grid search for model.layers.35.post_attention_layernorm: 100%|██████████| 20/20 [00:18<00:00,  1.09it/s, best_error=9.562e+00]
# Smoothing:  67%|██████▋   | 2/3 [00:29<00:15, 15.61s/it]
# Grid search for model.layers.35.mlp.up_proj:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.35.mlp.up_proj:   0%|          | 0/20 [00:00<?, ?it/s, best_error=2.930e-01]
# Grid search for model.layers.35.mlp.up_proj:   5%|▌         | 1/20 [00:00<00:06,  2.95it/s, best_error=2.930e-01]
# Grid search for model.layers.35.mlp.up_proj:   5%|▌         | 1/20 [00:00<00:06,  2.95it/s, best_error=2.598e-01]
# Grid search for model.layers.35.mlp.up_proj:  10%|█         | 2/20 [00:00<00:06,  2.94it/s, best_error=2.598e-01]
# Grid search for model.layers.35.mlp.up_proj:  10%|█         | 2/20 [00:01<00:06,  2.94it/s, best_error=2.080e-01]
# Grid search for model.layers.35.mlp.up_proj:  15%|█▌        | 3/20 [00:01<00:05,  2.95it/s, best_error=2.080e-01]
# Grid search for model.layers.35.mlp.up_proj:  15%|█▌        | 3/20 [00:01<00:05,  2.95it/s, best_error=2.080e-01]
# Grid search for model.layers.35.mlp.up_proj:  20%|██        | 4/20 [00:01<00:05,  2.96it/s, best_error=2.080e-01]
# Grid search for model.layers.35.mlp.up_proj:  20%|██        | 4/20 [00:01<00:05,  2.96it/s, best_error=2.080e-01]
# Grid search for model.layers.35.mlp.up_proj:  25%|██▌       | 5/20 [00:01<00:05,  2.95it/s, best_error=2.080e-01]
# Grid search for model.layers.35.mlp.up_proj:  25%|██▌       | 5/20 [00:02<00:05,  2.95it/s, best_error=2.080e-01]
# Grid search for model.layers.35.mlp.up_proj:  30%|███       | 6/20 [00:02<00:04,  2.94it/s, best_error=2.080e-01]
# Grid search for model.layers.35.mlp.up_proj:  30%|███       | 6/20 [00:02<00:04,  2.94it/s, best_error=1.992e-01]
# Grid search for model.layers.35.mlp.up_proj:  35%|███▌      | 7/20 [00:02<00:04,  2.94it/s, best_error=1.992e-01]
# Grid search for model.layers.35.mlp.up_proj:  35%|███▌      | 7/20 [00:02<00:04,  2.94it/s, best_error=1.895e-01]
# Grid search for model.layers.35.mlp.up_proj:  40%|████      | 8/20 [00:02<00:04,  2.94it/s, best_error=1.895e-01]
# Grid search for model.layers.35.mlp.up_proj:  40%|████      | 8/20 [00:03<00:04,  2.94it/s, best_error=1.816e-01]
# Grid search for model.layers.35.mlp.up_proj:  45%|████▌     | 9/20 [00:03<00:03,  2.94it/s, best_error=1.816e-01]
# Grid search for model.layers.35.mlp.up_proj:  45%|████▌     | 9/20 [00:03<00:03,  2.94it/s, best_error=1.816e-01]
# Grid search for model.layers.35.mlp.up_proj:  50%|█████     | 10/20 [00:03<00:03,  2.95it/s, best_error=1.816e-01]
# Grid search for model.layers.35.mlp.up_proj:  50%|█████     | 10/20 [00:03<00:03,  2.95it/s, best_error=1.816e-01]
# Grid search for model.layers.35.mlp.up_proj:  55%|█████▌    | 11/20 [00:03<00:03,  2.94it/s, best_error=1.816e-01]
# Grid search for model.layers.35.mlp.up_proj:  55%|█████▌    | 11/20 [00:04<00:03,  2.94it/s, best_error=1.816e-01]
# Grid search for model.layers.35.mlp.up_proj:  60%|██████    | 12/20 [00:04<00:02,  2.94it/s, best_error=1.816e-01]
# Grid search for model.layers.35.mlp.up_proj:  60%|██████    | 12/20 [00:04<00:02,  2.94it/s, best_error=1.816e-01]
# Grid search for model.layers.35.mlp.up_proj:  65%|██████▌   | 13/20 [00:04<00:02,  2.94it/s, best_error=1.816e-01]
# Grid search for model.layers.35.mlp.up_proj:  65%|██████▌   | 13/20 [00:04<00:02,  2.94it/s, best_error=1.816e-01]
# Grid search for model.layers.35.mlp.up_proj:  70%|███████   | 14/20 [00:04<00:02,  2.93it/s, best_error=1.816e-01]
# Grid search for model.layers.35.mlp.up_proj:  70%|███████   | 14/20 [00:05<00:02,  2.93it/s, best_error=1.816e-01]
# Grid search for model.layers.35.mlp.up_proj:  75%|███████▌  | 15/20 [00:05<00:01,  2.93it/s, best_error=1.816e-01]
# Grid search for model.layers.35.mlp.up_proj:  75%|███████▌  | 15/20 [00:05<00:01,  2.93it/s, best_error=1.816e-01]
# Grid search for model.layers.35.mlp.up_proj:  80%|████████  | 16/20 [00:05<00:01,  2.94it/s, best_error=1.816e-01]
# Grid search for model.layers.35.mlp.up_proj:  80%|████████  | 16/20 [00:05<00:01,  2.94it/s, best_error=1.816e-01]
# Grid search for model.layers.35.mlp.up_proj:  85%|████████▌ | 17/20 [00:05<00:01,  2.94it/s, best_error=1.816e-01]
# Grid search for model.layers.35.mlp.up_proj:  85%|████████▌ | 17/20 [00:06<00:01,  2.94it/s, best_error=1.816e-01]
# Grid search for model.layers.35.mlp.up_proj:  90%|█████████ | 18/20 [00:06<00:00,  2.94it/s, best_error=1.816e-01]
# Grid search for model.layers.35.mlp.up_proj:  90%|█████████ | 18/20 [00:06<00:00,  2.94it/s, best_error=1.816e-01]
# Grid search for model.layers.35.mlp.up_proj:  95%|█████████▌| 19/20 [00:06<00:00,  2.94it/s, best_error=1.816e-01]
# Grid search for model.layers.35.mlp.up_proj:  95%|█████████▌| 19/20 [00:06<00:00,  2.94it/s, best_error=1.816e-01]
# Grid search for model.layers.35.mlp.up_proj: 100%|██████████| 20/20 [00:06<00:00,  2.94it/s, best_error=1.816e-01]
# Smoothing: 100%|██████████| 3/3 [00:36<00:00, 12.27s/it]
# (36/37): Propagating: 100%|██████████| 64/64 [00:01<00:00, 41.50it/s]
# (37/37): Calibrating: 100%|██████████| 64/64 [00:00<00:00, 943.93it/s]
# Smoothing: 0it [00:00, ?it/s]
# (37/37): Propagating: 100%|██████████| 64/64 [00:00<00:00, 989.47it/s]
# Smoothing: 0it [00:00, ?it/s]
# Updating global scales: 100%|██████████| 252/252 [00:00<00:00, 265036.26it/s]
# Fusing global scales: 799it [00:00, 347171.75it/s]
# Calibrating weights: 100%|██████████| 252/252 [00:00<00:00, 821.66it/s]
# 2026-03-22T15:32:33.865285+0000 | finalize | INFO - Compression lifecycle finalized for 1 modifiers
# 2026-03-22T15:32:33.865865+0000 | post_process | WARNING - Optimized model is not saved. To save, please provide`output_dir` as input arg.Ex. `oneshot(..., output_dir=...)`
# Qwen3ForCausalLM(
#   (model): Qwen3Model(
#     (embed_tokens): Embedding(151936, 2560)
#     (layers): ModuleList(
#       (0-35): 36 x Qwen3DecoderLayer(
#         (self_attn): Qwen3Attention(
#           (q_proj): Linear(in_features=2560, out_features=4096, bias=False)
#           (k_proj): Linear(in_features=2560, out_features=1024, bias=False)
#           (v_proj): Linear(in_features=2560, out_features=1024, bias=False)
#           (o_proj): Linear(in_features=4096, out_features=2560, bias=False)
#           (q_norm): Qwen3RMSNorm((128,), eps=1e-06)
#           (k_norm): Qwen3RMSNorm((128,), eps=1e-06)
#         )
#         (mlp): Qwen3MLP(
#           (gate_proj): Linear(in_features=2560, out_features=9728, bias=False)
#           (up_proj): Linear(in_features=2560, out_features=9728, bias=False)
#           (down_proj): Linear(in_features=9728, out_features=2560, bias=False)
#           (act_fn): SiLUActivation()
#         )
#         (input_layernorm): Qwen3RMSNorm((2560,), eps=1e-06)
#         (post_attention_layernorm): Qwen3RMSNorm((2560,), eps=1e-06)
#       )
#     )
#     (norm): Qwen3RMSNorm((2560,), eps=1e-06)
#     (rotary_emb): Qwen3RotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=2560, out_features=151936, bias=False)
# )

# %% [markdown]
# **Saving**

# %%
model.config._name_or_path = ""

model.save_pretrained(OUTPUT_DIR,skip_sparsity_compression_stats=False)#VERY IMPORTANT
tokenizer.save_pretrained(OUTPUT_DIR)

print("Model saved successfully")
# Out:
# Calculating model sparsity: 100%|██████████| 903/903 [00:20<00:00, 43.36it/s]
# Checking whether model follows 2:4 sparsity structure: 100%|██████████| 253/253 [00:22<00:00, 11.19it/s]
# Compressing model: 252it [00:33,  7.46it/s]
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py:3970: UserWarning: Attempting to save a model with offloaded modules. Ensure that unallocated cpu memory exceeds the `shard_size` (5GB default)
#   warnings.warn(
# Saving checkpoint shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Model saved successfully

# %% [markdown]
# # PUSH TO HUGGING FACE

# %%
create_repo(REPO_ID, repo_type="model", exist_ok=True)

upload_folder(
    folder_path=OUTPUT_DIR,
    repo_id=REPO_ID,
    path_in_repo="Sparsity/25"
)
# Out:
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# CommitInfo(commit_url='https://huggingface.co/EdgeCompress01/Qwen3-4B-WANDA-AWQ-4bit/commit/ae6ca6ca89f324243b58ac4bb487a0ea744cf508', commit_message='Upload folder using huggingface_hub', commit_description='', oid='ae6ca6ca89f324243b58ac4bb487a0ea744cf508', pr_url=None, repo_url=RepoUrl('https://huggingface.co/EdgeCompress01/Qwen3-4B-WANDA-AWQ-4bit', endpoint='https://huggingface.co', repo_type='model', repo_id='EdgeCompress01/Qwen3-4B-WANDA-AWQ-4bit'), pr_revision=None, pr_num=None)
