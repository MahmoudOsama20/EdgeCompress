# %% [markdown]
# # Libraries

# %%
# 0. Clean slate — remove existing copies before reinstalling
# !pip uninstall -y torch torchvision torchaudio torchao

# 3. HuggingFace ecosystem + llmcompressor
# !pip install -q -U \
    transformers \
    accelerate \
    datasets \
    huggingface_hub \
    llmcompressor
# Out:
# Found existing installation: torch 2.10.0+cu128
# Uninstalling torch-2.10.0+cu128:
#   Successfully uninstalled torch-2.10.0+cu128
# Found existing installation: torchvision 0.25.0+cu128
# Uninstalling torchvision-0.25.0+cu128:
#   Successfully uninstalled torchvision-0.25.0+cu128
# Found existing installation: torchaudio 2.10.0+cu128
# Uninstalling torchaudio-2.10.0+cu128:
#   Successfully uninstalled torchaudio-2.10.0+cu128
# Found existing installation: torchao 0.10.0
# Uninstalling torchao-0.10.0:
#   Successfully uninstalled torchao-0.10.0
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.5/295.5 kB 7.4 MB/s eta 0:00:00ta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.5/196.5 kB 10.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 64.0 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 520.7/520.7 kB 27.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 29.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 563.6/563.6 kB 30.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.7/119.7 kB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 915.6/915.6 MB 2.1 MB/s eta 0:00:00:00:0100:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# easyocr 1.7.2 requires torchvision>=0.5, which is not installed.
# fastai 2.8.7 requires torchvision>=0.11, which is not installed.
# timm 1.0.25 requires torchvision, which is not installed.

# %%
import random
import numpy as np
import torch

from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    set_seed,
)

from llmcompressor import oneshot
from llmcompressor.modifiers.awq import AWQModifier

from huggingface_hub import (
    login,
    create_repo,
    upload_folder,
)

from kaggle_secrets import UserSecretsClient
from datasets import load_dataset
# Out:
# 2026-05-04 19:23:40.124396: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777922620.329866      57 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777922620.397518      57 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777922620.901798      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777922620.901855      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777922620.901858      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777922620.901860      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %% [markdown]
# # Global Variables

# %%
BASE_ID = "microsoft/Phi-4-mini-instruct"
MODEL_ID = "EdgeCompress01/Phi-4-mini-instruct-WANDA"
OUTPUT_DIR = "/kaggle/working/Phi-4-mini-instruct-WANDA-AWQ-4bit"
REPO_ID = f"EdgeCompress01/Phi-4-mini-instruct-WANDA-AWQ-4bit"
SEED = 42

# %% [markdown]
# # Functions

# %%
# --- 2. REPRODUCIBILITY ---
def set_reproducibility(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    set_seed(seed)
    # Ensure deterministic behavior in CuDNN
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    print(f"Global seed set to {seed}")

def format_chat(batch):
    texts = [
        tokenizer.apply_chat_template(
            messages,
            tokenize=False,
            add_generation_prompt=False
        )
        for messages in batch["messages"]
    ]
    return {"text": texts}

# %% [markdown]
# # Set Seed

# %%
set_reproducibility(SEED)
# Out:
# Global seed set to 42

# %% [markdown]
# # Huggingface Login

# %%
# --- 3. HUGGING FACE AUTHENTICATION ---
user_secrets = UserSecretsClient()
hf_token = user_secrets.get_secret("HF_TOKEN")
login(token=hf_token)
print("Logged in")
# Out:
# Logged in

# %% [markdown]
# # Load Model & Tokenizer

# %%
#Model
model = AutoModelForCausalLM.from_pretrained(
    MODEL_ID,
    subfolder="Models/25",
    device_map="auto",
    dtype=torch.bfloat16
)

#Tokenizer
tokenizer = AutoTokenizer.from_pretrained(BASE_ID)
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Models/25/model-00002-of-00002.safetenso(…):   0%|          | 0.00/2.77G [00:00<?, ?B/s]
# Models/25/model-00001-of-00002.safetenso(…):   0%|          | 0.00/4.90G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/169 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/15.5M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/249 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/587 [00:00<?, ?B/s]

# %% [markdown]
# # AWQ Quantization

# %% [markdown]
# **Configurations**

# %%
recipe = [
    AWQModifier(
        ignore=["lm_head", "embed_tokens"], 
        scheme="W4A16",
        targets=["Linear"]
    )
]

# %% [markdown]
# **Calibration Dataset**

# %%
dataset = load_dataset("HuggingFaceH4/ultrachat_200k", split="train_sft").shuffle(seed=SEED).select(range(64))

formatted_dataset = dataset.map(
    format_chat,
    batched=True,
    remove_columns=dataset.column_names  # keep only "text"
)
# Out:
# README.md: 0.00B [00:00, ?B/s]
# data/train_sft-00000-of-00003-a3ecf92756(…):   0%|          | 0.00/244M [00:00<?, ?B/s]
# data/train_sft-00001-of-00003-0a1804bcb6(…):   0%|          | 0.00/244M [00:00<?, ?B/s]
# data/train_sft-00002-of-00003-ee46ed25cf(…):   0%|          | 0.00/244M [00:00<?, ?B/s]
# data/test_sft-00000-of-00001-f7dfac4afe5(…):   0%|          | 0.00/81.2M [00:00<?, ?B/s]
# data/train_gen-00000-of-00003-a6c9fb894b(…):   0%|          | 0.00/244M [00:00<?, ?B/s]
# data/train_gen-00001-of-00003-d6a0402e41(…):   0%|          | 0.00/243M [00:00<?, ?B/s]
# data/train_gen-00002-of-00003-c0db75b92a(…):   0%|          | 0.00/243M [00:00<?, ?B/s]
# data/test_gen-00000-of-00001-3d4cd830914(…):   0%|          | 0.00/80.4M [00:00<?, ?B/s]
# Generating train_sft split:   0%|          | 0/207865 [00:00<?, ? examples/s]
# Generating test_sft split:   0%|          | 0/23110 [00:00<?, ? examples/s]
# Generating train_gen split:   0%|          | 0/256032 [00:00<?, ? examples/s]
# Generating test_gen split:   0%|          | 0/28304 [00:00<?, ? examples/s]
# Map:   0%|          | 0/64 [00:00<?, ? examples/s]

# %% [markdown]
# **Apply quantization**

# %%
oneshot(
    model=model,
    tokenizer=tokenizer,
    dataset=formatted_dataset,
    text_column="text",
    recipe=recipe,
    max_seq_length=512
)
# Out:
# 2026-05-04T19:26:04.218129+0000 | __init__ | WARNING - Disabling tokenizer parallelism due to threading conflict between FastTokenizer and Datasets. Set TOKENIZERS_PARALLELISM=false to suppress this warning.
# Tokenizing:   0%|          | 0/64 [00:00<?, ? examples/s]
# 2026-05-04T19:26:04.929323+0000 | _make_sampler | WARNING - Requested 512 samples but the provided dataset only has 64 samples.
# 2026-05-04T19:26:04.931173+0000 | reset | INFO - Compression lifecycle reset
# 2026-05-04T19:26:04.935405+0000 | from_modifiers | INFO - Creating recipe from modifiers
# 2026-05-04T19:26:05.062290+0000 | on_initialize | INFO - No AWQModifier.mappings provided, inferring from model...
# 2026-05-04T19:26:05.076954+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.0.self_attn.qkv_proj for mapping AWQMapping(smooth_layer='re:.*qkv_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-05-04T19:26:05.078519+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.1.self_attn.qkv_proj for mapping AWQMapping(smooth_layer='re:.*qkv_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-05-04T19:26:05.079498+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.2.self_attn.qkv_proj for mapping AWQMapping(smooth_layer='re:.*qkv_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-05-04T19:26:05.080466+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.3.self_attn.qkv_proj for mapping AWQMapping(smooth_layer='re:.*qkv_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-05-04T19:26:05.081523+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.4.self_attn.qkv_proj for mapping AWQMapping(smooth_layer='re:.*qkv_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-05-04T19:26:05.082528+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.5.self_attn.qkv_proj for mapping AWQMapping(smooth_layer='re:.*qkv_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-05-04T19:26:05.083636+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.6.self_attn.qkv_proj for mapping AWQMapping(smooth_layer='re:.*qkv_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-05-04T19:26:05.084674+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.7.self_attn.qkv_proj for mapping AWQMapping(smooth_layer='re:.*qkv_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-05-04T19:26:05.085537+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.8.self_attn.qkv_proj for mapping AWQMapping(smooth_layer='re:.*qkv_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-05-04T19:26:05.086520+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.9.self_attn.qkv_proj for mapping AWQMapping(smooth_layer='re:.*qkv_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-05-04T19:26:05.087493+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.10.self_attn.qkv_proj for mapping AWQMapping(smooth_layer='re:.*qkv_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-05-04T19:26:05.088716+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.11.self_attn.qkv_proj for mapping AWQMapping(smooth_layer='re:.*qkv_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-05-04T19:26:05.091568+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.12.self_attn.qkv_proj for mapping AWQMapping(smooth_layer='re:.*qkv_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-05-04T19:26:05.092580+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.13.self_attn.qkv_proj for mapping AWQMapping(smooth_layer='re:.*qkv_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-05-04T19:26:05.093768+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.14.self_attn.qkv_proj for mapping AWQMapping(smooth_layer='re:.*qkv_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-05-04T19:26:05.094812+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.15.self_attn.qkv_proj for mapping AWQMapping(smooth_layer='re:.*qkv_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-05-04T19:26:05.095805+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.16.self_attn.qkv_proj for mapping AWQMapping(smooth_layer='re:.*qkv_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-05-04T19:26:05.096746+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.17.self_attn.qkv_proj for mapping AWQMapping(smooth_layer='re:.*qkv_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-05-04T19:26:05.097703+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.18.self_attn.qkv_proj for mapping AWQMapping(smooth_layer='re:.*qkv_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-05-04T19:26:05.098629+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.19.self_attn.qkv_proj for mapping AWQMapping(smooth_layer='re:.*qkv_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-05-04T19:26:05.099513+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.20.self_attn.qkv_proj for mapping AWQMapping(smooth_layer='re:.*qkv_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-05-04T19:26:05.100574+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.21.self_attn.qkv_proj for mapping AWQMapping(smooth_layer='re:.*qkv_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-05-04T19:26:05.102405+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.22.self_attn.qkv_proj for mapping AWQMapping(smooth_layer='re:.*qkv_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-05-04T19:26:05.103547+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.23.self_attn.qkv_proj for mapping AWQMapping(smooth_layer='re:.*qkv_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-05-04T19:26:05.104488+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.24.self_attn.qkv_proj for mapping AWQMapping(smooth_layer='re:.*qkv_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-05-04T19:26:05.105459+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.25.self_attn.qkv_proj for mapping AWQMapping(smooth_layer='re:.*qkv_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-05-04T19:26:05.106401+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.26.self_attn.qkv_proj for mapping AWQMapping(smooth_layer='re:.*qkv_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-05-04T19:26:05.107656+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.27.self_attn.qkv_proj for mapping AWQMapping(smooth_layer='re:.*qkv_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-05-04T19:26:05.108905+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.28.self_attn.qkv_proj for mapping AWQMapping(smooth_layer='re:.*qkv_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-05-04T19:26:05.110053+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.29.self_attn.qkv_proj for mapping AWQMapping(smooth_layer='re:.*qkv_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-05-04T19:26:05.111167+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.30.self_attn.qkv_proj for mapping AWQMapping(smooth_layer='re:.*qkv_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-05-04T19:26:05.112487+0000 | _set_resolved_mappings | WARNING - skipping AWQ for model.layers.31.self_attn.qkv_proj for mapping AWQMapping(smooth_layer='re:.*qkv_proj$', balance_layers=['re:.*o_proj$'], activation_hook_target=None) because found incompatible balance layers
# 2026-05-04T19:26:05.134976+0000 | initialize | INFO - Compression lifecycle initialized for 1 modifiers
# 2026-05-04T19:26:05.136171+0000 | IndependentPipeline | INFO - Inferred `SequentialPipeline` for `AWQModifier`
# W0504 19:26:05.321000 57 torch/fx/_symbolic_trace.py:53] is_fx_tracing will return true for both fx.symbolic_trace and torch.export. Please use is_fx_tracing_symbolic_tracing() for specifically fx.symbolic_trace or torch.compiler.is_compiling() for specifically torch.export/compile.
# Preparing cache: 100%|██████████| 64/64 [00:00<00:00, 981.03it/s]
# (1/33): Calibrating: 100%|██████████| 64/64 [00:04<00:00, 15.99it/s]
# Smoothing:   0%|          | 0/3 [00:00<?, ?it/s]
# Grid search for model.layers.0.input_layernorm:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.0.input_layernorm:   0%|          | 0/20 [00:00<?, ?it/s, best_error=1.953e-03]
# Grid search for model.layers.0.input_layernorm:   5%|▌         | 1/20 [00:00<00:10,  1.79it/s, best_error=1.953e-03]
# Grid search for model.layers.0.input_layernorm:   5%|▌         | 1/20 [00:00<00:10,  1.79it/s, best_error=1.587e-03]
# Grid search for model.layers.0.input_layernorm:  10%|█         | 2/20 [00:00<00:08,  2.18it/s, best_error=1.587e-03]
# Grid search for model.layers.0.input_layernorm:  10%|█         | 2/20 [00:01<00:08,  2.18it/s, best_error=1.488e-03]
# Grid search for model.layers.0.input_layernorm:  15%|█▌        | 3/20 [00:01<00:07,  2.34it/s, best_error=1.488e-03]
# Grid search for model.layers.0.input_layernorm:  15%|█▌        | 3/20 [00:01<00:07,  2.34it/s, best_error=1.381e-03]
# Grid search for model.layers.0.input_layernorm:  20%|██        | 4/20 [00:01<00:06,  2.42it/s, best_error=1.381e-03]
# Grid search for model.layers.0.input_layernorm:  20%|██        | 4/20 [00:02<00:06,  2.42it/s, best_error=1.381e-03]
# Grid search for model.layers.0.input_layernorm:  25%|██▌       | 5/20 [00:02<00:06,  2.47it/s, best_error=1.381e-03]
# Grid search for model.layers.0.input_layernorm:  25%|██▌       | 5/20 [00:02<00:06,  2.47it/s, best_error=1.381e-03]
# Grid search for model.layers.0.input_layernorm:  30%|███       | 6/20 [00:02<00:05,  2.49it/s, best_error=1.381e-03]
# Grid search for model.layers.0.input_layernorm:  30%|███       | 6/20 [00:02<00:05,  2.49it/s, best_error=1.381e-03]
# Grid search for model.layers.0.input_layernorm:  35%|███▌      | 7/20 [00:02<00:05,  2.50it/s, best_error=1.381e-03]
# Grid search for model.layers.0.input_layernorm:  35%|███▌      | 7/20 [00:03<00:05,  2.50it/s, best_error=1.381e-03]
# Grid search for model.layers.0.input_layernorm:  40%|████      | 8/20 [00:03<00:04,  2.52it/s, best_error=1.381e-03]
# Grid search for model.layers.0.input_layernorm:  40%|████      | 8/20 [00:03<00:04,  2.52it/s, best_error=1.381e-03]
# Grid search for model.layers.0.input_layernorm:  45%|████▌     | 9/20 [00:03<00:04,  2.53it/s, best_error=1.381e-03]
# Grid search for model.layers.0.input_layernorm:  45%|████▌     | 9/20 [00:04<00:04,  2.53it/s, best_error=1.381e-03]
# Grid search for model.layers.0.input_layernorm:  50%|█████     | 10/20 [00:04<00:03,  2.53it/s, best_error=1.381e-03]
# Grid search for model.layers.0.input_layernorm:  50%|█████     | 10/20 [00:04<00:03,  2.53it/s, best_error=1.381e-03]
# Grid search for model.layers.0.input_layernorm:  55%|█████▌    | 11/20 [00:04<00:03,  2.53it/s, best_error=1.381e-03]
# Grid search for model.layers.0.input_layernorm:  55%|█████▌    | 11/20 [00:04<00:03,  2.53it/s, best_error=1.381e-03]
# Grid search for model.layers.0.input_layernorm:  60%|██████    | 12/20 [00:04<00:03,  2.54it/s, best_error=1.381e-03]
# Grid search for model.layers.0.input_layernorm:  60%|██████    | 12/20 [00:05<00:03,  2.54it/s, best_error=1.381e-03]
# Grid search for model.layers.0.input_layernorm:  65%|██████▌   | 13/20 [00:05<00:02,  2.54it/s, best_error=1.381e-03]
# Grid search for model.layers.0.input_layernorm:  65%|██████▌   | 13/20 [00:05<00:02,  2.54it/s, best_error=1.381e-03]
# Grid search for model.layers.0.input_layernorm:  70%|███████   | 14/20 [00:05<00:02,  2.54it/s, best_error=1.381e-03]
# Grid search for model.layers.0.input_layernorm:  70%|███████   | 14/20 [00:06<00:02,  2.54it/s, best_error=1.381e-03]
# Grid search for model.layers.0.input_layernorm:  75%|███████▌  | 15/20 [00:06<00:01,  2.54it/s, best_error=1.381e-03]
# Grid search for model.layers.0.input_layernorm:  75%|███████▌  | 15/20 [00:06<00:01,  2.54it/s, best_error=1.381e-03]
# Grid search for model.layers.0.input_layernorm:  80%|████████  | 16/20 [00:06<00:01,  2.54it/s, best_error=1.381e-03]
# Grid search for model.layers.0.input_layernorm:  80%|████████  | 16/20 [00:06<00:01,  2.54it/s, best_error=1.381e-03]
# Grid search for model.layers.0.input_layernorm:  85%|████████▌ | 17/20 [00:06<00:01,  2.55it/s, best_error=1.381e-03]
# Grid search for model.layers.0.input_layernorm:  85%|████████▌ | 17/20 [00:07<00:01,  2.55it/s, best_error=1.381e-03]
# Grid search for model.layers.0.input_layernorm:  90%|█████████ | 18/20 [00:07<00:00,  2.54it/s, best_error=1.381e-03]
# Grid search for model.layers.0.input_layernorm:  90%|█████████ | 18/20 [00:07<00:00,  2.54it/s, best_error=1.381e-03]
# Grid search for model.layers.0.input_layernorm:  95%|█████████▌| 19/20 [00:07<00:00,  2.55it/s, best_error=1.381e-03]
# Grid search for model.layers.0.input_layernorm:  95%|█████████▌| 19/20 [00:08<00:00,  2.55it/s, best_error=1.381e-03]
# Grid search for model.layers.0.input_layernorm: 100%|██████████| 20/20 [00:08<00:00,  2.54it/s, best_error=1.381e-03]
# Smoothing:  33%|███▎      | 1/3 [00:08<00:16,  8.42s/it]
# Grid search for model.layers.0.post_attention_layernorm:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.0.post_attention_layernorm:   0%|          | 0/20 [00:01<?, ?it/s, best_error=2.232e-04]
# Grid search for model.layers.0.post_attention_layernorm:   5%|▌         | 1/20 [00:01<00:24,  1.27s/it, best_error=2.232e-04]
# Grid search for model.layers.0.post_attention_layernorm:   5%|▌         | 1/20 [00:02<00:24,  1.27s/it, best_error=2.222e-04]
# Grid search for model.layers.0.post_attention_layernorm:  10%|█         | 2/20 [00:02<00:23,  1.28s/it, best_error=2.222e-04]
# Grid search for model.layers.0.post_attention_layernorm:  10%|█         | 2/20 [00:03<00:23,  1.28s/it, best_error=2.222e-04]
# Grid search for model.layers.0.post_attention_layernorm:  15%|█▌        | 3/20 [00:03<00:21,  1.29s/it, best_error=2.222e-04]
# Grid search for model.layers.0.post_attention_layernorm:  15%|█▌        | 3/20 [00:05<00:21,  1.29s/it, best_error=2.222e-04]
# Grid search for model.layers.0.post_attention_layernorm:  20%|██        | 4/20 [00:05<00:20,  1.29s/it, best_error=2.222e-04]
# Grid search for model.layers.0.post_attention_layernorm:  20%|██        | 4/20 [00:06<00:20,  1.29s/it, best_error=2.222e-04]
# Grid search for model.layers.0.post_attention_layernorm:  25%|██▌       | 5/20 [00:06<00:19,  1.30s/it, best_error=2.222e-04]
# Grid search for model.layers.0.post_attention_layernorm:  25%|██▌       | 5/20 [00:07<00:19,  1.30s/it, best_error=2.222e-04]
# Grid search for model.layers.0.post_attention_layernorm:  30%|███       | 6/20 [00:07<00:18,  1.30s/it, best_error=2.222e-04]
# Grid search for model.layers.0.post_attention_layernorm:  30%|███       | 6/20 [00:09<00:18,  1.30s/it, best_error=2.222e-04]
# Grid search for model.layers.0.post_attention_layernorm:  35%|███▌      | 7/20 [00:09<00:16,  1.30s/it, best_error=2.222e-04]
# Grid search for model.layers.0.post_attention_layernorm:  35%|███▌      | 7/20 [00:10<00:16,  1.30s/it, best_error=2.146e-04]
# Grid search for model.layers.0.post_attention_layernorm:  40%|████      | 8/20 [00:10<00:15,  1.30s/it, best_error=2.146e-04]
# Grid search for model.layers.0.post_attention_layernorm:  40%|████      | 8/20 [00:11<00:15,  1.30s/it, best_error=2.146e-04]
# Grid search for model.layers.0.post_attention_layernorm:  45%|████▌     | 9/20 [00:11<00:14,  1.30s/it, best_error=2.146e-04]
# Grid search for model.layers.0.post_attention_layernorm:  45%|████▌     | 9/20 [00:12<00:14,  1.30s/it, best_error=2.146e-04]
# Grid search for model.layers.0.post_attention_layernorm:  50%|█████     | 10/20 [00:12<00:13,  1.31s/it, best_error=2.146e-04]
# Grid search for model.layers.0.post_attention_layernorm:  50%|█████     | 10/20 [00:14<00:13,  1.31s/it, best_error=2.146e-04]
# Grid search for model.layers.0.post_attention_layernorm:  55%|█████▌    | 11/20 [00:14<00:11,  1.31s/it, best_error=2.146e-04]
# Grid search for model.layers.0.post_attention_layernorm:  55%|█████▌    | 11/20 [00:15<00:11,  1.31s/it, best_error=2.146e-04]
# Grid search for model.layers.0.post_attention_layernorm:  60%|██████    | 12/20 [00:15<00:10,  1.32s/it, best_error=2.146e-04]
# Grid search for model.layers.0.post_attention_layernorm:  60%|██████    | 12/20 [00:16<00:10,  1.32s/it, best_error=2.146e-04]
# Grid search for model.layers.0.post_attention_layernorm:  65%|██████▌   | 13/20 [00:16<00:09,  1.32s/it, best_error=2.146e-04]
# Grid search for model.layers.0.post_attention_layernorm:  65%|██████▌   | 13/20 [00:18<00:09,  1.32s/it, best_error=2.146e-04]
# Grid search for model.layers.0.post_attention_layernorm:  70%|███████   | 14/20 [00:18<00:07,  1.33s/it, best_error=2.146e-04]
# Grid search for model.layers.0.post_attention_layernorm:  70%|███████   | 14/20 [00:19<00:07,  1.33s/it, best_error=2.146e-04]
# Grid search for model.layers.0.post_attention_layernorm:  75%|███████▌  | 15/20 [00:19<00:06,  1.33s/it, best_error=2.146e-04]
# Grid search for model.layers.0.post_attention_layernorm:  75%|███████▌  | 15/20 [00:20<00:06,  1.33s/it, best_error=2.146e-04]
# Grid search for model.layers.0.post_attention_layernorm:  80%|████████  | 16/20 [00:20<00:05,  1.33s/it, best_error=2.146e-04]
# Grid search for model.layers.0.post_attention_layernorm:  80%|████████  | 16/20 [00:22<00:05,  1.33s/it, best_error=2.146e-04]
# Grid search for model.layers.0.post_attention_layernorm:  85%|████████▌ | 17/20 [00:22<00:03,  1.33s/it, best_error=2.146e-04]
# Grid search for model.layers.0.post_attention_layernorm:  85%|████████▌ | 17/20 [00:23<00:03,  1.33s/it, best_error=2.146e-04]
# Grid search for model.layers.0.post_attention_layernorm:  90%|█████████ | 18/20 [00:23<00:02,  1.33s/it, best_error=2.146e-04]
# Grid search for model.layers.0.post_attention_layernorm:  90%|█████████ | 18/20 [00:24<00:02,  1.33s/it, best_error=2.146e-04]
# Grid search for model.layers.0.post_attention_layernorm:  95%|█████████▌| 19/20 [00:24<00:01,  1.33s/it, best_error=2.146e-04]
# Grid search for model.layers.0.post_attention_layernorm:  95%|█████████▌| 19/20 [00:26<00:01,  1.33s/it, best_error=2.146e-04]
# Grid search for model.layers.0.post_attention_layernorm: 100%|██████████| 20/20 [00:26<00:00,  1.33s/it, best_error=2.146e-04]
# Smoothing:  67%|██████▋   | 2/3 [00:35<00:19, 19.69s/it]
# Grid search for model.layers.0.mlp.gate_up_proj:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.0.mlp.gate_up_proj:   0%|          | 0/20 [00:00<?, ?it/s, best_error=5.698e-05]
# Grid search for model.layers.0.mlp.gate_up_proj:   5%|▌         | 1/20 [00:00<00:12,  1.55it/s, best_error=5.698e-05]
# Grid search for model.layers.0.mlp.gate_up_proj:   5%|▌         | 1/20 [00:01<00:12,  1.55it/s, best_error=5.126e-05]
# Grid search for model.layers.0.mlp.gate_up_proj:  10%|█         | 2/20 [00:01<00:11,  1.54it/s, best_error=5.126e-05]
# Grid search for model.layers.0.mlp.gate_up_proj:  10%|█         | 2/20 [00:01<00:11,  1.54it/s, best_error=5.078e-05]
# Grid search for model.layers.0.mlp.gate_up_proj:  15%|█▌        | 3/20 [00:01<00:11,  1.54it/s, best_error=5.078e-05]
# Grid search for model.layers.0.mlp.gate_up_proj:  15%|█▌        | 3/20 [00:02<00:11,  1.54it/s, best_error=5.078e-05]
# Grid search for model.layers.0.mlp.gate_up_proj:  20%|██        | 4/20 [00:02<00:10,  1.54it/s, best_error=5.078e-05]
# Grid search for model.layers.0.mlp.gate_up_proj:  20%|██        | 4/20 [00:03<00:10,  1.54it/s, best_error=5.031e-05]
# Grid search for model.layers.0.mlp.gate_up_proj:  25%|██▌       | 5/20 [00:03<00:09,  1.54it/s, best_error=5.031e-05]
# Grid search for model.layers.0.mlp.gate_up_proj:  25%|██▌       | 5/20 [00:03<00:09,  1.54it/s, best_error=5.031e-05]
# Grid search for model.layers.0.mlp.gate_up_proj:  30%|███       | 6/20 [00:03<00:09,  1.54it/s, best_error=5.031e-05]
# Grid search for model.layers.0.mlp.gate_up_proj:  30%|███       | 6/20 [00:04<00:09,  1.54it/s, best_error=5.031e-05]
# Grid search for model.layers.0.mlp.gate_up_proj:  35%|███▌      | 7/20 [00:04<00:08,  1.54it/s, best_error=5.031e-05]
# Grid search for model.layers.0.mlp.gate_up_proj:  35%|███▌      | 7/20 [00:05<00:08,  1.54it/s, best_error=5.031e-05]
# Grid search for model.layers.0.mlp.gate_up_proj:  40%|████      | 8/20 [00:05<00:07,  1.54it/s, best_error=5.031e-05]
# Grid search for model.layers.0.mlp.gate_up_proj:  40%|████      | 8/20 [00:05<00:07,  1.54it/s, best_error=5.031e-05]
# Grid search for model.layers.0.mlp.gate_up_proj:  45%|████▌     | 9/20 [00:05<00:07,  1.53it/s, best_error=5.031e-05]
# Grid search for model.layers.0.mlp.gate_up_proj:  45%|████▌     | 9/20 [00:06<00:07,  1.53it/s, best_error=5.031e-05]
# Grid search for model.layers.0.mlp.gate_up_proj:  50%|█████     | 10/20 [00:06<00:06,  1.53it/s, best_error=5.031e-05]
# Grid search for model.layers.0.mlp.gate_up_proj:  50%|█████     | 10/20 [00:07<00:06,  1.53it/s, best_error=5.031e-05]
# Grid search for model.layers.0.mlp.gate_up_proj:  55%|█████▌    | 11/20 [00:07<00:05,  1.53it/s, best_error=5.031e-05]
# Grid search for model.layers.0.mlp.gate_up_proj:  55%|█████▌    | 11/20 [00:07<00:05,  1.53it/s, best_error=5.031e-05]
# Grid search for model.layers.0.mlp.gate_up_proj:  60%|██████    | 12/20 [00:07<00:05,  1.53it/s, best_error=5.031e-05]
# Grid search for model.layers.0.mlp.gate_up_proj:  60%|██████    | 12/20 [00:08<00:05,  1.53it/s, best_error=5.031e-05]
# Grid search for model.layers.0.mlp.gate_up_proj:  65%|██████▌   | 13/20 [00:08<00:04,  1.53it/s, best_error=5.031e-05]
# Grid search for model.layers.0.mlp.gate_up_proj:  65%|██████▌   | 13/20 [00:09<00:04,  1.53it/s, best_error=5.031e-05]
# Grid search for model.layers.0.mlp.gate_up_proj:  70%|███████   | 14/20 [00:09<00:03,  1.52it/s, best_error=5.031e-05]
# Grid search for model.layers.0.mlp.gate_up_proj:  70%|███████   | 14/20 [00:09<00:03,  1.52it/s, best_error=5.031e-05]
# Grid search for model.layers.0.mlp.gate_up_proj:  75%|███████▌  | 15/20 [00:09<00:03,  1.52it/s, best_error=5.031e-05]
# Grid search for model.layers.0.mlp.gate_up_proj:  75%|███████▌  | 15/20 [00:10<00:03,  1.52it/s, best_error=5.031e-05]
# Grid search for model.layers.0.mlp.gate_up_proj:  80%|████████  | 16/20 [00:10<00:02,  1.52it/s, best_error=5.031e-05]
# Grid search for model.layers.0.mlp.gate_up_proj:  80%|████████  | 16/20 [00:11<00:02,  1.52it/s, best_error=5.031e-05]
# Grid search for model.layers.0.mlp.gate_up_proj:  85%|████████▌ | 17/20 [00:11<00:01,  1.52it/s, best_error=5.031e-05]
# Grid search for model.layers.0.mlp.gate_up_proj:  85%|████████▌ | 17/20 [00:11<00:01,  1.52it/s, best_error=5.031e-05]
# Grid search for model.layers.0.mlp.gate_up_proj:  90%|█████████ | 18/20 [00:11<00:01,  1.52it/s, best_error=5.031e-05]
# Grid search for model.layers.0.mlp.gate_up_proj:  90%|█████████ | 18/20 [00:12<00:01,  1.52it/s, best_error=5.031e-05]
# Grid search for model.layers.0.mlp.gate_up_proj:  95%|█████████▌| 19/20 [00:12<00:00,  1.51it/s, best_error=5.031e-05]
# Grid search for model.layers.0.mlp.gate_up_proj:  95%|█████████▌| 19/20 [00:13<00:00,  1.51it/s, best_error=5.031e-05]
# Grid search for model.layers.0.mlp.gate_up_proj: 100%|██████████| 20/20 [00:13<00:00,  1.51it/s, best_error=5.031e-05]
# Smoothing: 100%|██████████| 3/3 [00:49<00:00, 16.58s/it]
# (1/33): Propagating: 100%|██████████| 64/64 [00:02<00:00, 21.72it/s]
# (2/33): Calibrating: 100%|██████████| 64/64 [00:02<00:00, 21.58it/s]
# Smoothing:   0%|          | 0/3 [00:00<?, ?it/s]
# Grid search for model.layers.1.input_layernorm:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.1.input_layernorm:   0%|          | 0/20 [00:00<?, ?it/s, best_error=2.106e-03]
# Grid search for model.layers.1.input_layernorm:   5%|▌         | 1/20 [00:00<00:08,  2.27it/s, best_error=2.106e-03]
# Grid search for model.layers.1.input_layernorm:   5%|▌         | 1/20 [00:00<00:08,  2.27it/s, best_error=1.732e-03]
# Grid search for model.layers.1.input_layernorm:  10%|█         | 2/20 [00:00<00:07,  2.26it/s, best_error=1.732e-03]
# Grid search for model.layers.1.input_layernorm:  10%|█         | 2/20 [00:01<00:07,  2.26it/s, best_error=1.572e-03]
# Grid search for model.layers.1.input_layernorm:  15%|█▌        | 3/20 [00:01<00:07,  2.25it/s, best_error=1.572e-03]
# Grid search for model.layers.1.input_layernorm:  15%|█▌        | 3/20 [00:01<00:07,  2.25it/s, best_error=1.541e-03]
# Grid search for model.layers.1.input_layernorm:  20%|██        | 4/20 [00:01<00:07,  2.25it/s, best_error=1.541e-03]
# Grid search for model.layers.1.input_layernorm:  20%|██        | 4/20 [00:02<00:07,  2.25it/s, best_error=1.480e-03]
# Grid search for model.layers.1.input_layernorm:  25%|██▌       | 5/20 [00:02<00:06,  2.25it/s, best_error=1.480e-03]
# Grid search for model.layers.1.input_layernorm:  25%|██▌       | 5/20 [00:02<00:06,  2.25it/s, best_error=1.480e-03]
# Grid search for model.layers.1.input_layernorm:  30%|███       | 6/20 [00:02<00:06,  2.24it/s, best_error=1.480e-03]
# Grid search for model.layers.1.input_layernorm:  30%|███       | 6/20 [00:03<00:06,  2.24it/s, best_error=1.480e-03]
# Grid search for model.layers.1.input_layernorm:  35%|███▌      | 7/20 [00:03<00:05,  2.25it/s, best_error=1.480e-03]
# Grid search for model.layers.1.input_layernorm:  35%|███▌      | 7/20 [00:03<00:05,  2.25it/s, best_error=1.480e-03]
# Grid search for model.layers.1.input_layernorm:  40%|████      | 8/20 [00:03<00:05,  2.25it/s, best_error=1.480e-03]
# Grid search for model.layers.1.input_layernorm:  40%|████      | 8/20 [00:04<00:05,  2.25it/s, best_error=1.480e-03]
# Grid search for model.layers.1.input_layernorm:  45%|████▌     | 9/20 [00:04<00:04,  2.24it/s, best_error=1.480e-03]
# Grid search for model.layers.1.input_layernorm:  45%|████▌     | 9/20 [00:04<00:04,  2.24it/s, best_error=1.480e-03]
# Grid search for model.layers.1.input_layernorm:  50%|█████     | 10/20 [00:04<00:04,  2.24it/s, best_error=1.480e-03]
# Grid search for model.layers.1.input_layernorm:  50%|█████     | 10/20 [00:04<00:04,  2.24it/s, best_error=1.480e-03]
# Grid search for model.layers.1.input_layernorm:  55%|█████▌    | 11/20 [00:04<00:04,  2.24it/s, best_error=1.480e-03]
# Grid search for model.layers.1.input_layernorm:  55%|█████▌    | 11/20 [00:05<00:04,  2.24it/s, best_error=1.480e-03]
# Grid search for model.layers.1.input_layernorm:  60%|██████    | 12/20 [00:05<00:03,  2.23it/s, best_error=1.480e-03]
# Grid search for model.layers.1.input_layernorm:  60%|██████    | 12/20 [00:05<00:03,  2.23it/s, best_error=1.480e-03]
# Grid search for model.layers.1.input_layernorm:  65%|██████▌   | 13/20 [00:05<00:03,  2.23it/s, best_error=1.480e-03]
# Grid search for model.layers.1.input_layernorm:  65%|██████▌   | 13/20 [00:06<00:03,  2.23it/s, best_error=1.480e-03]
# Grid search for model.layers.1.input_layernorm:  70%|███████   | 14/20 [00:06<00:02,  2.23it/s, best_error=1.480e-03]
# Grid search for model.layers.1.input_layernorm:  70%|███████   | 14/20 [00:06<00:02,  2.23it/s, best_error=1.480e-03]
# Grid search for model.layers.1.input_layernorm:  75%|███████▌  | 15/20 [00:06<00:02,  2.23it/s, best_error=1.480e-03]
# Grid search for model.layers.1.input_layernorm:  75%|███████▌  | 15/20 [00:07<00:02,  2.23it/s, best_error=1.480e-03]
# Grid search for model.layers.1.input_layernorm:  80%|████████  | 16/20 [00:07<00:01,  2.22it/s, best_error=1.480e-03]
# Grid search for model.layers.1.input_layernorm:  80%|████████  | 16/20 [00:07<00:01,  2.22it/s, best_error=1.480e-03]
# Grid search for model.layers.1.input_layernorm:  85%|████████▌ | 17/20 [00:07<00:01,  2.22it/s, best_error=1.480e-03]
# Grid search for model.layers.1.input_layernorm:  85%|████████▌ | 17/20 [00:08<00:01,  2.22it/s, best_error=1.480e-03]
# Grid search for model.layers.1.input_layernorm:  90%|█████████ | 18/20 [00:08<00:00,  2.22it/s, best_error=1.480e-03]
# Grid search for model.layers.1.input_layernorm:  90%|█████████ | 18/20 [00:08<00:00,  2.22it/s, best_error=1.480e-03]
# Grid search for model.layers.1.input_layernorm:  95%|█████████▌| 19/20 [00:08<00:00,  2.22it/s, best_error=1.480e-03]
# Grid search for model.layers.1.input_layernorm:  95%|█████████▌| 19/20 [00:08<00:00,  2.22it/s, best_error=1.480e-03]
# Grid search for model.layers.1.input_layernorm: 100%|██████████| 20/20 [00:08<00:00,  2.22it/s, best_error=1.480e-03]
# Smoothing:  33%|███▎      | 1/3 [00:09<00:18,  9.39s/it]
# Grid search for model.layers.1.post_attention_layernorm:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.1.post_attention_layernorm:   0%|          | 0/20 [00:01<?, ?it/s, best_error=3.052e-04]
# Grid search for model.layers.1.post_attention_layernorm:   5%|▌         | 1/20 [00:01<00:27,  1.47s/it, best_error=3.052e-04]
# Grid search for model.layers.1.post_attention_layernorm:   5%|▌         | 1/20 [00:02<00:27,  1.47s/it, best_error=2.956e-04]
# Grid search for model.layers.1.post_attention_layernorm:  10%|█         | 2/20 [00:02<00:26,  1.48s/it, best_error=2.956e-04]
# Grid search for model.layers.1.post_attention_layernorm:  10%|█         | 2/20 [00:04<00:26,  1.48s/it, best_error=2.842e-04]
# Grid search for model.layers.1.post_attention_layernorm:  15%|█▌        | 3/20 [00:04<00:25,  1.48s/it, best_error=2.842e-04]
# Grid search for model.layers.1.post_attention_layernorm:  15%|█▌        | 3/20 [00:05<00:25,  1.48s/it, best_error=2.689e-04]
# Grid search for model.layers.1.post_attention_layernorm:  20%|██        | 4/20 [00:05<00:23,  1.48s/it, best_error=2.689e-04]
# Grid search for model.layers.1.post_attention_layernorm:  20%|██        | 4/20 [00:07<00:23,  1.48s/it, best_error=2.632e-04]
# Grid search for model.layers.1.post_attention_layernorm:  25%|██▌       | 5/20 [00:07<00:22,  1.49s/it, best_error=2.632e-04]
# Grid search for model.layers.1.post_attention_layernorm:  25%|██▌       | 5/20 [00:08<00:22,  1.49s/it, best_error=2.594e-04]
# Grid search for model.layers.1.post_attention_layernorm:  30%|███       | 6/20 [00:08<00:20,  1.49s/it, best_error=2.594e-04]
# Grid search for model.layers.1.post_attention_layernorm:  30%|███       | 6/20 [00:10<00:20,  1.49s/it, best_error=2.556e-04]
# Grid search for model.layers.1.post_attention_layernorm:  35%|███▌      | 7/20 [00:10<00:19,  1.49s/it, best_error=2.556e-04]
# Grid search for model.layers.1.post_attention_layernorm:  35%|███▌      | 7/20 [00:11<00:19,  1.49s/it, best_error=2.556e-04]
# Grid search for model.layers.1.post_attention_layernorm:  40%|████      | 8/20 [00:11<00:17,  1.49s/it, best_error=2.556e-04]
# Grid search for model.layers.1.post_attention_layernorm:  40%|████      | 8/20 [00:13<00:17,  1.49s/it, best_error=2.556e-04]
# Grid search for model.layers.1.post_attention_layernorm:  45%|████▌     | 9/20 [00:13<00:16,  1.49s/it, best_error=2.556e-04]
# Grid search for model.layers.1.post_attention_layernorm:  45%|████▌     | 9/20 [00:14<00:16,  1.49s/it, best_error=2.556e-04]
# Grid search for model.layers.1.post_attention_layernorm:  50%|█████     | 10/20 [00:14<00:14,  1.50s/it, best_error=2.556e-04]
# Grid search for model.layers.1.post_attention_layernorm:  50%|█████     | 10/20 [00:16<00:14,  1.50s/it, best_error=2.556e-04]
# Grid search for model.layers.1.post_attention_layernorm:  55%|█████▌    | 11/20 [00:16<00:13,  1.51s/it, best_error=2.556e-04]
# Grid search for model.layers.1.post_attention_layernorm:  55%|█████▌    | 11/20 [00:17<00:13,  1.51s/it, best_error=2.556e-04]
# Grid search for model.layers.1.post_attention_layernorm:  60%|██████    | 12/20 [00:17<00:12,  1.51s/it, best_error=2.556e-04]
# Grid search for model.layers.1.post_attention_layernorm:  60%|██████    | 12/20 [00:19<00:12,  1.51s/it, best_error=2.556e-04]
# Grid search for model.layers.1.post_attention_layernorm:  65%|██████▌   | 13/20 [00:19<00:10,  1.51s/it, best_error=2.556e-04]
# Grid search for model.layers.1.post_attention_layernorm:  65%|██████▌   | 13/20 [00:20<00:10,  1.51s/it, best_error=2.556e-04]
# Grid search for model.layers.1.post_attention_layernorm:  70%|███████   | 14/20 [00:20<00:09,  1.51s/it, best_error=2.556e-04]
# Grid search for model.layers.1.post_attention_layernorm:  70%|███████   | 14/20 [00:22<00:09,  1.51s/it, best_error=2.556e-04]
# Grid search for model.layers.1.post_attention_layernorm:  75%|███████▌  | 15/20 [00:22<00:07,  1.51s/it, best_error=2.556e-04]
# Grid search for model.layers.1.post_attention_layernorm:  75%|███████▌  | 15/20 [00:24<00:07,  1.51s/it, best_error=2.556e-04]
# Grid search for model.layers.1.post_attention_layernorm:  80%|████████  | 16/20 [00:24<00:06,  1.52s/it, best_error=2.556e-04]
# Grid search for model.layers.1.post_attention_layernorm:  80%|████████  | 16/20 [00:25<00:06,  1.52s/it, best_error=2.556e-04]
# Grid search for model.layers.1.post_attention_layernorm:  85%|████████▌ | 17/20 [00:25<00:04,  1.53s/it, best_error=2.556e-04]
# Grid search for model.layers.1.post_attention_layernorm:  85%|████████▌ | 17/20 [00:27<00:04,  1.53s/it, best_error=2.556e-04]
# Grid search for model.layers.1.post_attention_layernorm:  90%|█████████ | 18/20 [00:27<00:03,  1.53s/it, best_error=2.556e-04]
# Grid search for model.layers.1.post_attention_layernorm:  90%|█████████ | 18/20 [00:28<00:03,  1.53s/it, best_error=2.556e-04]
# Grid search for model.layers.1.post_attention_layernorm:  95%|█████████▌| 19/20 [00:28<00:01,  1.54s/it, best_error=2.556e-04]
# Grid search for model.layers.1.post_attention_layernorm:  95%|█████████▌| 19/20 [00:30<00:01,  1.54s/it, best_error=2.556e-04]
# Grid search for model.layers.1.post_attention_layernorm: 100%|██████████| 20/20 [00:30<00:00,  1.55s/it, best_error=2.556e-04]
# Smoothing:  67%|██████▋   | 2/3 [00:41<00:22, 22.50s/it]
# Grid search for model.layers.1.mlp.gate_up_proj:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.1.mlp.gate_up_proj:   0%|          | 0/20 [00:00<?, ?it/s, best_error=2.222e-04]
# Grid search for model.layers.1.mlp.gate_up_proj:   5%|▌         | 1/20 [00:00<00:13,  1.42it/s, best_error=2.222e-04]
# Grid search for model.layers.1.mlp.gate_up_proj:   5%|▌         | 1/20 [00:01<00:13,  1.42it/s, best_error=2.222e-04]
# Grid search for model.layers.1.mlp.gate_up_proj:  10%|█         | 2/20 [00:01<00:12,  1.42it/s, best_error=2.222e-04]
# Grid search for model.layers.1.mlp.gate_up_proj:  10%|█         | 2/20 [00:02<00:12,  1.42it/s, best_error=2.222e-04]
# Grid search for model.layers.1.mlp.gate_up_proj:  15%|█▌        | 3/20 [00:02<00:12,  1.42it/s, best_error=2.222e-04]
# Grid search for model.layers.1.mlp.gate_up_proj:  15%|█▌        | 3/20 [00:02<00:12,  1.42it/s, best_error=2.222e-04]
# Grid search for model.layers.1.mlp.gate_up_proj:  20%|██        | 4/20 [00:02<00:11,  1.41it/s, best_error=2.222e-04]
# Grid search for model.layers.1.mlp.gate_up_proj:  20%|██        | 4/20 [00:03<00:11,  1.41it/s, best_error=2.222e-04]
# Grid search for model.layers.1.mlp.gate_up_proj:  25%|██▌       | 5/20 [00:03<00:10,  1.41it/s, best_error=2.222e-04]
# Grid search for model.layers.1.mlp.gate_up_proj:  25%|██▌       | 5/20 [00:04<00:10,  1.41it/s, best_error=2.222e-04]
# Grid search for model.layers.1.mlp.gate_up_proj:  30%|███       | 6/20 [00:04<00:09,  1.41it/s, best_error=2.222e-04]
# Grid search for model.layers.1.mlp.gate_up_proj:  30%|███       | 6/20 [00:04<00:09,  1.41it/s, best_error=2.222e-04]
# Grid search for model.layers.1.mlp.gate_up_proj:  35%|███▌      | 7/20 [00:04<00:09,  1.41it/s, best_error=2.222e-04]
# Grid search for model.layers.1.mlp.gate_up_proj:  35%|███▌      | 7/20 [00:05<00:09,  1.41it/s, best_error=2.222e-04]
# Grid search for model.layers.1.mlp.gate_up_proj:  40%|████      | 8/20 [00:05<00:08,  1.40it/s, best_error=2.222e-04]
# Grid search for model.layers.1.mlp.gate_up_proj:  40%|████      | 8/20 [00:06<00:08,  1.40it/s, best_error=2.222e-04]
# Grid search for model.layers.1.mlp.gate_up_proj:  45%|████▌     | 9/20 [00:06<00:07,  1.40it/s, best_error=2.222e-04]
# Grid search for model.layers.1.mlp.gate_up_proj:  45%|████▌     | 9/20 [00:07<00:07,  1.40it/s, best_error=2.222e-04]
# Grid search for model.layers.1.mlp.gate_up_proj:  50%|█████     | 10/20 [00:07<00:07,  1.39it/s, best_error=2.222e-04]
# Grid search for model.layers.1.mlp.gate_up_proj:  50%|█████     | 10/20 [00:07<00:07,  1.39it/s, best_error=2.222e-04]
# Grid search for model.layers.1.mlp.gate_up_proj:  55%|█████▌    | 11/20 [00:07<00:06,  1.39it/s, best_error=2.222e-04]
# Grid search for model.layers.1.mlp.gate_up_proj:  55%|█████▌    | 11/20 [00:08<00:06,  1.39it/s, best_error=2.222e-04]
# Grid search for model.layers.1.mlp.gate_up_proj:  60%|██████    | 12/20 [00:08<00:05,  1.39it/s, best_error=2.222e-04]
# Grid search for model.layers.1.mlp.gate_up_proj:  60%|██████    | 12/20 [00:09<00:05,  1.39it/s, best_error=2.213e-04]
# Grid search for model.layers.1.mlp.gate_up_proj:  65%|██████▌   | 13/20 [00:09<00:05,  1.38it/s, best_error=2.213e-04]
# Grid search for model.layers.1.mlp.gate_up_proj:  65%|██████▌   | 13/20 [00:10<00:05,  1.38it/s, best_error=2.213e-04]
# Grid search for model.layers.1.mlp.gate_up_proj:  70%|███████   | 14/20 [00:10<00:04,  1.38it/s, best_error=2.213e-04]
# Grid search for model.layers.1.mlp.gate_up_proj:  70%|███████   | 14/20 [00:10<00:04,  1.38it/s, best_error=2.213e-04]
# Grid search for model.layers.1.mlp.gate_up_proj:  75%|███████▌  | 15/20 [00:10<00:03,  1.38it/s, best_error=2.213e-04]
# Grid search for model.layers.1.mlp.gate_up_proj:  75%|███████▌  | 15/20 [00:11<00:03,  1.38it/s, best_error=2.213e-04]
# Grid search for model.layers.1.mlp.gate_up_proj:  80%|████████  | 16/20 [00:11<00:02,  1.38it/s, best_error=2.213e-04]
# Grid search for model.layers.1.mlp.gate_up_proj:  80%|████████  | 16/20 [00:12<00:02,  1.38it/s, best_error=2.213e-04]
# Grid search for model.layers.1.mlp.gate_up_proj:  85%|████████▌ | 17/20 [00:12<00:02,  1.37it/s, best_error=2.213e-04]
# Grid search for model.layers.1.mlp.gate_up_proj:  85%|████████▌ | 17/20 [00:12<00:02,  1.37it/s, best_error=2.213e-04]
# Grid search for model.layers.1.mlp.gate_up_proj:  90%|█████████ | 18/20 [00:12<00:01,  1.37it/s, best_error=2.213e-04]
# Grid search for model.layers.1.mlp.gate_up_proj:  90%|█████████ | 18/20 [00:13<00:01,  1.37it/s, best_error=2.213e-04]
# Grid search for model.layers.1.mlp.gate_up_proj:  95%|█████████▌| 19/20 [00:13<00:00,  1.37it/s, best_error=2.213e-04]
# Grid search for model.layers.1.mlp.gate_up_proj:  95%|█████████▌| 19/20 [00:14<00:00,  1.37it/s, best_error=2.213e-04]
# Grid search for model.layers.1.mlp.gate_up_proj: 100%|██████████| 20/20 [00:14<00:00,  1.37it/s, best_error=2.213e-04]
# Smoothing: 100%|██████████| 3/3 [00:56<00:00, 18.73s/it]
# (2/33): Propagating: 100%|██████████| 64/64 [00:03<00:00, 18.97it/s]
# (3/33): Calibrating: 100%|██████████| 64/64 [00:03<00:00, 18.90it/s]
# Smoothing:   0%|          | 0/3 [00:00<?, ?it/s]
# Grid search for model.layers.2.input_layernorm:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.2.input_layernorm:   0%|          | 0/20 [00:00<?, ?it/s, best_error=2.991e-03]
# Grid search for model.layers.2.input_layernorm:   5%|▌         | 1/20 [00:00<00:09,  1.92it/s, best_error=2.991e-03]
# Grid search for model.layers.2.input_layernorm:   5%|▌         | 1/20 [00:01<00:09,  1.92it/s, best_error=2.533e-03]
# Grid search for model.layers.2.input_layernorm:  10%|█         | 2/20 [00:01<00:09,  1.91it/s, best_error=2.533e-03]
# Grid search for model.layers.2.input_layernorm:  10%|█         | 2/20 [00:01<00:09,  1.91it/s, best_error=2.350e-03]
# Grid search for model.layers.2.input_layernorm:  15%|█▌        | 3/20 [00:01<00:08,  1.91it/s, best_error=2.350e-03]
# Grid search for model.layers.2.input_layernorm:  15%|█▌        | 3/20 [00:02<00:08,  1.91it/s, best_error=2.304e-03]
# Grid search for model.layers.2.input_layernorm:  20%|██        | 4/20 [00:02<00:08,  1.90it/s, best_error=2.304e-03]
# Grid search for model.layers.2.input_layernorm:  20%|██        | 4/20 [00:02<00:08,  1.90it/s, best_error=2.228e-03]
# Grid search for model.layers.2.input_layernorm:  25%|██▌       | 5/20 [00:02<00:07,  1.90it/s, best_error=2.228e-03]
# Grid search for model.layers.2.input_layernorm:  25%|██▌       | 5/20 [00:03<00:07,  1.90it/s, best_error=2.228e-03]
# Grid search for model.layers.2.input_layernorm:  30%|███       | 6/20 [00:03<00:07,  1.90it/s, best_error=2.228e-03]
# Grid search for model.layers.2.input_layernorm:  30%|███       | 6/20 [00:03<00:07,  1.90it/s, best_error=2.228e-03]
# Grid search for model.layers.2.input_layernorm:  35%|███▌      | 7/20 [00:03<00:06,  1.89it/s, best_error=2.228e-03]
# Grid search for model.layers.2.input_layernorm:  35%|███▌      | 7/20 [00:04<00:06,  1.89it/s, best_error=2.228e-03]
# Grid search for model.layers.2.input_layernorm:  40%|████      | 8/20 [00:04<00:06,  1.89it/s, best_error=2.228e-03]
# Grid search for model.layers.2.input_layernorm:  40%|████      | 8/20 [00:04<00:06,  1.89it/s, best_error=2.228e-03]
# Grid search for model.layers.2.input_layernorm:  45%|████▌     | 9/20 [00:04<00:05,  1.89it/s, best_error=2.228e-03]
# Grid search for model.layers.2.input_layernorm:  45%|████▌     | 9/20 [00:05<00:05,  1.89it/s, best_error=2.228e-03]
# Grid search for model.layers.2.input_layernorm:  50%|█████     | 10/20 [00:05<00:05,  1.89it/s, best_error=2.228e-03]
# Grid search for model.layers.2.input_layernorm:  50%|█████     | 10/20 [00:05<00:05,  1.89it/s, best_error=2.228e-03]
# Grid search for model.layers.2.input_layernorm:  55%|█████▌    | 11/20 [00:05<00:04,  1.88it/s, best_error=2.228e-03]
# Grid search for model.layers.2.input_layernorm:  55%|█████▌    | 11/20 [00:06<00:04,  1.88it/s, best_error=2.228e-03]
# Grid search for model.layers.2.input_layernorm:  60%|██████    | 12/20 [00:06<00:04,  1.88it/s, best_error=2.228e-03]
# Grid search for model.layers.2.input_layernorm:  60%|██████    | 12/20 [00:06<00:04,  1.88it/s, best_error=2.228e-03]
# Grid search for model.layers.2.input_layernorm:  65%|██████▌   | 13/20 [00:06<00:03,  1.87it/s, best_error=2.228e-03]
# Grid search for model.layers.2.input_layernorm:  65%|██████▌   | 13/20 [00:07<00:03,  1.87it/s, best_error=2.228e-03]
# Grid search for model.layers.2.input_layernorm:  70%|███████   | 14/20 [00:07<00:03,  1.87it/s, best_error=2.228e-03]
# Grid search for model.layers.2.input_layernorm:  70%|███████   | 14/20 [00:07<00:03,  1.87it/s, best_error=2.228e-03]
# Grid search for model.layers.2.input_layernorm:  75%|███████▌  | 15/20 [00:07<00:02,  1.87it/s, best_error=2.228e-03]
# Grid search for model.layers.2.input_layernorm:  75%|███████▌  | 15/20 [00:08<00:02,  1.87it/s, best_error=2.228e-03]
# Grid search for model.layers.2.input_layernorm:  80%|████████  | 16/20 [00:08<00:02,  1.87it/s, best_error=2.228e-03]
# Grid search for model.layers.2.input_layernorm:  80%|████████  | 16/20 [00:09<00:02,  1.87it/s, best_error=2.228e-03]
# Grid search for model.layers.2.input_layernorm:  85%|████████▌ | 17/20 [00:09<00:01,  1.86it/s, best_error=2.228e-03]
# Grid search for model.layers.2.input_layernorm:  85%|████████▌ | 17/20 [00:09<00:01,  1.86it/s, best_error=2.228e-03]
# Grid search for model.layers.2.input_layernorm:  90%|█████████ | 18/20 [00:09<00:01,  1.86it/s, best_error=2.228e-03]
# Grid search for model.layers.2.input_layernorm:  90%|█████████ | 18/20 [00:10<00:01,  1.86it/s, best_error=2.228e-03]
# Grid search for model.layers.2.input_layernorm:  95%|█████████▌| 19/20 [00:10<00:00,  1.86it/s, best_error=2.228e-03]
# Grid search for model.layers.2.input_layernorm:  95%|█████████▌| 19/20 [00:10<00:00,  1.86it/s, best_error=2.228e-03]
# Grid search for model.layers.2.input_layernorm: 100%|██████████| 20/20 [00:10<00:00,  1.86it/s, best_error=2.228e-03]
# Smoothing:  33%|███▎      | 1/3 [00:11<00:22, 11.20s/it]
# Grid search for model.layers.2.post_attention_layernorm:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.2.post_attention_layernorm:   0%|          | 0/20 [00:01<?, ?it/s, best_error=3.357e-04]
# Grid search for model.layers.2.post_attention_layernorm:   5%|▌         | 1/20 [00:01<00:33,  1.78s/it, best_error=3.357e-04]
# Grid search for model.layers.2.post_attention_layernorm:   5%|▌         | 1/20 [00:03<00:33,  1.78s/it, best_error=3.338e-04]
# Grid search for model.layers.2.post_attention_layernorm:  10%|█         | 2/20 [00:03<00:32,  1.79s/it, best_error=3.338e-04]
# Grid search for model.layers.2.post_attention_layernorm:  10%|█         | 2/20 [00:05<00:32,  1.79s/it, best_error=3.338e-04]
# Grid search for model.layers.2.post_attention_layernorm:  15%|█▌        | 3/20 [00:05<00:30,  1.79s/it, best_error=3.338e-04]
# Grid search for model.layers.2.post_attention_layernorm:  15%|█▌        | 3/20 [00:07<00:30,  1.79s/it, best_error=3.319e-04]
# Grid search for model.layers.2.post_attention_layernorm:  20%|██        | 4/20 [00:07<00:28,  1.78s/it, best_error=3.319e-04]
# Grid search for model.layers.2.post_attention_layernorm:  20%|██        | 4/20 [00:08<00:28,  1.78s/it, best_error=3.319e-04]
# Grid search for model.layers.2.post_attention_layernorm:  25%|██▌       | 5/20 [00:08<00:26,  1.78s/it, best_error=3.319e-04]
# Grid search for model.layers.2.post_attention_layernorm:  25%|██▌       | 5/20 [00:10<00:26,  1.78s/it, best_error=3.319e-04]
# Grid search for model.layers.2.post_attention_layernorm:  30%|███       | 6/20 [00:10<00:24,  1.77s/it, best_error=3.319e-04]
# Grid search for model.layers.2.post_attention_layernorm:  30%|███       | 6/20 [00:12<00:24,  1.77s/it, best_error=3.319e-04]
# Grid search for model.layers.2.post_attention_layernorm:  35%|███▌      | 7/20 [00:12<00:22,  1.76s/it, best_error=3.319e-04]
# Grid search for model.layers.2.post_attention_layernorm:  35%|███▌      | 7/20 [00:14<00:22,  1.76s/it, best_error=3.319e-04]
# Grid search for model.layers.2.post_attention_layernorm:  40%|████      | 8/20 [00:14<00:21,  1.76s/it, best_error=3.319e-04]
# ...
# Grid search for model.layers.31.input_layernorm:  20%|██        | 4/20 [00:02<00:08,  1.93it/s, best_error=1.926e-04]
# Grid search for model.layers.31.input_layernorm:  25%|██▌       | 5/20 [00:02<00:07,  1.93it/s, best_error=1.926e-04]
# Grid search for model.layers.31.input_layernorm:  25%|██▌       | 5/20 [00:03<00:07,  1.93it/s, best_error=1.926e-04]
# Grid search for model.layers.31.input_layernorm:  30%|███       | 6/20 [00:03<00:07,  1.93it/s, best_error=1.926e-04]
# Grid search for model.layers.31.input_layernorm:  30%|███       | 6/20 [00:03<00:07,  1.93it/s, best_error=1.926e-04]
# Grid search for model.layers.31.input_layernorm:  35%|███▌      | 7/20 [00:03<00:06,  1.93it/s, best_error=1.926e-04]
# Grid search for model.layers.31.input_layernorm:  35%|███▌      | 7/20 [00:04<00:06,  1.93it/s, best_error=1.926e-04]
# Grid search for model.layers.31.input_layernorm:  40%|████      | 8/20 [00:04<00:06,  1.93it/s, best_error=1.926e-04]
# Grid search for model.layers.31.input_layernorm:  40%|████      | 8/20 [00:04<00:06,  1.93it/s, best_error=1.926e-04]
# Grid search for model.layers.31.input_layernorm:  45%|████▌     | 9/20 [00:04<00:05,  1.93it/s, best_error=1.926e-04]
# Grid search for model.layers.31.input_layernorm:  45%|████▌     | 9/20 [00:05<00:05,  1.93it/s, best_error=1.926e-04]
# Grid search for model.layers.31.input_layernorm:  50%|█████     | 10/20 [00:05<00:05,  1.93it/s, best_error=1.926e-04]
# Grid search for model.layers.31.input_layernorm:  50%|█████     | 10/20 [00:05<00:05,  1.93it/s, best_error=1.926e-04]
# Grid search for model.layers.31.input_layernorm:  55%|█████▌    | 11/20 [00:05<00:04,  1.93it/s, best_error=1.926e-04]
# Grid search for model.layers.31.input_layernorm:  55%|█████▌    | 11/20 [00:06<00:04,  1.93it/s, best_error=1.926e-04]
# Grid search for model.layers.31.input_layernorm:  60%|██████    | 12/20 [00:06<00:04,  1.93it/s, best_error=1.926e-04]
# Grid search for model.layers.31.input_layernorm:  60%|██████    | 12/20 [00:06<00:04,  1.93it/s, best_error=1.926e-04]
# Grid search for model.layers.31.input_layernorm:  65%|██████▌   | 13/20 [00:06<00:03,  1.93it/s, best_error=1.926e-04]
# Grid search for model.layers.31.input_layernorm:  65%|██████▌   | 13/20 [00:07<00:03,  1.93it/s, best_error=1.926e-04]
# Grid search for model.layers.31.input_layernorm:  70%|███████   | 14/20 [00:07<00:03,  1.93it/s, best_error=1.926e-04]
# Grid search for model.layers.31.input_layernorm:  70%|███████   | 14/20 [00:07<00:03,  1.93it/s, best_error=1.926e-04]
# Grid search for model.layers.31.input_layernorm:  75%|███████▌  | 15/20 [00:07<00:02,  1.93it/s, best_error=1.926e-04]
# Grid search for model.layers.31.input_layernorm:  75%|███████▌  | 15/20 [00:08<00:02,  1.93it/s, best_error=1.926e-04]
# Grid search for model.layers.31.input_layernorm:  80%|████████  | 16/20 [00:08<00:02,  1.93it/s, best_error=1.926e-04]
# Grid search for model.layers.31.input_layernorm:  80%|████████  | 16/20 [00:08<00:02,  1.93it/s, best_error=1.926e-04]
# Grid search for model.layers.31.input_layernorm:  85%|████████▌ | 17/20 [00:08<00:01,  1.93it/s, best_error=1.926e-04]
# Grid search for model.layers.31.input_layernorm:  85%|████████▌ | 17/20 [00:09<00:01,  1.93it/s, best_error=1.926e-04]
# Grid search for model.layers.31.input_layernorm:  90%|█████████ | 18/20 [00:09<00:01,  1.93it/s, best_error=1.926e-04]
# Grid search for model.layers.31.input_layernorm:  90%|█████████ | 18/20 [00:09<00:01,  1.93it/s, best_error=1.926e-04]
# Grid search for model.layers.31.input_layernorm:  95%|█████████▌| 19/20 [00:09<00:00,  1.93it/s, best_error=1.926e-04]
# Grid search for model.layers.31.input_layernorm:  95%|█████████▌| 19/20 [00:10<00:00,  1.93it/s, best_error=1.926e-04]
# Grid search for model.layers.31.input_layernorm: 100%|██████████| 20/20 [00:10<00:00,  1.93it/s, best_error=1.926e-04]
# Smoothing:  33%|███▎      | 1/3 [00:10<00:21, 10.90s/it]
# Grid search for model.layers.31.post_attention_layernorm:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.31.post_attention_layernorm:   0%|          | 0/20 [00:01<?, ?it/s, best_error=2.747e-03]
# Grid search for model.layers.31.post_attention_layernorm:   5%|▌         | 1/20 [00:01<00:32,  1.69s/it, best_error=2.747e-03]
# Grid search for model.layers.31.post_attention_layernorm:   5%|▌         | 1/20 [00:03<00:32,  1.69s/it, best_error=2.609e-03]
# Grid search for model.layers.31.post_attention_layernorm:  10%|█         | 2/20 [00:03<00:30,  1.68s/it, best_error=2.609e-03]
# Grid search for model.layers.31.post_attention_layernorm:  10%|█         | 2/20 [00:05<00:30,  1.68s/it, best_error=2.548e-03]
# Grid search for model.layers.31.post_attention_layernorm:  15%|█▌        | 3/20 [00:05<00:28,  1.68s/it, best_error=2.548e-03]
# Grid search for model.layers.31.post_attention_layernorm:  15%|█▌        | 3/20 [00:06<00:28,  1.68s/it, best_error=2.518e-03]
# Grid search for model.layers.31.post_attention_layernorm:  20%|██        | 4/20 [00:06<00:26,  1.68s/it, best_error=2.518e-03]
# Grid search for model.layers.31.post_attention_layernorm:  20%|██        | 4/20 [00:08<00:26,  1.68s/it, best_error=2.441e-03]
# Grid search for model.layers.31.post_attention_layernorm:  25%|██▌       | 5/20 [00:08<00:25,  1.68s/it, best_error=2.441e-03]
# Grid search for model.layers.31.post_attention_layernorm:  25%|██▌       | 5/20 [00:10<00:25,  1.68s/it, best_error=2.380e-03]
# Grid search for model.layers.31.post_attention_layernorm:  30%|███       | 6/20 [00:10<00:23,  1.68s/it, best_error=2.380e-03]
# Grid search for model.layers.31.post_attention_layernorm:  30%|███       | 6/20 [00:11<00:23,  1.68s/it, best_error=2.380e-03]
# Grid search for model.layers.31.post_attention_layernorm:  35%|███▌      | 7/20 [00:11<00:21,  1.68s/it, best_error=2.380e-03]
# Grid search for model.layers.31.post_attention_layernorm:  35%|███▌      | 7/20 [00:13<00:21,  1.68s/it, best_error=2.380e-03]
# Grid search for model.layers.31.post_attention_layernorm:  40%|████      | 8/20 [00:13<00:20,  1.68s/it, best_error=2.380e-03]
# Grid search for model.layers.31.post_attention_layernorm:  40%|████      | 8/20 [00:15<00:20,  1.68s/it, best_error=2.380e-03]
# Grid search for model.layers.31.post_attention_layernorm:  45%|████▌     | 9/20 [00:15<00:18,  1.68s/it, best_error=2.380e-03]
# Grid search for model.layers.31.post_attention_layernorm:  45%|████▌     | 9/20 [00:16<00:18,  1.68s/it, best_error=2.380e-03]
# Grid search for model.layers.31.post_attention_layernorm:  50%|█████     | 10/20 [00:16<00:16,  1.68s/it, best_error=2.380e-03]
# Grid search for model.layers.31.post_attention_layernorm:  50%|█████     | 10/20 [00:18<00:16,  1.68s/it, best_error=2.380e-03]
# Grid search for model.layers.31.post_attention_layernorm:  55%|█████▌    | 11/20 [00:18<00:15,  1.68s/it, best_error=2.380e-03]
# Grid search for model.layers.31.post_attention_layernorm:  55%|█████▌    | 11/20 [00:20<00:15,  1.68s/it, best_error=2.380e-03]
# Grid search for model.layers.31.post_attention_layernorm:  60%|██████    | 12/20 [00:20<00:13,  1.68s/it, best_error=2.380e-03]
# Grid search for model.layers.31.post_attention_layernorm:  60%|██████    | 12/20 [00:21<00:13,  1.68s/it, best_error=2.380e-03]
# Grid search for model.layers.31.post_attention_layernorm:  65%|██████▌   | 13/20 [00:21<00:11,  1.68s/it, best_error=2.380e-03]
# Grid search for model.layers.31.post_attention_layernorm:  65%|██████▌   | 13/20 [00:23<00:11,  1.68s/it, best_error=2.380e-03]
# Grid search for model.layers.31.post_attention_layernorm:  70%|███████   | 14/20 [00:23<00:10,  1.68s/it, best_error=2.380e-03]
# Grid search for model.layers.31.post_attention_layernorm:  70%|███████   | 14/20 [00:25<00:10,  1.68s/it, best_error=2.380e-03]
# Grid search for model.layers.31.post_attention_layernorm:  75%|███████▌  | 15/20 [00:25<00:08,  1.68s/it, best_error=2.380e-03]
# Grid search for model.layers.31.post_attention_layernorm:  75%|███████▌  | 15/20 [00:26<00:08,  1.68s/it, best_error=2.380e-03]
# Grid search for model.layers.31.post_attention_layernorm:  80%|████████  | 16/20 [00:26<00:06,  1.67s/it, best_error=2.380e-03]
# Grid search for model.layers.31.post_attention_layernorm:  80%|████████  | 16/20 [00:28<00:06,  1.67s/it, best_error=2.380e-03]
# Grid search for model.layers.31.post_attention_layernorm:  85%|████████▌ | 17/20 [00:28<00:05,  1.67s/it, best_error=2.380e-03]
# Grid search for model.layers.31.post_attention_layernorm:  85%|████████▌ | 17/20 [00:30<00:05,  1.67s/it, best_error=2.380e-03]
# Grid search for model.layers.31.post_attention_layernorm:  90%|█████████ | 18/20 [00:30<00:03,  1.67s/it, best_error=2.380e-03]
# Grid search for model.layers.31.post_attention_layernorm:  90%|█████████ | 18/20 [00:31<00:03,  1.67s/it, best_error=2.380e-03]
# Grid search for model.layers.31.post_attention_layernorm:  95%|█████████▌| 19/20 [00:31<00:01,  1.67s/it, best_error=2.380e-03]
# Grid search for model.layers.31.post_attention_layernorm:  95%|█████████▌| 19/20 [00:33<00:01,  1.67s/it, best_error=2.380e-03]
# Grid search for model.layers.31.post_attention_layernorm: 100%|██████████| 20/20 [00:33<00:00,  1.68s/it, best_error=2.380e-03]
# Smoothing:  67%|██████▋   | 2/3 [00:46<00:25, 25.23s/it]
# Grid search for model.layers.31.mlp.gate_up_proj:   0%|          | 0/20 [00:00<?, ?it/s]
# Grid search for model.layers.31.mlp.gate_up_proj:   0%|          | 0/20 [00:00<?, ?it/s, best_error=1.289e+00]
# Grid search for model.layers.31.mlp.gate_up_proj:   5%|▌         | 1/20 [00:00<00:14,  1.35it/s, best_error=1.289e+00]
# Grid search for model.layers.31.mlp.gate_up_proj:   5%|▌         | 1/20 [00:01<00:14,  1.35it/s, best_error=1.031e+00]
# Grid search for model.layers.31.mlp.gate_up_proj:  10%|█         | 2/20 [00:01<00:13,  1.35it/s, best_error=1.031e+00]
# Grid search for model.layers.31.mlp.gate_up_proj:  10%|█         | 2/20 [00:02<00:13,  1.35it/s, best_error=8.086e-01]
# Grid search for model.layers.31.mlp.gate_up_proj:  15%|█▌        | 3/20 [00:02<00:12,  1.34it/s, best_error=8.086e-01]
# Grid search for model.layers.31.mlp.gate_up_proj:  15%|█▌        | 3/20 [00:02<00:12,  1.34it/s, best_error=6.445e-01]
# Grid search for model.layers.31.mlp.gate_up_proj:  20%|██        | 4/20 [00:02<00:11,  1.34it/s, best_error=6.445e-01]
# Grid search for model.layers.31.mlp.gate_up_proj:  20%|██        | 4/20 [00:03<00:11,  1.34it/s, best_error=6.094e-01]
# Grid search for model.layers.31.mlp.gate_up_proj:  25%|██▌       | 5/20 [00:03<00:11,  1.34it/s, best_error=6.094e-01]
# Grid search for model.layers.31.mlp.gate_up_proj:  25%|██▌       | 5/20 [00:04<00:11,  1.34it/s, best_error=4.434e-01]
# Grid search for model.layers.31.mlp.gate_up_proj:  30%|███       | 6/20 [00:04<00:10,  1.34it/s, best_error=4.434e-01]
# Grid search for model.layers.31.mlp.gate_up_proj:  30%|███       | 6/20 [00:05<00:10,  1.34it/s, best_error=4.355e-01]
# Grid search for model.layers.31.mlp.gate_up_proj:  35%|███▌      | 7/20 [00:05<00:09,  1.34it/s, best_error=4.355e-01]
# Grid search for model.layers.31.mlp.gate_up_proj:  35%|███▌      | 7/20 [00:05<00:09,  1.34it/s, best_error=1.396e-01]
# Grid search for model.layers.31.mlp.gate_up_proj:  40%|████      | 8/20 [00:05<00:08,  1.34it/s, best_error=1.396e-01]
# Grid search for model.layers.31.mlp.gate_up_proj:  40%|████      | 8/20 [00:06<00:08,  1.34it/s, best_error=9.375e-02]
# Grid search for model.layers.31.mlp.gate_up_proj:  45%|████▌     | 9/20 [00:06<00:08,  1.34it/s, best_error=9.375e-02]
# Grid search for model.layers.31.mlp.gate_up_proj:  45%|████▌     | 9/20 [00:07<00:08,  1.34it/s, best_error=7.373e-02]
# Grid search for model.layers.31.mlp.gate_up_proj:  50%|█████     | 10/20 [00:07<00:07,  1.34it/s, best_error=7.373e-02]
# Grid search for model.layers.31.mlp.gate_up_proj:  50%|█████     | 10/20 [00:08<00:07,  1.34it/s, best_error=7.373e-02]
# Grid search for model.layers.31.mlp.gate_up_proj:  55%|█████▌    | 11/20 [00:08<00:06,  1.34it/s, best_error=7.373e-02]
# Grid search for model.layers.31.mlp.gate_up_proj:  55%|█████▌    | 11/20 [00:08<00:06,  1.34it/s, best_error=7.178e-02]
# Grid search for model.layers.31.mlp.gate_up_proj:  60%|██████    | 12/20 [00:08<00:05,  1.34it/s, best_error=7.178e-02]
# Grid search for model.layers.31.mlp.gate_up_proj:  60%|██████    | 12/20 [00:09<00:05,  1.34it/s, best_error=7.178e-02]
# Grid search for model.layers.31.mlp.gate_up_proj:  65%|██████▌   | 13/20 [00:09<00:05,  1.34it/s, best_error=7.178e-02]
# Grid search for model.layers.31.mlp.gate_up_proj:  65%|██████▌   | 13/20 [00:10<00:05,  1.34it/s, best_error=7.178e-02]
# Grid search for model.layers.31.mlp.gate_up_proj:  70%|███████   | 14/20 [00:10<00:04,  1.34it/s, best_error=7.178e-02]
# Grid search for model.layers.31.mlp.gate_up_proj:  70%|███████   | 14/20 [00:11<00:04,  1.34it/s, best_error=7.178e-02]
# Grid search for model.layers.31.mlp.gate_up_proj:  75%|███████▌  | 15/20 [00:11<00:03,  1.34it/s, best_error=7.178e-02]
# Grid search for model.layers.31.mlp.gate_up_proj:  75%|███████▌  | 15/20 [00:11<00:03,  1.34it/s, best_error=7.178e-02]
# Grid search for model.layers.31.mlp.gate_up_proj:  80%|████████  | 16/20 [00:11<00:02,  1.34it/s, best_error=7.178e-02]
# Grid search for model.layers.31.mlp.gate_up_proj:  80%|████████  | 16/20 [00:12<00:02,  1.34it/s, best_error=7.178e-02]
# Grid search for model.layers.31.mlp.gate_up_proj:  85%|████████▌ | 17/20 [00:12<00:02,  1.34it/s, best_error=7.178e-02]
# Grid search for model.layers.31.mlp.gate_up_proj:  85%|████████▌ | 17/20 [00:13<00:02,  1.34it/s, best_error=7.178e-02]
# Grid search for model.layers.31.mlp.gate_up_proj:  90%|█████████ | 18/20 [00:13<00:01,  1.34it/s, best_error=7.178e-02]
# Grid search for model.layers.31.mlp.gate_up_proj:  90%|█████████ | 18/20 [00:14<00:01,  1.34it/s, best_error=7.178e-02]
# Grid search for model.layers.31.mlp.gate_up_proj:  95%|█████████▌| 19/20 [00:14<00:00,  1.34it/s, best_error=7.178e-02]
# Grid search for model.layers.31.mlp.gate_up_proj:  95%|█████████▌| 19/20 [00:14<00:00,  1.34it/s, best_error=7.178e-02]
# Grid search for model.layers.31.mlp.gate_up_proj: 100%|██████████| 20/20 [00:14<00:00,  1.35it/s, best_error=7.178e-02]
# Smoothing: 100%|██████████| 3/3 [01:01<00:00, 20.61s/it]
# (32/33): Propagating: 100%|██████████| 64/64 [00:03<00:00, 18.83it/s]
# (33/33): Calibrating: 100%|██████████| 64/64 [00:00<00:00, 808.56it/s]
# Smoothing: 0it [00:00, ?it/s]
# (33/33): Propagating: 100%|██████████| 64/64 [00:00<00:00, 847.97it/s]
# Smoothing: 0it [00:00, ?it/s]
# Updating global scales: 100%|██████████| 128/128 [00:00<00:00, 301612.87it/s]
# Fusing global scales: 519it [00:00, 356859.64it/s]
# Calibrating weights: 100%|██████████| 128/128 [00:00<00:00, 243.71it/s]
# 2026-05-04T20:02:43.019117+0000 | finalize | INFO - Compression lifecycle finalized for 1 modifiers
# 2026-05-04T20:02:43.019786+0000 | post_process | WARNING - Optimized model is not saved. To save, please provide`output_dir` as input arg.Ex. `oneshot(..., output_dir=...)`
# Phi3ForCausalLM(
#   (model): Phi3Model(
#     (embed_tokens): Embedding(200064, 3072, padding_idx=199999)
#     (layers): ModuleList(
#       (0-31): 32 x Phi3DecoderLayer(
#         (self_attn): Phi3Attention(
#           (o_proj): Linear(in_features=3072, out_features=3072, bias=False)
#           (qkv_proj): Linear(in_features=3072, out_features=5120, bias=False)
#         )
#         (mlp): Phi3MLP(
#           (gate_up_proj): Linear(in_features=3072, out_features=16384, bias=False)
#           (down_proj): Linear(in_features=8192, out_features=3072, bias=False)
#           (activation_fn): SiLUActivation()
#         )
#         (input_layernorm): Phi3RMSNorm((3072,), eps=1e-05)
#         (post_attention_layernorm): Phi3RMSNorm((3072,), eps=1e-05)
#         (resid_attn_dropout): Dropout(p=0.0, inplace=False)
#         (resid_mlp_dropout): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (norm): Phi3RMSNorm((3072,), eps=1e-05)
#     (rotary_emb): Phi3RotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=3072, out_features=200064, bias=False)
# )

# %% [markdown]
# **Saving**

# %%
model.config._name_or_path = ""

model.save_pretrained(OUTPUT_DIR,skip_sparsity_compression_stats=False)#VERY IMPORTANT
tokenizer.save_pretrained(OUTPUT_DIR)

print("Model saved successfully")
# Out:
# Calculating model sparsity: 100%|██████████| 451/451 [00:21<00:00, 20.53it/s]
# Checking whether model follows 2:4 sparsity structure: 100%|██████████| 129/129 [00:22<00:00,  5.72it/s]
# Compressing model: 128it [00:24,  5.13it/s]
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py:3970: UserWarning: Attempting to save a model with offloaded modules. Ensure that unallocated cpu memory exceeds the `shard_size` (5GB default)
#   warnings.warn(
# Saving checkpoint shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Model saved successfully

# %% [markdown]
# # PUSH TO HUGGING FACE

# %%
create_repo(REPO_ID, repo_type="model", exist_ok=True)

upload_folder(
    folder_path=OUTPUT_DIR,
    repo_id=REPO_ID,
    path_in_repo="Sparsity/25"
)
# Out:
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# CommitInfo(commit_url='https://huggingface.co/EdgeCompress01/Phi-4-mini-instruct-WANDA-AWQ-4bit/commit/392f88045c2eb728ef4778b01eece5193b1fd330', commit_message='Upload folder using huggingface_hub', commit_description='', oid='392f88045c2eb728ef4778b01eece5193b1fd330', pr_url=None, repo_url=RepoUrl('https://huggingface.co/EdgeCompress01/Phi-4-mini-instruct-WANDA-AWQ-4bit', endpoint='https://huggingface.co', repo_type='model', repo_id='EdgeCompress01/Phi-4-mini-instruct-WANDA-AWQ-4bit'), pr_revision=None, pr_num=None)
