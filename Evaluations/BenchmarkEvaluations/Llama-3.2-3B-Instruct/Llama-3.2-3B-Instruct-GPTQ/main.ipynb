# %% [markdown]
# # Libraries

# %%
# 1. Base Framework
# !pip install -q -U \
    torch==2.11.0 \
    torchvision==0.26.0 \
    torchaudio==2.11.0 \
    --index-url https://download.pytorch.org/whl/cu126

# 2. torchao - force reinstall to actually replace Kaggle's broken copy
# !pip install -q --no-deps --force-reinstall torchao \
    --index-url https://download.pytorch.org/whl/cu128

# 3. Evaluation Framework
# !pip install -q "lm_eval[hf]"

# 4. Compression Tools
# !pip install -q gptqmodel optimum

# 5. Utilities
# !pip install -q langdetect --break-system-packages  # for IFEval Task
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.8/296.8 MB 114.6 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 MB 93.9 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.7/897.7 kB 229.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.2/200.2 MB 129.4 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 203.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 227.6 MB/s eta 0:00:00a 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 186.5 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 MB 137.7 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 MB 93.3 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 188.7 MB/s eta 0:00:00a 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.6/23.6 MB 198.6 MB/s eta 0:00:00a 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.3/89.3 kB 111.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 830.5/830.5 MB 1.2 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 2.8 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 7.6 MB/s eta 0:00:000:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 51.6 MB/s eta 0:00:00a 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.4/56.4 kB 2.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 95.3 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 7.7 MB/s eta 0:00:00
#   Building wheel for sqlitedict (setup.py) ... done
#   Building wheel for word2number (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 885.6/885.6 kB 20.0 MB/s eta 0:00:0000:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 4.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.5/94.5 kB 6.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 4.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 88.1 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.2/161.2 kB 12.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.7/383.7 kB 27.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.2/69.2 kB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.6/10.6 MB 89.3 MB/s eta 0:00:00:00:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.3/324.3 kB 26.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 52.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 103.4 MB/s eta 0:00:0000:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 642.6/642.6 kB 37.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 111.6 MB/s eta 0:00:0000:01
#   Building wheel for gptqmodel (pyproject.toml) ... done
#   Building wheel for defuser (pyproject.toml) ... done
#   Building wheel for device-smi (pyproject.toml) ... done
#   Building wheel for logbar (pyproject.toml) ... done
#   Building wheel for tokenicer (pyproject.toml) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.35.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# google-adk 1.25.1 requires google-cloud-bigquery-storage>=2.0.0, which is not installed.
# google-cloud-videointelligence 2.18.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.1 which is incompatible.
# google-cloud-vision 3.12.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.1 which is incompatible.
# google-colab 1.0.0 requires jupyter-server==2.14.0, but you have jupyter-server 2.12.5 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# grpc-google-iam-v1 0.14.3 requires protobuf!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.1 which is incompatible.
# google-cloud-language 2.19.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.1 which is incompatible.
# dopamine-rl 4.1.2 requires gym<=0.25.2, but you have gym 0.26.2 which is incompatible.
# google-cloud-spanner 3.63.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.1 which is incompatible.
# google-cloud-aiplatform 1.138.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.1 which is incompatible.
# google-cloud-resource-manager 1.16.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.1 which is incompatible.
# google-cloud-firestore 2.23.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0dev,>=3.20.2, but you have protobuf 7.34.1 which is incompatible.
# google-cloud-translate 3.24.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.1 which is incompatible.
# google-cloud-bigquery-connection 1.20.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.1 which is incompatible.
# google-cloud-logging 3.13.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.1 which is incompatible.
# google-ai-generativelanguage 0.6.15 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 7.34.1 which is incompatible.
# ydf 0.15.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 7.34.1 which is incompatible.
# google-cloud-trace 1.18.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.1 which is incompatible.
# google-cloud-functions 1.22.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.1 which is incompatible.
# googleapis-common-protos 1.72.0 requires protobuf!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.1 which is incompatible.
# google-cloud-secret-manager 2.26.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.1 which is incompatible.
# google-cloud-discoveryengine 0.13.12 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.1 which is incompatible.
# google-cloud-datastore 2.23.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.1 which is incompatible.
# google-cloud-pubsub 2.35.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.1 which is incompatible.
# wandb 0.25.0 requires protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0; python_version > "3.9" and sys_platform == "linux", but you have protobuf 7.34.1 which is incompatible.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.2.6 which is incompatible.
# tensorflow 2.19.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3, but you have protobuf 7.34.1 which is incompatible.
# google-cloud-appengine-logging 1.8.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.1 which is incompatible.
# google-cloud-bigtable 2.35.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.1 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.6 which is incompatible.
# google-cloud-dataproc 5.25.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.1 which is incompatible.
# google-cloud-speech 2.36.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.1 which is incompatible.
# google-cloud-monitoring 2.29.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.1 which is incompatible.
# proto-plus 1.27.1 requires protobuf<7.0.0,>=3.19.0, but you have protobuf 7.34.1 which is incompatible.
# google-api-core 2.30.0 requires protobuf<7.0.0,>=4.25.8, but you have protobuf 7.34.1 which is incompatible.
# opentelemetry-proto 1.38.0 requires protobuf<7.0,>=5.0, but you have protobuf 7.34.1 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 7.34.1 which is incompatible.
# google-cloud-audit-log 0.4.0 requires protobuf!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.1 which is incompatible.
# google-cloud-iam 2.21.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.1 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 18.5 MB/s eta 0:00:0000:01
#   Preparing metadata (setup.py) ... done
#   Building wheel for langdetect (setup.py) ... done

# %%
# Libraries
import gc
import glob
import shutil
import os
import random
import subprocess

import numpy as np
import torch
import lm_eval

from dataclasses import dataclass
from typing import Optional
from huggingface_hub import login
from IPython.display import FileLink
from kaggle_secrets import UserSecretsClient

# %% [markdown]
# # Global Variables

# %%
# --- Identity ---
user_name = "Abdelrahmanemam01"
email     = "abdulrahmanemam01@gmail.com"
repo      = "MahmoudOsama20/EdgeCompress"  # Fixed

# --- Model ---
QWEN       = False
model      = "Qwen3-4B"             if QWEN else "Llama-3.2-3B-Instruct"
MODEL_NAME       = "Llama-3.2-3B-Instruct-GPTQ"
MODEL_PRETRAINED = "EdgeCompress01/Llama-3.2-3B-Instruct-GPTQ-4bit"
MODEL_PRETRAINED_FIX = MODEL_PRETRAINED.replace("/", "__")

# --- Reproducibility ---
SEED = 42

# --- Environment ---
os.environ["HF_ALLOW_CODE_EVAL"] = "1"

# %% [markdown]
# # Classes

# %%
@dataclass
class Task:
    key:               str
    name:              str
    category:          str
    num_fewshot:       int  = 0
    batch_size:        int  = 2
    limit:             Optional[int] = None
    apply_chat_template: bool = True
    max_gen_toks:      Optional[int] = None

# %% [markdown]
# # Functions

# %%
# REPRODUCIBILITY
def set_reproducibility(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    # Ensure deterministic behavior in CuDNN
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    print(f"Global seed set to {seed}")

# %% [markdown]
# # Seeding

# %%
set_reproducibility(SEED)
# Out:
# Global seed set to 42

# %% [markdown]
# # Huggingface login

# %%
# HUGGING FACE AUTHENTICATION
user_secrets = UserSecretsClient()
hf_token = user_secrets.get_secret("HF_TOKEN")
login(token=hf_token)
print("Logging into Hugging Face...")
# Out:
# Logging into Hugging Face...

# %% [markdown]
# # GitHub login

# %%
token = UserSecretsClient().get_secret("GIT_TOKEN")
print("Logging into GitHub...")
# Out:
# Logging into GitHub...

# %% [markdown]
# # Evaluations

# %% [markdown]
# **Configurations**

# %%
# Task definition
TASKS = [
    # Reasoning
     Task("arc_challenge","arc_challenge",              "reasoning",           batch_size=16),

    # Perplexity
     Task("wikitext",     "wikitext",                  "perplexity",          batch_size=1,  apply_chat_template=False),

    # Knowledge
     Task("mmlu",         "mmlu",                      "knowledge",           num_fewshot=5, batch_size=2,  limit=1400),
    
    # Instruction Following
     Task("ifeval",       "ifeval",                    "instruction_following",batch_size=14,  max_gen_toks=1024),
    
    # Math
     Task("gsm8k",        "gsm8k_cot",                 "math",                num_fewshot=8, batch_size=12,  max_gen_toks=1024),
]


# Model args
MODEL_ARGS = ",".join([
    f"pretrained={MODEL_PRETRAINED}",
    "dtype=float16",
    "parallelize=True",
    "max_length=4096",
    "trust_remote_code=True",
    #"enable_thinking=False",
])

results_dir = f"evaluation_results/{MODEL_NAME}"

# %% [markdown]
# **Evaluation loop**

# %%
for t in TASKS:
    print(f"\n[{t.category.upper()}] {t.key}")

    cmd = [
        "lm_eval",
        "--model",       "hf",
        "--model_args",  MODEL_ARGS,
        "--tasks",       t.name,
        "--num_fewshot", str(t.num_fewshot),
        "--batch_size",  str(t.batch_size),
        "--seed",        str(SEED),
        "--verbosity", "DEBUG",
        "--output_path", f"{results_dir}/{t.key}",
    ]

    if t.limit is not None:
        cmd += ["--limit", str(t.limit)]
        
    if t.apply_chat_template:
            cmd.append("--apply_chat_template")
        
    if t.max_gen_toks is not None:                             
        cmd += ["--gen_kwargs", f"max_gen_toks={t.max_gen_toks}"]

    subprocess.run(cmd, check=True)
    
    # Push To GitHub
    target_dir_in_repo = f"New_Evaluations/{model}/{MODEL_NAME}/results/{t.key}"
    source_folder = f"{results_dir}/{t.key}/{MODEL_PRETRAINED_FIX}"  # The Kaggle folder you want to upload
    remote_url = f"https://{token}@github.com/{repo}.git"
    
    # A temporary workspace in Kaggle to handle the cloning
    temp_repo_dir = "/kaggle/working/temp_git_repo" 
    # ---------------------

    # 2. Clean up any previous runs and clone the existing repository
    os.system(f"rm -rf {temp_repo_dir}")
    os.system(f"git clone {remote_url} {temp_repo_dir}")
    
    # 3. Create the target directory inside the cloned repo
    full_target_path = f"{temp_repo_dir}/{target_dir_in_repo}"
    os.makedirs(full_target_path, exist_ok=True)
    
    # 4. Copy the contents of your Kaggle folder into the target GitHub folder
    # (Using cp -r to recursively copy all files and subfolders)
    os.system(f"cp -r {source_folder}/* {full_target_path}/")
    
    # 5. Configure, commit, and push the changes
    os.system(f"""
        git -C {temp_repo_dir} config user.email "{email}" && \
        git -C {temp_repo_dir} config user.name "{user_name}" && \
        git -C {temp_repo_dir} add . && \
        git -C {temp_repo_dir} commit -m "Add Kaggle results to {target_dir_in_repo}" && \
        git -C {temp_repo_dir} push origin main
    """)
    
    print(f"Successfully pushed to {repo} inside the '{target_dir_in_repo}' folder!")
    
    torch.cuda.empty_cache()
    gc.collect()
    print("Done")
# Out:
# [REASONING] arc_challenge
# 2026-04-11:03:28:58 INFO     [config.evaluate_config:301] Using default fewshot_as_multiturn=True.
# 2026-04-11:03:29:04 INFO     [_cli.run:376] Selected Tasks: ['arc_challenge']
# 2026-04-11:03:29:05 INFO     [evaluator:211] Setting random seed to 42 | Setting numpy seed to 42 | Setting torch manual seed to 42 | Setting fewshot manual seed to 42
# 2026-04-11:03:29:05 INFO     [evaluator:236] Initializing hf model, with arguments: {'pretrained': 'EdgeCompress01/Llama-3.2-3B-Instruct-GPTQ-4bit', 'dtype': 'float16', 'parallelize': True, 'max_length': 4096, 'trust_remote_code': True}
# 2026-04-11:03:29:13 INFO     [models.huggingface:178] Using `accelerate launch` or `parallelize=True`, device 'cuda:0' will be overridden when placing model.
# 2026-04-11:03:29:14 DEBUG    [models.huggingface:537] Using model type 'causal'
# 2026-04-11:03:29:19 INFO     [models.huggingface:406] Model parallel was set to True, setting max memory per GPU to {0: 15525019648, 1: 15525019648} and device map to auto
# /usr/local/lib/python3.12/dist-packages/transformers/quantizers/auto.py:262: UserWarning: You passed `quantization_config` or equivalent parameters to `from_pretrained` but the model you're loading already has a `quantization_config` attribute. The `quantization_config` from the model will be used.However, loading attributes (e.g. ['backend', 'max_input_length']) will be overwritten with the one you passed to `from_pretrained`. The rest will be ignored.
#   warnings.warn(warning_msg)
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# WARN  Python GIL is enabled: Multi-gpu quant acceleration for MoE models is sub-optimal and multi-core accelerated cpu packing is also disabled. We recommend Python >= 3.13.3t with Pytorch > 2.8 for mult-gpu quantization and multi-cpu packing with env `PYTHON_GIL=0`.
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# INFO  ENV: Auto setting PYTORCH_ALLOC_CONF='expandable_segments:True,max_split_size_mb:256,garbage_collection_threshold:0.7' for memory saving.
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# INFO  ENV: Auto setting CUDA_DEVICE_ORDER=PCI_BUS_ID for correctness.
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/EdgeCompress01/Llama-3.2-3B-Instruct-GPTQ-4bit/resolve/main/model.safetensors "HTTP/1.1 302 Found"
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# INFO
#
# ┌─────────────┐    ┌────────────────────────┐    ┌────────────┐    ┌─────────┐
# │ GPT-QModel  │ -> │ ▓▓▓▓▓▓▓▓▓▓▓▓ 16bit     │ -> │ ▒▒▒▒ 8bit  │ -> │ ░░ 4bit │
# └─────────────┘    └────────────────────────┘    └────────────┘    └─────────┘
# GPT-QModel   : 6.0.3
# Transformers : 5.5.3
# Torch        : 2.11.0+cu126
# Triton       : 3.6.0
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/kernels-community/quantization-gptq/resolve/main/kernel-status.toml "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/kernels-community/quantization-gptq/tree/main/build?recursive=false&expand=false "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/kernels-community/quantization-gptq/revision/main "HTTP/1.1 200 OK"
# Fetching 24 files:   0%|          | 0/24 [00:00<?, ?it/s]INFO:httpx:HTTP Request: HEAD https://huggingface.co/kernels-community/quantization-gptq/resolve/4d9c20d702eb50ca44631773879001dc6b92ecbd/build/torch210-cxx11-cpu-x86_64-linux/_quantization_gptq_cpu_ba11934.abi3.so "HTTP/1.1 302 Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/kernels-community/quantization-gptq/resolve/4d9c20d702eb50ca44631773879001dc6b92ecbd/build/torch210-cxx11-cpu-x86_64-linux/__init__.py "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/kernels-community/quantization-gptq/resolve/4d9c20d702eb50ca44631773879001dc6b92ecbd/build/torch210-cxx11-cpu-x86_64-linux/metadata.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/kernels-community/quantization-gptq/resolve/4d9c20d702eb50ca44631773879001dc6b92ecbd/build/torch210-cxx11-cpu-x86_64-linux/_ops.py "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/kernels-community/quantization-gptq/resolve/4d9c20d702eb50ca44631773879001dc6b92ecbd/build/torch210-cxx11-cpu-x86_64-linux/custom_ops.py "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/kernels-community/quantization-gptq/resolve/4d9c20d702eb50ca44631773879001dc6b92ecbd/build/torch211-cxx11-cpu-x86_64-linux/_ops.py "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/kernels-community/quantization-gptq/resolve/4d9c20d702eb50ca44631773879001dc6b92ecbd/build/torch210-cxx11-cpu-x86_64-linux/quantization_gptq/__init__.py "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/kernels-community/quantization-gptq/resolve/4d9c20d702eb50ca44631773879001dc6b92ecbd/build/torch211-cxx11-cpu-x86_64-linux/__init__.py "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/kernels-community/quantization-gptq/xet-read-token/4d9c20d702eb50ca44631773879001dc6b92ecbd "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/kernels-community/quantization-gptq/4d9c20d702eb50ca44631773879001dc6b92ecbd/build%2Ftorch210-cxx11-cpu-x86_64-linux%2F__init__.py "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/kernels-community/quantization-gptq/4d9c20d702eb50ca44631773879001dc6b92ecbd/build%2Ftorch210-cxx11-cpu-x86_64-linux%2Fmetadata.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/kernels-community/quantization-gptq/4d9c20d702eb50ca44631773879001dc6b92ecbd/build%2Ftorch211-cxx11-cpu-x86_64-linux%2F_ops.py "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/kernels-community/quantization-gptq/4d9c20d702eb50ca44631773879001dc6b92ecbd/build%2Ftorch210-cxx11-cpu-x86_64-linux%2Fcustom_ops.py "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/kernels-community/quantization-gptq/4d9c20d702eb50ca44631773879001dc6b92ecbd/build%2Ftorch210-cxx11-cpu-x86_64-linux%2Fquantization_gptq%2F__init__.py "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/kernels-community/quantization-gptq/4d9c20d702eb50ca44631773879001dc6b92ecbd/build%2Ftorch211-cxx11-cpu-x86_64-linux%2F__init__.py "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/kernels-community/quantization-gptq/4d9c20d702eb50ca44631773879001dc6b92ecbd/build%2Ftorch210-cxx11-cpu-x86_64-linux%2F_ops.py "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/kernels-community/quantization-gptq/4d9c20d702eb50ca44631773879001dc6b92ecbd/build%2Ftorch210-cxx11-cpu-x86_64-linux%2F__init__.py "HTTP/1.1 200 OK"
# Fetching 24 files:   4%|▍         | 1/24 [00:00<00:06,  3.51it/s]INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/kernels-community/quantization-gptq/4d9c20d702eb50ca44631773879001dc6b92ecbd/build%2Ftorch210-cxx11-cpu-x86_64-linux%2Fcustom_ops.py "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/kernels-community/quantization-gptq/4d9c20d702eb50ca44631773879001dc6b92ecbd/build%2Ftorch210-cxx11-cpu-x86_64-linux%2Fmetadata.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/kernels-community/quantization-gptq/4d9c20d702eb50ca44631773879001dc6b92ecbd/build%2Ftorch210-cxx11-cpu-x86_64-linux%2Fquantization_gptq%2F__init__.py "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/kernels-community/quantization-gptq/4d9c20d702eb50ca44631773879001dc6b92ecbd/build%2Ftorch211-cxx11-cpu-x86_64-linux%2F_ops.py "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/kernels-community/quantization-gptq/resolve/4d9c20d702eb50ca44631773879001dc6b92ecbd/build/torch211-cxx11-cpu-x86_64-linux/_quantization_gptq_cpu_ba11934.abi3.so "HTTP/1.1 302 Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/kernels-community/quantization-gptq/resolve/4d9c20d702eb50ca44631773879001dc6b92ecbd/build/torch211-cxx11-cpu-x86_64-linux/custom_ops.py "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/kernels-community/quantization-gptq/resolve/4d9c20d702eb50ca44631773879001dc6b92ecbd/build/torch211-cxx11-cpu-x86_64-linux/quantization_gptq/__init__.py "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/kernels-community/quantization-gptq/resolve/4d9c20d702eb50ca44631773879001dc6b92ecbd/build/torch28-cxx11-cpu-x86_64-linux/_ops.py "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/kernels-community/quantization-gptq/resolve/4d9c20d702eb50ca44631773879001dc6b92ecbd/build/torch28-cxx11-cpu-x86_64-linux/__init__.py "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/kernels-community/quantization-gptq/resolve/4d9c20d702eb50ca44631773879001dc6b92ecbd/build/torch28-cxx11-cpu-x86_64-linux/_quantization_gptq_491482a.abi3.so "HTTP/1.1 302 Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/kernels-community/quantization-gptq/4d9c20d702eb50ca44631773879001dc6b92ecbd/build%2Ftorch211-cxx11-cpu-x86_64-linux%2Fcustom_ops.py "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/kernels-community/quantization-gptq/resolve/4d9c20d702eb50ca44631773879001dc6b92ecbd/build/torch211-cxx11-cpu-x86_64-linux/metadata.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/kernels-community/quantization-gptq/4d9c20d702eb50ca44631773879001dc6b92ecbd/build%2Ftorch211-cxx11-cpu-x86_64-linux%2Fquantization_gptq%2F__init__.py "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/kernels-community/quantization-gptq/4d9c20d702eb50ca44631773879001dc6b92ecbd/build%2Ftorch28-cxx11-cpu-x86_64-linux%2F_ops.py "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/kernels-community/quantization-gptq/4d9c20d702eb50ca44631773879001dc6b92ecbd/build%2Ftorch28-cxx11-cpu-x86_64-linux%2F__init__.py "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/kernels-community/quantization-gptq/resolve/4d9c20d702eb50ca44631773879001dc6b92ecbd/build/torch28-cxx11-cpu-x86_64-linux/custom_ops.py "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/kernels-community/quantization-gptq/4d9c20d702eb50ca44631773879001dc6b92ecbd/build%2Ftorch211-cxx11-cpu-x86_64-linux%2Fmetadata.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/kernels-community/quantization-gptq/4d9c20d702eb50ca44631773879001dc6b92ecbd/build%2Ftorch28-cxx11-cpu-x86_64-linux%2F_ops.py "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/kernels-community/quantization-gptq/resolve/4d9c20d702eb50ca44631773879001dc6b92ecbd/build/torch28-cxx11-cpu-x86_64-linux/metadata.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/kernels-community/quantization-gptq/resolve/4d9c20d702eb50ca44631773879001dc6b92ecbd/build/torch28-cxx11-cpu-x86_64-linux/quantization_gptq/__init__.py "HTTP/1.1 307 Temporary Redirect"
# Fetching 24 files:  12%|█▎        | 3/24 [00:00<00:03,  5.50it/s]INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/kernels-community/quantization-gptq/4d9c20d702eb50ca44631773879001dc6b92ecbd/build%2Ftorch28-cxx11-cpu-x86_64-linux%2Fcustom_ops.py "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/kernels-community/quantization-gptq/resolve/4d9c20d702eb50ca44631773879001dc6b92ecbd/build/torch29-cxx11-cpu-x86_64-linux/__init__.py "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/kernels-community/quantization-gptq/resolve/4d9c20d702eb50ca44631773879001dc6b92ecbd/build/torch29-cxx11-cpu-x86_64-linux/_ops.py "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/kernels-community/quantization-gptq/4d9c20d702eb50ca44631773879001dc6b92ecbd/build%2Ftorch28-cxx11-cpu-x86_64-linux%2Fmetadata.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/kernels-community/quantization-gptq/4d9c20d702eb50ca44631773879001dc6b92ecbd/build%2Ftorch28-cxx11-cpu-x86_64-linux%2Fquantization_gptq%2F__init__.py "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/kernels-community/quantization-gptq/resolve/4d9c20d702eb50ca44631773879001dc6b92ecbd/build/torch29-cxx11-cpu-x86_64-linux/_quantization_gptq_cpu_833865c.abi3.so "HTTP/1.1 302 Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/kernels-community/quantization-gptq/resolve/4d9c20d702eb50ca44631773879001dc6b92ecbd/build/torch29-cxx11-cpu-x86_64-linux/custom_ops.py "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/kernels-community/quantization-gptq/resolve/4d9c20d702eb50ca44631773879001dc6b92ecbd/build/torch29-cxx11-cpu-x86_64-linux/metadata.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/kernels-community/quantization-gptq/4d9c20d702eb50ca44631773879001dc6b92ecbd/build%2Ftorch29-cxx11-cpu-x86_64-linux%2F__init__.py "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/kernels-community/quantization-gptq/4d9c20d702eb50ca44631773879001dc6b92ecbd/build%2Ftorch29-cxx11-cpu-x86_64-linux%2F_ops.py "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/kernels-community/quantization-gptq/4d9c20d702eb50ca44631773879001dc6b92ecbd/build%2Ftorch28-cxx11-cpu-x86_64-linux%2Fmetadata.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/kernels-community/quantization-gptq/4d9c20d702eb50ca44631773879001dc6b92ecbd/build%2Ftorch28-cxx11-cpu-x86_64-linux%2Fquantization_gptq%2F__init__.py "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/kernels-community/quantization-gptq/4d9c20d702eb50ca44631773879001dc6b92ecbd/build%2Ftorch29-cxx11-cpu-x86_64-linux%2Fcustom_ops.py "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/kernels-community/quantization-gptq/4d9c20d702eb50ca44631773879001dc6b92ecbd/build%2Ftorch29-cxx11-cpu-x86_64-linux%2Fmetadata.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/kernels-community/quantization-gptq/resolve/4d9c20d702eb50ca44631773879001dc6b92ecbd/build/torch29-cxx11-cpu-x86_64-linux/quantization_gptq/__init__.py "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/kernels-community/quantization-gptq/4d9c20d702eb50ca44631773879001dc6b92ecbd/build%2Ftorch29-cxx11-cpu-x86_64-linux%2F_ops.py "HTTP/1.1 200 OK"
# Fetching 24 files:  62%|██████▎   | 15/24 [00:00<00:00, 22.79it/s]INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/kernels-community/quantization-gptq/4d9c20d702eb50ca44631773879001dc6b92ecbd/build%2Ftorch29-cxx11-cpu-x86_64-linux%2Fmetadata.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/kernels-community/quantization-gptq/4d9c20d702eb50ca44631773879001dc6b92ecbd/build%2Ftorch29-cxx11-cpu-x86_64-linux%2Fquantization_gptq%2F__init__.py "HTTP/1.1 200 OK"
# Fetching 24 files: 100%|██████████| 24/24 [00:01<00:00, 22.19it/s]
# `loss_type=None` was set in the config but it is unrecognized. Using the default loss: `ForCausalLMLoss`.
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# INFO  HFKernelLinear: loaded CPU gemm_4bit kernel from `kernels-community/quantization-gptq` variant `torch211-cxx11-cpu-x86_64-linux`.
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# INFO  Kernel: Auto-selection: adding candidate `TritonV2QuantLinear`
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# INFO  Kernel: selected -> `TritonV2QuantLinear`.
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# Loading weights: 100%|██████████| 842/842 [00:00<00:00, 993.39it/s]
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/EdgeCompress01/Llama-3.2-3B-Instruct-GPTQ-4bit/resolve/main/generation_config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/EdgeCompress01/Llama-3.2-3B-Instruct-GPTQ-4bit/6611689afbf16f086c49f3235b64e6a7c9330711/generation_config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/EdgeCompress01/Llama-3.2-3B-Instruct-GPTQ-4bit/6611689afbf16f086c49f3235b64e6a7c9330711/generation_config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/EdgeCompress01/Llama-3.2-3B-Instruct-GPTQ-4bit/resolve/main/custom_generate/generate.py "HTTP/1.1 404 Not Found"
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# INFO  QuantizeConfig: offload_to_disk_path auto set to `./gptqmodel_offload/ixofhaqz-wrzfhomi/`
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# INFO  Format: Converting `format` from `FORMAT.GPTQ` to internal `FORMAT.GPTQ_V2`.
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# INFO  Format: Converting GPTQ v1 to v2
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# INFO  Optimize: `TritonV2QuantLinear` compilation triggered.
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# INFO  gc.collect() reclaimed 184 objects in 0.275s
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/datasets/allenai/ai2_arc/resolve/main/README.md "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/datasets/allenai/ai2_arc/210d026faf9955653af8916fad021475a3f00453/README.md "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/datasets/allenai/ai2_arc/210d026faf9955653af8916fad021475a3f00453/README.md "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/datasets/allenai/ai2_arc/resolve/210d026faf9955653af8916fad021475a3f00453/ai2_arc.py "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://s3.amazonaws.com/datasets.huggingface.co/datasets/datasets/allenai/ai2_arc/allenai/ai2_arc.py "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/datasets/allenai/ai2_arc/revision/210d026faf9955653af8916fad021475a3f00453 "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/datasets/allenai/ai2_arc/resolve/210d026faf9955653af8916fad021475a3f00453/.huggingface.yaml "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: GET https://datasets-server.huggingface.co/info?dataset=allenai/ai2_arc "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/datasets/allenai/ai2_arc/tree/210d026faf9955653af8916fad021475a3f00453/ARC-Challenge?recursive=true&expand=false "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/datasets/allenai/ai2_arc/tree/210d026faf9955653af8916fad021475a3f00453?recursive=false&expand=false "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/datasets/allenai/ai2_arc/resolve/210d026faf9955653af8916fad021475a3f00453/dataset_infos.json "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/datasets/allenai/ai2_arc/resolve/210d026faf9955653af8916fad021475a3f00453/ARC-Challenge/train-00000-of-00001.parquet "HTTP/1.1 302 Found"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/datasets/allenai/ai2_arc/xet-read-token/210d026faf9955653af8916fad021475a3f00453 "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/datasets/allenai/ai2_arc/resolve/210d026faf9955653af8916fad021475a3f00453/ARC-Challenge/test-00000-of-00001.parquet "HTTP/1.1 302 Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/datasets/allenai/ai2_arc/resolve/210d026faf9955653af8916fad021475a3f00453/ARC-Challenge/validation-00000-of-00001.parquet "HTTP/1.1 302 Found"
# Generating train split: 100%|██████████| 1119/1119 [00:00<00:00, 20256.74 examples/s]
# Generating test split: 100%|██████████| 1172/1172 [00:00<00:00, 262634.20 examples/s]
# Generating validation split: 100%|██████████| 299/299 [00:00<00:00, 109146.81 examples/s]
# 2026-04-11:03:29:38 INFO     [tasks:700] Selected tasks:
# 2026-04-11:03:29:38 INFO     [tasks:691] Task: arc_challenge (arc/arc_challenge.yaml)
# 2026-04-11:03:29:38 WARNING  [evaluator:333] Overwriting default num_fewshot of arc_challenge from None to 0
# 2026-04-11:03:29:38 WARNING  [evaluator:490] Chat template formatting change affects loglikelihood and multiple-choice tasks. See docs/chat-template-readme.md for details.
# 2026-04-11:03:29:38 INFO     [api.task:311] Building contexts for arc_challenge on rank 0...
# 100%|██████████| 1172/1172 [00:02<00:00, 465.00it/s]
# 2026-04-11:03:29:41 DEBUG    [evaluator:553] Task: arc_challenge; number of requests on this rank: 4687
# 2026-04-11:03:29:41 INFO     [evaluator:584] Running loglikelihood requests
# Running loglikelihood requests: 100%|██████████| 4687/4687 [02:11<00:00, 35.70it/s]
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/EdgeCompress01/Llama-3.2-3B-Instruct-GPTQ-4bit/revision/main "HTTP/1.1 200 OK"
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# 2026-04-11:03:31:58 INFO     [loggers.evaluation_tracker:247] Saving results aggregated
# hf ({'pretrained': 'EdgeCompress01/Llama-3.2-3B-Instruct-GPTQ-4bit', 'dtype': 'float16', 'parallelize': True, 'max_length': 4096}), gen_kwargs: ({}), limit: None, num_fewshot: 0, batch_size: 16
# |    Tasks    |Version|Filter|n-shot| Metric |   |Value |   |Stderr|
# |-------------|------:|------|-----:|--------|---|-----:|---|-----:|
# |arc_challenge|      1|none  |     0|acc     |↑  |0.4206|±  |0.0144|
# |             |       |none  |     0|acc_norm|↑  |0.4480|±  |0.0145|
# Cloning into '/kaggle/working/temp_git_repo'...
# [main 78d3a05] Add Kaggle results to New_Evaluations/Llama-3.2-3B-Instruct/Llama-3.2-3B-Instruct-GPTQ/results/arc_challenge
#  1 file changed, 145 insertions(+)
#  create mode 100644 New_Evaluations/Llama-3.2-3B-Instruct/Llama-3.2-3B-Instruct-GPTQ/results/arc_challenge/results_2026-04-11T03-31-58.531736.json
# To https://github.com/MahmoudOsama20/EdgeCompress.git
#    dd541f7..78d3a05  main -> main
# Successfully pushed to MahmoudOsama20/EdgeCompress inside the 'New_Evaluations/Llama-3.2-3B-Instruct/Llama-3.2-3B-Instruct-GPTQ/results/arc_challenge' folder!
# Done
#
# [PERPLEXITY] wikitext
# 2026-04-11:03:32:08 INFO     [_cli.run:376] Selected Tasks: ['wikitext']
# 2026-04-11:03:32:08 WARNING  [evaluator:181] pretrained=EdgeCompress01/Llama-3.2-3B-Instruct-GPTQ-4bit appears to be an instruct or chat variant but chat template is not applied.
#         Recommend setting `apply_chat_template` (optionally `fewshot_as_multiturn`).
# 2026-04-11:03:32:10 INFO     [evaluator:211] Setting random seed to 42 | Setting numpy seed to 42 | Setting torch manual seed to 42 | Setting fewshot manual seed to 42
# 2026-04-11:03:32:10 INFO     [evaluator:236] Initializing hf model, with arguments: {'pretrained': 'EdgeCompress01/Llama-3.2-3B-Instruct-GPTQ-4bit', 'dtype': 'float16', 'parallelize': True, 'max_length': 4096, 'trust_remote_code': True}
# 2026-04-11:03:32:15 INFO     [models.huggingface:178] Using `accelerate launch` or `parallelize=True`, device 'cuda:0' will be overridden when placing model.
# 2026-04-11:03:32:15 DEBUG    [models.huggingface:537] Using model type 'causal'
# 2026-04-11:03:32:19 INFO     [models.huggingface:406] Model parallel was set to True, setting max memory per GPU to {0: 15525019648, 1: 15525019648} and device map to auto
# /usr/local/lib/python3.12/dist-packages/transformers/quantizers/auto.py:262: UserWarning: You passed `quantization_config` or equivalent parameters to `from_pretrained` but the model you're loading already has a `quantization_config` attribute. The `quantization_config` from the model will be used.However, loading attributes (e.g. ['backend', 'max_input_length']) will be overwritten with the one you passed to `from_pretrained`. The rest will be ignored.
#   warnings.warn(warning_msg)
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# WARN  Python GIL is enabled: Multi-gpu quant acceleration for MoE models is sub-optimal and multi-core accelerated cpu packing is also disabled. We recommend Python >= 3.13.3t with Pytorch > 2.8 for mult-gpu quantization and multi-cpu packing with env `PYTHON_GIL=0`.
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# INFO  ENV: Auto setting PYTORCH_ALLOC_CONF='expandable_segments:True,max_split_size_mb:256,garbage_collection_threshold:0.7' for memory saving.
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# INFO  ENV: Auto setting CUDA_DEVICE_ORDER=PCI_BUS_ID for correctness.
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/kernels-community/quantization-gptq/resolve/main/kernel-status.toml "HTTP/1.1 404 Not Found"
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# INFO
#
# ┌─────────────┐    ┌────────────────────────┐    ┌────────────┐    ┌─────────┐
# │ GPT-QModel  │ -> │ ▓▓▓▓▓▓▓▓▓▓▓▓ 16bit     │ -> │ ▒▒▒▒ 8bit  │ -> │ ░░ 4bit │
# └─────────────┘    └────────────────────────┘    └────────────┘    └─────────┘
# GPT-QModel   : 6.0.3
# Transformers : 5.5.3
# Torch        : 2.11.0+cu126
# Triton       : 3.6.0
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/kernels-community/quantization-gptq/tree/main/build?recursive=false&expand=false "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/kernels-community/quantization-gptq/revision/main "HTTP/1.1 200 OK"
# Fetching 24 files: 100%|██████████| 24/24 [00:00<00:00, 4948.06it/s]
# `loss_type=None` was set in the config but it is unrecognized. Using the default loss: `ForCausalLMLoss`.
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# INFO  HFKernelLinear: loaded CPU gemm_4bit kernel from `kernels-community/quantization-gptq` variant `torch211-cxx11-cpu-x86_64-linux`.
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# INFO  Kernel: Auto-selection: adding candidate `TritonV2QuantLinear`
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# INFO  Kernel: selected -> `TritonV2QuantLinear`.
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# Loading weights: 100%|██████████| 842/842 [00:00<00:00, 962.12it/s]
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/EdgeCompress01/Llama-3.2-3B-Instruct-GPTQ-4bit/resolve/main/generation_config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/EdgeCompress01/Llama-3.2-3B-Instruct-GPTQ-4bit/6611689afbf16f086c49f3235b64e6a7c9330711/generation_config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/EdgeCompress01/Llama-3.2-3B-Instruct-GPTQ-4bit/resolve/main/custom_generate/generate.py "HTTP/1.1 404 Not Found"
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# INFO  QuantizeConfig: offload_to_disk_path auto set to `./gptqmodel_offload/btgbnfxh-bigtiqtd/`
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# INFO  Format: Converting `format` from `FORMAT.GPTQ` to internal `FORMAT.GPTQ_V2`.
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# INFO  Format: Converting GPTQ v1 to v2
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# INFO  Optimize: `TritonV2QuantLinear` compilation triggered.
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# INFO  gc.collect() reclaimed 230 objects in 0.276s
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# 2026-04-11:03:32:24 WARNING  [api.task:729] [Task: wikitext] metric word_perplexity is defined, but aggregation is not. using default aggregation=weighted_perplexity
# 2026-04-11:03:32:24 WARNING  [api.task:741] [Task: wikitext] metric word_perplexity is defined, but higher_is_better is not. using default higher_is_better=False
# 2026-04-11:03:32:24 WARNING  [api.task:729] [Task: wikitext] metric byte_perplexity is defined, but aggregation is not. using default aggregation=weighted_perplexity
# 2026-04-11:03:32:24 WARNING  [api.task:741] [Task: wikitext] metric byte_perplexity is defined, but higher_is_better is not. using default higher_is_better=False
# 2026-04-11:03:32:24 WARNING  [api.task:729] [Task: wikitext] metric bits_per_byte is defined, but aggregation is not. using default aggregation=bits_per_byte
# 2026-04-11:03:32:24 WARNING  [api.task:741] [Task: wikitext] metric bits_per_byte is defined, but higher_is_better is not. using default higher_is_better=False
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/datasets/EleutherAI/wikitext_document_level/resolve/main/README.md "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/datasets/EleutherAI/wikitext_document_level/647234772b9554e208af6c826f23b99e3cac88c8/README.md "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/datasets/EleutherAI/wikitext_document_level/647234772b9554e208af6c826f23b99e3cac88c8/README.md "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/datasets/EleutherAI/wikitext_document_level/resolve/647234772b9554e208af6c826f23b99e3cac88c8/wikitext_document_level.py "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://s3.amazonaws.com/datasets.huggingface.co/datasets/datasets/EleutherAI/wikitext_document_level/EleutherAI/wikitext_document_level.py "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/datasets/EleutherAI/wikitext_document_level/revision/647234772b9554e208af6c826f23b99e3cac88c8 "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/datasets/EleutherAI/wikitext_document_level/resolve/647234772b9554e208af6c826f23b99e3cac88c8/.huggingface.yaml "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: GET https://datasets-server.huggingface.co/info?dataset=EleutherAI/wikitext_document_level "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/datasets/EleutherAI/wikitext_document_level/tree/647234772b9554e208af6c826f23b99e3cac88c8/wikitext-103-raw-v1?recursive=true&expand=false "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/datasets/EleutherAI/wikitext_document_level/tree/647234772b9554e208af6c826f23b99e3cac88c8?recursive=false&expand=false "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/datasets/EleutherAI/wikitext_document_level/resolve/647234772b9554e208af6c826f23b99e3cac88c8/dataset_infos.json "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/datasets/EleutherAI/wikitext_document_level/tree/647234772b9554e208af6c826f23b99e3cac88c8/wikitext-2-raw-v1?recursive=true&expand=false "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/datasets/EleutherAI/wikitext_document_level/resolve/647234772b9554e208af6c826f23b99e3cac88c8/wikitext-2-raw-v1/wikitext-2-raw-v1-train.parquet "HTTP/1.1 302 Found"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/datasets/EleutherAI/wikitext_document_level/xet-read-token/647234772b9554e208af6c826f23b99e3cac88c8 "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/datasets/EleutherAI/wikitext_document_level/resolve/647234772b9554e208af6c826f23b99e3cac88c8/wikitext-2-raw-v1/wikitext-2-raw-v1-validation.parquet "HTTP/1.1 302 Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/datasets/EleutherAI/wikitext_document_level/resolve/647234772b9554e208af6c826f23b99e3cac88c8/wikitext-2-raw-v1/wikitext-2-raw-v1-test.parquet "HTTP/1.1 302 Found"
# Generating train split: 100%|██████████| 629/629 [00:00<00:00, 8112.87 examples/s]
# Generating validation split: 100%|██████████| 60/60 [00:00<00:00, 10417.61 examples/s]
# Generating test split: 100%|██████████| 62/62 [00:00<00:00, 10589.52 examples/s]
# 2026-04-11:03:32:27 INFO     [tasks:700] Selected tasks:
# 2026-04-11:03:32:27 INFO     [tasks:691] Task: wikitext (wikitext/wikitext.yaml)
# 2026-04-11:03:32:27 WARNING  [evaluator:333] Overwriting default num_fewshot of wikitext from None to 0
# 2026-04-11:03:32:27 INFO     [api.task:311] Building contexts for wikitext on rank 0...
# 100%|██████████| 62/62 [00:00<00:00, 333.39it/s]
# 2026-04-11:03:32:28 DEBUG    [evaluator:553] Task: wikitext; number of requests on this rank: 62
# 2026-04-11:03:32:28 INFO     [evaluator:584] Running loglikelihood_rolling requests
# 100%|██████████| 62/62 [00:00<00:00, 108.51it/s]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:02<00:00,  2.53s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.25s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.37s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:02<00:00,  2.80s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.52s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.61s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:02<00:00,  2.13s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:02<00:00,  2.84s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.74s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.78s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.80s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:02<00:00,  2.79s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.66s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.63s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.53s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:01<00:00,  1.57s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:03<00:00,  3.93s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.48s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.49s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.48s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:00<00:00,  1.31it/s]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:02<00:00,  2.48s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:00<00:00,  2.83it/s]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:01<00:00,  1.62s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.52s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.54s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:00<00:00,  1.21it/s]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.61s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.64s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.82s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.65s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.67s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:01<00:00,  1.11s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.65s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.66s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.65s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.63s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.59s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.57s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:02<00:00,  2.80s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.61s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.58s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.58s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.63s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.63s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:00<00:00,  1.02it/s]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:00<00:00,  8.84it/s]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:00<00:00,  6.76it/s]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.66s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.68s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:01<00:00,  1.42s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.71s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.66s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:01<00:00,  1.56s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.67s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.67s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.62s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.63s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.64s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:01<00:00,  1.41s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.63s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.64s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.67s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.63s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.66s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.66s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.69s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.69s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.68s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.69s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.71s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.65s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:02<00:00,  2.99s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:00<00:00,  1.13it/s]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.66s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.66s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:02<00:00,  2.54s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:00<00:00,  1.18it/s]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:01<00:00,  1.08s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.65s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.64s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:01<00:00,  1.24s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:01<00:00,  1.32s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:03<00:00,  3.37s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:03<00:00,  3.37s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:00<00:00,  1.20it/s]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:00<00:00,  1.35it/s]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:00<00:00,  1.38it/s]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.65s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.66s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:00<00:00,  2.80it/s]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.37s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.63s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.65s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.66s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.66s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.92s/it]
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/EdgeCompress01/Llama-3.2-3B-Instruct-GPTQ-4bit/revision/main "HTTP/1.1 200 OK"
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# 2026-04-11:03:39:25 INFO     [loggers.evaluation_tracker:247] Saving results aggregated
# hf ({'pretrained': 'EdgeCompress01/Llama-3.2-3B-Instruct-GPTQ-4bit', 'dtype': 'float16', 'parallelize': True, 'max_length': 4096}), gen_kwargs: ({}), limit: None, num_fewshot: 0, batch_size: 1
# | Tasks  |Version|Filter|n-shot|    Metric     |   | Value |   |Stderr|
# |--------|------:|------|-----:|---------------|---|------:|---|------|
# |wikitext|      2|none  |     0|bits_per_byte  |↓  | 0.7491|±  |   N/A|
# |        |       |none  |     0|byte_perplexity|↓  | 1.6807|±  |   N/A|
# |        |       |none  |     0|word_perplexity|↓  |16.0614|±  |   N/A|
# Cloning into '/kaggle/working/temp_git_repo'...
# [main 6b39a04] Add Kaggle results to New_Evaluations/Llama-3.2-3B-Instruct/Llama-3.2-3B-Instruct-GPTQ/results/wikitext
#  1 file changed, 144 insertions(+)
# ...
# 2026-04-11:05:43:40 INFO     [evaluator:314] ifeval: Using gen_kwargs: {'until': [], 'do_sample': False, 'temperature': 0.0, 'max_gen_toks': 1024}
# 2026-04-11:05:43:40 INFO     [evaluator:329] num_fewshot has been set to 0 for ifeval in its config. Manual configuration will be ignored.
# 2026-04-11:05:43:40 WARNING  [evaluator:490] Chat template formatting change affects loglikelihood and multiple-choice tasks. See docs/chat-template-readme.md for details.
# 2026-04-11:05:43:40 INFO     [api.task:311] Building contexts for ifeval on rank 0...
# 100%|██████████| 541/541 [00:00<00:00, 12700.20it/s]
# 2026-04-11:05:43:40 DEBUG    [evaluator:553] Task: ifeval; number of requests on this rank: 541
# 2026-04-11:05:43:40 INFO     [evaluator:584] Running generate_until requests
# Running generate_until requests:   0%|          | 0/541 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Running generate_until requests: 100%|██████████| 541/541 [1:08:27<00:00,  7.59s/it]
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/EdgeCompress01/Llama-3.2-3B-Instruct-GPTQ-4bit/revision/main "HTTP/1.1 200 OK"
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# 2026-04-11:06:52:11 INFO     [loggers.evaluation_tracker:247] Saving results aggregated
# hf ({'pretrained': 'EdgeCompress01/Llama-3.2-3B-Instruct-GPTQ-4bit', 'dtype': 'float16', 'parallelize': True, 'max_length': 4096}), gen_kwargs: ({'max_gen_toks': 1024}), limit: None, num_fewshot: 0, batch_size: 14
# |Tasks |Version|Filter|n-shot|        Metric         |   |Value |   |Stderr|
# |------|------:|------|-----:|-----------------------|---|-----:|---|------|
# |ifeval|      4|none  |     0|inst_level_loose_acc   |↑  |0.7818|±  |   N/A|
# |      |       |none  |     0|inst_level_strict_acc  |↑  |0.7410|±  |   N/A|
# |      |       |none  |     0|prompt_level_loose_acc |↑  |0.7006|±  |0.0197|
# |      |       |none  |     0|prompt_level_strict_acc|↑  |0.6488|±  |0.0205|
# Cloning into '/kaggle/working/temp_git_repo'...
# [main f43d695] Add Kaggle results to New_Evaluations/Llama-3.2-3B-Instruct/Llama-3.2-3B-Instruct-GPTQ/results/ifeval
#  1 file changed, 162 insertions(+)
#  create mode 100644 New_Evaluations/Llama-3.2-3B-Instruct/Llama-3.2-3B-Instruct-GPTQ/results/ifeval/results_2026-04-11T06-52-11.745420.json
# To https://github.com/MahmoudOsama20/EdgeCompress.git
#    197d45a..f43d695  main -> main
# Successfully pushed to MahmoudOsama20/EdgeCompress inside the 'New_Evaluations/Llama-3.2-3B-Instruct/Llama-3.2-3B-Instruct-GPTQ/results/ifeval' folder!
# Done
#
# [MATH] gsm8k
# 2026-04-11:06:52:16 INFO     [config.evaluate_config:301] Using default fewshot_as_multiturn=True.
# 2026-04-11:06:52:21 INFO     [_cli.run:376] Selected Tasks: ['gsm8k_cot']
# 2026-04-11:06:52:22 INFO     [evaluator:211] Setting random seed to 42 | Setting numpy seed to 42 | Setting torch manual seed to 42 | Setting fewshot manual seed to 42
# 2026-04-11:06:52:22 WARNING  [evaluator:223] generation_kwargs: {'max_gen_toks': 1024} specified through cli, these settings will update set parameters in yaml tasks. Ensure 'do_sample=True' for non-greedy decoding!
# 2026-04-11:06:52:22 INFO     [evaluator:236] Initializing hf model, with arguments: {'pretrained': 'EdgeCompress01/Llama-3.2-3B-Instruct-GPTQ-4bit', 'dtype': 'float16', 'parallelize': True, 'max_length': 4096, 'trust_remote_code': True}
# 2026-04-11:06:52:27 INFO     [models.huggingface:178] Using `accelerate launch` or `parallelize=True`, device 'cuda:0' will be overridden when placing model.
# 2026-04-11:06:52:28 DEBUG    [models.huggingface:537] Using model type 'causal'
# 2026-04-11:06:52:31 INFO     [models.huggingface:406] Model parallel was set to True, setting max memory per GPU to {0: 15525019648, 1: 15525019648} and device map to auto
# /usr/local/lib/python3.12/dist-packages/transformers/quantizers/auto.py:262: UserWarning: You passed `quantization_config` or equivalent parameters to `from_pretrained` but the model you're loading already has a `quantization_config` attribute. The `quantization_config` from the model will be used.However, loading attributes (e.g. ['backend', 'max_input_length']) will be overwritten with the one you passed to `from_pretrained`. The rest will be ignored.
#   warnings.warn(warning_msg)
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# WARN  Python GIL is enabled: Multi-gpu quant acceleration for MoE models is sub-optimal and multi-core accelerated cpu packing is also disabled. We recommend Python >= 3.13.3t with Pytorch > 2.8 for mult-gpu quantization and multi-cpu packing with env `PYTHON_GIL=0`.
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# INFO  ENV: Auto setting PYTORCH_ALLOC_CONF='expandable_segments:True,max_split_size_mb:256,garbage_collection_threshold:0.7' for memory saving.
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# INFO  ENV: Auto setting CUDA_DEVICE_ORDER=PCI_BUS_ID for correctness.
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/kernels-community/quantization-gptq/resolve/main/kernel-status.toml "HTTP/1.1 404 Not Found"
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# INFO
#
# ┌─────────────┐    ┌────────────────────────┐    ┌────────────┐    ┌─────────┐
# │ GPT-QModel  │ -> │ ▓▓▓▓▓▓▓▓▓▓▓▓ 16bit     │ -> │ ▒▒▒▒ 8bit  │ -> │ ░░ 4bit │
# └─────────────┘    └────────────────────────┘    └────────────┘    └─────────┘
# GPT-QModel   : 6.0.3
# Transformers : 5.5.3
# Torch        : 2.11.0+cu126
# Triton       : 3.6.0
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/kernels-community/quantization-gptq/tree/main/build?recursive=false&expand=false "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/kernels-community/quantization-gptq/revision/main "HTTP/1.1 200 OK"
# Fetching 24 files: 100%|██████████| 24/24 [00:00<00:00, 3600.39it/s]
# `loss_type=None` was set in the config but it is unrecognized. Using the default loss: `ForCausalLMLoss`.
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# INFO  HFKernelLinear: loaded CPU gemm_4bit kernel from `kernels-community/quantization-gptq` variant `torch211-cxx11-cpu-x86_64-linux`.
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# INFO  Kernel: Auto-selection: adding candidate `TritonV2QuantLinear`
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# INFO  Kernel: selected -> `TritonV2QuantLinear`.
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# Loading weights: 100%|██████████| 842/842 [00:00<00:00, 1119.05it/s]
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/EdgeCompress01/Llama-3.2-3B-Instruct-GPTQ-4bit/resolve/main/generation_config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/EdgeCompress01/Llama-3.2-3B-Instruct-GPTQ-4bit/6611689afbf16f086c49f3235b64e6a7c9330711/generation_config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/EdgeCompress01/Llama-3.2-3B-Instruct-GPTQ-4bit/resolve/main/custom_generate/generate.py "HTTP/1.1 404 Not Found"
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# INFO  QuantizeConfig: offload_to_disk_path auto set to `./gptqmodel_offload/chauakqw-csdgtvpe/`
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# INFO  Format: Converting `format` from `FORMAT.GPTQ` to internal `FORMAT.GPTQ_V2`.
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# INFO  Format: Converting GPTQ v1 to v2
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# INFO  Optimize: `TritonV2QuantLinear` compilation triggered.
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# INFO  gc.collect() reclaimed 230 objects in 0.259s
# {'text/plain': '', 'text/html': '<pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>'}
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/datasets/openai/gsm8k/resolve/main/README.md "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/datasets/openai/gsm8k/740312add88f781978c0658806c59bc2815b9866/README.md "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/datasets/openai/gsm8k/740312add88f781978c0658806c59bc2815b9866/README.md "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/datasets/openai/gsm8k/resolve/740312add88f781978c0658806c59bc2815b9866/gsm8k.py "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://s3.amazonaws.com/datasets.huggingface.co/datasets/datasets/openai/gsm8k/openai/gsm8k.py "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/datasets/openai/gsm8k/revision/740312add88f781978c0658806c59bc2815b9866 "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/datasets/openai/gsm8k/resolve/740312add88f781978c0658806c59bc2815b9866/.huggingface.yaml "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: GET https://datasets-server.huggingface.co/info?dataset=openai/gsm8k "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/datasets/openai/gsm8k/tree/740312add88f781978c0658806c59bc2815b9866/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/datasets/openai/gsm8k/tree/740312add88f781978c0658806c59bc2815b9866?recursive=false&expand=false "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/datasets/openai/gsm8k/resolve/740312add88f781978c0658806c59bc2815b9866/dataset_infos.json "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/datasets/openai/gsm8k/resolve/740312add88f781978c0658806c59bc2815b9866/main/train-00000-of-00001.parquet "HTTP/1.1 302 Found"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/datasets/openai/gsm8k/xet-read-token/740312add88f781978c0658806c59bc2815b9866 "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/datasets/openai/gsm8k/resolve/740312add88f781978c0658806c59bc2815b9866/main/test-00000-of-00001.parquet "HTTP/1.1 302 Found"
# Generating train split: 100%|██████████| 7473/7473 [00:00<00:00, 452334.02 examples/s]
# Generating test split: 100%|██████████| 1319/1319 [00:00<00:00, 348952.12 examples/s]
# 2026-04-11:06:52:38 INFO     [tasks:700] Selected tasks:
# 2026-04-11:06:52:38 INFO     [tasks:691] Task: gsm8k_cot (gsm8k/gsm8k-cot.yaml)
# 2026-04-11:06:52:38 INFO     [evaluator:314] gsm8k_cot: Using gen_kwargs: {'do_sample': False, 'until': ['Q:', '</s>', '<|im_end|>'], 'max_gen_toks': 1024}
# 2026-04-11:06:52:38 WARNING  [evaluator:333] Overwriting default num_fewshot of gsm8k_cot from 8 to 8
# 2026-04-11:06:52:38 WARNING  [evaluator:490] Chat template formatting change affects loglikelihood and multiple-choice tasks. See docs/chat-template-readme.md for details.
# 2026-04-11:06:52:38 INFO     [api.task:311] Building contexts for gsm8k_cot on rank 0...
# 100%|██████████| 1319/1319 [00:18<00:00, 72.76it/s]
# 2026-04-11:06:52:56 DEBUG    [evaluator:553] Task: gsm8k_cot; number of requests on this rank: 1319
# 2026-04-11:06:52:56 INFO     [evaluator:584] Running generate_until requests
# Running generate_until requests:   0%|          | 0/1319 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Running generate_until requests: 100%|██████████| 1319/1319 [1:13:54<00:00,  3.36s/it]
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/EdgeCompress01/Llama-3.2-3B-Instruct-GPTQ-4bit/revision/main "HTTP/1.1 200 OK"
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# 2026-04-11:08:06:56 INFO     [loggers.evaluation_tracker:247] Saving results aggregated
# hf ({'pretrained': 'EdgeCompress01/Llama-3.2-3B-Instruct-GPTQ-4bit', 'dtype': 'float16', 'parallelize': True, 'max_length': 4096}), gen_kwargs: ({'max_gen_toks': 1024}), limit: None, num_fewshot: 8, batch_size: 12
# |  Tasks  |Version|     Filter     |n-shot|  Metric   |   |Value |   |Stderr|
# |---------|------:|----------------|-----:|-----------|---|-----:|---|-----:|
# |gsm8k_cot|      3|flexible-extract|     8|exact_match|↑  |0.7165|±  |0.0124|
# |         |       |strict-match    |     8|exact_match|↑  |0.6209|±  |0.0134|
# Cloning into '/kaggle/working/temp_git_repo'...
# [main 13f57b6] Add Kaggle results to New_Evaluations/Llama-3.2-3B-Instruct/Llama-3.2-3B-Instruct-GPTQ/results/gsm8k
#  1 file changed, 214 insertions(+)
#  create mode 100644 New_Evaluations/Llama-3.2-3B-Instruct/Llama-3.2-3B-Instruct-GPTQ/results/gsm8k/results_2026-04-11T08-06-56.759827.json
# Successfully pushed to MahmoudOsama20/EdgeCompress inside the 'New_Evaluations/Llama-3.2-3B-Instruct/Llama-3.2-3B-Instruct-GPTQ/results/gsm8k' folder!
# Done
# To https://github.com/MahmoudOsama20/EdgeCompress.git
#    f43d695..13f57b6  main -> main

# %% [markdown]
# # Save reports

# %%
zip_path = shutil.make_archive(
    "evaluation_results",   # zip file name
    "zip",                  # format
    "evaluation_results"    # folder to compress
)
