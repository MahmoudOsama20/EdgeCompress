# %% [markdown]
# # Libraries

# %%
#!pip install -q torch==2.9.0 torchvision torchaudio --index-url https://download.pytorch.org/whl/cu126
# !pip -q install "lm_eval[hf]"
# !pip -q install --upgrade transformers
# !pip -q install langdetect --break-system-packages #for If-eval Task

# %%
# Libraries
import gc
import glob
import shutil
import os
import random
import subprocess

import numpy as np
import torch
import lm_eval

from dataclasses import dataclass
from typing import Optional
from huggingface_hub import login
from IPython.display import FileLink
from kaggle_secrets import UserSecretsClient

# %% [markdown]
# # Global Variables

# %%
MODEL_NAME       = "Llama-3.2-3B-Instruct-WANDA-50"
MODEL_PRETRAINED = "EdgeCompress01/Llama-3.2-3B-Instruct-WANDA"
SUB_FOLDER = "Models/50"
SEED             = 42

os.environ["HF_ALLOW_CODE_EVAL"] = "1"

# %% [markdown]
# # Classes

# %%
@dataclass
class Task:
    key:               str
    name:              str
    category:          str
    num_fewshot:       int  = 0
    batch_size:        int  = 2
    limit:             Optional[int] = None
    apply_chat_template: bool = True
    max_gen_toks:      Optional[int] = None

# %% [markdown]
# # Functions

# %%
# REPRODUCIBILITY
def set_reproducibility(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    # Ensure deterministic behavior in CuDNN
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    print(f"Global seed set to {seed}")

# %% [markdown]
# # Seeding

# %%
set_reproducibility(SEED)
# Out:
# Global seed set to 42

# %% [markdown]
# # Huggingface login

# %%
# HUGGING FACE AUTHENTICATION
user_secrets = UserSecretsClient()
hf_token = user_secrets.get_secret("HF_TOKEN")
login(token=hf_token)
print("Logging into Hugging Face...")
# Out:
# Logging into Hugging Face...

# %% [markdown]
# # Evaluations

# %% [markdown]
# **Configurations**

# %%
# Task definition
TASKS = [
    # Math
     Task("gsm8k",        "gsm8k_cot",                 "math",                num_fewshot=8, batch_size=12,  max_gen_toks=1024),

    # Reasoning
     Task("arc_challenge","arc_challenge",              "reasoning",           batch_size=16),

    # Instruction Following
     Task("ifeval",       "ifeval",                    "instruction_following",batch_size=14,  max_gen_toks=1024),

    # Perplexity
     Task("wikitext",     "wikitext",                  "perplexity",          batch_size=1,  apply_chat_template=False),

    # Knowledge
     Task("mmlu",         "mmlu",                      "knowledge",           num_fewshot=5, batch_size=2,  limit=1400),
]


# Model args
MODEL_ARGS = ",".join([
    f"pretrained={MODEL_PRETRAINED}",
    f"subfolder={SUB_FOLDER}",
    "dtype=float16",
    "parallelize=True",
    "max_length=4096",
    "trust_remote_code=True",
    #"enable_thinking=False",
])

results_dir = f"evaluation_results/{MODEL_NAME}"

# %% [markdown]
# **Evaluation loop**

# %%
for t in TASKS:
    print(f"\n[{t.category.upper()}] {t.key}")

    cmd = [
        "lm_eval",
        "--model",       "hf",
        "--model_args",  MODEL_ARGS,
        "--tasks",       t.name,
        "--num_fewshot", str(t.num_fewshot),
        "--batch_size",  str(t.batch_size),
        "--seed",        str(SEED),
        "--verbosity", "WARNING",
        "--output_path", f"{results_dir}/{t.key}",
    ]

    if t.limit is not None:
        cmd += ["--limit", str(t.limit)]
        
    if t.apply_chat_template:
            cmd.append("--apply_chat_template")
        
    if t.max_gen_toks is not None:                             
        cmd += ["--gen_kwargs", f"max_gen_toks={t.max_gen_toks}"]

    subprocess.run(cmd, check=True)

    torch.cuda.empty_cache()
    gc.collect()
    print("Done")
# Out:
# [MATH] gsm8k
# 2026-04-06:10:45:23 INFO     [config.evaluate_config:301] Using default fewshot_as_multiturn=True.
# 2026-04-06:10:45:31 INFO     [_cli.run:376] Selected Tasks: ['gsm8k_cot']
# 2026-04-06:10:45:33 WARNING  [evaluator:223] generation_kwargs: {'max_gen_toks': 1024} specified through cli, these settings will update set parameters in yaml tasks. Ensure 'do_sample=True' for non-greedy decoding!
# Fetching 2 files: 100%|██████████| 2/2 [00:36<00:00, 18.37s/it]
# Loading weights: 100%|██████████| 254/254 [00:01<00:00, 141.38it/s]
# Generating train split: 100%|██████████| 7473/7473 [00:00<00:00, 113628.33 examples/s]
# Generating test split: 100%|██████████| 1319/1319 [00:00<00:00, 273199.36 examples/s]
# 2026-04-06:10:46:38 WARNING  [evaluator:333] Overwriting default num_fewshot of gsm8k_cot from 8 to 8
# 2026-04-06:10:46:38 WARNING  [evaluator:490] Chat template formatting change affects loglikelihood and multiple-choice tasks. See docs/chat-template-readme.md for details.
# 100%|██████████| 1319/1319 [00:21<00:00, 61.14it/s]
# Running generate_until requests:   0%|          | 0/1319 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Running generate_until requests: 100%|██████████| 1319/1319 [2:44:29<00:00,  7.48s/it]
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# hf ({'pretrained': 'EdgeCompress01/Llama-3.2-3B-Instruct-WANDA', 'subfolder': 'Models/50', 'dtype': 'float16', 'parallelize': True, 'max_length': 4096}), gen_kwargs: ({'max_gen_toks': 1024}), limit: None, num_fewshot: 8, batch_size: 4
# |  Tasks  |Version|     Filter     |n-shot|  Metric   |   |Value |   |Stderr|
# |---------|------:|----------------|-----:|-----------|---|-----:|---|-----:|
# |gsm8k_cot|      3|flexible-extract|     8|exact_match|↑  |0.2305|±  |0.0116|
# |         |       |strict-match    |     8|exact_match|↑  |0.2229|±  |0.0115|
#
# Done
#
# [INSTRUCTION_FOLLOWING] ifeval
# 2026-04-06:13:31:41 INFO     [config.evaluate_config:301] Using default fewshot_as_multiturn=True.
# 2026-04-06:13:31:47 INFO     [_cli.run:376] Selected Tasks: ['ifeval']
# 2026-04-06:13:31:49 WARNING  [evaluator:223] generation_kwargs: {'max_gen_toks': 1024} specified through cli, these settings will update set parameters in yaml tasks. Ensure 'do_sample=True' for non-greedy decoding!
# Loading weights: 100%|██████████| 254/254 [00:01<00:00, 144.77it/s]
# Generating train split: 100%|██████████| 541/541 [00:00<00:00, 42280.66 examples/s]
# 2026-04-06:13:32:03 WARNING  [evaluator:490] Chat template formatting change affects loglikelihood and multiple-choice tasks. See docs/chat-template-readme.md for details.
# 100%|██████████| 541/541 [00:00<00:00, 9968.49it/s]
# Running generate_until requests:   0%|          | 0/541 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Running generate_until requests: 100%|██████████| 541/541 [2:11:56<00:00, 14.63s/it]
# ERROR:root:Unable to detect language for text (, 2019)
#
# (, ) due to No features in text.
# ERROR:root:Unable to detect language for text (, 2019)
#
# (, ) due to No features in text.
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# hf ({'pretrained': 'EdgeCompress01/Llama-3.2-3B-Instruct-WANDA', 'subfolder': 'Models/50', 'dtype': 'float16', 'parallelize': True, 'max_length': 4096}), gen_kwargs: ({'max_gen_toks': 1024}), limit: None, num_fewshot: 0, batch_size: 4
# |Tasks |Version|Filter|n-shot|        Metric         |   |Value |   |Stderr|
# |------|------:|------|-----:|-----------------------|---|-----:|---|------|
# |ifeval|      4|none  |     0|inst_level_loose_acc   |↑  |0.5528|±  |   N/A|
# |      |       |none  |     0|inst_level_strict_acc  |↑  |0.5096|±  |   N/A|
# |      |       |none  |     0|prompt_level_loose_acc |↑  |0.4510|±  |0.0214|
# |      |       |none  |     0|prompt_level_strict_acc|↑  |0.4085|±  |0.0212|
#
# Done
#
# [REASONING] arc_challenge
# 2026-04-06:15:44:08 INFO     [config.evaluate_config:301] Using default fewshot_as_multiturn=True.
# 2026-04-06:15:44:14 INFO     [_cli.run:376] Selected Tasks: ['arc_challenge']
# Loading weights: 100%|██████████| 254/254 [00:01<00:00, 143.01it/s]
# Generating train split: 100%|██████████| 1119/1119 [00:00<00:00, 120715.69 examples/s]
# Generating test split: 100%|██████████| 1172/1172 [00:00<00:00, 221010.89 examples/s]
# Generating validation split: 100%|██████████| 299/299 [00:00<00:00, 93589.32 examples/s]
# 2026-04-06:15:44:30 WARNING  [evaluator:333] Overwriting default num_fewshot of arc_challenge from None to 0
# 2026-04-06:15:44:30 WARNING  [evaluator:490] Chat template formatting change affects loglikelihood and multiple-choice tasks. See docs/chat-template-readme.md for details.
# 100%|██████████| 1172/1172 [00:02<00:00, 416.73it/s]
# Running loglikelihood requests: 100%|██████████| 4687/4687 [02:00<00:00, 38.87it/s]
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# hf ({'pretrained': 'EdgeCompress01/Llama-3.2-3B-Instruct-WANDA', 'subfolder': 'Models/50', 'dtype': 'float16', 'parallelize': True, 'max_length': 4096}), gen_kwargs: ({}), limit: None, num_fewshot: 0, batch_size: 8
# |    Tasks    |Version|Filter|n-shot| Metric |   |Value |   |Stderr|
# |-------------|------:|------|-----:|--------|---|-----:|---|-----:|
# |arc_challenge|      1|none  |     0|acc     |↑  |0.3234|±  |0.0137|
# |             |       |none  |     0|acc_norm|↑  |0.3618|±  |0.0140|
#
# Done
#
# [PERPLEXITY] wikitext
# 2026-04-06:15:46:49 INFO     [_cli.run:376] Selected Tasks: ['wikitext']
# 2026-04-06:15:46:49 WARNING  [evaluator:181] pretrained=EdgeCompress01/Llama-3.2-3B-Instruct-WANDA appears to be an instruct or chat variant but chat template is not applied. Recommend
#         setting `apply_chat_template` (optionally `fewshot_as_multiturn`).
# Loading weights: 100%|██████████| 254/254 [00:01<00:00, 144.34it/s]
# 2026-04-06:15:47:03 WARNING  [api.task:729] [Task: wikitext] metric word_perplexity is defined, but aggregation is not. using default aggregation=weighted_perplexity
# 2026-04-06:15:47:03 WARNING  [api.task:741] [Task: wikitext] metric word_perplexity is defined, but higher_is_better is not. using default higher_is_better=False
# 2026-04-06:15:47:03 WARNING  [api.task:729] [Task: wikitext] metric byte_perplexity is defined, but aggregation is not. using default aggregation=weighted_perplexity
# 2026-04-06:15:47:03 WARNING  [api.task:741] [Task: wikitext] metric byte_perplexity is defined, but higher_is_better is not. using default higher_is_better=False
# 2026-04-06:15:47:03 WARNING  [api.task:729] [Task: wikitext] metric bits_per_byte is defined, but aggregation is not. using default aggregation=bits_per_byte
# 2026-04-06:15:47:03 WARNING  [api.task:741] [Task: wikitext] metric bits_per_byte is defined, but higher_is_better is not. using default higher_is_better=False
# Generating train split: 100%|██████████| 629/629 [00:00<00:00, 7016.59 examples/s]
# Generating validation split: 100%|██████████| 60/60 [00:00<00:00, 8782.04 examples/s]
# Generating test split: 100%|██████████| 62/62 [00:00<00:00, 8582.12 examples/s]
# 2026-04-06:15:47:06 WARNING  [evaluator:333] Overwriting default num_fewshot of wikitext from None to 0
# 100%|██████████| 62/62 [00:00<00:00, 264.35it/s]
# 100%|██████████| 62/62 [00:00<00:00, 74.38it/s]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:01<00:00,  1.24s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.79s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.88s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:02<00:00,  2.45s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.89s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.90s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:01<00:00,  1.88s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:02<00:00,  2.44s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.98s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.99s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.01s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:02<00:00,  2.40s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.99s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.97s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.96s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:01<00:00,  1.40s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:03<00:00,  3.47s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.93s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.91s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.89s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:00<00:00,  1.54it/s]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:02<00:00,  2.13s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:00<00:00,  3.43it/s]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:01<00:00,  1.39s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.90s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.92s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:00<00:00,  1.46it/s]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.89s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.94s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:05<00:00,  5.05s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.98s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.97s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:00<00:00,  1.07it/s]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.95s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.96s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.94s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.95s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.93s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.93s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:02<00:00,  2.46s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.92s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.93s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.92s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.94s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.92s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:00<00:00,  1.21it/s]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:00<00:00, 14.98it/s]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:00<00:00, 10.54it/s]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.89s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.94s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:01<00:00,  1.23s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.94s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.97s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:01<00:00,  1.34s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.94s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.94s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.93s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.91s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.94s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:01<00:00,  1.23s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.91s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.95s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.92s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.94s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.93s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.94s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.93s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.94s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.92s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.92s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.95s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.93s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:02<00:00,  2.60s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:00<00:00,  1.37it/s]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.93s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.94s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:02<00:00,  2.15s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:00<00:00,  1.45it/s]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:00<00:00,  1.09it/s]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.94s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.92s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:01<00:00,  1.10s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:01<00:00,  1.13s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:03<00:00,  3.00s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:03<00:00,  3.03s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:00<00:00,  1.48it/s]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:00<00:00,  1.49it/s]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:00<00:00,  1.62it/s]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:00<00:00,  1.65it/s]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.92s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.94s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:00<00:00,  3.49it/s]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:03<00:00,  3.82s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.94s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.94s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.91s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.94s/it]
# Running loglikelihood requests: 100%|██████████| 1/1 [00:04<00:00,  4.37s/it]
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# hf ({'pretrained': 'EdgeCompress01/Llama-3.2-3B-Instruct-WANDA', 'subfolder': 'Models/50', 'dtype': 'float16', 'parallelize': True, 'max_length': 4096}), gen_kwargs: ({}), limit: None, num_fewshot: 0, batch_size: 1
# | Tasks  |Version|Filter|n-shot|    Metric     |   | Value |   |Stderr|
# |--------|------:|------|-----:|---------------|---|------:|---|------|
# |wikitext|      2|none  |     0|bits_per_byte  |↓  | 0.8678|±  |   N/A|
# |        |       |none  |     0|byte_perplexity|↓  | 1.8249|±  |   N/A|
# |        |       |none  |     0|word_perplexity|↓  |24.9427|±  |   N/A|
#
# Done
#
# [KNOWLEDGE] mmlu
# 2026-04-06:15:53:14 WARNING  [config.evaluate_config:281] --limit SHOULD ONLY BE USED FOR TESTING. REAL METRICS SHOULD NOT BE COMPUTED USING LIMIT.
# 2026-04-06:15:53:14 INFO     [config.evaluate_config:301] Using default fewshot_as_multiturn=True.
# 2026-04-06:15:53:20 INFO     [_cli.run:376] Selected Tasks: ['mmlu']
# Loading weights: 100%|██████████| 254/254 [00:01<00:00, 144.92it/s]
# Generating test split: 100%|██████████| 171/171 [00:00<00:00, 22216.14 examples/s]
# Generating validation split: 100%|██████████| 19/19 [00:00<00:00, 7751.36 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2306.08 examples/s]
# Generating test split: 100%|██████████| 1534/1534 [00:00<00:00, 124123.43 examples/s]
# Generating validation split: 100%|██████████| 170/170 [00:00<00:00, 50623.48 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2125.85 examples/s]
# Generating test split: 100%|██████████| 324/324 [00:00<00:00, 90098.42 examples/s]
# Generating validation split: 100%|██████████| 35/35 [00:00<00:00, 13609.03 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2184.53 examples/s]
# Generating test split: 100%|██████████| 311/311 [00:00<00:00, 92185.76 examples/s]
# Generating validation split: 100%|██████████| 34/34 [00:00<00:00, 13128.92 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2146.08 examples/s]
# Generating test split: 100%|██████████| 895/895 [00:00<00:00, 194785.29 examples/s]
# Generating validation split: 100%|██████████| 100/100 [00:00<00:00, 33748.83 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 1974.35 examples/s]
# Generating test split: 100%|██████████| 346/346 [00:00<00:00, 101804.92 examples/s]
# Generating validation split: 100%|██████████| 38/38 [00:00<00:00, 14618.32 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2076.18 examples/s]
# Generating test split: 100%|██████████| 163/163 [00:00<00:00, 42606.98 examples/s]
# Generating validation split: 100%|██████████| 18/18 [00:00<00:00, 4742.30 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 1478.22 examples/s]
# Generating test split: 100%|██████████| 108/108 [00:00<00:00, 33529.60 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 4028.06 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2038.05 examples/s]
# Generating test split: 100%|██████████| 121/121 [00:00<00:00, 36960.95 examples/s]
# Generating validation split: 100%|██████████| 13/13 [00:00<00:00, 5155.14 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2099.67 examples/s]
# Generating test split: 100%|██████████| 237/237 [00:00<00:00, 48433.54 examples/s]
# Generating validation split: 100%|██████████| 26/26 [00:00<00:00, 8862.41 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 1948.84 examples/s]
# Generating test split: 100%|██████████| 204/204 [00:00<00:00, 46524.82 examples/s]
# Generating validation split: 100%|██████████| 22/22 [00:00<00:00, 7431.92 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 1884.40 examples/s]
# Generating test split: 100%|██████████| 165/165 [00:00<00:00, 42114.05 examples/s]
# Generating validation split: 100%|██████████| 18/18 [00:00<00:00, 6529.23 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2126.28 examples/s]
# Generating test split: 100%|██████████| 126/126 [00:00<00:00, 40262.25 examples/s]
# Generating validation split: 100%|██████████| 14/14 [00:00<00:00, 5322.24 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2051.41 examples/s]
# Generating test split: 100%|██████████| 100/100 [00:00<00:00, 31493.50 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 4337.85 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 1933.93 examples/s]
# Generating test split: 100%|██████████| 201/201 [00:00<00:00, 59605.14 examples/s]
# Generating validation split: 100%|██████████| 22/22 [00:00<00:00, 8509.29 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2247.75 examples/s]
# Generating test split: 100%|██████████| 245/245 [00:00<00:00, 57006.79 examples/s]
# Generating validation split: 100%|██████████| 27/27 [00:00<00:00, 9287.81 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2073.10 examples/s]
# Generating test split: 100%|██████████| 110/110 [00:00<00:00, 35807.02 examples/s]
# Generating validation split: 100%|██████████| 12/12 [00:00<00:00, 4511.22 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 1970.27 examples/s]
# Generating test split: 100%|██████████| 612/612 [00:00<00:00, 155617.71 examples/s]
# Generating validation split: 100%|██████████| 69/69 [00:00<00:00, 26536.49 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2126.50 examples/s]
# Generating test split: 100%|██████████| 131/131 [00:00<00:00, 42855.77 examples/s]
# Generating validation split: 100%|██████████| 12/12 [00:00<00:00, 4647.86 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2098.20 examples/s]
# Generating test split: 100%|██████████| 545/545 [00:00<00:00, 155133.74 examples/s]
# Generating validation split: 100%|██████████| 60/60 [00:00<00:00, 23329.77 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2139.73 examples/s]
# Generating test split: 100%|██████████| 238/238 [00:00<00:00, 69612.58 examples/s]
# Generating validation split: 100%|██████████| 26/26 [00:00<00:00, 9791.86 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2169.62 examples/s]
# Generating test split: 100%|██████████| 390/390 [00:00<00:00, 115252.49 examples/s]
# Generating validation split: 100%|██████████| 43/43 [00:00<00:00, 16830.45 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2294.23 examples/s]
# Generating test split: 100%|██████████| 193/193 [00:00<00:00, 57067.37 examples/s]
# Generating validation split: 100%|██████████| 21/21 [00:00<00:00, 8085.96 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2065.35 examples/s]
# Generating test split: 100%|██████████| 198/198 [00:00<00:00, 63511.18 examples/s]
# Generating validation split: 100%|██████████| 22/22 [00:00<00:00, 9540.39 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2414.68 examples/s]
# Generating test split: 100%|██████████| 114/114 [00:00<00:00, 36968.51 examples/s]
# Generating validation split: 100%|██████████| 12/12 [00:00<00:00, 4840.51 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2071.26 examples/s]
# Generating test split: 100%|██████████| 166/166 [00:00<00:00, 51881.85 examples/s]
# Generating validation split: 100%|██████████| 18/18 [00:00<00:00, 6654.10 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2118.98 examples/s]
# Generating test split: 100%|██████████| 272/272 [00:00<00:00, 68523.68 examples/s]
# Generating validation split: 100%|██████████| 31/31 [00:00<00:00, 12036.98 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2073.51 examples/s]
# Generating test split: 100%|██████████| 282/282 [00:00<00:00, 82087.15 examples/s]
# Generating validation split: 100%|██████████| 31/31 [00:00<00:00, 12036.98 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2146.30 examples/s]
# Generating test split: 100%|██████████| 306/306 [00:00<00:00, 90722.91 examples/s]
# Generating validation split: 100%|██████████| 33/33 [00:00<00:00, 13175.82 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2102.83 examples/s]
# Generating test split: 100%|██████████| 783/783 [00:00<00:00, 211729.74 examples/s]
# Generating validation split: 100%|██████████| 86/86 [00:00<00:00, 30576.43 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2126.07 examples/s]
# Generating test split: 100%|██████████| 100/100 [00:00<00:00, 33211.69 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 4315.13 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2030.16 examples/s]
# Generating test split: 100%|██████████| 234/234 [00:00<00:00, 70533.03 examples/s]
# Generating validation split: 100%|██████████| 25/25 [00:00<00:00, 9366.47 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2003.01 examples/s]
# Generating test split: 100%|██████████| 103/103 [00:00<00:00, 33502.39 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 4386.93 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2264.99 examples/s]
# Generating test split: 100%|██████████| 223/223 [00:00<00:00, 72259.72 examples/s]
# Generating validation split: 100%|██████████| 23/23 [00:00<00:00, 9430.01 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2226.51 examples/s]
# Generating test split: 100%|██████████| 100/100 [00:00<00:00, 33659.45 examples/s]
# Generating validation split: 100%|██████████| 10/10 [00:00<00:00, 3889.38 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2140.82 examples/s]
# Generating test split: 100%|██████████| 173/173 [00:00<00:00, 52045.23 examples/s]
# Generating validation split: 100%|██████████| 22/22 [00:00<00:00, 8361.24 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2165.14 examples/s]
# Generating test split: 100%|██████████| 265/265 [00:00<00:00, 77895.48 examples/s]
# Generating validation split: 100%|██████████| 29/29 [00:00<00:00, 11417.89 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2222.74 examples/s]
# Generating test split: 100%|██████████| 100/100 [00:00<00:00, 33070.28 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 4535.27 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2187.95 examples/s]
# Generating test split: 100%|██████████| 112/112 [00:00<00:00, 36367.74 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 4497.69 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2207.53 examples/s]
# Generating test split: 100%|██████████| 216/216 [00:00<00:00, 60811.50 examples/s]
# Generating validation split: 100%|██████████| 23/23 [00:00<00:00, 8873.98 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2151.81 examples/s]
# Generating test split: 100%|██████████| 151/151 [00:00<00:00, 48461.24 examples/s]
# Generating validation split: 100%|██████████| 17/17 [00:00<00:00, 6874.58 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2099.46 examples/s]
# Generating test split: 100%|██████████| 270/270 [00:00<00:00, 86007.60 examples/s]
# Generating validation split: 100%|██████████| 29/29 [00:00<00:00, 11655.31 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2185.22 examples/s]
# Generating test split: 100%|██████████| 100/100 [00:00<00:00, 30292.53 examples/s]
# Generating validation split: 100%|██████████| 9/9 [00:00<00:00, 3476.58 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2182.26 examples/s]
# Generating test split: 100%|██████████| 203/203 [00:00<00:00, 61422.86 examples/s]
# Generating validation split: 100%|██████████| 22/22 [00:00<00:00, 8111.35 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 1943.25 examples/s]
# Generating test split: 100%|██████████| 310/310 [00:00<00:00, 90000.29 examples/s]
# Generating validation split: 100%|██████████| 32/32 [00:00<00:00, 12208.27 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2205.44 examples/s]
# Generating test split: 100%|██████████| 378/378 [00:00<00:00, 110230.61 examples/s]
# Generating validation split: 100%|██████████| 41/41 [00:00<00:00, 15756.50 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2078.45 examples/s]
# Generating test split: 100%|██████████| 145/145 [00:00<00:00, 46581.96 examples/s]
# Generating validation split: 100%|██████████| 16/16 [00:00<00:00, 6075.40 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2060.68 examples/s]
# Generating test split: 100%|██████████| 235/235 [00:00<00:00, 73491.01 examples/s]
# Generating validation split: 100%|██████████| 26/26 [00:00<00:00, 10012.11 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2177.28 examples/s]
# Generating test split: 100%|██████████| 100/100 [00:00<00:00, 31775.03 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 4211.53 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2066.77 examples/s]
# Generating test split: 100%|██████████| 102/102 [00:00<00:00, 32838.43 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 4188.21 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2084.44 examples/s]
# Generating test split: 100%|██████████| 100/100 [00:00<00:00, 32945.60 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 4266.84 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2078.24 examples/s]
# Generating test split: 100%|██████████| 100/100 [00:00<00:00, 31446.27 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 4590.78 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2293.22 examples/s]
# Generating test split: 100%|██████████| 100/100 [00:00<00:00, 29579.01 examples/s]
# Generating validation split: 100%|██████████| 8/8 [00:00<00:00, 3130.66 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2120.91 examples/s]
# Generating test split: 100%|██████████| 144/144 [00:00<00:00, 44888.87 examples/s]
# Generating validation split: 100%|██████████| 16/16 [00:00<00:00, 6490.85 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2202.20 examples/s]
# Generating test split: 100%|██████████| 152/152 [00:00<00:00, 47130.50 examples/s]
# Generating validation split: 100%|██████████| 16/16 [00:00<00:00, 6480.82 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2313.21 examples/s]
# Generating test split: 100%|██████████| 135/135 [00:00<00:00, 43007.07 examples/s]
# Generating validation split: 100%|██████████| 14/14 [00:00<00:00, 5571.71 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2076.18 examples/s]
# Generating test split: 100%|██████████| 100/100 [00:00<00:00, 32415.98 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 4396.55 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2018.24 examples/s]
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_abstract_algebra from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_anatomy from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_astronomy from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_college_biology from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_college_chemistry from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_college_computer_science from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_college_mathematics from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_college_physics from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_computer_security from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_conceptual_physics from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_electrical_engineering from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_elementary_mathematics from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_biology from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_chemistry from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_computer_science from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_mathematics from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_physics from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_statistics from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_machine_learning from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_business_ethics from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_clinical_knowledge from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_college_medicine from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_global_facts from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_human_aging from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_management from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_marketing from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_medical_genetics from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_miscellaneous from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_nutrition from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_professional_accounting from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_professional_medicine from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_virology from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_econometrics from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_geography from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_government_and_politics from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_macroeconomics from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_microeconomics from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_psychology from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_human_sexuality from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_professional_psychology from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_public_relations from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_security_studies from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_sociology from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_us_foreign_policy from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_formal_logic from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_european_history from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_us_history from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_world_history from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_international_law from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_jurisprudence from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_logical_fallacies from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_moral_disputes from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_moral_scenarios from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_philosophy from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_prehistory from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_professional_law from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_world_religions from None to 5
# 2026-04-06:15:55:14 WARNING  [evaluator:490] Chat template formatting change affects loglikelihood and multiple-choice tasks. See docs/chat-template-readme.md for details.
# 100%|██████████| 100/100 [00:00<00:00, 114.40it/s]
# 100%|██████████| 135/135 [00:01<00:00, 117.15it/s]
# 100%|██████████| 152/152 [00:01<00:00, 117.76it/s]
# 100%|██████████| 144/144 [00:01<00:00, 116.42it/s]
# 100%|██████████| 100/100 [00:00<00:00, 118.54it/s]
# 100%|██████████| 100/100 [00:00<00:00, 118.75it/s]
# 100%|██████████| 100/100 [00:00<00:00, 118.81it/s]
# 100%|██████████| 102/102 [00:00<00:00, 118.54it/s]
# 100%|██████████| 100/100 [00:00<00:00, 118.93it/s]
# 100%|██████████| 235/235 [00:01<00:00, 119.19it/s]
# 100%|██████████| 145/145 [00:01<00:00, 118.54it/s]
# 100%|██████████| 378/378 [00:03<00:00, 119.29it/s]
# 100%|██████████| 310/310 [00:02<00:00, 120.65it/s]
# 100%|██████████| 203/203 [00:01<00:00, 120.36it/s]
# 100%|██████████| 100/100 [00:00<00:00, 120.06it/s]
# 100%|██████████| 270/270 [00:02<00:00, 121.23it/s]
# 100%|██████████| 151/151 [00:01<00:00, 118.09it/s]
# 100%|██████████| 216/216 [00:02<00:00, 103.00it/s]
# 100%|██████████| 112/112 [00:00<00:00, 117.05it/s]
# 100%|██████████| 100/100 [00:00<00:00, 118.09it/s]
# 100%|██████████| 265/265 [00:02<00:00, 119.66it/s]
# 100%|██████████| 173/173 [00:01<00:00, 119.42it/s]
# 100%|██████████| 100/100 [00:00<00:00, 119.63it/s]
# 100%|██████████| 223/223 [00:01<00:00, 117.41it/s]
# 100%|██████████| 103/103 [00:00<00:00, 118.84it/s]
# 100%|██████████| 234/234 [00:01<00:00, 120.48it/s]
# 100%|██████████| 100/100 [00:00<00:00, 122.09it/s]
# 100%|██████████| 783/783 [00:06<00:00, 119.47it/s]
# 100%|██████████| 306/306 [00:02<00:00, 119.32it/s]
# 100%|██████████| 282/282 [00:02<00:00, 120.14it/s]
# 100%|██████████| 272/272 [00:02<00:00, 120.08it/s]
# 100%|██████████| 166/166 [00:01<00:00, 120.11it/s]
# 100%|██████████| 114/114 [00:00<00:00, 115.26it/s]
# 100%|██████████| 198/198 [00:01<00:00, 119.45it/s]
# 100%|██████████| 193/193 [00:01<00:00, 119.65it/s]
# 100%|██████████| 390/390 [00:03<00:00, 119.19it/s]
# 100%|██████████| 238/238 [00:01<00:00, 119.45it/s]
# 100%|██████████| 545/545 [00:04<00:00, 118.88it/s]
# 100%|██████████| 131/131 [00:01<00:00, 120.48it/s]
# 100%|██████████| 612/612 [00:05<00:00, 119.53it/s]
# 100%|██████████| 110/110 [00:00<00:00, 121.55it/s]
# 100%|██████████| 245/245 [00:02<00:00, 120.40it/s]
# 100%|██████████| 201/201 [00:01<00:00, 120.41it/s]
# 100%|██████████| 100/100 [00:00<00:00, 119.75it/s]
# 100%|██████████| 126/126 [00:01<00:00, 120.61it/s]
# 100%|██████████| 165/165 [00:01<00:00, 120.22it/s]
# 100%|██████████| 204/204 [00:01<00:00, 120.79it/s]
# 100%|██████████| 237/237 [00:02<00:00, 117.83it/s]
# 100%|██████████| 121/121 [00:01<00:00, 119.94it/s]
# 100%|██████████| 108/108 [00:00<00:00, 120.15it/s]
# 100%|██████████| 163/163 [00:01<00:00, 119.63it/s]
# 100%|██████████| 346/346 [00:02<00:00, 119.29it/s]
# 100%|██████████| 895/895 [00:07<00:00, 119.10it/s]
# 100%|██████████| 311/311 [00:02<00:00, 119.77it/s]
# 100%|██████████| 324/324 [00:02<00:00, 118.76it/s]
# 100%|██████████| 1400/1400 [00:11<00:00, 120.13it/s]
# 100%|██████████| 171/171 [00:01<00:00, 121.55it/s]
# Running loglikelihood requests: 100%|██████████| 55632/55632 [1:40:27<00:00,  9.23it/s]
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# hf ({'pretrained': 'EdgeCompress01/Llama-3.2-3B-Instruct-WANDA', 'subfolder': 'Models/50', 'dtype': 'float16', 'parallelize': True, 'max_length': 4096}), gen_kwargs: ({}), limit: 1400.0, num_fewshot: 5, batch_size: 2
# |                 Tasks                 |Version|Filter|n-shot|Metric|   |Value |   |Stderr|
# |---------------------------------------|------:|------|-----:|------|---|-----:|---|-----:|
# |mmlu                                   |      2|none  |      |acc   |↑  |0.4551|±  |0.0041|
# | - humanities                          |      2|none  |      |acc   |↑  |0.3977|±  |0.0070|
# |  - formal_logic                       |      1|none  |     5|acc   |↑  |0.2937|±  |0.0407|
# |  - high_school_european_history       |      1|none  |     5|acc   |↑  |0.5273|±  |0.0390|
# |  - high_school_us_history             |      1|none  |     5|acc   |↑  |0.4804|±  |0.0351|
# |  - high_school_world_history          |      1|none  |     5|acc   |↑  |0.5359|±  |0.0325|
# |  - international_law                  |      1|none  |     5|acc   |↑  |0.6033|±  |0.0447|
# |  - jurisprudence                      |      1|none  |     5|acc   |↑  |0.5370|±  |0.0482|
# |  - logical_fallacies                  |      1|none  |     5|acc   |↑  |0.4479|±  |0.0391|
# |  - moral_disputes                     |      1|none  |     5|acc   |↑  |0.4451|±  |0.0268|
# |  - moral_scenarios                    |      1|none  |     5|acc   |↑  |0.2559|±  |0.0146|
# |  - philosophy                         |      1|none  |     5|acc   |↑  |0.5338|±  |0.0283|
# |  - prehistory                         |      1|none  |     5|acc   |↑  |0.5123|±  |0.0278|
# |  - professional_law                   |      1|none  |     5|acc   |↑  |0.3207|±  |0.0125|
# |  - world_religions                    |      1|none  |     5|acc   |↑  |0.5906|±  |0.0377|
# | - other                               |      2|none  |      |acc   |↑  |0.5140|±  |0.0089|
# |  - business_ethics                    |      1|none  |     5|acc   |↑  |0.4400|±  |0.0499|
# |  - clinical_knowledge                 |      1|none  |     5|acc   |↑  |0.5358|±  |0.0307|
# |  - college_medicine                   |      1|none  |     5|acc   |↑  |0.4277|±  |0.0377|
# |  - global_facts                       |      1|none  |     5|acc   |↑  |0.3700|±  |0.0485|
# |  - human_aging                        |      1|none  |     5|acc   |↑  |0.4619|±  |0.0335|
# |  - management                         |      1|none  |     5|acc   |↑  |0.5825|±  |0.0488|
# |  - marketing                          |      1|none  |     5|acc   |↑  |0.6795|±  |0.0306|
# |  - medical_genetics                   |      1|none  |     5|acc   |↑  |0.5300|±  |0.0502|
# |  - miscellaneous                      |      1|none  |     5|acc   |↑  |0.5760|±  |0.0177|
# |  - nutrition                          |      1|none  |     5|acc   |↑  |0.5621|±  |0.0284|
# |  - professional_accounting            |      1|none  |     5|acc   |↑  |0.3830|±  |0.0290|
# |  - professional_medicine              |      1|none  |     5|acc   |↑  |0.4301|±  |0.0301|
# |  - virology                           |      1|none  |     5|acc   |↑  |0.4639|±  |0.0388|
# | - social sciences                     |      2|none  |      |acc   |↑  |0.5268|±  |0.0089|
# |  - econometrics                       |      1|none  |     5|acc   |↑  |0.2982|±  |0.0430|
# |  - high_school_geography              |      1|none  |     5|acc   |↑  |0.5758|±  |0.0352|
# |  - high_school_government_and_politics|      1|none  |     5|acc   |↑  |0.6425|±  |0.0346|
# |  - high_school_macroeconomics         |      1|none  |     5|acc   |↑  |0.4718|±  |0.0253|
# |  - high_school_microeconomics         |      1|none  |     5|acc   |↑  |0.5126|±  |0.0325|
# |  - high_school_psychology             |      1|none  |     5|acc   |↑  |0.6110|±  |0.0209|
# |  - human_sexuality                    |      1|none  |     5|acc   |↑  |0.5649|±  |0.0435|
# |  - professional_psychology            |      1|none  |     5|acc   |↑  |0.4167|±  |0.0199|
# |  - public_relations                   |      1|none  |     5|acc   |↑  |0.5636|±  |0.0475|
# |  - security_studies                   |      1|none  |     5|acc   |↑  |0.5347|±  |0.0319|
# |  - sociology                          |      1|none  |     5|acc   |↑  |0.6418|±  |0.0339|
# |  - us_foreign_policy                  |      1|none  |     5|acc   |↑  |0.5900|±  |0.0494|
# | - stem                                |      2|none  |      |acc   |↑  |0.4104|±  |0.0087|
# |  - abstract_algebra                   |      1|none  |     5|acc   |↑  |0.3000|±  |0.0461|
# |  - anatomy                            |      1|none  |     5|acc   |↑  |0.4444|±  |0.0429|
# |  - astronomy                          |      1|none  |     5|acc   |↑  |0.5197|±  |0.0407|
# |  - college_biology                    |      1|none  |     5|acc   |↑  |0.4514|±  |0.0416|
# |  - college_chemistry                  |      1|none  |     5|acc   |↑  |0.3400|±  |0.0476|
# |  - college_computer_science           |      1|none  |     5|acc   |↑  |0.3600|±  |0.0482|
# |  - college_mathematics                |      1|none  |     5|acc   |↑  |0.3300|±  |0.0473|
# |  - college_physics                    |      1|none  |     5|acc   |↑  |0.3039|±  |0.0458|
# |  - computer_security                  |      1|none  |     5|acc   |↑  |0.5200|±  |0.0502|
# |  - conceptual_physics                 |      1|none  |     5|acc   |↑  |0.4128|±  |0.0322|
# |  - electrical_engineering             |      1|none  |     5|acc   |↑  |0.5103|±  |0.0417|
# |  - elementary_mathematics             |      1|none  |     5|acc   |↑  |0.3307|±  |0.0242|
# |  - high_school_biology                |      1|none  |     5|acc   |↑  |0.5484|±  |0.0283|
# |  - high_school_chemistry              |      1|none  |     5|acc   |↑  |0.4335|±  |0.0349|
# |  - high_school_computer_science       |      1|none  |     5|acc   |↑  |0.4900|±  |0.0502|
# |  - high_school_mathematics            |      1|none  |     5|acc   |↑  |0.3296|±  |0.0287|
# |  - high_school_physics                |      1|none  |     5|acc   |↑  |0.3576|±  |0.0391|
# |  - high_school_statistics             |      1|none  |     5|acc   |↑  |0.4167|±  |0.0336|
# |  - machine_learning                   |      1|none  |     5|acc   |↑  |0.3393|±  |0.0449|
#
# |      Groups      |Version|Filter|n-shot|Metric|   |Value |   |Stderr|
# |------------------|------:|------|------|------|---|-----:|---|-----:|
# |mmlu              |      2|none  |      |acc   |↑  |0.4551|±  |0.0041|
# | - humanities     |      2|none  |      |acc   |↑  |0.3977|±  |0.0070|
# | - other          |      2|none  |      |acc   |↑  |0.5140|±  |0.0089|
# | - social sciences|      2|none  |      |acc   |↑  |0.5268|±  |0.0089|
# | - stem           |      2|none  |      |acc   |↑  |0.4104|±  |0.0087|
#
# Done

# %% [markdown]
# # Save reports

# %%
zip_path = shutil.make_archive(
    "evaluation_results",   # zip file name
    "zip",                  # format
    "evaluation_results"    # folder to compress
)
