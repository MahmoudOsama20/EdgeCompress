# %% [markdown]
# # Libraries

# %%
# 0. Clean slate — remove existing copies before reinstalling
# !pip uninstall -y torch torchvision torchaudio torchao

# !pip install -q torch==2.10.0 torchvision==0.25.0 torchaudio==2.10.0 torchao==0.16.0 --index-url https://download.pytorch.org/whl/cu128

# 3. Evaluation Framework
# !pip install -q "lm_eval[hf]"

# !pip install -q "cuda-core==0.3.*" "numba-cuda[cu12]<0.23.0,>=0.22.2" "numba<0.62.0,>=0.60.0"

# !pip install -q transformers==4.57.6
# Out:
# Found existing installation: torch 2.10.0+cu128
# Uninstalling torch-2.10.0+cu128:
#   Successfully uninstalled torch-2.10.0+cu128
# Found existing installation: torchvision 0.25.0+cu128
# Uninstalling torchvision-0.25.0+cu128:
#   Successfully uninstalled torchvision-0.25.0+cu128
# Found existing installation: torchaudio 2.10.0+cu128
# Uninstalling torchaudio-2.10.0+cu128:
#   Successfully uninstalled torchaudio-2.10.0+cu128
# Found existing installation: torchao 0.10.0
# Uninstalling torchao-0.10.0:
#   Successfully uninstalled torchao-0.10.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 916.9/916.9 MB 2.1 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 104.7 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 69.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 38.4 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 109.1 MB/s eta 0:00:0000:010:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cuda 26.2.0 requires cuda-core==0.3.*, but you have cuda-core 1.0.1 which is incompatible.
# dask-cuda 26.2.0 requires numba-cuda<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# distributed-ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cuml-cu12 26.2.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cudf-cu12 26.2.1 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cudf-cu12 26.2.1 requires numba-cuda[cu12]<0.23.0,>=0.22.2, but you have numba-cuda 0.30.2 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.9/58.9 kB 1.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 64.7 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 6.0 MB/s eta 0:00:00
#   Building wheel for sqlitedict (setup.py) ... done
#   Building wheel for word2number (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 713.9 kB/s eta 0:00:000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 39.2 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 65.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 89.6 MB/s eta 0:00:00:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 MB 46.8 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 88.1 MB/s eta 0:00:00:00:0100:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.39.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# google-colab 1.0.0 requires jupyter-server==2.14.0, but you have jupyter-server 2.12.5 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# dopamine-rl 4.1.2 requires gym<=0.25.2, but you have gym 0.26.2 which is incompatible.
# moviepy 1.0.3 requires decorator<5.0,>=4.0.2, but you have decorator 5.3.1 which is incompatible.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.2.6 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 1.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 88.9 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 30.6 MB/s eta 0:00:00

# %%
# Libraries
import gc
import glob
import shutil
import os
import random
import subprocess

import numpy as np
import torch
import lm_eval

from dataclasses import dataclass
from typing import Optional
from huggingface_hub import login
from IPython.display import FileLink
from kaggle_secrets import UserSecretsClient

# %% [markdown]
# # Global Variables

# %%
# --- Identity ---
user_name = "Abdelrahmanemam01"
email     = "abdulrahmanemam01@gmail.com"
repo      = "MahmoudOsama20/EdgeCompress"  # Fixed

# --- Model ---
model      = "Llama-3.2-3B-Instruct"
MODEL_NAME       = "Llama-3.2-3B-Instruct-Original"
MODEL_PRETRAINED = "meta-llama/Llama-3.2-3B-Instruct"
MODEL_PRETRAINED_FIX = MODEL_PRETRAINED.replace("/", "__")

# --- Reproducibility ---
SEED = 42

# --- Environment ---
os.environ["HF_ALLOW_CODE_EVAL"] = "1"

# %% [markdown]
# # Classes

# %%
@dataclass
class Task:
    key:               str
    name:              str
    category:          str
    num_fewshot:       int  = 0
    batch_size:        int  = 2
    limit:             Optional[int] = None
    apply_chat_template: bool = True
    max_gen_toks:      Optional[int] = None

# %% [markdown]
# # Functions

# %%
# REPRODUCIBILITY
def set_reproducibility(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    # Ensure deterministic behavior in CuDNN
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    print(f"Global seed set to {seed}")

# %% [markdown]
# # Seeding

# %%
set_reproducibility(SEED)
# Out:
# Global seed set to 42

# %% [markdown]
# # Huggingface login

# %%
# HUGGING FACE AUTHENTICATION
user_secrets = UserSecretsClient()
hf_token = user_secrets.get_secret("HF_TOKEN")
login(token=hf_token)
print("Logging into Hugging Face...")
# Out:
# Logging into Hugging Face...

# %% [markdown]
# # GitHub login

# %%
token = UserSecretsClient().get_secret("GIT_TOKEN")
print("Logging into GitHub...")
# Out:
# Logging into GitHub...

# %% [markdown]
# # Evaluations

# %% [markdown]
# **Configurations**

# %%
TASKS = [
    Task("arabic_mmlu",     "arabicmmlu",     "arabic_knowledge",   num_fewshot=0, batch_size=2),
]

# Model args
MODEL_ARGS = ",".join([
    f"pretrained={MODEL_PRETRAINED}",
    f"tokenizer={MODEL_PRETRAINED}",
    "dtype=float16",
    "parallelize=True",
    "max_length=4096",
])

results_dir = f"evaluation_results/{MODEL_NAME}"

# %% [markdown]
# **Evaluation loop**

# %%
for t in TASKS:
    print(f"\n[{t.category.upper()}] {t.key}")

    cmd = [
        "lm_eval",
        "--model",       "hf",
        "--model_args",  MODEL_ARGS,
        "--tasks",       t.name,
        "--num_fewshot", str(t.num_fewshot),
        "--batch_size",  str(t.batch_size),
        "--seed",        str(SEED),
        "--verbosity", "DEBUG",
        "--output_path", f"{results_dir}/{t.key}",
    ]

    if t.limit is not None:
        cmd += ["--limit", str(t.limit)]
        
    if t.apply_chat_template:
            cmd.append("--apply_chat_template")
        
    if t.max_gen_toks is not None:                             
        cmd += ["--gen_kwargs", f"max_gen_toks={t.max_gen_toks}"]

    subprocess.run(cmd, check=True)
    
    # Push To GitHub
    target_dir_in_repo = f"Evaluations/BenchmarkEvaluations/ArabicEvaluations/{model}/{MODEL_NAME}/results/{t.key}"
    source_folder = f"{results_dir}/{t.key}/{MODEL_PRETRAINED_FIX}"  # The Kaggle folder you want to upload
    remote_url = f"https://{token}@github.com/{repo}.git"
    
    # A temporary workspace in Kaggle to handle the cloning
    temp_repo_dir = "/kaggle/working/temp_git_repo" 
    # ---------------------

    # 2. Clean up any previous runs and clone the existing repository
    os.system(f"rm -rf {temp_repo_dir}")
    os.system(f"git clone {remote_url} {temp_repo_dir}")
    
    # 3. Create the target directory inside the cloned repo
    full_target_path = f"{temp_repo_dir}/{target_dir_in_repo}"
    os.makedirs(full_target_path, exist_ok=True)
    
    # 4. Copy the contents of your Kaggle folder into the target GitHub folder
    # (Using cp -r to recursively copy all files and subfolders)
    os.system(f"cp -r {source_folder}/* {full_target_path}/")
    
    # 5. Configure, commit, and push the changes
    os.system(f"""
        git -C {temp_repo_dir} config user.email "{email}" && \
        git -C {temp_repo_dir} config user.name "{user_name}" && \
        git -C {temp_repo_dir} add . && \
        git -C {temp_repo_dir} commit -m "Add Kaggle results to {target_dir_in_repo}" && \
        git -C {temp_repo_dir} push origin main
    """)
    
    print(f"Successfully pushed to {repo} inside the '{target_dir_in_repo}' folder!")
    
    torch.cuda.empty_cache()
    gc.collect()
    print("Done")
# Out:
# [ARABIC_KNOWLEDGE] arabic_mmlu
# 2026-06-05:21:31:22 INFO     [_cli.run:388] Selected Tasks: ['arabicmmlu']
# 2026-06-05:21:31:22 INFO     [evaluator:162] Setting verbosity through simple_evaluate is deprecated.
# 2026-06-05:21:31:23 INFO     [evaluator:214] Setting random seed to 42 | Setting numpy seed to 42 | Setting torch manual seed to 42 | Setting fewshot manual seed to 42
# 2026-06-05:21:31:23 INFO     [evaluator:239] Initializing hf model, with arguments: {'pretrained': 'meta-llama/Llama-3.2-3B-Instruct', 'tokenizer': 'meta-llama/Llama-3.2-3B-Instruct', 'dtype': 'float16', 'parallelize': True, 'max_length': 4096}
# 2026-06-05:21:31:29 INFO     [models.huggingface:306] Using `accelerate launch` or `parallelize=True`, device 'cuda:0' will be overridden when placing model.
# 2026-06-05:21:31:32 INFO     [models.huggingface:562] Model parallel was set to True, setting max memory per GPU to {0: 15525019648, 1: 15525019648} and device map to auto
# 2026-06-05 21:31:36.102956: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1780695096.497157     152 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1780695096.605919     152 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1780695097.573350     152 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780695097.573397     152 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780695097.573400     152 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780695097.573402     152 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Fetching 2 files: 100%|██████████| 2/2 [00:22<00:00, 11.22s/it]
# Loading checkpoint shards: 100%|██████████| 2/2 [00:05<00:00,  2.97s/it]
# Generating test split: 100%|██████████| 1211/1211 [00:00<00:00, 19710.29 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 139.74 examples/s]
# Generating test split: 100%|██████████| 864/864 [00:00<00:00, 69053.88 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 608.31 examples/s]
# Generating test split: 100%|██████████| 172/172 [00:00<00:00, 25422.71 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 585.09 examples/s]
# Generating test split: 100%|██████████| 162/162 [00:00<00:00, 26775.32 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 789.89 examples/s]
# Generating test split: 100%|██████████| 75/75 [00:00<00:00, 11978.25 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 548.73 examples/s]
# Generating test split: 100%|██████████| 74/74 [00:00<00:00, 14210.17 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 770.92 examples/s]
# Generating test split: 100%|██████████| 87/87 [00:00<00:00, 15730.00 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 628.61 examples/s]
# Generating test split: 100%|██████████| 236/236 [00:00<00:00, 30270.82 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 542.60 examples/s]
# Generating test split: 100%|██████████| 360/360 [00:00<00:00, 40624.98 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 809.82 examples/s]
# Generating test split: 100%|██████████| 87/87 [00:00<00:00, 16080.04 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 781.30 examples/s]
# Generating test split: 100%|██████████| 137/137 [00:00<00:00, 18876.50 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 703.94 examples/s]
# Generating test split: 100%|██████████| 1038/1038 [00:00<00:00, 66044.02 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 576.27 examples/s]
# Generating test split: 100%|██████████| 272/272 [00:00<00:00, 35116.06 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 585.88 examples/s]
# Generating test split: 100%|██████████| 57/57 [00:00<00:00, 11670.18 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 757.82 examples/s]
# Generating test split: 100%|██████████| 210/210 [00:00<00:00, 33043.36 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 796.29 examples/s]
# Generating test split: 100%|██████████| 241/241 [00:00<00:00, 36235.56 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 798.46 examples/s]
# Generating test split: 100%|██████████| 705/705 [00:00<00:00, 75004.68 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 637.27 examples/s]
# Generating test split: 100%|██████████| 760/760 [00:00<00:00, 63936.28 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 668.49 examples/s]
# Generating test split: 100%|██████████| 203/203 [00:00<00:00, 34189.03 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 843.87 examples/s]
# Generating test split: 100%|██████████| 102/102 [00:00<00:00, 19983.14 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 860.19 examples/s]
# Generating test split: 100%|██████████| 639/639 [00:00<00:00, 65918.01 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 859.02 examples/s]
# Generating test split: 100%|██████████| 334/334 [00:00<00:00, 36934.73 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 684.45 examples/s]
# Generating test split: 100%|██████████| 238/238 [00:00<00:00, 36700.16 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 734.64 examples/s]
# Generating test split: 100%|██████████| 999/999 [00:00<00:00, 86920.92 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 654.85 examples/s]
# Generating test split: 100%|██████████| 314/314 [00:00<00:00, 38502.35 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 809.61 examples/s]
# Generating test split: 100%|██████████| 39/39 [00:00<00:00, 8172.76 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 838.80 examples/s]
# Generating test split: 100%|██████████| 1409/1409 [00:00<00:00, 78490.36 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 646.47 examples/s]
# Generating test split: 100%|██████████| 261/261 [00:00<00:00, 37607.38 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 833.14 examples/s]
# Generating test split: 100%|██████████| 27/27 [00:00<00:00, 5715.18 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 807.37 examples/s]
# Generating test split: 100%|██████████| 190/190 [00:00<00:00, 34704.43 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 631.23 examples/s]
# Generating test split: 100%|██████████| 64/64 [00:00<00:00, 12708.21 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 852.15 examples/s]
# Generating test split: 100%|██████████| 409/409 [00:00<00:00, 62412.51 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 809.87 examples/s]
# Generating test split: 100%|██████████| 242/242 [00:00<00:00, 31381.10 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 792.57 examples/s]
# Generating test split: 100%|██████████| 336/336 [00:00<00:00, 43321.33 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 719.56 examples/s]
# Generating test split: 100%|██████████| 255/255 [00:00<00:00, 34787.69 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 798.61 examples/s]
# Generating test split: 100%|██████████| 612/612 [00:00<00:00, 17391.02 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 546.39 examples/s]
# Generating test split: 100%|██████████| 365/365 [00:00<00:00, 48978.50 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 833.08 examples/s]
# Generating test split: 100%|██████████| 390/390 [00:00<00:00, 42121.25 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 672.34 examples/s]
# Generating test split: 100%|██████████| 27/27 [00:00<00:00, 5731.08 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 734.94 examples/s]
# Generating test split: 100%|██████████| 252/252 [00:00<00:00, 41840.10 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 690.04 examples/s]
# 2026-06-05:21:32:57 INFO     [evaluator_utils:446] Selected tasks:
# 2026-06-05:21:32:57 INFO     [evaluator_utils:462] Group: arabicmmlu
# 2026-06-05:21:32:57 INFO     [evaluator_utils:462]   Group: arabicmmlu_other
# 2026-06-05:21:32:57 INFO     [evaluator_utils:470]     Task: arabicmmlu_driving_test (arabicmmlu/arabicmmlu_driving_test.yaml)
# 2026-06-05:21:32:57 INFO     [evaluator_utils:470]     Task: arabicmmlu_general_knowledge (arabicmmlu/arabicmmlu_general_knowledge.yaml)
# 2026-06-05:21:32:57 INFO     [evaluator_utils:470]     Task: arabicmmlu_general_knowledge_middle_school (arabicmmlu/arabicmmlu_general_knowledge_middle_school.yaml)
# 2026-06-05:21:32:57 INFO     [evaluator_utils:470]     Task: arabicmmlu_general_knowledge_primary_school (arabicmmlu/arabicmmlu_general_knowledge_primary_school.yaml)
# 2026-06-05:21:32:57 INFO     [evaluator_utils:470]     Task: arabicmmlu_management_university (arabicmmlu/arabicmmlu_management_university.yaml)
# 2026-06-05:21:32:57 INFO     [evaluator_utils:462]   Group: arabicmmlu_social_science
# 2026-06-05:21:32:57 INFO     [evaluator_utils:470]     Task: arabicmmlu_accounting_university (arabicmmlu/arabicmmlu_accounting_university.yaml)
# 2026-06-05:21:32:57 INFO     [evaluator_utils:470]     Task: arabicmmlu_civics_high_school (arabicmmlu/arabicmmlu_civics_high_school.yaml)
# 2026-06-05:21:32:57 INFO     [evaluator_utils:470]     Task: arabicmmlu_civics_middle_school (arabicmmlu/arabicmmlu_civics_middle_school.yaml)
# 2026-06-05:21:32:57 INFO     [evaluator_utils:470]     Task: arabicmmlu_economics_high_school (arabicmmlu/arabicmmlu_economics_high_school.yaml)
# 2026-06-05:21:32:57 INFO     [evaluator_utils:470]     Task: arabicmmlu_economics_middle_school (arabicmmlu/arabicmmlu_economics_middle_school.yaml)
# 2026-06-05:21:32:57 INFO     [evaluator_utils:470]     Task: arabicmmlu_economics_university (arabicmmlu/arabicmmlu_economics_university.yaml)
# 2026-06-05:21:32:57 INFO     [evaluator_utils:470]     Task: arabicmmlu_geography_high_school (arabicmmlu/arabicmmlu_geography_high_school.yaml)
# 2026-06-05:21:32:57 INFO     [evaluator_utils:470]     Task: arabicmmlu_geography_middle_school (arabicmmlu/arabicmmlu_geography_middle_school.yaml)
# 2026-06-05:21:32:57 INFO     [evaluator_utils:470]     Task: arabicmmlu_geography_primary_school (arabicmmlu/arabicmmlu_geography_primary_school.yaml)
# 2026-06-05:21:32:57 INFO     [evaluator_utils:470]     Task: arabicmmlu_political_science_university (arabicmmlu/arabicmmlu_political_science_university.yaml)
# 2026-06-05:21:32:57 INFO     [evaluator_utils:470]     Task: arabicmmlu_social_science_middle_school (arabicmmlu/arabicmmlu_social_science_middle_school.yaml)
# 2026-06-05:21:32:57 INFO     [evaluator_utils:470]     Task: arabicmmlu_social_science_primary_school (arabicmmlu/arabicmmlu_social_science_primary_school.yaml)
# 2026-06-05:21:32:57 INFO     [evaluator_utils:462]   Group: arabicmmlu_humanities
# 2026-06-05:21:32:57 INFO     [evaluator_utils:470]     Task: arabicmmlu_history_high_school (arabicmmlu/arabicmmlu_history_high_school.yaml)
# 2026-06-05:21:32:57 INFO     [evaluator_utils:470]     Task: arabicmmlu_history_middle_school (arabicmmlu/arabicmmlu_history_middle_school.yaml)
# 2026-06-05:21:32:57 INFO     [evaluator_utils:470]     Task: arabicmmlu_history_primary_school (arabicmmlu/arabicmmlu_history_primary_school.yaml)
# 2026-06-05:21:32:57 INFO     [evaluator_utils:470]     Task: arabicmmlu_islamic_studies (arabicmmlu/arabicmmlu_islamic_studies.yaml)
# 2026-06-05:21:32:57 INFO     [evaluator_utils:470]     Task: arabicmmlu_islamic_studies_high_school (arabicmmlu/arabicmmlu_islamic_studies_high_school.yaml)
# 2026-06-05:21:32:57 INFO     [evaluator_utils:470]     Task: arabicmmlu_islamic_studies_middle_school (arabicmmlu/arabicmmlu_islamic_studies_middle_school.yaml)
# 2026-06-05:21:32:57 INFO     [evaluator_utils:470]     Task: arabicmmlu_islamic_studies_primary_school (arabicmmlu/arabicmmlu_islamic_studies_primary_school.yaml)
# 2026-06-05:21:32:57 INFO     [evaluator_utils:470]     Task: arabicmmlu_law_professional (arabicmmlu/arabicmmlu_law_professional.yaml)
# 2026-06-05:21:32:57 INFO     [evaluator_utils:470]     Task: arabicmmlu_philosophy_high_school (arabicmmlu/arabicmmlu_philosophy_high_school.yaml)
# 2026-06-05:21:32:57 INFO     [evaluator_utils:462]   Group: arabicmmlu_stem
# 2026-06-05:21:32:57 INFO     [evaluator_utils:470]     Task: arabicmmlu_biology_high_school (arabicmmlu/arabicmmlu_biology_high_school.yaml)
# 2026-06-05:21:32:57 INFO     [evaluator_utils:470]     Task: arabicmmlu_computer_science_high_school (arabicmmlu/arabicmmlu_computer_science_high_school.yaml)
# 2026-06-05:21:32:57 INFO     [evaluator_utils:470]     Task: arabicmmlu_computer_science_middle_school (arabicmmlu/arabicmmlu_computer_science_middle_school.yaml)
# 2026-06-05:21:32:57 INFO     [evaluator_utils:470]     Task: arabicmmlu_computer_science_primary_school (arabicmmlu/arabicmmlu_computer_science_primary_school.yaml)
# 2026-06-05:21:32:57 INFO     [evaluator_utils:470]     Task: arabicmmlu_computer_science_university (arabicmmlu/arabicmmlu_computer_science_university.yaml)
# 2026-06-05:21:32:57 INFO     [evaluator_utils:470]     Task: arabicmmlu_math_primary_school (arabicmmlu/arabicmmlu_math_primary_school.yaml)
# 2026-06-05:21:32:57 INFO     [evaluator_utils:470]     Task: arabicmmlu_natural_science_middle_school (arabicmmlu/arabicmmlu_natural_science_middle_school.yaml)
# 2026-06-05:21:32:57 INFO     [evaluator_utils:470]     Task: arabicmmlu_natural_science_primary_school (arabicmmlu/arabicmmlu_natural_science_primary_school.yaml)
# 2026-06-05:21:32:57 INFO     [evaluator_utils:470]     Task: arabicmmlu_physics_high_school (arabicmmlu/arabicmmlu_physics_high_school.yaml)
# 2026-06-05:21:32:57 INFO     [evaluator_utils:462]   Group: arabicmmlu_language
# 2026-06-05:21:32:57 INFO     [evaluator_utils:470]     Task: arabicmmlu_arabic_language_general (arabicmmlu/arabicmmlu_arabic_language_general.yaml)
# 2026-06-05:21:32:57 INFO     [evaluator_utils:470]     Task: arabicmmlu_arabic_language_grammar (arabicmmlu/arabicmmlu_arabic_language_grammar.yaml)
# 2026-06-05:21:32:57 INFO     [evaluator_utils:470]     Task: arabicmmlu_arabic_language_high_school (arabicmmlu/arabicmmlu_arabic_language_high_school.yaml)
# 2026-06-05:21:32:57 INFO     [evaluator_utils:470]     Task: arabicmmlu_arabic_language_middle_school (arabicmmlu/arabicmmlu_arabic_language_middle_school.yaml)
# 2026-06-05:21:32:57 INFO     [evaluator_utils:470]     Task: arabicmmlu_arabic_language_primary_school (arabicmmlu/arabicmmlu_arabic_language_primary_school.yaml)
# 2026-06-05:21:32:57 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_driving_test from None to 0
# 2026-06-05:21:32:57 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_general_knowledge from None to 0
# 2026-06-05:21:32:57 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_general_knowledge_middle_school from None to 0
# 2026-06-05:21:32:57 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_general_knowledge_primary_school from None to 0
# 2026-06-05:21:32:57 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_management_university from None to 0
# 2026-06-05:21:32:57 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_accounting_university from None to 0
# 2026-06-05:21:32:57 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_civics_high_school from None to 0
# 2026-06-05:21:32:57 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_civics_middle_school from None to 0
# 2026-06-05:21:32:57 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_economics_high_school from None to 0
# 2026-06-05:21:32:57 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_economics_middle_school from None to 0
# 2026-06-05:21:32:57 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_economics_university from None to 0
# 2026-06-05:21:32:57 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_geography_high_school from None to 0
# 2026-06-05:21:32:57 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_geography_middle_school from None to 0
# 2026-06-05:21:32:57 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_geography_primary_school from None to 0
# 2026-06-05:21:32:57 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_political_science_university from None to 0
# 2026-06-05:21:32:57 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_social_science_middle_school from None to 0
# 2026-06-05:21:32:57 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_social_science_primary_school from None to 0
# 2026-06-05:21:32:57 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_history_high_school from None to 0
# 2026-06-05:21:32:57 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_history_middle_school from None to 0
# 2026-06-05:21:32:57 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_history_primary_school from None to 0
# 2026-06-05:21:32:57 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_islamic_studies from None to 0
# 2026-06-05:21:32:57 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_islamic_studies_high_school from None to 0
# 2026-06-05:21:32:57 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_islamic_studies_middle_school from None to 0
# 2026-06-05:21:32:57 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_islamic_studies_primary_school from None to 0
# 2026-06-05:21:32:57 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_law_professional from None to 0
# 2026-06-05:21:32:57 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_philosophy_high_school from None to 0
# 2026-06-05:21:32:57 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_biology_high_school from None to 0
# 2026-06-05:21:32:57 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_computer_science_high_school from None to 0
# 2026-06-05:21:32:57 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_computer_science_middle_school from None to 0
# 2026-06-05:21:32:57 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_computer_science_primary_school from None to 0
# 2026-06-05:21:32:57 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_computer_science_university from None to 0
# 2026-06-05:21:32:57 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_math_primary_school from None to 0
# 2026-06-05:21:32:57 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_natural_science_middle_school from None to 0
# 2026-06-05:21:32:57 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_natural_science_primary_school from None to 0
# 2026-06-05:21:32:57 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_physics_high_school from None to 0
# 2026-06-05:21:32:57 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_arabic_language_general from None to 0
# 2026-06-05:21:32:57 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_arabic_language_grammar from None to 0
# 2026-06-05:21:32:57 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_arabic_language_high_school from None to 0
# 2026-06-05:21:32:57 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_arabic_language_middle_school from None to 0
# 2026-06-05:21:32:57 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_arabic_language_primary_school from None to 0
# 2026-06-05:21:32:57 INFO     [api.task:312] Building contexts for arabicmmlu_driving_test on rank 0...
# 100%|██████████| 1211/1211 [00:00<00:00, 11783.31it/s]
# 2026-06-05:21:32:57 INFO     [api.task:312] Building contexts for arabicmmlu_general_knowledge on rank 0...
# 100%|██████████| 864/864 [00:00<00:00, 13484.05it/s]
# 2026-06-05:21:32:57 INFO     [api.task:312] Building contexts for arabicmmlu_general_knowledge_middle_school on rank 0...
# 100%|██████████| 172/172 [00:00<00:00, 13203.15it/s]
# 2026-06-05:21:32:57 INFO     [api.task:312] Building contexts for arabicmmlu_general_knowledge_primary_school on rank 0...
# 100%|██████████| 162/162 [00:00<00:00, 13343.23it/s]
# 2026-06-05:21:32:58 INFO     [api.task:312] Building contexts for arabicmmlu_management_university on rank 0...
# 100%|██████████| 75/75 [00:00<00:00, 12730.59it/s]
# 2026-06-05:21:32:58 INFO     [api.task:312] Building contexts for arabicmmlu_accounting_university on rank 0...
# 100%|██████████| 74/74 [00:00<00:00, 12852.11it/s]
# 2026-06-05:21:32:58 INFO     [api.task:312] Building contexts for arabicmmlu_civics_high_school on rank 0...
# 100%|██████████| 87/87 [00:00<00:00, 13107.67it/s]
# 2026-06-05:21:32:58 INFO     [api.task:312] Building contexts for arabicmmlu_civics_middle_school on rank 0...
# 100%|██████████| 236/236 [00:00<00:00, 13252.32it/s]
# 2026-06-05:21:32:58 INFO     [api.task:312] Building contexts for arabicmmlu_economics_high_school on rank 0...
# 100%|██████████| 360/360 [00:00<00:00, 13129.77it/s]
# 2026-06-05:21:32:58 INFO     [api.task:312] Building contexts for arabicmmlu_economics_middle_school on rank 0...
# 100%|██████████| 87/87 [00:00<00:00, 12755.33it/s]
# 2026-06-05:21:32:58 INFO     [api.task:312] Building contexts for arabicmmlu_economics_university on rank 0...
# 100%|██████████| 137/137 [00:00<00:00, 12784.67it/s]
# 2026-06-05:21:32:58 INFO     [api.task:312] Building contexts for arabicmmlu_geography_high_school on rank 0...
# 100%|██████████| 1038/1038 [00:00<00:00, 12956.44it/s]
# 2026-06-05:21:32:58 INFO     [api.task:312] Building contexts for arabicmmlu_geography_middle_school on rank 0...
# 100%|██████████| 272/272 [00:00<00:00, 12747.65it/s]
# 2026-06-05:21:32:58 INFO     [api.task:312] Building contexts for arabicmmlu_geography_primary_school on rank 0...
# 100%|██████████| 57/57 [00:00<00:00, 12364.26it/s]
# 2026-06-05:21:32:58 INFO     [api.task:312] Building contexts for arabicmmlu_political_science_university on rank 0...
# 100%|██████████| 210/210 [00:00<00:00, 12734.45it/s]
# 2026-06-05:21:32:58 INFO     [api.task:312] Building contexts for arabicmmlu_social_science_middle_school on rank 0...
# 100%|██████████| 241/241 [00:00<00:00, 11873.37it/s]
# 2026-06-05:21:32:58 INFO     [api.task:312] Building contexts for arabicmmlu_social_science_primary_school on rank 0...
# 100%|██████████| 705/705 [00:00<00:00, 13837.53it/s]
# 2026-06-05:21:32:58 INFO     [api.task:312] Building contexts for arabicmmlu_history_high_school on rank 0...
# 100%|██████████| 760/760 [00:00<00:00, 12924.60it/s]
# 2026-06-05:21:32:58 INFO     [api.task:312] Building contexts for arabicmmlu_history_middle_school on rank 0...
# 100%|██████████| 203/203 [00:00<00:00, 12951.29it/s]
# 2026-06-05:21:32:58 INFO     [api.task:312] Building contexts for arabicmmlu_history_primary_school on rank 0...
# 100%|██████████| 102/102 [00:00<00:00, 12445.64it/s]
# 2026-06-05:21:32:58 INFO     [api.task:312] Building contexts for arabicmmlu_islamic_studies on rank 0...
# 100%|██████████| 639/639 [00:00<00:00, 12206.52it/s]
# 2026-06-05:21:32:58 INFO     [api.task:312] Building contexts for arabicmmlu_islamic_studies_high_school on rank 0...
# 100%|██████████| 334/334 [00:00<00:00, 12611.72it/s]
# 2026-06-05:21:32:58 INFO     [api.task:312] Building contexts for arabicmmlu_islamic_studies_middle_school on rank 0...
# 100%|██████████| 238/238 [00:00<00:00, 12889.05it/s]
# 2026-06-05:21:32:58 INFO     [api.task:312] Building contexts for arabicmmlu_islamic_studies_primary_school on rank 0...
# 100%|██████████| 999/999 [00:00<00:00, 13512.82it/s]
# 2026-06-05:21:32:59 INFO     [api.task:312] Building contexts for arabicmmlu_law_professional on rank 0...
# 100%|██████████| 314/314 [00:00<00:00, 12855.54it/s]
# 2026-06-05:21:32:59 INFO     [api.task:312] Building contexts for arabicmmlu_philosophy_high_school on rank 0...
# 100%|██████████| 39/39 [00:00<00:00, 11995.15it/s]
# 2026-06-05:21:32:59 INFO     [api.task:312] Building contexts for arabicmmlu_biology_high_school on rank 0...
# 100%|██████████| 1409/1409 [00:00<00:00, 12852.34it/s]
# 2026-06-05:21:32:59 INFO     [api.task:312] Building contexts for arabicmmlu_computer_science_high_school on rank 0...
# 100%|██████████| 261/261 [00:00<00:00, 12477.07it/s]
# 2026-06-05:21:32:59 INFO     [api.task:312] Building contexts for arabicmmlu_computer_science_middle_school on rank 0...
# 100%|██████████| 27/27 [00:00<00:00, 10620.48it/s]
# 2026-06-05:21:32:59 INFO     [api.task:312] Building contexts for arabicmmlu_computer_science_primary_school on rank 0...
# 100%|██████████| 190/190 [00:00<00:00, 13509.14it/s]
# 2026-06-05:21:32:59 INFO     [api.task:312] Building contexts for arabicmmlu_computer_science_university on rank 0...
# 100%|██████████| 64/64 [00:00<00:00, 11171.31it/s]
# 2026-06-05:21:32:59 INFO     [api.task:312] Building contexts for arabicmmlu_math_primary_school on rank 0...
# 100%|██████████| 409/409 [00:00<00:00, 13611.17it/s]
# 2026-06-05:21:32:59 INFO     [api.task:312] Building contexts for arabicmmlu_natural_science_middle_school on rank 0...
# 100%|██████████| 242/242 [00:00<00:00, 12699.68it/s]
# 2026-06-05:21:32:59 INFO     [api.task:312] Building contexts for arabicmmlu_natural_science_primary_school on rank 0...
# 100%|██████████| 336/336 [00:00<00:00, 13238.95it/s]
# 2026-06-05:21:32:59 INFO     [api.task:312] Building contexts for arabicmmlu_physics_high_school on rank 0...
# 100%|██████████| 255/255 [00:00<00:00, 12814.17it/s]
# 2026-06-05:21:32:59 INFO     [api.task:312] Building contexts for arabicmmlu_arabic_language_general on rank 0...
# 100%|██████████| 612/612 [00:00<00:00, 11892.29it/s]
# 2026-06-05:21:32:59 INFO     [api.task:312] Building contexts for arabicmmlu_arabic_language_grammar on rank 0...
# 100%|██████████| 365/365 [00:00<00:00, 13270.93it/s]
# 2026-06-05:21:32:59 INFO     [api.task:312] Building contexts for arabicmmlu_arabic_language_high_school on rank 0...
# 100%|██████████| 390/390 [00:00<00:00, 13172.11it/s]
# 2026-06-05:21:32:59 INFO     [api.task:312] Building contexts for arabicmmlu_arabic_language_middle_school on rank 0...
# 100%|██████████| 27/27 [00:00<00:00, 11390.69it/s]
# 2026-06-05:21:32:59 INFO     [api.task:312] Building contexts for arabicmmlu_arabic_language_primary_school on rank 0...
# 100%|██████████| 252/252 [00:00<00:00, 13348.04it/s]
# 2026-06-05:21:33:00 INFO     [evaluator:585] Running loglikelihood requests
# Tokenizing inputs: 100%|██████████| 52291/52291 [00:43<00:00, 1192.56it/s]
# Running loglikelihood requests: 100%|██████████| 52291/52291 [15:48<00:00, 55.12it/s]
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# 2026-06-05:21:49:38 INFO     [loggers.evaluation_tracker:247] Saving results aggregated
# hf ({'pretrained': 'meta-llama/Llama-3.2-3B-Instruct', 'tokenizer': 'meta-llama/Llama-3.2-3B-Instruct', 'dtype': 'float16', 'parallelize': True, 'max_length': 4096}), gen_kwargs: ({}), limit: None, num_fewshot: 0, batch_size: 2
# |                Tasks                 |Version|Filter|n-shot|Metric|   |Value |   |Stderr|
# |--------------------------------------|------:|------|-----:|------|---|-----:|---|-----:|
# |arabicmmlu                            |      1|none  |      |acc   |   |0.3776|±  |0.0040|
# | - Humanities                         |      1|none  |     0|acc   |↑  |0.3878|±  |0.0080|
# |  - History (High School)             |      1|none  |     0|acc   |↑  |0.3421|±  |0.0172|
# |  - History (Middle School)           |      1|none  |     0|acc   |↑  |0.3350|±  |0.0332|
# |  - History (Primary School)          |      1|none  |     0|acc   |↑  |0.4020|±  |0.0488|
# |  - Islamic Studies                   |      1|none  |     0|acc   |↑  |0.3161|±  |0.0184|
# |  - Islamic Studies
# Cloning into '/kaggle/working/temp_git_repo'...
# Successfully pushed to MahmoudOsama20/EdgeCompress inside the 'Evaluations/BenchmarkEvaluations/ArabicEvaluations/Llama-3.2-3B-Instruct/Llama-3.2-3B-Instruct-Original/results/arabic_mmlu' folder!
# Done
# To https://github.com/MahmoudOsama20/EdgeCompress.git
#    be1a5fa..e1c5d1e  main -> main

# %% [markdown]
# # Save reports

# %%
zip_path = shutil.make_archive(
    "evaluation_results",   # zip file name
    "zip",                  # format
    "evaluation_results"    # folder to compress
)
