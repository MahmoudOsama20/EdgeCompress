# %% [markdown]
# # Libraries

# %%
# 0. Clean slate — remove existing copies before reinstalling
# !pip uninstall -y torch torchvision torchaudio torchao

# !pip install -q torch==2.10.0 torchvision==0.25.0 torchaudio==2.10.0 torchao==0.16.0 --index-url https://download.pytorch.org/whl/cu128

# 3. Evaluation Framework
# !pip install -q "lm_eval[hf]"

# !pip install -q "cuda-core==0.3.*" "numba-cuda[cu12]<0.23.0,>=0.22.2" "numba<0.62.0,>=0.60.0"

# !pip install -q transformers==4.57.6
# Out:
# Found existing installation: torch 2.10.0+cu128
# Uninstalling torch-2.10.0+cu128:
#   Successfully uninstalled torch-2.10.0+cu128
# Found existing installation: torchvision 0.25.0+cu128
# Uninstalling torchvision-0.25.0+cu128:
#   Successfully uninstalled torchvision-0.25.0+cu128
# Found existing installation: torchaudio 2.10.0+cu128
# Uninstalling torchaudio-2.10.0+cu128:
#   Successfully uninstalled torchaudio-2.10.0+cu128
# Found existing installation: torchao 0.10.0
# Uninstalling torchao-0.10.0:
#   Successfully uninstalled torchao-0.10.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 916.9/916.9 MB 2.1 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 105.3 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 60.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 2.2 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 5.4 MB/s eta 0:00:00:00:010:01m
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cuda 26.2.0 requires cuda-core==0.3.*, but you have cuda-core 1.0.1 which is incompatible.
# dask-cuda 26.2.0 requires numba-cuda<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# distributed-ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cuml-cu12 26.2.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cudf-cu12 26.2.1 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cudf-cu12 26.2.1 requires numba-cuda[cu12]<0.23.0,>=0.22.2, but you have numba-cuda 0.30.2 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.9/58.9 kB 1.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 72.4 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 5.1 MB/s eta 0:00:00
#   Building wheel for sqlitedict (setup.py) ... done
#   Building wheel for word2number (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 4.2 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 9.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 23.4 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 MB 36.4 MB/s eta 0:00:0000:0100:01m
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 46.7 MB/s eta 0:00:0000:0100:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.39.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# google-colab 1.0.0 requires jupyter-server==2.14.0, but you have jupyter-server 2.12.5 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# dopamine-rl 4.1.2 requires gym<=0.25.2, but you have gym 0.26.2 which is incompatible.
# moviepy 1.0.3 requires decorator<5.0,>=4.0.2, but you have decorator 5.3.1 which is incompatible.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.2.6 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 1.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 79.2 MB/s eta 0:00:00:00:01:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 31.6 MB/s eta 0:00:00

# %%
# Libraries
import gc
import glob
import shutil
import os
import random
import subprocess

import numpy as np
import torch
import lm_eval

from dataclasses import dataclass
from typing import Optional
from huggingface_hub import login
from IPython.display import FileLink
from kaggle_secrets import UserSecretsClient

# %% [markdown]
# # Global Variables

# %%
# --- Identity ---
user_name = "Abdelrahmanemam01"
email     = "abdulrahmanemam01@gmail.com"
repo      = "MahmoudOsama20/EdgeCompress"  # Fixed

# --- Model ---
model      = "Phi-4-mini-instruct"
MODEL_NAME       = "Phi-4-mini-instruct-Original"
MODEL_PRETRAINED = "microsoft/Phi-4-mini-instruct"
MODEL_PRETRAINED_FIX = MODEL_PRETRAINED.replace("/", "__")

# --- Reproducibility ---
SEED = 42

# --- Environment ---
os.environ["HF_ALLOW_CODE_EVAL"] = "1"

# %% [markdown]
# # Classes

# %%
@dataclass
class Task:
    key:               str
    name:              str
    category:          str
    num_fewshot:       int  = 0
    batch_size:        int  = 2
    limit:             Optional[int] = None
    apply_chat_template: bool = True
    max_gen_toks:      Optional[int] = None

# %% [markdown]
# # Functions

# %%
# REPRODUCIBILITY
def set_reproducibility(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    # Ensure deterministic behavior in CuDNN
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    print(f"Global seed set to {seed}")

# %% [markdown]
# # Seeding

# %%
set_reproducibility(SEED)
# Out:
# Global seed set to 42

# %% [markdown]
# # Huggingface login

# %%
# HUGGING FACE AUTHENTICATION
user_secrets = UserSecretsClient()
hf_token = user_secrets.get_secret("HF_TOKEN")
login(token=hf_token)
print("Logging into Hugging Face...")
# Out:
# Logging into Hugging Face...

# %% [markdown]
# # GitHub login

# %%
token = UserSecretsClient().get_secret("GIT_TOKEN")
print("Logging into GitHub...")
# Out:
# Logging into GitHub...

# %% [markdown]
# # Evaluations

# %% [markdown]
# **Configurations**

# %%
TASKS = [
    Task("arabic_mmlu",     "arabicmmlu",     "arabic_knowledge",   num_fewshot=0, batch_size=2),
]

# Model args
MODEL_ARGS = ",".join([
    f"pretrained={MODEL_PRETRAINED}",
    f"tokenizer={MODEL_PRETRAINED}",
    "dtype=float16",
    "parallelize=True",
    "max_length=4096",
])

results_dir = f"evaluation_results/{MODEL_NAME}"

# %% [markdown]
# **Evaluation loop**

# %%
for t in TASKS:
    print(f"\n[{t.category.upper()}] {t.key}")

    cmd = [
        "lm_eval",
        "--model",       "hf",
        "--model_args",  MODEL_ARGS,
        "--tasks",       t.name,
        "--num_fewshot", str(t.num_fewshot),
        "--batch_size",  str(t.batch_size),
        "--seed",        str(SEED),
        "--verbosity", "DEBUG",
        "--fewshot_as_multiturn",
        "--output_path", f"{results_dir}/{t.key}",
    ]

    if t.limit is not None:
        cmd += ["--limit", str(t.limit)]
        
    if t.apply_chat_template:
            cmd.append("--apply_chat_template")
        
    if t.max_gen_toks is not None:                             
        cmd += ["--gen_kwargs", f"max_gen_toks={t.max_gen_toks}"]

    subprocess.run(cmd, check=True)
    
    # Push To GitHub
    target_dir_in_repo = f"Evaluations/BenchmarkEvaluations/ArabicEvaluations/{model}/{MODEL_NAME}/results/{t.key}"
    source_folder = f"{results_dir}/{t.key}/{MODEL_PRETRAINED_FIX}"  # The Kaggle folder you want to upload
    remote_url = f"https://{token}@github.com/{repo}.git"
    
    # A temporary workspace in Kaggle to handle the cloning
    temp_repo_dir = "/kaggle/working/temp_git_repo" 
    # ---------------------

    # 2. Clean up any previous runs and clone the existing repository
    os.system(f"rm -rf {temp_repo_dir}")
    os.system(f"git clone {remote_url} {temp_repo_dir}")
    
    # 3. Create the target directory inside the cloned repo
    full_target_path = f"{temp_repo_dir}/{target_dir_in_repo}"
    os.makedirs(full_target_path, exist_ok=True)
    
    # 4. Copy the contents of your Kaggle folder into the target GitHub folder
    # (Using cp -r to recursively copy all files and subfolders)
    os.system(f"cp -r {source_folder}/* {full_target_path}/")
    
    # 5. Configure, commit, and push the changes
    os.system(f"""
        git -C {temp_repo_dir} config user.email "{email}" && \
        git -C {temp_repo_dir} config user.name "{user_name}" && \
        git -C {temp_repo_dir} add . && \
        git -C {temp_repo_dir} commit -m "Add Kaggle results to {target_dir_in_repo}" && \
        git -C {temp_repo_dir} push origin main
    """)
    
    print(f"Successfully pushed to {repo} inside the '{target_dir_in_repo}' folder!")
    
    torch.cuda.empty_cache()
    gc.collect()
    print("Done")
# Out:
# [ARABIC_KNOWLEDGE] arabic_mmlu
# 2026-06-05:21:17:39 INFO     [_cli.run:388] Selected Tasks: ['arabicmmlu']
# 2026-06-05:21:17:39 INFO     [evaluator:162] Setting verbosity through simple_evaluate is deprecated.
# 2026-06-05:21:17:41 INFO     [evaluator:214] Setting random seed to 42 | Setting numpy seed to 42 | Setting torch manual seed to 42 | Setting fewshot manual seed to 42
# 2026-06-05:21:17:41 INFO     [evaluator:239] Initializing hf model, with arguments: {'pretrained': 'microsoft/Phi-4-mini-instruct', 'tokenizer': 'microsoft/Phi-4-mini-instruct', 'dtype': 'float16', 'parallelize': True, 'max_length': 4096}
# 2026-06-05:21:17:47 INFO     [models.huggingface:306] Using `accelerate launch` or `parallelize=True`, device 'cuda:0' will be overridden when placing model.
# 2026-06-05:21:17:53 INFO     [models.huggingface:562] Model parallel was set to True, setting max memory per GPU to {0: 15525019648, 1: 15525019648} and device map to auto
# 2026-06-05 21:17:57.690963: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1780694278.108494     152 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1780694278.220709     152 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1780694279.190576     152 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780694279.190613     152 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780694279.190617     152 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780694279.190619     152 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Fetching 2 files: 100%|██████████| 2/2 [00:29<00:00, 14.70s/it]
# Loading checkpoint shards: 100%|██████████| 2/2 [00:07<00:00,  3.70s/it]
# Generating test split: 100%|██████████| 1211/1211 [00:00<00:00, 8240.38 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 121.76 examples/s]
# Generating test split: 100%|██████████| 864/864 [00:00<00:00, 70565.25 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 569.47 examples/s]
# Generating test split: 100%|██████████| 172/172 [00:00<00:00, 17746.24 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 526.77 examples/s]
# Generating test split: 100%|██████████| 162/162 [00:00<00:00, 24882.90 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 653.01 examples/s]
# Generating test split: 100%|██████████| 75/75 [00:00<00:00, 12855.97 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 529.49 examples/s]
# Generating test split: 100%|██████████| 74/74 [00:00<00:00, 12931.90 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 388.90 examples/s]
# Generating test split: 100%|██████████| 87/87 [00:00<00:00, 15299.34 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 748.72 examples/s]
# Generating test split: 100%|██████████| 236/236 [00:00<00:00, 29524.14 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 646.60 examples/s]
# Generating test split: 100%|██████████| 360/360 [00:00<00:00, 41397.97 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 766.74 examples/s]
# Generating test split: 100%|██████████| 87/87 [00:00<00:00, 15969.56 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 765.29 examples/s]
# Generating test split: 100%|██████████| 137/137 [00:00<00:00, 22956.32 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 797.95 examples/s]
# Generating test split: 100%|██████████| 1038/1038 [00:00<00:00, 63595.55 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 625.14 examples/s]
# Generating test split: 100%|██████████| 272/272 [00:00<00:00, 38863.93 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 619.76 examples/s]
# Generating test split: 100%|██████████| 57/57 [00:00<00:00, 11521.15 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 741.17 examples/s]
# Generating test split: 100%|██████████| 210/210 [00:00<00:00, 31594.94 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 776.48 examples/s]
# Generating test split: 100%|██████████| 241/241 [00:00<00:00, 32465.95 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 750.46 examples/s]
# Generating test split: 100%|██████████| 705/705 [00:00<00:00, 80752.21 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 631.26 examples/s]
# Generating test split: 100%|██████████| 760/760 [00:00<00:00, 60615.94 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 759.88 examples/s]
# Generating test split: 100%|██████████| 203/203 [00:00<00:00, 31494.13 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 768.99 examples/s]
# Generating test split: 100%|██████████| 102/102 [00:00<00:00, 19092.24 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 727.50 examples/s]
# Generating test split: 100%|██████████| 639/639 [00:00<00:00, 69337.20 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 812.85 examples/s]
# Generating test split: 100%|██████████| 334/334 [00:00<00:00, 42915.71 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 625.89 examples/s]
# Generating test split: 100%|██████████| 238/238 [00:00<00:00, 35024.89 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 766.18 examples/s]
# Generating test split: 100%|██████████| 999/999 [00:00<00:00, 81673.78 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 615.15 examples/s]
# Generating test split: 100%|██████████| 314/314 [00:00<00:00, 37690.28 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 783.35 examples/s]
# Generating test split: 100%|██████████| 39/39 [00:00<00:00, 8297.97 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 843.98 examples/s]
# Generating test split: 100%|██████████| 1409/1409 [00:00<00:00, 66833.75 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 483.98 examples/s]
# Generating test split: 100%|██████████| 261/261 [00:00<00:00, 38169.92 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 714.53 examples/s]
# Generating test split: 100%|██████████| 27/27 [00:00<00:00, 5601.81 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 765.57 examples/s]
# Generating test split: 100%|██████████| 190/190 [00:00<00:00, 33075.36 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 625.61 examples/s]
# Generating test split: 100%|██████████| 64/64 [00:00<00:00, 12681.19 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 776.05 examples/s]
# Generating test split: 100%|██████████| 409/409 [00:00<00:00, 60459.24 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 706.03 examples/s]
# Generating test split: 100%|██████████| 242/242 [00:00<00:00, 34400.51 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 756.68 examples/s]
# Generating test split: 100%|██████████| 336/336 [00:00<00:00, 44182.40 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 774.86 examples/s]
# Generating test split: 100%|██████████| 255/255 [00:00<00:00, 34911.46 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 776.96 examples/s]
# Generating test split: 100%|██████████| 612/612 [00:00<00:00, 18266.47 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 582.70 examples/s]
# Generating test split: 100%|██████████| 365/365 [00:00<00:00, 46609.05 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 679.72 examples/s]
# Generating test split: 100%|██████████| 390/390 [00:00<00:00, 42623.93 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 611.59 examples/s]
# Generating test split: 100%|██████████| 27/27 [00:00<00:00, 4720.95 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 795.88 examples/s]
# Generating test split: 100%|██████████| 252/252 [00:00<00:00, 39711.62 examples/s]
# Generating dev split: 100%|██████████| 3/3 [00:00<00:00, 653.59 examples/s]
# 2026-06-05:21:19:25 INFO     [evaluator_utils:446] Selected tasks:
# 2026-06-05:21:19:25 INFO     [evaluator_utils:462] Group: arabicmmlu
# 2026-06-05:21:19:25 INFO     [evaluator_utils:462]   Group: arabicmmlu_other
# 2026-06-05:21:19:25 INFO     [evaluator_utils:470]     Task: arabicmmlu_driving_test (arabicmmlu/arabicmmlu_driving_test.yaml)
# 2026-06-05:21:19:25 INFO     [evaluator_utils:470]     Task: arabicmmlu_general_knowledge (arabicmmlu/arabicmmlu_general_knowledge.yaml)
# 2026-06-05:21:19:25 INFO     [evaluator_utils:470]     Task: arabicmmlu_general_knowledge_middle_school (arabicmmlu/arabicmmlu_general_knowledge_middle_school.yaml)
# 2026-06-05:21:19:25 INFO     [evaluator_utils:470]     Task: arabicmmlu_general_knowledge_primary_school (arabicmmlu/arabicmmlu_general_knowledge_primary_school.yaml)
# 2026-06-05:21:19:25 INFO     [evaluator_utils:470]     Task: arabicmmlu_management_university (arabicmmlu/arabicmmlu_management_university.yaml)
# 2026-06-05:21:19:25 INFO     [evaluator_utils:462]   Group: arabicmmlu_social_science
# 2026-06-05:21:19:25 INFO     [evaluator_utils:470]     Task: arabicmmlu_accounting_university (arabicmmlu/arabicmmlu_accounting_university.yaml)
# 2026-06-05:21:19:25 INFO     [evaluator_utils:470]     Task: arabicmmlu_civics_high_school (arabicmmlu/arabicmmlu_civics_high_school.yaml)
# 2026-06-05:21:19:25 INFO     [evaluator_utils:470]     Task: arabicmmlu_civics_middle_school (arabicmmlu/arabicmmlu_civics_middle_school.yaml)
# 2026-06-05:21:19:25 INFO     [evaluator_utils:470]     Task: arabicmmlu_economics_high_school (arabicmmlu/arabicmmlu_economics_high_school.yaml)
# 2026-06-05:21:19:25 INFO     [evaluator_utils:470]     Task: arabicmmlu_economics_middle_school (arabicmmlu/arabicmmlu_economics_middle_school.yaml)
# 2026-06-05:21:19:25 INFO     [evaluator_utils:470]     Task: arabicmmlu_economics_university (arabicmmlu/arabicmmlu_economics_university.yaml)
# 2026-06-05:21:19:25 INFO     [evaluator_utils:470]     Task: arabicmmlu_geography_high_school (arabicmmlu/arabicmmlu_geography_high_school.yaml)
# 2026-06-05:21:19:25 INFO     [evaluator_utils:470]     Task: arabicmmlu_geography_middle_school (arabicmmlu/arabicmmlu_geography_middle_school.yaml)
# 2026-06-05:21:19:25 INFO     [evaluator_utils:470]     Task: arabicmmlu_geography_primary_school (arabicmmlu/arabicmmlu_geography_primary_school.yaml)
# 2026-06-05:21:19:25 INFO     [evaluator_utils:470]     Task: arabicmmlu_political_science_university (arabicmmlu/arabicmmlu_political_science_university.yaml)
# 2026-06-05:21:19:25 INFO     [evaluator_utils:470]     Task: arabicmmlu_social_science_middle_school (arabicmmlu/arabicmmlu_social_science_middle_school.yaml)
# 2026-06-05:21:19:25 INFO     [evaluator_utils:470]     Task: arabicmmlu_social_science_primary_school (arabicmmlu/arabicmmlu_social_science_primary_school.yaml)
# 2026-06-05:21:19:25 INFO     [evaluator_utils:462]   Group: arabicmmlu_humanities
# 2026-06-05:21:19:25 INFO     [evaluator_utils:470]     Task: arabicmmlu_history_high_school (arabicmmlu/arabicmmlu_history_high_school.yaml)
# 2026-06-05:21:19:25 INFO     [evaluator_utils:470]     Task: arabicmmlu_history_middle_school (arabicmmlu/arabicmmlu_history_middle_school.yaml)
# 2026-06-05:21:19:25 INFO     [evaluator_utils:470]     Task: arabicmmlu_history_primary_school (arabicmmlu/arabicmmlu_history_primary_school.yaml)
# 2026-06-05:21:19:25 INFO     [evaluator_utils:470]     Task: arabicmmlu_islamic_studies (arabicmmlu/arabicmmlu_islamic_studies.yaml)
# 2026-06-05:21:19:25 INFO     [evaluator_utils:470]     Task: arabicmmlu_islamic_studies_high_school (arabicmmlu/arabicmmlu_islamic_studies_high_school.yaml)
# 2026-06-05:21:19:25 INFO     [evaluator_utils:470]     Task: arabicmmlu_islamic_studies_middle_school (arabicmmlu/arabicmmlu_islamic_studies_middle_school.yaml)
# 2026-06-05:21:19:25 INFO     [evaluator_utils:470]     Task: arabicmmlu_islamic_studies_primary_school (arabicmmlu/arabicmmlu_islamic_studies_primary_school.yaml)
# 2026-06-05:21:19:25 INFO     [evaluator_utils:470]     Task: arabicmmlu_law_professional (arabicmmlu/arabicmmlu_law_professional.yaml)
# 2026-06-05:21:19:25 INFO     [evaluator_utils:470]     Task: arabicmmlu_philosophy_high_school (arabicmmlu/arabicmmlu_philosophy_high_school.yaml)
# 2026-06-05:21:19:25 INFO     [evaluator_utils:462]   Group: arabicmmlu_stem
# 2026-06-05:21:19:25 INFO     [evaluator_utils:470]     Task: arabicmmlu_biology_high_school (arabicmmlu/arabicmmlu_biology_high_school.yaml)
# 2026-06-05:21:19:25 INFO     [evaluator_utils:470]     Task: arabicmmlu_computer_science_high_school (arabicmmlu/arabicmmlu_computer_science_high_school.yaml)
# 2026-06-05:21:19:25 INFO     [evaluator_utils:470]     Task: arabicmmlu_computer_science_middle_school (arabicmmlu/arabicmmlu_computer_science_middle_school.yaml)
# 2026-06-05:21:19:25 INFO     [evaluator_utils:470]     Task: arabicmmlu_computer_science_primary_school (arabicmmlu/arabicmmlu_computer_science_primary_school.yaml)
# 2026-06-05:21:19:25 INFO     [evaluator_utils:470]     Task: arabicmmlu_computer_science_university (arabicmmlu/arabicmmlu_computer_science_university.yaml)
# 2026-06-05:21:19:25 INFO     [evaluator_utils:470]     Task: arabicmmlu_math_primary_school (arabicmmlu/arabicmmlu_math_primary_school.yaml)
# 2026-06-05:21:19:25 INFO     [evaluator_utils:470]     Task: arabicmmlu_natural_science_middle_school (arabicmmlu/arabicmmlu_natural_science_middle_school.yaml)
# 2026-06-05:21:19:25 INFO     [evaluator_utils:470]     Task: arabicmmlu_natural_science_primary_school (arabicmmlu/arabicmmlu_natural_science_primary_school.yaml)
# 2026-06-05:21:19:25 INFO     [evaluator_utils:470]     Task: arabicmmlu_physics_high_school (arabicmmlu/arabicmmlu_physics_high_school.yaml)
# 2026-06-05:21:19:25 INFO     [evaluator_utils:462]   Group: arabicmmlu_language
# 2026-06-05:21:19:25 INFO     [evaluator_utils:470]     Task: arabicmmlu_arabic_language_general (arabicmmlu/arabicmmlu_arabic_language_general.yaml)
# 2026-06-05:21:19:25 INFO     [evaluator_utils:470]     Task: arabicmmlu_arabic_language_grammar (arabicmmlu/arabicmmlu_arabic_language_grammar.yaml)
# 2026-06-05:21:19:25 INFO     [evaluator_utils:470]     Task: arabicmmlu_arabic_language_high_school (arabicmmlu/arabicmmlu_arabic_language_high_school.yaml)
# 2026-06-05:21:19:25 INFO     [evaluator_utils:470]     Task: arabicmmlu_arabic_language_middle_school (arabicmmlu/arabicmmlu_arabic_language_middle_school.yaml)
# 2026-06-05:21:19:25 INFO     [evaluator_utils:470]     Task: arabicmmlu_arabic_language_primary_school (arabicmmlu/arabicmmlu_arabic_language_primary_school.yaml)
# 2026-06-05:21:19:25 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_driving_test from None to 0
# 2026-06-05:21:19:25 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_general_knowledge from None to 0
# 2026-06-05:21:19:25 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_general_knowledge_middle_school from None to 0
# 2026-06-05:21:19:25 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_general_knowledge_primary_school from None to 0
# 2026-06-05:21:19:25 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_management_university from None to 0
# 2026-06-05:21:19:25 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_accounting_university from None to 0
# 2026-06-05:21:19:25 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_civics_high_school from None to 0
# 2026-06-05:21:19:25 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_civics_middle_school from None to 0
# 2026-06-05:21:19:25 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_economics_high_school from None to 0
# 2026-06-05:21:19:25 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_economics_middle_school from None to 0
# 2026-06-05:21:19:25 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_economics_university from None to 0
# 2026-06-05:21:19:25 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_geography_high_school from None to 0
# 2026-06-05:21:19:25 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_geography_middle_school from None to 0
# 2026-06-05:21:19:25 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_geography_primary_school from None to 0
# 2026-06-05:21:19:25 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_political_science_university from None to 0
# 2026-06-05:21:19:25 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_social_science_middle_school from None to 0
# 2026-06-05:21:19:25 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_social_science_primary_school from None to 0
# 2026-06-05:21:19:25 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_history_high_school from None to 0
# 2026-06-05:21:19:25 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_history_middle_school from None to 0
# 2026-06-05:21:19:25 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_history_primary_school from None to 0
# 2026-06-05:21:19:25 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_islamic_studies from None to 0
# 2026-06-05:21:19:25 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_islamic_studies_high_school from None to 0
# 2026-06-05:21:19:25 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_islamic_studies_middle_school from None to 0
# 2026-06-05:21:19:25 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_islamic_studies_primary_school from None to 0
# 2026-06-05:21:19:25 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_law_professional from None to 0
# 2026-06-05:21:19:25 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_philosophy_high_school from None to 0
# 2026-06-05:21:19:25 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_biology_high_school from None to 0
# 2026-06-05:21:19:25 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_computer_science_high_school from None to 0
# 2026-06-05:21:19:25 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_computer_science_middle_school from None to 0
# 2026-06-05:21:19:25 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_computer_science_primary_school from None to 0
# 2026-06-05:21:19:25 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_computer_science_university from None to 0
# 2026-06-05:21:19:25 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_math_primary_school from None to 0
# 2026-06-05:21:19:25 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_natural_science_middle_school from None to 0
# 2026-06-05:21:19:25 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_natural_science_primary_school from None to 0
# 2026-06-05:21:19:25 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_physics_high_school from None to 0
# 2026-06-05:21:19:25 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_arabic_language_general from None to 0
# 2026-06-05:21:19:25 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_arabic_language_grammar from None to 0
# 2026-06-05:21:19:25 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_arabic_language_high_school from None to 0
# 2026-06-05:21:19:25 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_arabic_language_middle_school from None to 0
# 2026-06-05:21:19:25 WARNING  [evaluator:333] Overwriting default num_fewshot of arabicmmlu_arabic_language_primary_school from None to 0
# 2026-06-05:21:19:25 INFO     [api.task:312] Building contexts for arabicmmlu_driving_test on rank 0...
# 100%|██████████| 1211/1211 [00:00<00:00, 15659.36it/s]
# 2026-06-05:21:19:26 INFO     [api.task:312] Building contexts for arabicmmlu_general_knowledge on rank 0...
# 100%|██████████| 864/864 [00:00<00:00, 17300.64it/s]
# 2026-06-05:21:19:26 INFO     [api.task:312] Building contexts for arabicmmlu_general_knowledge_middle_school on rank 0...
# 100%|██████████| 172/172 [00:00<00:00, 17806.25it/s]
# 2026-06-05:21:19:26 INFO     [api.task:312] Building contexts for arabicmmlu_general_knowledge_primary_school on rank 0...
# 100%|██████████| 162/162 [00:00<00:00, 17402.41it/s]
# 2026-06-05:21:19:26 INFO     [api.task:312] Building contexts for arabicmmlu_management_university on rank 0...
# 100%|██████████| 75/75 [00:00<00:00, 16977.32it/s]
# 2026-06-05:21:19:26 INFO     [api.task:312] Building contexts for arabicmmlu_accounting_university on rank 0...
# 100%|██████████| 74/74 [00:00<00:00, 14126.74it/s]
# 2026-06-05:21:19:26 INFO     [api.task:312] Building contexts for arabicmmlu_civics_high_school on rank 0...
# 100%|██████████| 87/87 [00:00<00:00, 17005.52it/s]
# 2026-06-05:21:19:26 INFO     [api.task:312] Building contexts for arabicmmlu_civics_middle_school on rank 0...
# 100%|██████████| 236/236 [00:00<00:00, 16466.31it/s]
# 2026-06-05:21:19:26 INFO     [api.task:312] Building contexts for arabicmmlu_economics_high_school on rank 0...
# 100%|██████████| 360/360 [00:00<00:00, 16670.16it/s]
# 2026-06-05:21:19:26 INFO     [api.task:312] Building contexts for arabicmmlu_economics_middle_school on rank 0...
# 100%|██████████| 87/87 [00:00<00:00, 16294.74it/s]
# 2026-06-05:21:19:26 INFO     [api.task:312] Building contexts for arabicmmlu_economics_university on rank 0...
# 100%|██████████| 137/137 [00:00<00:00, 17071.29it/s]
# 2026-06-05:21:19:26 INFO     [api.task:312] Building contexts for arabicmmlu_geography_high_school on rank 0...
# 100%|██████████| 1038/1038 [00:00<00:00, 17389.01it/s]
# 2026-06-05:21:19:26 INFO     [api.task:312] Building contexts for arabicmmlu_geography_middle_school on rank 0...
# 100%|██████████| 272/272 [00:00<00:00, 17661.59it/s]
# 2026-06-05:21:19:26 INFO     [api.task:312] Building contexts for arabicmmlu_geography_primary_school on rank 0...
# 100%|██████████| 57/57 [00:00<00:00, 14644.74it/s]
# 2026-06-05:21:19:26 INFO     [api.task:312] Building contexts for arabicmmlu_political_science_university on rank 0...
# 100%|██████████| 210/210 [00:00<00:00, 17965.69it/s]
# 2026-06-05:21:19:26 INFO     [api.task:312] Building contexts for arabicmmlu_social_science_middle_school on rank 0...
# 100%|██████████| 241/241 [00:00<00:00, 17214.36it/s]
# 2026-06-05:21:19:26 INFO     [api.task:312] Building contexts for arabicmmlu_social_science_primary_school on rank 0...
# 100%|██████████| 705/705 [00:00<00:00, 17666.51it/s]
# 2026-06-05:21:19:26 INFO     [api.task:312] Building contexts for arabicmmlu_history_high_school on rank 0...
# 100%|██████████| 760/760 [00:00<00:00, 16547.47it/s]
# 2026-06-05:21:19:26 INFO     [api.task:312] Building contexts for arabicmmlu_history_middle_school on rank 0...
# 100%|██████████| 203/203 [00:00<00:00, 16727.77it/s]
# 2026-06-05:21:19:26 INFO     [api.task:312] Building contexts for arabicmmlu_history_primary_school on rank 0...
# 100%|██████████| 102/102 [00:00<00:00, 14419.25it/s]
# 2026-06-05:21:19:27 INFO     [api.task:312] Building contexts for arabicmmlu_islamic_studies on rank 0...
# 100%|██████████| 639/639 [00:00<00:00, 17689.78it/s]
# 2026-06-05:21:19:27 INFO     [api.task:312] Building contexts for arabicmmlu_islamic_studies_high_school on rank 0...
# 100%|██████████| 334/334 [00:00<00:00, 17093.08it/s]
# 2026-06-05:21:19:27 INFO     [api.task:312] Building contexts for arabicmmlu_islamic_studies_middle_school on rank 0...
# 100%|██████████| 238/238 [00:00<00:00, 18272.49it/s]
# 2026-06-05:21:19:27 INFO     [api.task:312] Building contexts for arabicmmlu_islamic_studies_primary_school on rank 0...
# 100%|██████████| 999/999 [00:00<00:00, 18310.14it/s]
# 2026-06-05:21:19:27 INFO     [api.task:312] Building contexts for arabicmmlu_law_professional on rank 0...
# 100%|██████████| 314/314 [00:00<00:00, 16763.76it/s]
# 2026-06-05:21:19:27 INFO     [api.task:312] Building contexts for arabicmmlu_philosophy_high_school on rank 0...
# 100%|██████████| 39/39 [00:00<00:00, 15493.26it/s]
# 2026-06-05:21:19:27 INFO     [api.task:312] Building contexts for arabicmmlu_biology_high_school on rank 0...
# 100%|██████████| 1409/1409 [00:00<00:00, 17783.92it/s]
# 2026-06-05:21:19:27 INFO     [api.task:312] Building contexts for arabicmmlu_computer_science_high_school on rank 0...
# 100%|██████████| 261/261 [00:00<00:00, 17368.13it/s]
# 2026-06-05:21:19:27 INFO     [api.task:312] Building contexts for arabicmmlu_computer_science_middle_school on rank 0...
# 100%|██████████| 27/27 [00:00<00:00, 15579.34it/s]
# 2026-06-05:21:19:27 INFO     [api.task:312] Building contexts for arabicmmlu_computer_science_primary_school on rank 0...
# 100%|██████████| 190/190 [00:00<00:00, 18367.66it/s]
# 2026-06-05:21:19:27 INFO     [api.task:312] Building contexts for arabicmmlu_computer_science_university on rank 0...
# 100%|██████████| 64/64 [00:00<00:00, 14749.20it/s]
# 2026-06-05:21:19:27 INFO     [api.task:312] Building contexts for arabicmmlu_math_primary_school on rank 0...
# 100%|██████████| 409/409 [00:00<00:00, 17403.04it/s]
# 2026-06-05:21:19:27 INFO     [api.task:312] Building contexts for arabicmmlu_natural_science_middle_school on rank 0...
# 100%|██████████| 242/242 [00:00<00:00, 17993.01it/s]
# 2026-06-05:21:19:27 INFO     [api.task:312] Building contexts for arabicmmlu_natural_science_primary_school on rank 0...
# 100%|██████████| 336/336 [00:00<00:00, 17863.71it/s]
# 2026-06-05:21:19:27 INFO     [api.task:312] Building contexts for arabicmmlu_physics_high_school on rank 0...
# 100%|██████████| 255/255 [00:00<00:00, 17589.80it/s]
# 2026-06-05:21:19:27 INFO     [api.task:312] Building contexts for arabicmmlu_arabic_language_general on rank 0...
# 100%|██████████| 612/612 [00:00<00:00, 16591.14it/s]
# 2026-06-05:21:19:27 INFO     [api.task:312] Building contexts for arabicmmlu_arabic_language_grammar on rank 0...
# 100%|██████████| 365/365 [00:00<00:00, 17527.29it/s]
# 2026-06-05:21:19:28 INFO     [api.task:312] Building contexts for arabicmmlu_arabic_language_high_school on rank 0...
# 100%|██████████| 390/390 [00:00<00:00, 17814.67it/s]
# 2026-06-05:21:19:28 INFO     [api.task:312] Building contexts for arabicmmlu_arabic_language_middle_school on rank 0...
# 100%|██████████| 27/27 [00:00<00:00, 12619.37it/s]
# 2026-06-05:21:19:28 INFO     [api.task:312] Building contexts for arabicmmlu_arabic_language_primary_school on rank 0...
# 100%|██████████| 252/252 [00:00<00:00, 18390.95it/s]
# 2026-06-05:21:19:28 INFO     [evaluator:585] Running loglikelihood requests
# Tokenizing inputs: 100%|██████████| 52291/52291 [00:36<00:00, 1413.33it/s]
# Running loglikelihood requests: 100%|██████████| 52291/52291 [15:35<00:00, 55.90it/s]
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# 2026-06-05:21:35:46 INFO     [loggers.evaluation_tracker:247] Saving results aggregated
# hf ({'pretrained': 'microsoft/Phi-4-mini-instruct', 'tokenizer': 'microsoft/Phi-4-mini-instruct', 'dtype': 'float16', 'parallelize': True, 'max_length': 4096}), gen_kwargs: ({}), limit: None, num_fewshot: 0, batch_size: 2
# |                Tasks                 |Version|Filter|n-shot|Metric|   |Value |   |Stderr|
# |--------------------------------------|------:|------|-----:|------|---|-----:|---|-----:|
# |arabicmmlu                            |      1|none  |      |acc   |   |0.4791|±  |0.0041|
# | - Humanities                         |      1|none  |     0|acc   |↑  |0.4633|±  |0.0080|
# |  - History (High School)             |      1|none  |     0|acc   |↑  |0.3579|±  |0.0174|
# |  - History (Middle School)           |      1|none  |     0|acc   |↑  |0.4975|±  |0.0352|
# |  - History (Primary School)          |      1|none  |     0|acc   |↑  |0.4118|±  |0.0490|
# |  - Islamic Studies                   |      1|none  |     0|acc   |↑  |0.3302|±  |0.0186|
# |  - Islamic Studies (High School)     |      1|none  |     0|acc   |↑  |0.5928|±  |0.0269|
# |  - Islamic Studies (Middle School)   |      1|none  |     0|acc   |↑  |0.5588|±  |0.0323|
# |  - Islamic Studies (Primary School)  |      1|none  |     0|acc   |↑  |0.6256|±  |0.0153|
# |  - Law (Professional)                |      1|none  |     0|acc   |↑  |0.2643|±  |0.0249|
# |  - Philosophy (High School)          |      1|none  |     0|acc   |↑  |0.4103|±  |0.0798|
# | - Language                           |      1|none  |     0|acc   |↑  |0.4860|±  |0.0120|
# |  - Arabic Language (General)         |      1|none  |     0|acc   |↑  |0.5964|±  |0.0198|
# |  - Arabic Language (Grammar)         |      1|none  |     0|acc   |↑  |0.4247|±  |0.0259|
# |  - Arabic Language (High School)     |      1|none  |     0|acc   |↑  |0.3308|±  |0.0239|
# |  - Arabic Language (Middle School)   |      1|none  |     0|acc   |↑  |0.4815|±  |0.0980|
# |  - Arabic Language (Primary School)  |      1|none  |     0|acc   |↑  |0.5476|±  |0.0314|
# | - Other                              |      1|none  |     0|acc   |↑  |0.5145|±  |0.0100|
# |  - Driving Test                      |      1|none  |     0|acc   |↑  |0.5483|±  |0.0143|
# |  - General Knowledge                 |      1|none  |     0|acc   |↑  |0.4468|±  |0.0169|
# |  - General Knowledge (Middle School) |      1|none  |     0|acc   |↑  |0.5058|±  |0.0382|
# |  - General Knowledge (Primary School)|      1|none  |     0|acc   |↑  |0.5741|±  |0.0390|
# |  - Management (University)           |      1|none  |     0|acc   |↑  |0.6400|±  |0.0558|
# | - Social Science                     |      1|none  |     0|acc   |↑  |0.4806|±  |0.0083|
# |  - Accounting (University)           |      1|none  |     0|acc   |↑  |0.5000|±  |0.0585|
# |  - Civics (High School)              |      1|none  |     0|acc   |↑  |0.4598|±  |0.0537|
# |  - Civics (Middle School)            |      1|none  |     0|acc   |↑  |0.3941|±  |0.0319|
# |  - Economics (High School)           |      1|none  |     0|acc   |↑  |0.4972|±  |0.0264|
# |  - Economics (Middle School)         |      1|none  |     0|acc   |↑  |0.6897|±  |0.0499|
# |  - Economics (University)            |      1|none  |     0|acc   |↑  |0.5036|±  |0.0429|
# |  - Geography (High School)           |      1|none  |     0|acc   |↑  |0.4104|±  |0.0153|
# |  - Geography (Middle School)         |      1|none  |     0|acc   |↑  |0.5147|±  |0.0304|
# |  - Geography (Primary School)        |      1|none  |     0|acc   |↑  |0.4737|±  |0.0667|
# |  - Political Science (University)    |      1|none  |     0|acc   |↑  |0.4190|±  |0.0341|
# |  - Social Science (Middle School)    |      1|none  |     0|acc   |↑  |0.4315|±  |0.0320|
# |  - Social Science (Primary School)   |      1|none  |     0|acc   |↑  |0.5972|±  |0.0185|
# | - STEM                               |      1|none  |     0|acc   |↑  |0.4645|±  |0.0086|
# |  - Biology (High School)             |      1|none  |     0|acc   |↑  |0.3754|±  |0.0129|
# |  - Computer Science (High School)    |      1|none  |     0|acc   |↑  |0.5134|±  |0.0310|
# |  - Computer Science (Middle School)  |      1|none  |     0|acc   |↑  |0.7778|±  |0.0815|
# |  - Computer Science (Primary School) |      1|none  |     0|acc   |↑  |0.5947|±  |0.0357|
# |  - Computer Science (University)     |      1|none  |     0|acc   |↑  |0.5469|±  |0.0627|
# |  - Math (Primary School)             |      1|none  |     0|acc   |↑  |0.5134|±  |0.0247|
# |  - Natural Science (Middle School)   |      1|none  |     0|acc   |↑  |0.5579|±  |0.0320|
# |  - Natural Science (Primary School)  |      1|none  |     0|acc   |↑  |0.6488|±  |0.0261|
# |  - Physics (High School)             |      1|none  |     0|acc   |↑  |0.3451|±  |0.0298|
#
# |     Groups      |Version|Filter|n-shot|Metric|   |Value |   |Stderr|
# |-----------------|------:|------|-----:|------|---|-----:|---|-----:|
# |arabicmmlu       |      1|none  |      |acc   |   |0.4791|±  |0.0041|
# | - Humanities    |      1|none  |     0|acc   |↑  |0.4633|±  |0.0080|
# | - Language      |      1|none  |     0|acc   |↑  |0.4860|±  |0.0120|
# | - Other         |      1|none  |     0|acc   |↑  |0.5145|±  |0.0100|
# | - Social Science|      1|none  |     0|acc   |↑  |0.4806|±  |0.0083|
# | - STEM          |      1|none  |     0|acc   |↑  |0.4645|±  |0.0086|
# Cloning into '/kaggle/working/temp_git_repo'...
# [main be1a5fa] Add Kaggle results to Evaluations/BenchmarkEvaluations/ArabicEvaluations/Phi-4-mini-instruct/Phi-4-mini-instruct-Original/results/arabic_mmlu
#  1 file changed, 2836 insertions(+)
#  create mode 100644 Evaluations/BenchmarkEvaluations/ArabicEvaluations/Phi-4-mini-instruct/Phi-4-mini-instruct-Original/results/arabic_mmlu/results_2026-06-05T21-35-46.644637.json
# Successfully pushed to MahmoudOsama20/EdgeCompress inside the 'Evaluations/BenchmarkEvaluations/ArabicEvaluations/Phi-4-mini-instruct/Phi-4-mini-instruct-Original/results/arabic_mmlu' folder!
# Done
# To https://github.com/MahmoudOsama20/EdgeCompress.git
#    abea15f..be1a5fa  main -> main

# %% [markdown]
# # Save reports

# %%
zip_path = shutil.make_archive(
    "evaluation_results",   # zip file name
    "zip",                  # format
    "evaluation_results"    # folder to compress
)
