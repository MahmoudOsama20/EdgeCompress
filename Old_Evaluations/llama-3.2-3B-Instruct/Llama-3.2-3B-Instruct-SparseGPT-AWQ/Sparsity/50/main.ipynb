# %% [markdown]
# # Libraries

# %%
# !pip -q install "lm_eval[hf]"
# !pip -q install compressed-tensors
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.4/56.4 kB 3.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 98.9 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 5.4 MB/s eta 0:00:00
#   Building wheel for sqlitedict (setup.py) ... done
#   Building wheel for word2number (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.5/196.5 kB 11.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 22.2 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 33.5 MB/s eta 0:00:00

# %%
# 2. Libraries
import random
import numpy as np
import torch
import os
import gc

import lm_eval
import subprocess

from huggingface_hub import login
from kaggle_secrets import UserSecretsClient

import shutil
from IPython.display import FileLink

# %% [markdown]
# # Functions

# %%
# --- 2. REPRODUCIBILITY ---
def set_reproducibility(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    # Ensure deterministic behavior in CuDNN
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    print(f"Global seed set to {seed}")

# %% [markdown]
# # Global Variables

# %%
model_name = "EdgeCompress01/Llama-3.2-3B-Instruct-SparseGPT-AWQ-4bit"
subfolder = "Sparsity/50"
SEED = 42
os.environ["HF_ALLOW_CODE_EVAL"] = "1"

# %% [markdown]
# # Seed for reproducibility

# %%
set_reproducibility(SEED)
# Out:
# Global seed set to 42

# %% [markdown]
# # Login to huggingface

# %%
# --- 3. HUGGING FACE AUTHENTICATION ---
user_secrets = UserSecretsClient()
hf_token = user_secrets.get_secret("HF_TOKEN")
login(token=hf_token)
print("Logging into Hugging Face...")
# Out:
# Logging into Hugging Face...

# %% [markdown]
# # Do Evaluation

# %% [markdown]
# **Configurations**

# %%
tasks_config = {
    "gsm8k": {
        "task_name": "gsm8k_cot",
        "fewshot": 2   # 🔻 reduced from 8
    },
    "mmlu": {
        "task_name": "mmlu",
        "fewshot": 2   # 🔻 reduced from 5
    },
    "arc_challenge": {
        "task_name": "arc_challenge",
        "fewshot": 0   # keep
    },
    "wikitext": {
        "task_name": "wikitext",
        "fewshot": 0   # keep
    }
}

# %%
for task, cfg in tasks_config.items():
    print(f"Starting evaluation for: {task}")

    model_args = f"pretrained={model_name},subfolder={subfolder},max_length=2048,dtype=float16,parallelize=True"
    command = [
        "lm_eval",
        "--model", "hf",
        "--model_args", model_args,
        "--tasks", cfg["task_name"],
        "--batch_size", str(3),   
        "--verbosity", "WARNING",
        "--seed", str(SEED),
        "--limit", str(100),
        "--num_fewshot", str(cfg["fewshot"]),
        "--output_path", f"evaluation_results/{task}"
    ]

    subprocess.run(command, check=True)
    
    torch.cuda.empty_cache()
    gc.collect()
    print(f"Finished {task}\n")
# Out:
# Starting evaluation for: gsm8k
# 2026-03-28:13:28:27 WARNING  [config.evaluate_config:281] --limit SHOULD ONLY BE USED FOR TESTING. REAL METRICS SHOULD NOT BE COMPUTED USING LIMIT.
# 2026-03-28:13:28:34 INFO     [_cli.run:376] Selected Tasks: ['gsm8k_cot']
# 2026-03-28:13:28:34 WARNING  [evaluator:181] pretrained=EdgeCompress01/Llama-3.2-3B-Instruct-SparseGPT-AWQ-4bit appears to be an instruct or chat variant but chat template is not
#         applied. Recommend setting `apply_chat_template` (optionally `fewshot_as_multiturn`).
# 2026-03-28 13:28:53.771388: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774704534.121503     123 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774704534.223688     123 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774704535.086204     123 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774704535.086251     123 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774704535.086254     123 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774704535.086256     123 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# /usr/local/lib/python3.12/dist-packages/transformers/quantizers/auto.py:239: UserWarning: You passed `quantization_config` or equivalent parameters to `from_pretrained` but the model you're loading already has a `quantization_config` attribute. The `quantization_config` from the model will be used.However, loading attributes (e.g. ['run_compressed']) will be overwritten with the one you passed to `from_pretrained`. The rest will be ignored.
#   warnings.warn(warning_msg)
# Compressing model: 196it [00:00, 1404.86it/s]
# Generating train split: 100%|██████████| 7473/7473 [00:00<00:00, 88264.71 examples/s]
# Generating test split: 100%|██████████| 1319/1319 [00:00<00:00, 355751.20 examples/s]
# 2026-03-28:13:29:38 WARNING  [evaluator:333] Overwriting default num_fewshot of gsm8k_cot from 8 to 2
# 100%|██████████| 100/100 [00:00<00:00, 120.15it/s]
# Running generate_until requests:   0%|          | 0/100 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Running generate_until requests: 100%|██████████| 100/100 [29:06<00:00, 17.47s/it]
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# hf ({'pretrained': 'EdgeCompress01/Llama-3.2-3B-Instruct-SparseGPT-AWQ-4bit', 'subfolder': 'Sparsity/50', 'max_length': 2048, 'dtype': 'float16', 'parallelize': True}), gen_kwargs: ({}), limit: 100.0, num_fewshot: 2, batch_size: 3
# |  Tasks  |Version|     Filter     |n-shot|  Metric   |   |Value|   |Stderr|
# |---------|------:|----------------|-----:|-----------|---|----:|---|-----:|
# |gsm8k_cot|      3|flexible-extract|     2|exact_match|↑  | 0.07|±  |0.0256|
# |         |       |strict-match    |     2|exact_match|↑  | 0.06|±  |0.0239|
#
# Finished gsm8k
#
# Starting evaluation for: mmlu
# 2026-03-28:13:58:55 WARNING  [config.evaluate_config:281] --limit SHOULD ONLY BE USED FOR TESTING. REAL METRICS SHOULD NOT BE COMPUTED USING LIMIT.
# 2026-03-28:13:59:00 INFO     [_cli.run:376] Selected Tasks: ['mmlu']
# 2026-03-28:13:59:00 WARNING  [evaluator:181] pretrained=EdgeCompress01/Llama-3.2-3B-Instruct-SparseGPT-AWQ-4bit appears to be an instruct or chat variant but chat template is not
#         applied. Recommend setting `apply_chat_template` (optionally `fewshot_as_multiturn`).
# 2026-03-28 13:59:07.570272: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774706347.590980     712 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774706347.596894     712 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774706347.612501     712 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774706347.612524     712 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774706347.612526     712 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774706347.612529     712 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# /usr/local/lib/python3.12/dist-packages/transformers/quantizers/auto.py:239: UserWarning: You passed `quantization_config` or equivalent parameters to `from_pretrained` but the model you're loading already has a `quantization_config` attribute. The `quantization_config` from the model will be used.However, loading attributes (e.g. ['run_compressed']) will be overwritten with the one you passed to `from_pretrained`. The rest will be ignored.
#   warnings.warn(warning_msg)
# Compressing model: 196it [00:00, 1315.22it/s]
# Generating test split: 100%|██████████| 171/171 [00:00<00:00, 16142.83 examples/s]
# Generating validation split: 100%|██████████| 19/19 [00:00<00:00, 10485.76 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 3032.32 examples/s]
# Generating test split: 100%|██████████| 1534/1534 [00:00<00:00, 142315.03 examples/s]
# Generating validation split: 100%|██████████| 170/170 [00:00<00:00, 63022.07 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2893.02 examples/s]
# Generating test split: 100%|██████████| 324/324 [00:00<00:00, 107887.78 examples/s]
# Generating validation split: 100%|██████████| 35/35 [00:00<00:00, 17379.03 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2950.41 examples/s]
# Generating test split: 100%|██████████| 311/311 [00:00<00:00, 114917.50 examples/s]
# Generating validation split: 100%|██████████| 34/34 [00:00<00:00, 18289.90 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2776.21 examples/s]
# Generating test split: 100%|██████████| 895/895 [00:00<00:00, 248586.32 examples/s]
# Generating validation split: 100%|██████████| 100/100 [00:00<00:00, 48500.28 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2730.31 examples/s]
# Generating test split: 100%|██████████| 346/346 [00:00<00:00, 88322.63 examples/s]
# Generating validation split: 100%|██████████| 38/38 [00:00<00:00, 17732.93 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 1913.98 examples/s]
# Generating test split: 100%|██████████| 163/163 [00:00<00:00, 62999.59 examples/s]
# Generating validation split: 100%|██████████| 18/18 [00:00<00:00, 9146.77 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2798.07 examples/s]
# Generating test split: 100%|██████████| 108/108 [00:00<00:00, 41842.31 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 5697.38 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2626.69 examples/s]
# Generating test split: 100%|██████████| 121/121 [00:00<00:00, 44073.88 examples/s]
# Generating validation split: 100%|██████████| 13/13 [00:00<00:00, 6340.23 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2726.76 examples/s]
# Generating test split: 100%|██████████| 237/237 [00:00<00:00, 58101.00 examples/s]
# Generating validation split: 100%|██████████| 26/26 [00:00<00:00, 12949.99 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2819.51 examples/s]
# Generating test split: 100%|██████████| 204/204 [00:00<00:00, 57715.89 examples/s]
# Generating validation split: 100%|██████████| 22/22 [00:00<00:00, 11464.12 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2804.05 examples/s]
# Generating test split: 100%|██████████| 165/165 [00:00<00:00, 49334.20 examples/s]
# Generating validation split: 100%|██████████| 18/18 [00:00<00:00, 8217.86 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2571.61 examples/s]
# Generating test split: 100%|██████████| 126/126 [00:00<00:00, 49019.79 examples/s]
# Generating validation split: 100%|██████████| 14/14 [00:00<00:00, 7589.54 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2766.69 examples/s]
# Generating test split: 100%|██████████| 100/100 [00:00<00:00, 39779.06 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 5845.35 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2822.55 examples/s]
# Generating test split: 100%|██████████| 201/201 [00:00<00:00, 73751.65 examples/s]
# Generating validation split: 100%|██████████| 22/22 [00:00<00:00, 11205.18 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2832.84 examples/s]
# Generating test split: 100%|██████████| 245/245 [00:00<00:00, 74077.60 examples/s]
# Generating validation split: 100%|██████████| 27/27 [00:00<00:00, 13296.49 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2837.44 examples/s]
# Generating test split: 100%|██████████| 110/110 [00:00<00:00, 42826.83 examples/s]
# Generating validation split: 100%|██████████| 12/12 [00:00<00:00, 6206.89 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2914.74 examples/s]
# Generating test split: 100%|██████████| 612/612 [00:00<00:00, 162339.62 examples/s]
# Generating validation split: 100%|██████████| 69/69 [00:00<00:00, 29256.67 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2546.32 examples/s]
# Generating test split: 100%|██████████| 131/131 [00:00<00:00, 49647.95 examples/s]
# Generating validation split: 100%|██████████| 12/12 [00:00<00:00, 6137.26 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2688.66 examples/s]
# Generating test split: 100%|██████████| 545/545 [00:00<00:00, 178098.61 examples/s]
# Generating validation split: 100%|██████████| 60/60 [00:00<00:00, 27265.25 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2553.45 examples/s]
# Generating test split: 100%|██████████| 238/238 [00:00<00:00, 82499.53 examples/s]
# Generating validation split: 100%|██████████| 26/26 [00:00<00:00, 12810.04 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2797.32 examples/s]
# Generating test split: 100%|██████████| 390/390 [00:00<00:00, 129218.62 examples/s]
# Generating validation split: 100%|██████████| 43/43 [00:00<00:00, 19806.18 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2467.24 examples/s]
# Generating test split: 100%|██████████| 193/193 [00:00<00:00, 65366.66 examples/s]
# Generating validation split: 100%|██████████| 21/21 [00:00<00:00, 10335.65 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2883.08 examples/s]
# Generating test split: 100%|██████████| 198/198 [00:00<00:00, 79976.14 examples/s]
# Generating validation split: 100%|██████████| 22/22 [00:00<00:00, 12998.27 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2835.14 examples/s]
# Generating test split: 100%|██████████| 114/114 [00:00<00:00, 45861.37 examples/s]
# Generating validation split: 100%|██████████| 12/12 [00:00<00:00, 5948.66 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2707.40 examples/s]
# Generating test split: 100%|██████████| 166/166 [00:00<00:00, 64599.60 examples/s]
# Generating validation split: 100%|██████████| 18/18 [00:00<00:00, 8329.38 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2895.82 examples/s]
# Generating test split: 100%|██████████| 272/272 [00:00<00:00, 77751.70 examples/s]
# Generating validation split: 100%|██████████| 31/31 [00:00<00:00, 15089.18 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2649.59 examples/s]
# Generating test split: 100%|██████████| 282/282 [00:00<00:00, 101007.15 examples/s]
# Generating validation split: 100%|██████████| 31/31 [00:00<00:00, 15374.65 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2810.07 examples/s]
# Generating test split: 100%|██████████| 306/306 [00:00<00:00, 112268.81 examples/s]
# Generating validation split: 100%|██████████| 33/33 [00:00<00:00, 16540.63 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2834.76 examples/s]
# Generating test split: 100%|██████████| 783/783 [00:00<00:00, 252218.73 examples/s]
# Generating validation split: 100%|██████████| 86/86 [00:00<00:00, 44433.38 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2806.31 examples/s]
# Generating test split: 100%|██████████| 100/100 [00:00<00:00, 39741.37 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 5648.55 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2877.15 examples/s]
# Generating test split: 100%|██████████| 234/234 [00:00<00:00, 79865.50 examples/s]
# Generating validation split: 100%|██████████| 25/25 [00:00<00:00, 9396.68 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2761.95 examples/s]
# Generating test split: 100%|██████████| 103/103 [00:00<00:00, 34132.36 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 4643.92 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2495.72 examples/s]
# Generating test split: 100%|██████████| 223/223 [00:00<00:00, 85387.05 examples/s]
# Generating validation split: 100%|██████████| 23/23 [00:00<00:00, 11934.80 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2796.58 examples/s]
# Generating test split: 100%|██████████| 100/100 [00:00<00:00, 40306.59 examples/s]
# Generating validation split: 100%|██████████| 10/10 [00:00<00:00, 5206.43 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2717.22 examples/s]
# Generating test split: 100%|██████████| 173/173 [00:00<00:00, 65613.04 examples/s]
# Generating validation split: 100%|██████████| 22/22 [00:00<00:00, 11994.63 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2633.95 examples/s]
# Generating test split: 100%|██████████| 265/265 [00:00<00:00, 100278.83 examples/s]
# Generating validation split: 100%|██████████| 29/29 [00:00<00:00, 14286.45 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2857.16 examples/s]
# Generating test split: 100%|██████████| 100/100 [00:00<00:00, 38904.59 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 5819.54 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2632.96 examples/s]
# Generating test split: 100%|██████████| 112/112 [00:00<00:00, 45256.46 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 5723.53 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2942.13 examples/s]
# Generating test split: 100%|██████████| 216/216 [00:00<00:00, 77453.16 examples/s]
# Generating validation split: 100%|██████████| 23/23 [00:00<00:00, 11018.73 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2819.89 examples/s]
# Generating test split: 100%|██████████| 151/151 [00:00<00:00, 57918.60 examples/s]
# Generating validation split: 100%|██████████| 17/17 [00:00<00:00, 8781.18 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2714.06 examples/s]
# Generating test split: 100%|██████████| 270/270 [00:00<00:00, 96511.17 examples/s]
# Generating validation split: 100%|██████████| 29/29 [00:00<00:00, 14963.07 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 3016.18 examples/s]
# Generating test split: 100%|██████████| 100/100 [00:00<00:00, 38757.20 examples/s]
# Generating validation split: 100%|██████████| 9/9 [00:00<00:00, 4699.79 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2659.67 examples/s]
# Generating test split: 100%|██████████| 203/203 [00:00<00:00, 73667.05 examples/s]
# Generating validation split: 100%|██████████| 22/22 [00:00<00:00, 10263.01 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2562.50 examples/s]
# Generating test split: 100%|██████████| 310/310 [00:00<00:00, 103943.90 examples/s]
# Generating validation split: 100%|██████████| 32/32 [00:00<00:00, 15688.81 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2704.26 examples/s]
# Generating test split: 100%|██████████| 378/378 [00:00<00:00, 146868.63 examples/s]
# Generating validation split: 100%|██████████| 41/41 [00:00<00:00, 20575.07 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2819.13 examples/s]
# Generating test split: 100%|██████████| 145/145 [00:00<00:00, 58076.21 examples/s]
# Generating validation split: 100%|██████████| 16/16 [00:00<00:00, 8102.98 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2747.12 examples/s]
# Generating test split: 100%|██████████| 235/235 [00:00<00:00, 88758.35 examples/s]
# Generating validation split: 100%|██████████| 26/26 [00:00<00:00, 12787.51 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2681.78 examples/s]
# Generating test split: 100%|██████████| 100/100 [00:00<00:00, 39643.71 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 5348.64 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2528.82 examples/s]
# Generating test split: 100%|██████████| 102/102 [00:00<00:00, 40963.14 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 5744.19 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2785.06 examples/s]
# Generating test split: 100%|██████████| 100/100 [00:00<00:00, 40360.89 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 6097.98 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2807.43 examples/s]
# Generating test split: 100%|██████████| 100/100 [00:00<00:00, 37776.31 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 5013.29 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2535.85 examples/s]
# Generating test split: 100%|██████████| 100/100 [00:00<00:00, 38377.75 examples/s]
# Generating validation split: 100%|██████████| 8/8 [00:00<00:00, 3943.87 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2449.94 examples/s]
# Generating test split: 100%|██████████| 144/144 [00:00<00:00, 54515.73 examples/s]
# Generating validation split: 100%|██████████| 16/16 [00:00<00:00, 8398.06 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2565.64 examples/s]
# Generating test split: 100%|██████████| 152/152 [00:00<00:00, 56963.39 examples/s]
# Generating validation split: 100%|██████████| 16/16 [00:00<00:00, 7808.80 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2859.49 examples/s]
# Generating test split: 100%|██████████| 135/135 [00:00<00:00, 53742.51 examples/s]
# Generating validation split: 100%|██████████| 14/14 [00:00<00:00, 6808.15 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2534.32 examples/s]
# Generating test split: 100%|██████████| 100/100 [00:00<00:00, 40840.35 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 6132.02 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2812.70 examples/s]
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_abstract_algebra from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_anatomy from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_astronomy from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_college_biology from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_college_chemistry from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_college_computer_science from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_college_mathematics from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_college_physics from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_computer_security from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_conceptual_physics from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_electrical_engineering from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_elementary_mathematics from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_biology from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_chemistry from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_computer_science from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_mathematics from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_physics from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_statistics from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_machine_learning from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_business_ethics from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_clinical_knowledge from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_college_medicine from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_global_facts from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_human_aging from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_management from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_marketing from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_medical_genetics from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_miscellaneous from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_nutrition from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_professional_accounting from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_professional_medicine from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_virology from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_econometrics from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_geography from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_government_and_politics from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_macroeconomics from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_microeconomics from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_psychology from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_human_sexuality from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_professional_psychology from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_public_relations from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_security_studies from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_sociology from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_us_foreign_policy from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_formal_logic from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_european_history from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_us_history from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_world_history from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_international_law from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_jurisprudence from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_logical_fallacies from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_moral_disputes from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_moral_scenarios from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_philosophy from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_prehistory from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_professional_law from None to 2
# 2026-03-28:14:01:14 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_world_religions from None to 2
# 100%|██████████| 100/100 [00:00<00:00, 266.47it/s]
# 100%|██████████| 100/100 [00:00<00:00, 264.59it/s]
# 100%|██████████| 100/100 [00:00<00:00, 272.26it/s]
# 100%|██████████| 100/100 [00:00<00:00, 278.25it/s]
# 100%|██████████| 100/100 [00:00<00:00, 279.42it/s]
# 100%|██████████| 100/100 [00:00<00:00, 277.50it/s]
# 100%|██████████| 100/100 [00:00<00:00, 280.17it/s]
# 100%|██████████| 100/100 [00:00<00:00, 277.87it/s]
# 100%|██████████| 100/100 [00:00<00:00, 279.32it/s]
# 100%|██████████| 100/100 [00:00<00:00, 275.88it/s]
# 100%|██████████| 100/100 [00:00<00:00, 277.65it/s]
# 100%|██████████| 100/100 [00:00<00:00, 278.31it/s]
# 100%|██████████| 100/100 [00:00<00:00, 276.59it/s]
# 100%|██████████| 100/100 [00:00<00:00, 258.48it/s]
# 100%|██████████| 100/100 [00:00<00:00, 278.12it/s]
# 100%|██████████| 100/100 [00:00<00:00, 278.27it/s]
# 100%|██████████| 100/100 [00:00<00:00, 278.01it/s]
# 100%|██████████| 100/100 [00:00<00:00, 274.57it/s]
# 100%|██████████| 100/100 [00:00<00:00, 276.57it/s]
# 100%|██████████| 100/100 [00:00<00:00, 276.98it/s]
# 100%|██████████| 100/100 [00:00<00:00, 277.22it/s]
# 100%|██████████| 100/100 [00:00<00:00, 280.73it/s]
# 100%|██████████| 100/100 [00:00<00:00, 275.44it/s]
# 100%|██████████| 100/100 [00:00<00:00, 277.62it/s]
# 100%|██████████| 100/100 [00:00<00:00, 279.68it/s]
# 100%|██████████| 100/100 [00:00<00:00, 280.20it/s]
# 100%|██████████| 100/100 [00:00<00:00, 277.02it/s]
# 100%|██████████| 100/100 [00:00<00:00, 278.24it/s]
# 100%|██████████| 100/100 [00:00<00:00, 277.95it/s]
# 100%|██████████| 100/100 [00:00<00:00, 278.59it/s]
# 100%|██████████| 100/100 [00:00<00:00, 276.44it/s]
# 100%|██████████| 100/100 [00:00<00:00, 264.32it/s]
# 100%|██████████| 100/100 [00:00<00:00, 275.08it/s]
# 100%|██████████| 100/100 [00:00<00:00, 256.46it/s]
# 100%|██████████| 100/100 [00:00<00:00, 252.27it/s]
# 100%|██████████| 100/100 [00:00<00:00, 263.40it/s]
# 100%|██████████| 100/100 [00:00<00:00, 275.45it/s]
# 100%|██████████| 100/100 [00:00<00:00, 278.07it/s]
# 100%|██████████| 100/100 [00:00<00:00, 281.25it/s]
# 100%|██████████| 100/100 [00:00<00:00, 278.59it/s]
# 100%|██████████| 100/100 [00:00<00:00, 257.89it/s]
# 100%|██████████| 100/100 [00:00<00:00, 277.17it/s]
# 100%|██████████| 100/100 [00:00<00:00, 279.36it/s]
# 100%|██████████| 100/100 [00:00<00:00, 276.25it/s]
# 100%|██████████| 100/100 [00:00<00:00, 270.63it/s]
# 100%|██████████| 100/100 [00:00<00:00, 269.62it/s]
# 100%|██████████| 100/100 [00:00<00:00, 280.74it/s]
# 100%|██████████| 100/100 [00:00<00:00, 278.51it/s]
# 100%|██████████| 100/100 [00:00<00:00, 280.87it/s]
# 100%|██████████| 100/100 [00:00<00:00, 280.27it/s]
# 100%|██████████| 100/100 [00:00<00:00, 278.89it/s]
# 100%|██████████| 100/100 [00:00<00:00, 278.40it/s]
# 100%|██████████| 100/100 [00:00<00:00, 280.05it/s]
# 100%|██████████| 100/100 [00:00<00:00, 279.60it/s]
# 100%|██████████| 100/100 [00:00<00:00, 281.98it/s]
# 100%|██████████| 100/100 [00:00<00:00, 278.27it/s]
# 100%|██████████| 100/100 [00:00<00:00, 280.75it/s]
# Running loglikelihood requests: 100%|██████████| 22800/22800 [25:15<00:00, 15.05it/s]
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# hf ({'pretrained': 'EdgeCompress01/Llama-3.2-3B-Instruct-SparseGPT-AWQ-4bit', 'subfolder': 'Sparsity/50', 'max_length': 2048, 'dtype': 'float16', 'parallelize': True}), gen_kwargs: ({}), limit: 100.0, num_fewshot: 2, batch_size: 3
# |                 Tasks                 |Version|Filter|n-shot|Metric|   |Value |   |Stderr|
# |---------------------------------------|------:|------|-----:|------|---|-----:|---|-----:|
# |mmlu                                   |      2|none  |      |acc   |↑  |0.4098|±  |0.0064|
# | - humanities                          |      2|none  |      |acc   |↑  |0.4000|±  |0.0134|
# |  - formal_logic                       |      1|none  |     2|acc   |↑  |0.2600|±  |0.0441|
# |  - high_school_european_history       |      1|none  |     2|acc   |↑  |0.3700|±  |0.0485|
# |  - high_school_us_history             |      1|none  |     2|acc   |↑  |0.4500|±  |0.0500|
# |  - high_school_world_history          |      1|none  |     2|acc   |↑  |0.4500|±  |0.0500|
# |  - international_law                  |      1|none  |     2|acc   |↑  |0.5400|±  |0.0501|
# |  - jurisprudence                      |      1|none  |     2|acc   |↑  |0.4700|±  |0.0502|
# |  - logical_fallacies                  |      1|none  |     2|acc   |↑  |0.4400|±  |0.0499|
# |  - moral_disputes                     |      1|none  |     2|acc   |↑  |0.3700|±  |0.0485|
# |  - moral_scenarios                    |      1|none  |     2|acc   |↑  |0.2100|±  |0.0409|
# |  - philosophy                         |      1|none  |     2|acc   |↑  |0.4300|±  |0.0498|
# |  - prehistory                         |      1|none  |     2|acc   |↑  |0.4500|±  |0.0500|
# |  - professional_law                   |      1|none  |     2|acc   |↑  |0.2600|±  |0.0441|
# |  - world_religions                    |      1|none  |     2|acc   |↑  |0.5000|±  |0.0503|
# | - other                               |      2|none  |      |acc   |↑  |0.4323|±  |0.0136|
# |  - business_ethics                    |      1|none  |     2|acc   |↑  |0.4200|±  |0.0496|
# |  - clinical_knowledge                 |      1|none  |     2|acc   |↑  |0.4400|±  |0.0499|
# |  - college_medicine                   |      1|none  |     2|acc   |↑  |0.3600|±  |0.0482|
# |  - global_facts                       |      1|none  |     2|acc   |↑  |0.3200|±  |0.0469|
# |  - human_aging                        |      1|none  |     2|acc   |↑  |0.4300|±  |0.0498|
# |  - management                         |      1|none  |     2|acc   |↑  |0.5500|±  |0.0500|
# |  - marketing                          |      1|none  |     2|acc   |↑  |0.6000|±  |0.0492|
# |  - medical_genetics                   |      1|none  |     2|acc   |↑  |0.4000|±  |0.0492|
# |  - miscellaneous                      |      1|none  |     2|acc   |↑  |0.5500|±  |0.0500|
# |  - nutrition                          |      1|none  |     2|acc   |↑  |0.4800|±  |0.0502|
# |  - professional_accounting            |      1|none  |     2|acc   |↑  |0.2900|±  |0.0456|
# |  - professional_medicine              |      1|none  |     2|acc   |↑  |0.3700|±  |0.0485|
# |  - virology                           |      1|none  |     2|acc   |↑  |0.4100|±  |0.0494|
# | - social sciences                     |      2|none  |      |acc   |↑  |0.4675|±  |0.0142|
# |  - econometrics                       |      1|none  |     2|acc   |↑  |0.2700|±  |0.0446|
# |  - high_school_geography              |      1|none  |     2|acc   |↑  |0.4600|±  |0.0501|
# |  - high_school_government_and_politics|      1|none  |     2|acc   |↑  |0.6000|±  |0.0492|
# |  - high_school_macroeconomics         |      1|none  |     2|acc   |↑  |0.3800|±  |0.0488|
# |  - high_school_microeconomics         |      1|none  |     2|acc   |↑  |0.4600|±  |0.0501|
# |  - high_school_psychology             |      1|none  |     2|acc   |↑  |0.5500|±  |0.0500|
# |  - human_sexuality                    |      1|none  |     2|acc   |↑  |0.4400|±  |0.0499|
# |  - professional_psychology   Finished mmlu
#
# Starting evaluation for: arc_challenge
# 2026-03-28:14:27:28 WARNING  [config.evaluate_config:281] --limit SHOULD ONLY BE USED FOR TESTING. REAL METRICS SHOULD NOT BE COMPUTED USING LIMIT.
# 2026-03-28:14:27:33 INFO     [_cli.run:376] Selected Tasks: ['arc_challenge']
# 2026-03-28:14:27:33 WARNING  [evaluator:181] pretrained=EdgeCompress01/Llama-3.2-3B-Instruct-SparseGPT-AWQ-4bit appears to be an instruct or chat variant but chat template is not
#         applied. Recommend setting `apply_chat_template` (optionally `fewshot_as_multiturn`).
# 2026-03-28 14:27:40.407985: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774708060.429568    1126 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774708060.436028    1126 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774708060.453002    1126 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774708060.453025    1126 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774708060.453029    1126 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774708060.453032    1126 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# /usr/local/lib/python3.12/dist-packages/transformers/quantizers/auto.py:239: UserWarning: You passed `quantization_config` or equivalent parameters to `from_pretrained` but the model you're loading already has a `quantization_config` attribute. The `quantization_config` from the model will be used.However, loading attributes (e.g. ['run_compressed']) will be overwritten with the one you passed to `from_pretrained`. The rest will be ignored.
#   warnings.warn(warning_msg)
# Compressing model: 196it [00:00, 1333.51it/s]
# Generating train split: 100%|██████████| 1119/1119 [00:00<00:00, 169211.75 examples/s]
# Generating test split: 100%|██████████| 1172/1172 [00:00<00:00, 287116.66 examples/s]
# Generating validation split: 100%|██████████| 299/299 [00:00<00:00, 118680.50 examples/s]
# 2026-03-28:14:27:51 WARNING  [evaluator:333] Overwriting default num_fewshot of arc_challenge from None to 0
# 100%|██████████| 100/100 [00:00<00:00, 505.95it/s]
# Running loglikelihood requests: 100%|██████████| 400/400 [00:56<00:00,  7.06it/s]
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# Finished arc_challenge
#
# Starting evaluation for: wikitext
# 2026-03-28:14:28:54 WARNING  [config.evaluate_config:281] --limit SHOULD ONLY BE USED FOR TESTING. REAL METRICS SHOULD NOT BE COMPUTED USING LIMIT.
# 2026-03-28:14:28:59 INFO     [_cli.run:376] Selected Tasks: ['wikitext']
# 2026-03-28:14:28:59 WARNING  [evaluator:181] pretrained=EdgeCompress01/Llama-3.2-3B-Instruct-SparseGPT-AWQ-4bit appears to be an instruct or chat variant but chat template is not
#         applied. Recommend setting `apply_chat_template` (optionally `fewshot_as_multiturn`).
# 2026-03-28 14:29:07.385345: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774708147.406017    1203 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774708147.412000    1203 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774708147.427626    1203 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774708147.427646    1203 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774708147.427649    1203 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774708147.427651    1203 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# /usr/local/lib/python3.12/dist-packages/transformers/quantizers/auto.py:239: UserWarning: You passed `quantization_config` or equivalent parameters to `from_pretrained` but the model you're loading already has a `quantization_config` attribute. The `quantization_config` from the model will be used.However, loading attributes (e.g. ['run_compressed']) will be overwritten with the one you passed to `from_pretrained`. The rest will be ignored.
#   warnings.warn(warning_msg)
# Compressing model: 196it [00:00, 1308.63it/s]
# 2026-03-28:14:29:15 WARNING  [api.task:729] [Task: wikitext] metric word_perplexity is defined, but aggregation is not. using default aggregation=weighted_perplexity
# 2026-03-28:14:29:15 WARNING  [api.task:741] [Task: wikitext] metric word_perplexity is defined, but higher_is_better is not. using default higher_is_better=False
# 2026-03-28:14:29:15 WARNING  [api.task:729] [Task: wikitext] metric byte_perplexity is defined, but aggregation is not. using default aggregation=weighted_perplexity
# 2026-03-28:14:29:15 WARNING  [api.task:741] [Task: wikitext] metric byte_perplexity is defined, but higher_is_better is not. using default higher_is_better=False
# 2026-03-28:14:29:15 WARNING  [api.task:729] [Task: wikitext] metric bits_per_byte is defined, but aggregation is not. using default aggregation=bits_per_byte
# 2026-03-28:14:29:15 WARNING  [api.task:741] [Task: wikitext] metric bits_per_byte is defined, but higher_is_better is not. using default higher_is_better=False
# Generating train split: 100%|██████████| 629/629 [00:00<00:00, 8506.67 examples/s]
# Generating validation split: 100%|██████████| 60/60 [00:00<00:00, 10194.37 examples/s]
# Generating test split: 100%|██████████| 62/62 [00:00<00:00, 10803.33 examples/s]
# 2026-03-28:14:29:19 WARNING  [evaluator:333] Overwriting default num_fewshot of wikitext from None to 0
# 100%|██████████| 62/62 [00:00<00:00, 332.71it/s]
# 100%|██████████| 62/62 [00:00<00:00, 107.01it/s]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:06<00:00,  2.04s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:04<00:00,  1.66s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.67s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.68s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.72s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.73s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.76s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.79s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.85s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.87s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.87s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.87s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.80s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.75s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.73s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.72s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.72s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.72s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.71s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.73s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.73s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.75s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.78s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.80s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.80s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.79s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:03<00:00,  1.02s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.78s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.76s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.75s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.75s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.76s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.76s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.75s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.76s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.76s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.76s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.76s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.77s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.77s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.76s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.74s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.75s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.74s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.75s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.76s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.76s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.76s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:02<00:00,  1.14it/s]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.78s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.76s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.76s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.76s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.76s/it]
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# Finished wikitext

# %% [markdown]
# # Save reports

# %%
zip_path = shutil.make_archive(f"evaluation_results", 'zip', f"evaluation_results")
FileLink(zip_path)
# Out:
# /kaggle/working/evaluation_results.zip
