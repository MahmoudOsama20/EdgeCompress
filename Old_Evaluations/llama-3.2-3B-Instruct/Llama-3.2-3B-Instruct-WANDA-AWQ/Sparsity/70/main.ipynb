# %% [markdown]
# # Libraries

# %%
# !pip -q install "lm_eval[hf]"
# !pip -q install compressed-tensors
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.4/56.4 kB 1.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 81.0 MB/s eta 0:00:00:00:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 7.1 MB/s eta 0:00:00
#   Building wheel for sqlitedict (setup.py) ... done
#   Building wheel for word2number (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 1.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.5/196.5 kB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 101.1 MB/s eta 0:00:0000:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 37.8 MB/s eta 0:00:00

# %%
# 2. Libraries
import random
import numpy as np
import torch
import os
import gc

import lm_eval
import subprocess

from huggingface_hub import login
from kaggle_secrets import UserSecretsClient

import shutil
from IPython.display import FileLink

# %% [markdown]
# # Functions

# %%
# --- 2. REPRODUCIBILITY ---
def set_reproducibility(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    # Ensure deterministic behavior in CuDNN
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    print(f"Global seed set to {seed}")

# %% [markdown]
# # Global Variables

# %%
model_name = "EdgeCompress01/Llama-3.2-3B-Instruct-WANDA-AWQ-4bit"
subfolder = "Sparsity/70"
SEED = 42
os.environ["HF_ALLOW_CODE_EVAL"] = "1"

# %% [markdown]
# # Seed for reproducibility

# %%
set_reproducibility(SEED)
# Out:
# Global seed set to 42

# %% [markdown]
# # Login to huggingface

# %%
# --- 3. HUGGING FACE AUTHENTICATION ---
user_secrets = UserSecretsClient()
hf_token = user_secrets.get_secret("HF_TOKEN")
login(token=hf_token)
print("Logging into Hugging Face...")
# Out:
# Logging into Hugging Face...

# %% [markdown]
# # Do Evaluation

# %% [markdown]
# **Configurations**

# %%
tasks_config = {
    "gsm8k": {
        "task_name": "gsm8k_cot",
        "fewshot": 2   # 🔻 reduced from 8
    },
    "mmlu": {
        "task_name": "mmlu",
        "fewshot": 2   # 🔻 reduced from 5
    },
    "arc_challenge": {
        "task_name": "arc_challenge",
        "fewshot": 0   # keep
    },
    "wikitext": {
        "task_name": "wikitext",
        "fewshot": 0   # keep
    }
}

# %%
for task, cfg in tasks_config.items():
    print(f"Starting evaluation for: {task}")

    model_args = f"pretrained={model_name},subfolder={subfolder},max_length=2048,dtype=float16,parallelize=True"
    command = [
        "lm_eval",
        "--model", "hf",
        "--model_args", model_args,
        "--tasks", cfg["task_name"],
        "--batch_size", str(3),   
        "--verbosity", "WARNING",
        "--seed", str(SEED),
        "--limit", str(100),
        "--num_fewshot", str(cfg["fewshot"]),
        "--output_path", f"evaluation_results/{task}"
    ]

    subprocess.run(command, check=True)
    
    torch.cuda.empty_cache()
    gc.collect()
    print(f"Finished {task}\n")
# Out:
# Starting evaluation for: gsm8k
# 2026-03-28:16:49:03 WARNING  [config.evaluate_config:281] --limit SHOULD ONLY BE USED FOR TESTING. REAL METRICS SHOULD NOT BE COMPUTED USING LIMIT.
# 2026-03-28:16:49:09 INFO     [_cli.run:376] Selected Tasks: ['gsm8k_cot']
# 2026-03-28:16:49:09 WARNING  [evaluator:181] pretrained=EdgeCompress01/Llama-3.2-3B-Instruct-WANDA-AWQ-4bit appears to be an instruct or chat variant but chat template is not applied.
#         Recommend setting `apply_chat_template` (optionally `fewshot_as_multiturn`).
# 2026-03-28 16:49:23.703005: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774716563.898233     160 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774716563.956076     160 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774716564.441977     160 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774716564.442026     160 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774716564.442032     160 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774716564.442037     160 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# /usr/local/lib/python3.12/dist-packages/transformers/quantizers/auto.py:239: UserWarning: You passed `quantization_config` or equivalent parameters to `from_pretrained` but the model you're loading already has a `quantization_config` attribute. The `quantization_config` from the model will be used.However, loading attributes (e.g. ['run_compressed']) will be overwritten with the one you passed to `from_pretrained`. The rest will be ignored.
#   warnings.warn(warning_msg)
# Compressing model: 196it [00:00, 1356.67it/s]
# Generating train split: 100%|██████████| 7473/7473 [00:00<00:00, 128306.66 examples/s]
# Generating test split: 100%|██████████| 1319/1319 [00:00<00:00, 294788.03 examples/s]
# 2026-03-28:16:49:57 WARNING  [evaluator:333] Overwriting default num_fewshot of gsm8k_cot from 8 to 2
# 100%|██████████| 100/100 [00:00<00:00, 217.82it/s]
# Running generate_until requests:   0%|          | 0/100 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Running generate_until requests: 100%|██████████| 100/100 [1:00:07<00:00, 36.07s/it]
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# hf ({'pretrained': 'EdgeCompress01/Llama-3.2-3B-Instruct-WANDA-AWQ-4bit', 'subfolder': 'Sparsity/70', 'max_length': 2048, 'dtype': 'float16', 'parallelize': True}), gen_kwargs: ({}), limit: 100.0, num_fewshot: 2, batch_size: 3
# |  Tasks  |Version|     Filter     |n-shot|  Metric   |   |Value|   |Stderr|
# |---------|------:|----------------|-----:|-----------|---|----:|---|-----:|
# |gsm8k_cot|      3|flexible-extract|     2|exact_match|↑  | 0.03|±  |0.0171|
# |         |       |strict-match    |     2|exact_match|↑  | 0.00|±  |0.0000|
#
# Finished gsm8k
#
# Starting evaluation for: mmlu
# 2026-03-28:17:50:12 WARNING  [config.evaluate_config:281] --limit SHOULD ONLY BE USED FOR TESTING. REAL METRICS SHOULD NOT BE COMPUTED USING LIMIT.
# 2026-03-28:17:50:17 INFO     [_cli.run:376] Selected Tasks: ['mmlu']
# 2026-03-28:17:50:17 WARNING  [evaluator:181] pretrained=EdgeCompress01/Llama-3.2-3B-Instruct-WANDA-AWQ-4bit appears to be an instruct or chat variant but chat template is not applied.
#         Recommend setting `apply_chat_template` (optionally `fewshot_as_multiturn`).
# 2026-03-28 17:50:24.965221: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774720224.986992     755 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774720224.993378     755 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774720225.010977     755 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774720225.011025     755 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774720225.011030     755 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774720225.011034     755 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# /usr/local/lib/python3.12/dist-packages/transformers/quantizers/auto.py:239: UserWarning: You passed `quantization_config` or equivalent parameters to `from_pretrained` but the model you're loading already has a `quantization_config` attribute. The `quantization_config` from the model will be used.However, loading attributes (e.g. ['run_compressed']) will be overwritten with the one you passed to `from_pretrained`. The rest will be ignored.
#   warnings.warn(warning_msg)
# Compressing model: 196it [00:00, 1342.94it/s]
# Generating test split: 100%|██████████| 171/171 [00:00<00:00, 27265.77 examples/s]
# Generating validation split: 100%|██████████| 19/19 [00:00<00:00, 8869.42 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2614.58 examples/s]
# Generating test split: 100%|██████████| 1534/1534 [00:00<00:00, 134863.38 examples/s]
# Generating validation split: 100%|██████████| 170/170 [00:00<00:00, 60237.53 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2425.57 examples/s]
# Generating test split: 100%|██████████| 324/324 [00:00<00:00, 92383.04 examples/s]
# Generating validation split: 100%|██████████| 35/35 [00:00<00:00, 15192.04 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2418.86 examples/s]
# Generating test split: 100%|██████████| 311/311 [00:00<00:00, 100094.27 examples/s]
# Generating validation split: 100%|██████████| 34/34 [00:00<00:00, 15504.06 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2594.52 examples/s]
# Generating test split: 100%|██████████| 895/895 [00:00<00:00, 251399.82 examples/s]
# Generating validation split: 100%|██████████| 100/100 [00:00<00:00, 48066.74 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2806.31 examples/s]
# Generating test split: 100%|██████████| 346/346 [00:00<00:00, 111684.56 examples/s]
# Generating validation split: 100%|██████████| 38/38 [00:00<00:00, 15298.86 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2284.98 examples/s]
# Generating test split: 100%|██████████| 163/163 [00:00<00:00, 59740.61 examples/s]
# Generating validation split: 100%|██████████| 18/18 [00:00<00:00, 8887.28 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2852.88 examples/s]
# Generating test split: 100%|██████████| 108/108 [00:00<00:00, 41896.49 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 4876.58 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2801.06 examples/s]
# Generating test split: 100%|██████████| 121/121 [00:00<00:00, 45808.36 examples/s]
# Generating validation split: 100%|██████████| 13/13 [00:00<00:00, 6480.38 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2717.22 examples/s]
# Generating test split: 100%|██████████| 237/237 [00:00<00:00, 55524.22 examples/s]
# Generating validation split: 100%|██████████| 26/26 [00:00<00:00, 12661.31 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2650.26 examples/s]
# Generating test split: 100%|██████████| 204/204 [00:00<00:00, 61025.46 examples/s]
# Generating validation split: 100%|██████████| 22/22 [00:00<00:00, 9815.41 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2761.23 examples/s]
# Generating test split: 100%|██████████| 165/165 [00:00<00:00, 48819.14 examples/s]
# Generating validation split: 100%|██████████| 18/18 [00:00<00:00, 8201.79 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2600.96 examples/s]
# Generating test split: 100%|██████████| 126/126 [00:00<00:00, 51179.77 examples/s]
# Generating validation split: 100%|██████████| 14/14 [00:00<00:00, 7069.62 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2752.89 examples/s]
# Generating test split: 100%|██████████| 100/100 [00:00<00:00, 40427.03 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 5582.93 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2605.81 examples/s]
# Generating test split: 100%|██████████| 201/201 [00:00<00:00, 76676.23 examples/s]
# Generating validation split: 100%|██████████| 22/22 [00:00<00:00, 11021.82 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2675.62 examples/s]
# Generating test split: 100%|██████████| 245/245 [00:00<00:00, 72107.53 examples/s]
# Generating validation split: 100%|██████████| 27/27 [00:00<00:00, 11421.71 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2862.62 examples/s]
# Generating test split: 100%|██████████| 110/110 [00:00<00:00, 39845.71 examples/s]
# Generating validation split: 100%|██████████| 12/12 [00:00<00:00, 5923.46 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2718.63 examples/s]
# Generating test split: 100%|██████████| 612/612 [00:00<00:00, 136931.29 examples/s]
# Generating validation split: 100%|██████████| 69/69 [00:00<00:00, 24820.50 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 1926.82 examples/s]
# Generating test split: 100%|██████████| 131/131 [00:00<00:00, 47547.06 examples/s]
# Generating validation split: 100%|██████████| 12/12 [00:00<00:00, 4681.14 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2017.07 examples/s]
# Generating test split: 100%|██████████| 545/545 [00:00<00:00, 172299.37 examples/s]
# Generating validation split: 100%|██████████| 60/60 [00:00<00:00, 26225.33 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2543.54 examples/s]
# Generating test split: 100%|██████████| 238/238 [00:00<00:00, 85730.36 examples/s]
# Generating validation split: 100%|██████████| 26/26 [00:00<00:00, 12649.57 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2374.49 examples/s]
# Generating test split: 100%|██████████| 390/390 [00:00<00:00, 117436.90 examples/s]
# Generating validation split: 100%|██████████| 43/43 [00:00<00:00, 19194.88 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2495.12 examples/s]
# Generating test split: 100%|██████████| 193/193 [00:00<00:00, 68782.45 examples/s]
# Generating validation split: 100%|██████████| 21/21 [00:00<00:00, 7776.83 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2571.61 examples/s]
# Generating test split: 100%|██████████| 198/198 [00:00<00:00, 69635.43 examples/s]
# Generating validation split: 100%|██████████| 22/22 [00:00<00:00, 10244.77 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2759.77 examples/s]
# Generating test split: 100%|██████████| 114/114 [00:00<00:00, 41895.26 examples/s]
# Generating validation split: 100%|██████████| 12/12 [00:00<00:00, 5424.25 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2563.44 examples/s]
# Generating test split: 100%|██████████| 166/166 [00:00<00:00, 64462.04 examples/s]
# Generating validation split: 100%|██████████| 18/18 [00:00<00:00, 8389.54 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2716.17 examples/s]
# Generating test split: 100%|██████████| 272/272 [00:00<00:00, 76112.53 examples/s]
# Generating validation split: 100%|██████████| 31/31 [00:00<00:00, 12110.97 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2357.41 examples/s]
# Generating test split: 100%|██████████| 282/282 [00:00<00:00, 91582.94 examples/s]
# Generating validation split: 100%|██████████| 31/31 [00:00<00:00, 14902.40 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2535.55 examples/s]
# Generating test split: 100%|██████████| 306/306 [00:00<00:00, 108199.04 examples/s]
# Generating validation split: 100%|██████████| 33/33 [00:00<00:00, 15599.24 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2524.26 examples/s]
# Generating test split: 100%|██████████| 783/783 [00:00<00:00, 252801.17 examples/s]
# Generating validation split: 100%|██████████| 86/86 [00:00<00:00, 38154.24 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2428.10 examples/s]
# Generating test split: 100%|██████████| 100/100 [00:00<00:00, 35436.84 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 4687.33 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2471.31 examples/s]
# Generating test split: 100%|██████████| 234/234 [00:00<00:00, 85145.06 examples/s]
# Generating validation split: 100%|██████████| 25/25 [00:00<00:00, 10961.49 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2201.27 examples/s]
# Generating test split: 100%|██████████| 103/103 [00:00<00:00, 38906.10 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 4992.14 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2329.65 examples/s]
# Generating test split: 100%|██████████| 223/223 [00:00<00:00, 76503.34 examples/s]
# Generating validation split: 100%|██████████| 23/23 [00:00<00:00, 9434.62 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2270.38 examples/s]
# Generating test split: 100%|██████████| 100/100 [00:00<00:00, 35968.65 examples/s]
# Generating validation split: 100%|██████████| 10/10 [00:00<00:00, 4687.42 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2148.06 examples/s]
# Generating test split: 100%|██████████| 173/173 [00:00<00:00, 61068.39 examples/s]
# Generating validation split: 100%|██████████| 22/22 [00:00<00:00, 10908.46 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2528.82 examples/s]
# Generating test split: 100%|██████████| 265/265 [00:00<00:00, 71418.79 examples/s]
# Generating validation split: 100%|██████████| 29/29 [00:00<00:00, 10474.02 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 1737.20 examples/s]
# Generating test split: 100%|██████████| 100/100 [00:00<00:00, 34804.61 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 4818.52 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2384.75 examples/s]
# Generating test split: 100%|██████████| 112/112 [00:00<00:00, 40781.50 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 4921.32 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2365.39 examples/s]
# Generating test split: 100%|██████████| 216/216 [00:00<00:00, 70175.81 examples/s]
# Generating validation split: 100%|██████████| 23/23 [00:00<00:00, 10619.66 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2546.94 examples/s]
# Generating test split: 100%|██████████| 151/151 [00:00<00:00, 54331.29 examples/s]
# Generating validation split: 100%|██████████| 17/17 [00:00<00:00, 8190.12 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2602.25 examples/s]
# Generating test split: 100%|██████████| 270/270 [00:00<00:00, 96248.69 examples/s]
# Generating validation split: 100%|██████████| 29/29 [00:00<00:00, 14256.31 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2377.45 examples/s]
# Generating test split: 100%|██████████| 100/100 [00:00<00:00, 34853.78 examples/s]
# Generating validation split: 100%|██████████| 9/9 [00:00<00:00, 3786.61 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2230.54 examples/s]
# Generating test split: 100%|██████████| 203/203 [00:00<00:00, 76796.58 examples/s]
# Generating validation split: 100%|██████████| 22/22 [00:00<00:00, 10192.72 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2578.57 examples/s]
# Generating test split: 100%|██████████| 310/310 [00:00<00:00, 104705.61 examples/s]
# Generating validation split: 100%|██████████| 32/32 [00:00<00:00, 14035.11 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2490.38 examples/s]
# Generating test split: 100%|██████████| 378/378 [00:00<00:00, 133488.84 examples/s]
# Generating validation split: 100%|██████████| 41/41 [00:00<00:00, 19816.37 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2436.28 examples/s]
# Generating test split: 100%|██████████| 145/145 [00:00<00:00, 54267.34 examples/s]
# Generating validation split: 100%|██████████| 16/16 [00:00<00:00, 7570.09 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2660.01 examples/s]
# Generating test split: 100%|██████████| 235/235 [00:00<00:00, 89167.85 examples/s]
# Generating validation split: 100%|██████████| 26/26 [00:00<00:00, 12798.02 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2590.68 examples/s]
# Generating test split: 100%|██████████| 100/100 [00:00<00:00, 39144.23 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 5647.17 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2456.26 examples/s]
# Generating test split: 100%|██████████| 102/102 [00:00<00:00, 37396.77 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 5157.32 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2221.32 examples/s]
# Generating test split: 100%|██████████| 100/100 [00:00<00:00, 39847.08 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 5105.95 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2388.01 examples/s]
# Generating test split: 100%|██████████| 100/100 [00:00<00:00, 38621.58 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 5024.76 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2659.34 examples/s]
# Generating test split: 100%|██████████| 100/100 [00:00<00:00, 36008.79 examples/s]
# Generating validation split: 100%|██████████| 8/8 [00:00<00:00, 3944.80 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2690.73 examples/s]
# Generating test split: 100%|██████████| 144/144 [00:00<00:00, 56770.35 examples/s]
# Generating validation split: 100%|██████████| 16/16 [00:00<00:00, 7577.79 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2600.96 examples/s]
# Generating test split: 100%|██████████| 152/152 [00:00<00:00, 56408.97 examples/s]
# Generating validation split: 100%|██████████| 16/16 [00:00<00:00, 7205.93 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2565.64 examples/s]
# Generating test split: 100%|██████████| 135/135 [00:00<00:00, 52869.38 examples/s]
# Generating validation split: 100%|██████████| 14/14 [00:00<00:00, 6693.29 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2910.29 examples/s]
# Generating test split: 100%|██████████| 100/100 [00:00<00:00, 26788.68 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 5139.51 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2656.30 examples/s]
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_abstract_algebra from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_anatomy from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_astronomy from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_college_biology from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_college_chemistry from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_college_computer_science from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_college_mathematics from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_college_physics from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_computer_security from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_conceptual_physics from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_electrical_engineering from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_elementary_mathematics from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_biology from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_chemistry from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_computer_science from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_mathematics from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_physics from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_statistics from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_machine_learning from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_business_ethics from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_clinical_knowledge from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_college_medicine from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_global_facts from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_human_aging from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_management from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_marketing from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_medical_genetics from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_miscellaneous from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_nutrition from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_professional_accounting from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_professional_medicine from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_virology from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_econometrics from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_geography from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_government_and_politics from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_macroeconomics from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_microeconomics from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_psychology from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_human_sexuality from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_professional_psychology from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_public_relations from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_security_studies from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_sociology from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_us_foreign_policy from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_formal_logic from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_european_history from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_us_history from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_world_history from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_international_law from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_jurisprudence from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_logical_fallacies from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_moral_disputes from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_moral_scenarios from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_philosophy from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_prehistory from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_professional_law from None to 2
# 2026-03-28:17:51:32 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_world_religions from None to 2
# 100%|██████████| 100/100 [00:00<00:00, 260.67it/s]
# 100%|██████████| 100/100 [00:00<00:00, 250.10it/s]
# 100%|██████████| 100/100 [00:00<00:00, 270.10it/s]
# 100%|██████████| 100/100 [00:00<00:00, 266.44it/s]
# 100%|██████████| 100/100 [00:00<00:00, 269.01it/s]
# 100%|██████████| 100/100 [00:00<00:00, 270.66it/s]
# 100%|██████████| 100/100 [00:00<00:00, 266.85it/s]
# 100%|██████████| 100/100 [00:00<00:00, 266.62it/s]
# 100%|██████████| 100/100 [00:00<00:00, 263.81it/s]
# 100%|██████████| 100/100 [00:00<00:00, 267.64it/s]
# 100%|██████████| 100/100 [00:00<00:00, 264.98it/s]
# 100%|██████████| 100/100 [00:00<00:00, 270.54it/s]
# 100%|██████████| 100/100 [00:00<00:00, 268.56it/s]
# 100%|██████████| 100/100 [00:00<00:00, 271.22it/s]
# 100%|██████████| 100/100 [00:00<00:00, 271.13it/s]
# 100%|██████████| 100/100 [00:00<00:00, 274.20it/s]
# 100%|██████████| 100/100 [00:00<00:00, 271.20it/s]
# 100%|██████████| 100/100 [00:00<00:00, 270.74it/s]
# 100%|██████████| 100/100 [00:00<00:00, 270.36it/s]
# 100%|██████████| 100/100 [00:00<00:00, 269.92it/s]
# 100%|██████████| 100/100 [00:00<00:00, 270.96it/s]
# 100%|██████████| 100/100 [00:00<00:00, 271.09it/s]
# 100%|██████████| 100/100 [00:00<00:00, 269.77it/s]
# 100%|██████████| 100/100 [00:00<00:00, 270.75it/s]
# 100%|██████████| 100/100 [00:00<00:00, 272.50it/s]
# 100%|██████████| 100/100 [00:00<00:00, 272.92it/s]
# 100%|██████████| 100/100 [00:00<00:00, 269.59it/s]
# 100%|██████████| 100/100 [00:00<00:00, 264.51it/s]
# 100%|██████████| 100/100 [00:00<00:00, 251.81it/s]
# 100%|██████████| 100/100 [00:00<00:00, 268.58it/s]
# 100%|██████████| 100/100 [00:00<00:00, 267.14it/s]
# 100%|██████████| 100/100 [00:00<00:00, 268.44it/s]
# 100%|██████████| 100/100 [00:00<00:00, 267.43it/s]
# 100%|██████████| 100/100 [00:00<00:00, 273.80it/s]
# 100%|██████████| 100/100 [00:00<00:00, 267.47it/s]
# 100%|██████████| 100/100 [00:00<00:00, 265.46it/s]
# 100%|██████████| 100/100 [00:00<00:00, 271.11it/s]
# 100%|██████████| 100/100 [00:00<00:00, 271.74it/s]
# 100%|██████████| 100/100 [00:00<00:00, 272.21it/s]
# 100%|██████████| 100/100 [00:00<00:00, 272.35it/s]
# 100%|██████████| 100/100 [00:00<00:00, 269.44it/s]
# 100%|██████████| 100/100 [00:00<00:00, 270.15it/s]
# 100%|██████████| 100/100 [00:00<00:00, 272.35it/s]
# 100%|██████████| 100/100 [00:00<00:00, 270.98it/s]
# 100%|██████████| 100/100 [00:00<00:00, 270.59it/s]
# 100%|██████████| 100/100 [00:00<00:00, 269.80it/s]
# 100%|██████████| 100/100 [00:00<00:00, 267.07it/s]
# 100%|██████████| 100/100 [00:00<00:00, 269.43it/s]
# 100%|██████████| 100/100 [00:00<00:00, 271.30it/s]
# 100%|██████████| 100/100 [00:00<00:00, 274.27it/s]
# 100%|██████████| 100/100 [00:00<00:00, 258.30it/s]
# 100%|██████████| 100/100 [00:00<00:00, 265.19it/s]
# 100%|██████████| 100/100 [00:00<00:00, 271.97it/s]
# 100%|██████████| 100/100 [00:00<00:00, 273.21it/s]
# 100%|██████████| 100/100 [00:00<00:00, 267.66it/s]
# 100%|██████████| 100/100 [00:00<00:00, 253.25it/s]
# 100%|██████████| 100/100 [00:00<00:00, 271.11it/s]
# Running loglikelihood requests: 100%|██████████| 22800/22800 [24:40<00:00, 15.40it/s]
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# hf ({'pretrained': 'EdgeCompress01/Llama-3.2-3B-Instruct-WANDA-AWQ-4bit', 'subfolder': 'Sparsity/70', 'max_length': 2048, 'dtype': 'float16', 'parallelize': True}), gen_kwargs: ({}), limit: 100.0, num_fewshot: 2, batch_size: 3
# |                 Tasks                 |Version|Filter|n-shot|Metric|   |Value |   |Stderr|
# |---------------------------------------|------:|------|-----:|------|---|-----:|---|-----:|
# |mmlu                                   |      2|none  |      |acc   |↑  |0.2477|±  |0.0057|
# | - humanities                          |      2|none  |      |acc   |↑  |0.2477|±  |0.0119|
# |  - formal_logic                       |      1|none  |     2|acc   |↑  |0.1300|±  |0.0338|
# |  - high_school_european_history       |      1|none  |     2|acc   |↑  |0.2500|±  |0.0435|
# |  - high_school_us_history             |      1|none  |     2|acc   |↑  |0.2500|±  |0.0435|
# |  - high_school_world_history          |      1|none  |     2|acc   |↑  |0.2700|±  |0.0446|
# |  - international_law                  |      1|none  |     2|acc   |↑  |0.2500|±  |0.0435|
# |  - jurisprudence                      |      1|none  |     2|acc   |↑  |0.3000|±  |0.0461|
# |  - logical_fallacies                  |      1|none  |     2|acc   |↑  |0.1900|±  |0.0394|
# |  - moral_disputes                     |      1|none  |     2|acc   |↑  |0.2300|±  |0.0423|
# |  - moral_scenarios                    |      1|none  |     2|acc   |↑  |0.2000|±  |0.0402|
# |  - philosophy                         |      1|none  |     2|acc   |↑  |0.3000|±  |0.0461|
# |  - prehistory                         |      1|none  |     2|acc   |↑  |0.2300|±  |0.0423|
# |  - professional_law                   |      1|none  |     2|acc   |↑  |0.2200|±  |0.0416|
# |  - world_religions                    |      1|none  |     2|acc   |↑  |0.4000|±  |0.0492|
# | - other                               |      2|none  |      |acc   |↑  |0.2746|±  |0.0124|
# |  - business_ethics                    |      1|none  |     2|acc   |↑  |0.2600|±  |0.0441|
# |  - clinical_knowledge                 |      1|none  |     2|acc   |↑  |0.3000|±  |0.0461|
# |  - college_medicine                   |      1|none  |     2|acc   |↑  |0.2100|±  |0.0409|
# |  - global_facts                       |      1|none  |     2|acc   |↑  |0.3200|±  |0.0469|
# |  - human_aging                        |      1|none  |     2|acc   |↑  |0.3100|±  |0.0465|
# |  - management                         |      1|none  |     2|acc   |↑  |0.1800|±  |0.0386|
# |  - marketing                          |      1|none  |     2|acc   |↑  |0.3300|±  |0.0473|
# |  - medical_genetics                   |      1|none  |     2|acc   |↑  |0.3100|±  |0.0465|
# |  - miscellaneous                      |      1|none  |     2|acc   |↑  |0.3000|±  |0.0461|
# |  - nutrition                          |      1|none  |     2|acc   |↑  |0.2100|±  |0.0409|
# |  - professional_accounting            |      1|none  |     2|acc   |↑  |0.2200|±  |0.0416|
# |  - professional_medicine              |      1|none  |     2|acc   |↑  |0.3600|±  |0.0482|
# |  - virology                           |      1|none  |     2|acc   |↑  |0.2600|±  |0.0441|
# | - social sciences                     |      2|none  |      |acc   |↑  |0.2125|±  |0.0118|
# |  - econometrics                       |      1|none  |     2|acc   |↑  |0.2000|±  |0.0402|
# |  - high_school_geography              |      1|none  |     2|acc   |↑  |0.1700|±  |0.0378|
# |  - high_school_government_and_politics|      1|none  |     2|acc   |↑  |0.1600|±  |0.0368|
# |  - high_school_macroeconomics         |      1|none  |     2|acc   |↑  |0.2700|±  |0.0446|
# |  - high_school_microeconomics         |      1|none  |     2|acc   |↑  |0.1700|±  |0.0378|
# |  - high_school_psychology             |      1|none  |     2|acc   |↑  |0.2300|±  |0.0423|
# |  - human_sexuality                    |      1|none  |     2|acc   |↑  |0.2100|±  |0.0409|
# |  - professional_psychology            |      1|none  |     2|acc   |↑  |0.2400|±  |0.0429|
# |  - public_relations                   |      1|none  |     2|acc   |↑  |0.2100|±  |0.0409|
# |  - security_studies                   |      1|none  |     2|acc   |↑  |0.2100|±  |0.0409|
# |  - sociology                          |      1|none  |     2|acc   |↑  |0.2000|±  |0.0402|
# |  - us_foreign_policy                  |      1|none  |     2|acc   |↑  |0.2800|±  |0.0451|
# | - stem                                |      2|none  |      |acc   |↑  |0.2516|±  |0.0098|
# |  - abstract_algebra                   |      1|none  |     2|acc   |↑  |0.3100|±  |0.0465|
# |  - anatomy                            |      1|none  |     2|acc   |↑  |0.1600|±  |0.0368|
# |  - astronomy                          |      1|none  |     2|acc   |↑  |0.1800|±  |0.0386|
# |  - college_biology                    |      1|none  |     2|acc   |↑  |0.2500|±  |0.0435|
# |  - college_chemistry                  |      1|none  |     2|acc   |↑  |0.2800|±  |0.0451|
# |  - college_computer_science           |      1|none  |     2|acc   |↑  |0.1700|±  |0.0378|
# |  - college_mathematics                |      1|none  |     2|acc   |↑  |0.2500|±  |0.0435|
# |  - college_physics                    |      1|none  |     2|acc   |↑  |0.2100|±  |0.0409|
# |  - computer_security                  |      1|none  |     2|acc   |↑  |0.2700|±  |0.0446|
# |  - conceptual_physics                 |      1|none  |     2|acc   |↑  |0.3300|±  |0.0473|
# |  - electrical_engineering             |      1|none  |     2|acc   |↑  |0.2700|±  |0.0446|
# |  - elementary_mathematics             |      1|none  |     2|acc   |↑  |0.2600|±  |0.0441|
# |  - high_school_biology                |      1|none  |     2|acc   |↑  |0.1200|±  |0.0327|
# |  - high_school_chemistry              |      1|none  |     2|acc   |↑  |0.1800|±  |0.0386|
# |  - high_school_computer_science       |      1|none  |     2|acc   |↑  |0.3000|±  |0.0461|
# |  - high_school_mathematics            |      1|none  |     2|acc   |↑  |0.2400|±  |0.0429|
# |  - high_school_physics                |      1|none  |     2|acc   |↑  |0.2100|±  |0.0409|
# |  - high_school_statistics             |      1|none  |     2|acc   |↑  |0.4800|±  |0.0502|
# |  - machine_learning                   |      1|none  |     2|acc   |↑  |0.3100|±  |0.0465|
#
# |      Groups      |Version|Filter|n-shot|Metric|   |Value |   |Stderr|
# |------------------|------:|------|------|------|---|-----:|---|-----:|
# |mmlu              |      2|none  |      |acc   |↑  |0.2477|±  |0.0057|
# | - humanities     |      2|none  |      |acc   |↑  |0.2477|±  |0.0119|
# | - other          |      2|none  |      |acc   |↑  |0.2746|±  |0.0124|
# | - social sciences|      2|none  |      |acc   |↑  |0.2125|±  |0.0118|
# | - stem           |      2|none  |      |acc   |↑  |0.2516|±  |0.0098|
#
# Finished mmlu
#
# Starting evaluation for: arc_challenge
# 2026-03-28:18:17:12 WARNING  [config.evaluate_config:281] --limit SHOULD ONLY BE USED FOR TESTING. REAL METRICS SHOULD NOT BE COMPUTED USING LIMIT.
# 2026-03-28:18:17:17 INFO     [_cli.run:376] Selected Tasks: ['arc_challenge']
# 2026-03-28:18:17:17 WARNING  [evaluator:181] pretrained=EdgeCompress01/Llama-3.2-3B-Instruct-WANDA-AWQ-4bit appears to be an instruct or chat variant but chat template is not applied.
#         Recommend setting `apply_chat_template` (optionally `fewshot_as_multiturn`).
# 2026-03-28 18:17:24.701269: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774721844.721968    1173 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774721844.727958    1173 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774721844.744036    1173 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774721844.744057    1173 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774721844.744060    1173 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774721844.744062    1173 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# /usr/local/lib/python3.12/dist-packages/transformers/quantizers/auto.py:239: UserWarning: You passed `quantization_config` or equivalent parameters to `from_pretrained` but the model you're loading already has a `quantization_config` attribute. The `quantization_config` from the model will be used.However, loading attributes (e.g. ['run_compressed']) will be overwritten with the one you passed to `from_pretrained`. The rest will be ignored.
#   warnings.warn(warning_msg)
# Compressing model: 196it [00:00, 1334.82it/s]
# Generating train split: 100%|██████████| 1119/1119 [00:00<00:00, 169854.74 examples/s]
# Generating test split: 100%|██████████| 1172/1172 [00:00<00:00, 245307.86 examples/s]
# Generating validation split: 100%|██████████| 299/299 [00:00<00:00, 112768.36 examples/s]
# 2026-03-28:18:17:34 WARNING  [evaluator:333] Overwriting default num_fewshot of arc_challenge from None to 0
# 100%|██████████| 100/100 [00:00<00:00, 518.23it/s]
# Running loglikelihood requests: 100%|██████████| 400/400 [00:56<00:00,  7.13it/s]
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# hf ({'pretrained': 'EdgeCompress01/Llama-3.2-3B-Instruct-WANDA-AWQ-4bit', 'subfolder': 'Sparsity/70', 'max_length': 2048, 'dtype': 'float16', 'parallelize': True}), gen_kwargs: ({}), limit: 100.0, num_fewshot: 0, batch_size: 3
# |    Tasks    |Version|Filter|n-shot| Metric |   |Value|   |Stderr|
# |-------------|------:|------|-----:|--------|---|----:|---|-----:|
# |arc_challenge|      1|none  |     0|acc     |↑  | 0.20|±  |0.0402|
# |             |       |none  |     0|acc_norm|↑  | 0.23|±  |0.0423|
#
# Finished arc_challenge
#
# Starting evaluation for: wikitext
# 2026-03-28:18:18:36 WARNING  [config.evaluate_config:281] --limit SHOULD ONLY BE USED FOR TESTING. REAL METRICS SHOULD NOT BE COMPUTED USING LIMIT.
# 2026-03-28:18:18:41 INFO     [_cli.run:376] Selected Tasks: ['wikitext']
# 2026-03-28:18:18:41 WARNING  [evaluator:181] pretrained=EdgeCompress01/Llama-3.2-3B-Instruct-WANDA-AWQ-4bit appears to be an instruct or chat variant but chat template is not applied.
#         Recommend setting `apply_chat_template` (optionally `fewshot_as_multiturn`).
# 2026-03-28 18:18:48.589785: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774721928.612941    1249 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774721928.619050    1249 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774721928.634763    1249 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774721928.634805    1249 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774721928.634810    1249 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774721928.634814    1249 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# /usr/local/lib/python3.12/dist-packages/transformers/quantizers/auto.py:239: UserWarning: You passed `quantization_config` or equivalent parameters to `from_pretrained` but the model you're loading already has a `quantization_config` attribute. The `quantization_config` from the model will be used.However, loading attributes (e.g. ['run_compressed']) will be overwritten with the one you passed to `from_pretrained`. The rest will be ignored.
#   warnings.warn(warning_msg)
# Compressing model: 196it [00:00, 1244.43it/s]
# 2026-03-28:18:18:56 WARNING  [api.task:729] [Task: wikitext] metric word_perplexity is defined, but aggregation is not. using default aggregation=weighted_perplexity
# 2026-03-28:18:18:56 WARNING  [api.task:741] [Task: wikitext] metric word_perplexity is defined, but higher_is_better is not. using default higher_is_better=False
# 2026-03-28:18:18:56 WARNING  [api.task:729] [Task: wikitext] metric byte_perplexity is defined, but aggregation is not. using default aggregation=weighted_perplexity
# 2026-03-28:18:18:56 WARNING  [api.task:741] [Task: wikitext] metric byte_perplexity is defined, but higher_is_better is not. using default higher_is_better=False
# 2026-03-28:18:18:56 WARNING  [api.task:729] [Task: wikitext] metric bits_per_byte is defined, but aggregation is not. using default aggregation=bits_per_byte
# 2026-03-28:18:18:56 WARNING  [api.task:741] [Task: wikitext] metric bits_per_byte is defined, but higher_is_better is not. using default higher_is_better=False
# Generating train split: 100%|██████████| 629/629 [00:00<00:00, 8407.00 examples/s]
# Generating validation split: 100%|██████████| 60/60 [00:00<00:00, 9739.10 examples/s]
# Generating test split: 100%|██████████| 62/62 [00:00<00:00, 10810.51 examples/s]
# 2026-03-28:18:18:59 WARNING  [evaluator:333] Overwriting default num_fewshot of wikitext from None to 0
# 100%|██████████| 62/62 [00:00<00:00, 333.36it/s]
# 100%|██████████| 62/62 [00:00<00:00, 106.82it/s]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:06<00:00,  2.02s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:04<00:00,  1.62s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:04<00:00,  1.65s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:04<00:00,  1.66s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.69s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.72s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.73s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.76s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.78s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.79s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.80s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.79s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.74s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.72s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.71s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.68s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.68s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.68s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.67s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.68s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.69s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.70s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.72s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.72s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.73s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.73s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:02<00:00,  1.00it/s]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.73s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.73s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.72s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.73s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.71s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.72s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.71s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.72s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.71s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.71s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.72s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.71s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.72s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.73s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.72s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.73s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.72s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.73s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.72s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.72s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.72s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:02<00:00,  1.18it/s]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.73s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.71s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.72s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.73s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:05<00:00,  1.72s/it]
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# hf ({'pretrained': 'EdgeCompress01/Llama-3.2-3B-Instruct-WANDA-AWQ-4bit', 'subfolder': 'Sparsity/70', 'max_length': 2048, 'dtype': 'float16', 'parallelize': True}), gen_kwargs: ({}), limit: 100.0, num_fewshot: 0, batch_size: 3
# | Tasks  |Version|Filter|n-shot|    Metric     |   | Value  |   |Stderr|
# |--------|------:|------|-----:|---------------|---|-------:|---|------|
# |wikitext|      2|none  |     0|bits_per_byte  |↓  |  1.8182|±  |   N/A|
# |        |       |none  |     0|byte_perplexity|↓  |  3.5265|±  |   N/A|
# |        |       |none  |     0|word_perplexity|↓  |845.0620|±  |   N/A|
#
# Finished wikitext

# %% [markdown]
# # Save reports

# %%
zip_path = shutil.make_archive(f"evaluation_results", 'zip', f"evaluation_results")
FileLink(zip_path)
# Out:
# /kaggle/working/evaluation_results.zip
