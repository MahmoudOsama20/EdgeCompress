# %% [markdown]
# # Libraries

# %%
# !pip -q install "lm_eval[hf]"
# !pip -q install compressed-tensors
# !pip install --upgrade transformers #FIX
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.4/56.4 kB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 66.4 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 5.5 MB/s eta 0:00:00
#   Building wheel for sqlitedict (setup.py) ... done
#   Building wheel for word2number (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 1.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.5/196.5 kB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 90.8 MB/s eta 0:00:00:00:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 33.0 MB/s eta 0:00:00
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.6)
# Collecting transformers
#   Downloading transformers-5.4.0-py3-none-any.whl.metadata (32 kB)
# Collecting huggingface-hub<2.0,>=1.5.0 (from transformers)
#   Downloading huggingface_hub-1.8.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from transformers) (0.24.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.3)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (3.24.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (2026.2.0)
# Collecting hf-xet<2.0.0,>=1.4.2 (from huggingface-hub<2.0,>=1.5.0->transformers)
#   Downloading hf_xet-1.4.2-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers) (0.1.2)
# Downloading transformers-5.4.0-py3-none-any.whl (10.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 71.4 MB/s eta 0:00:00:00:01:01
# Downloading huggingface_hub-1.8.0-py3-none-any.whl (625 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 625.2/625.2 kB 36.0 MB/s eta 0:00:00
# Downloading hf_xet-1.4.2-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 107.0 MB/s eta 0:00:0000:01
# Installing collected packages: hf-xet, huggingface-hub, transformers
#   Attempting uninstall: hf-xet
#     Found existing installation: hf-xet 1.3.0
#     Uninstalling hf-xet-1.3.0:
#       Successfully uninstalled hf-xet-1.3.0
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 0.36.2
#     Uninstalling huggingface_hub-0.36.2:
#       Successfully uninstalled huggingface_hub-0.36.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.57.6
#     Uninstalling transformers-4.57.6:
#       Successfully uninstalled transformers-4.57.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# compressed-tensors 0.14.0.1 requires transformers<5.0.0, but you have transformers 5.4.0 which is incompatible.
# Successfully installed hf-xet-1.4.2 huggingface-hub-1.8.0 transformers-5.4.0

# %%
# 2. Libraries
import random
import numpy as np
import torch
import os
import gc

import lm_eval
import subprocess

from huggingface_hub import login
from kaggle_secrets import UserSecretsClient

import shutil
from IPython.display import FileLink

# %% [markdown]
# # Functions

# %%
# --- 2. REPRODUCIBILITY ---
def set_reproducibility(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    # Ensure deterministic behavior in CuDNN
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    print(f"Global seed set to {seed}")

# %% [markdown]
# # Global Variables

# %%
model_name = "EdgeCompress01/Qwen3-4B-SparseGPT"
subfolder = "Models/25"
SEED = 42
os.environ["HF_ALLOW_CODE_EVAL"] = "1"

# %% [markdown]
# # Seed for reproducibility

# %%
set_reproducibility(SEED)
# Out:
# Global seed set to 42

# %% [markdown]
# # Login to huggingface

# %%
# --- 3. HUGGING FACE AUTHENTICATION ---
user_secrets = UserSecretsClient()
hf_token = user_secrets.get_secret("HF_TOKEN")
login(token=hf_token)
print("Logging into Hugging Face...")
# Out:
# Logging into Hugging Face...

# %% [markdown]
# # Do Evaluation

# %% [markdown]
# **Configurations**

# %%
tasks_config = {
    "gsm8k": {
        "task_name": "gsm8k_cot",
        "fewshot": 2   # 🔻 reduced from 8
    },
    "mmlu": {
        "task_name": "mmlu",
        "fewshot": 2   # 🔻 reduced from 5
    },
    "arc_challenge": {
        "task_name": "arc_challenge",
        "fewshot": 0   # keep
    },
    "wikitext": {
        "task_name": "wikitext",
        "fewshot": 0   # keep
    }
}

# %%
for task, cfg in tasks_config.items():
    print(f"Starting evaluation for: {task}")

    model_args = f"pretrained={model_name},subfolder={subfolder},max_length=2048,dtype=float16,parallelize=True"
    command = [
        "lm_eval",
        "--model", "hf",
        "--model_args", model_args,
        "--tasks", cfg["task_name"],
        "--batch_size", str(3),   
        "--verbosity", "WARNING",
        "--seed", str(SEED),
        "--limit", str(100),
        "--num_fewshot", str(cfg["fewshot"]),
        "--output_path", f"evaluation_results/{task}"
    ]

    subprocess.run(command, check=True)
    
    torch.cuda.empty_cache()
    gc.collect()
    print(f"Finished {task}\n")
# Out:
# Starting evaluation for: gsm8k
# 2026-03-27:12:00:27 WARNING  [config.evaluate_config:281] --limit SHOULD ONLY BE USED FOR TESTING. REAL METRICS SHOULD NOT BE COMPUTED USING LIMIT.
# 2026-03-27:12:00:34 INFO     [_cli.run:376] Selected Tasks: ['gsm8k_cot']
# Loading weights: 100%|██████████| 398/398 [00:02<00:00, 178.11it/s]
# Generating train split: 100%|██████████| 7473/7473 [00:00<00:00, 122032.92 examples/s]
# Generating test split: 100%|██████████| 1319/1319 [00:00<00:00, 288064.93 examples/s]
# 2026-03-27:12:01:27 WARNING  [evaluator:333] Overwriting default num_fewshot of gsm8k_cot from 8 to 2
# 100%|██████████| 100/100 [00:00<00:00, 194.52it/s]
# Running generate_until requests:   0%|          | 0/100 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Running generate_until requests: 100%|██████████| 100/100 [06:17<00:00,  3.78s/it]
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# hf ({'pretrained': 'EdgeCompress01/Qwen3-4B-SparseGPT', 'subfolder': 'Models/25', 'max_length': 2048, 'dtype': 'float16', 'parallelize': True}), gen_kwargs: ({}), limit: 100.0, num_fewshot: 2, batch_size: 3
# |  Tasks  |Version|     Filter     |n-shot|  Metric   |   |Value|   |Stderr|
# |---------|------:|----------------|-----:|-----------|---|----:|---|-----:|
# |gsm8k_cot|      3|flexible-extract|     2|exact_match|↑  | 0.84|±  |0.0368|
# |         |       |strict-match    |     2|exact_match|↑  | 0.71|±  |0.0456|
#
# Finished gsm8k
#
# Starting evaluation for: mmlu
# 2026-03-27:12:07:52 WARNING  [config.evaluate_config:281] --limit SHOULD ONLY BE USED FOR TESTING. REAL METRICS SHOULD NOT BE COMPUTED USING LIMIT.
# 2026-03-27:12:07:58 INFO     [_cli.run:376] Selected Tasks: ['mmlu']
# Loading weights: 100%|██████████| 398/398 [00:02<00:00, 183.14it/s]
# Generating test split: 100%|██████████| 171/171 [00:00<00:00, 26985.70 examples/s]
# Generating validation split: 100%|██████████| 19/19 [00:00<00:00, 7663.41 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2438.27 examples/s]
# Generating test split: 100%|██████████| 1534/1534 [00:00<00:00, 130175.66 examples/s]
# Generating validation split: 100%|██████████| 170/170 [00:00<00:00, 61157.19 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2126.93 examples/s]
# Generating test split: 100%|██████████| 324/324 [00:00<00:00, 88026.59 examples/s]
# Generating validation split: 100%|██████████| 35/35 [00:00<00:00, 15045.67 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2206.37 examples/s]
# Generating test split: 100%|██████████| 311/311 [00:00<00:00, 98902.76 examples/s]
# Generating validation split: 100%|██████████| 34/34 [00:00<00:00, 14904.51 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2282.99 examples/s]
# Generating test split: 100%|██████████| 895/895 [00:00<00:00, 199984.13 examples/s]
# Generating validation split: 100%|██████████| 100/100 [00:00<00:00, 44229.72 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2467.53 examples/s]
# Generating test split: 100%|██████████| 346/346 [00:00<00:00, 100153.84 examples/s]
# Generating validation split: 100%|██████████| 38/38 [00:00<00:00, 16320.25 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2476.56 examples/s]
# Generating test split: 100%|██████████| 163/163 [00:00<00:00, 57664.60 examples/s]
# Generating validation split: 100%|██████████| 18/18 [00:00<00:00, 7831.69 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2440.82 examples/s]
# Generating test split: 100%|██████████| 108/108 [00:00<00:00, 39652.03 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 4889.50 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2566.27 examples/s]
# Generating test split: 100%|██████████| 121/121 [00:00<00:00, 40760.64 examples/s]
# Generating validation split: 100%|██████████| 13/13 [00:00<00:00, 6168.09 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2560.00 examples/s]
# Generating test split: 100%|██████████| 237/237 [00:00<00:00, 49717.42 examples/s]
# Generating validation split: 100%|██████████| 26/26 [00:00<00:00, 11262.20 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2420.54 examples/s]
# Generating test split: 100%|██████████| 204/204 [00:00<00:00, 50316.85 examples/s]
# Generating validation split: 100%|██████████| 22/22 [00:00<00:00, 10319.24 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2351.59 examples/s]
# Generating test split: 100%|██████████| 165/165 [00:00<00:00, 44686.52 examples/s]
# Generating validation split: 100%|██████████| 18/18 [00:00<00:00, 7898.88 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2565.64 examples/s]
# Generating test split: 100%|██████████| 126/126 [00:00<00:00, 42441.56 examples/s]
# Generating validation split: 100%|██████████| 14/14 [00:00<00:00, 6592.60 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2589.08 examples/s]
# Generating test split: 100%|██████████| 100/100 [00:00<00:00, 33277.56 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 4756.43 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2419.70 examples/s]
# Generating test split: 100%|██████████| 201/201 [00:00<00:00, 68191.79 examples/s]
# Generating validation split: 100%|██████████| 22/22 [00:00<00:00, 10147.88 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2445.66 examples/s]
# Generating test split: 100%|██████████| 245/245 [00:00<00:00, 71455.70 examples/s]
# Generating validation split: 100%|██████████| 27/27 [00:00<00:00, 11762.17 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2245.83 examples/s]
# Generating test split: 100%|██████████| 110/110 [00:00<00:00, 35586.07 examples/s]
# Generating validation split: 100%|██████████| 12/12 [00:00<00:00, 5358.99 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2538.92 examples/s]
# Generating test split: 100%|██████████| 612/612 [00:00<00:00, 161228.19 examples/s]
# Generating validation split: 100%|██████████| 69/69 [00:00<00:00, 29673.64 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2242.70 examples/s]
# Generating test split: 100%|██████████| 131/131 [00:00<00:00, 43182.48 examples/s]
# Generating validation split: 100%|██████████| 12/12 [00:00<00:00, 5563.35 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2584.93 examples/s]
# Generating test split: 100%|██████████| 545/545 [00:00<00:00, 160020.70 examples/s]
# Generating validation split: 100%|██████████| 60/60 [00:00<00:00, 26003.12 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2419.14 examples/s]
# Generating test split: 100%|██████████| 238/238 [00:00<00:00, 77545.59 examples/s]
# Generating validation split: 100%|██████████| 26/26 [00:00<00:00, 11991.63 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2515.17 examples/s]
# Generating test split: 100%|██████████| 390/390 [00:00<00:00, 125635.83 examples/s]
# Generating validation split: 100%|██████████| 43/43 [00:00<00:00, 17699.22 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2366.45 examples/s]
# Generating test split: 100%|██████████| 193/193 [00:00<00:00, 64646.28 examples/s]
# Generating validation split: 100%|██████████| 21/21 [00:00<00:00, 8862.99 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2375.84 examples/s]
# Generating test split: 100%|██████████| 198/198 [00:00<00:00, 66651.06 examples/s]
# Generating validation split: 100%|██████████| 22/22 [00:00<00:00, 9057.19 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2530.96 examples/s]
# Generating test split: 100%|██████████| 114/114 [00:00<00:00, 38381.01 examples/s]
# Generating validation split: 100%|██████████| 12/12 [00:00<00:00, 5329.48 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2106.63 examples/s]
# Generating test split: 100%|██████████| 166/166 [00:00<00:00, 57140.29 examples/s]
# Generating validation split: 100%|██████████| 18/18 [00:00<00:00, 7504.72 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2270.14 examples/s]
# Generating test split: 100%|██████████| 272/272 [00:00<00:00, 70658.41 examples/s]
# Generating validation split: 100%|██████████| 31/31 [00:00<00:00, 13096.64 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2245.83 examples/s]
# Generating test split: 100%|██████████| 282/282 [00:00<00:00, 86950.95 examples/s]
# Generating validation split: 100%|██████████| 31/31 [00:00<00:00, 13727.14 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2511.56 examples/s]
# Generating test split: 100%|██████████| 306/306 [00:00<00:00, 95988.11 examples/s]
# Generating validation split: 100%|██████████| 33/33 [00:00<00:00, 13663.58 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2312.19 examples/s]
# Generating test split: 100%|██████████| 783/783 [00:00<00:00, 251446.29 examples/s]
# Generating validation split: 100%|██████████| 86/86 [00:00<00:00, 37865.86 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2339.53 examples/s]
# Generating test split: 100%|██████████| 100/100 [00:00<00:00, 35647.66 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 4972.23 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2425.57 examples/s]
# Generating test split: 100%|██████████| 234/234 [00:00<00:00, 84159.42 examples/s]
# Generating validation split: 100%|██████████| 25/25 [00:00<00:00, 11623.72 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2714.76 examples/s]
# Generating test split: 100%|██████████| 103/103 [00:00<00:00, 38173.84 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 4922.89 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2543.24 examples/s]
# Generating test split: 100%|██████████| 223/223 [00:00<00:00, 75235.67 examples/s]
# Generating validation split: 100%|██████████| 23/23 [00:00<00:00, 11059.15 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2625.05 examples/s]
# Generating test split: 100%|██████████| 100/100 [00:00<00:00, 35815.08 examples/s]
# Generating validation split: 100%|██████████| 10/10 [00:00<00:00, 4672.28 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2186.81 examples/s]
# Generating test split: 100%|██████████| 173/173 [00:00<00:00, 53213.16 examples/s]
# Generating validation split: 100%|██████████| 22/22 [00:00<00:00, 9118.05 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2210.55 examples/s]
# Generating test split: 100%|██████████| 265/265 [00:00<00:00, 86991.51 examples/s]
# Generating validation split: 100%|██████████| 29/29 [00:00<00:00, 13527.00 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2537.39 examples/s]
# Generating test split: 100%|██████████| 100/100 [00:00<00:00, 35681.02 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 4530.38 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2489.50 examples/s]
# Generating test split: 100%|██████████| 112/112 [00:00<00:00, 40164.33 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 5196.23 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2305.07 examples/s]
# Generating test split: 100%|██████████| 216/216 [00:00<00:00, 68148.76 examples/s]
# Generating validation split: 100%|██████████| 23/23 [00:00<00:00, 10185.72 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2538.62 examples/s]
# Generating test split: 100%|██████████| 151/151 [00:00<00:00, 52963.70 examples/s]
# Generating validation split: 100%|██████████| 17/17 [00:00<00:00, 7634.17 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2527.60 examples/s]
# Generating test split: 100%|██████████| 270/270 [00:00<00:00, 90502.84 examples/s]
# Generating validation split: 100%|██████████| 29/29 [00:00<00:00, 12706.03 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2283.98 examples/s]
# Generating test split: 100%|██████████| 100/100 [00:00<00:00, 32204.42 examples/s]
# Generating validation split: 100%|██████████| 9/9 [00:00<00:00, 3966.04 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2438.27 examples/s]
# Generating test split: 100%|██████████| 203/203 [00:00<00:00, 65030.45 examples/s]
# Generating validation split: 100%|██████████| 22/22 [00:00<00:00, 9315.97 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2240.31 examples/s]
# Generating test split: 100%|██████████| 310/310 [00:00<00:00, 89882.08 examples/s]
# Generating validation split: 100%|██████████| 32/32 [00:00<00:00, 13771.57 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2504.06 examples/s]
# Generating test split: 100%|██████████| 378/378 [00:00<00:00, 120383.21 examples/s]
# Generating validation split: 100%|██████████| 41/41 [00:00<00:00, 17831.45 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2481.25 examples/s]
# Generating test split: 100%|██████████| 145/145 [00:00<00:00, 44633.35 examples/s]
# Generating validation split: 100%|██████████| 16/16 [00:00<00:00, 6372.51 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2279.02 examples/s]
# Generating test split: 100%|██████████| 235/235 [00:00<00:00, 76490.88 examples/s]
# Generating validation split: 100%|██████████| 26/26 [00:00<00:00, 9991.01 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2123.27 examples/s]
# Generating test split: 100%|██████████| 100/100 [00:00<00:00, 33950.98 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 4797.48 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2416.35 examples/s]
# Generating test split: 100%|██████████| 102/102 [00:00<00:00, 37050.23 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 4633.19 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2243.90 examples/s]
# Generating test split: 100%|██████████| 100/100 [00:00<00:00, 35272.93 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 4936.06 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2506.46 examples/s]
# Generating test split: 100%|██████████| 100/100 [00:00<00:00, 32561.94 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 5020.39 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2403.34 examples/s]
# Generating test split: 100%|██████████| 100/100 [00:00<00:00, 38318.14 examples/s]
# Generating validation split: 100%|██████████| 8/8 [00:00<00:00, 3706.85 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2401.69 examples/s]
# Generating test split: 100%|██████████| 144/144 [00:00<00:00, 52031.34 examples/s]
# Generating validation split: 100%|██████████| 16/16 [00:00<00:00, 6947.81 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2748.20 examples/s]
# Generating test split: 100%|██████████| 152/152 [00:00<00:00, 49955.67 examples/s]
# Generating validation split: 100%|██████████| 16/16 [00:00<00:00, 6745.97 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2300.01 examples/s]
# Generating test split: 100%|██████████| 135/135 [00:00<00:00, 48981.92 examples/s]
# Generating validation split: 100%|██████████| 14/14 [00:00<00:00, 6036.83 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2484.19 examples/s]
# Generating test split: 100%|██████████| 100/100 [00:00<00:00, 35019.65 examples/s]
# Generating validation split: 100%|██████████| 11/11 [00:00<00:00, 4978.13 examples/s]
# Generating dev split: 100%|██████████| 5/5 [00:00<00:00, 2241.50 examples/s]
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_abstract_algebra from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_anatomy from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_astronomy from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_college_biology from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_college_chemistry from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_college_computer_science from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_college_mathematics from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_college_physics from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_computer_security from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_conceptual_physics from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_electrical_engineering from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_elementary_mathematics from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_biology from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_chemistry from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_computer_science from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_mathematics from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_physics from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_statistics from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_machine_learning from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_business_ethics from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_clinical_knowledge from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_college_medicine from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_global_facts from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_human_aging from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_management from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_marketing from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_medical_genetics from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_miscellaneous from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_nutrition from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_professional_accounting from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_professional_medicine from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_virology from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_econometrics from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_geography from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_government_and_politics from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_macroeconomics from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_microeconomics from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_psychology from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_human_sexuality from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_professional_psychology from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_public_relations from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_security_studies from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_sociology from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_us_foreign_policy from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_formal_logic from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_european_history from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_us_history from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_high_school_world_history from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_international_law from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_jurisprudence from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_logical_fallacies from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_moral_disputes from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_moral_scenarios from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_philosophy from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_prehistory from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_professional_law from None to 2
# 2026-03-27:12:09:41 WARNING  [evaluator:333] Overwriting default num_fewshot of mmlu_world_religions from None to 2
# 100%|██████████| 100/100 [00:00<00:00, 228.30it/s]
# 100%|██████████| 100/100 [00:00<00:00, 250.78it/s]
# 100%|██████████| 100/100 [00:00<00:00, 251.43it/s]
# 100%|██████████| 100/100 [00:00<00:00, 254.59it/s]
# 100%|██████████| 100/100 [00:00<00:00, 250.41it/s]
# 100%|██████████| 100/100 [00:00<00:00, 252.38it/s]
# 100%|██████████| 100/100 [00:00<00:00, 251.42it/s]
# 100%|██████████| 100/100 [00:00<00:00, 242.34it/s]
# 100%|██████████| 100/100 [00:00<00:00, 254.67it/s]
# 100%|██████████| 100/100 [00:00<00:00, 250.24it/s]
# 100%|██████████| 100/100 [00:00<00:00, 249.55it/s]
# 100%|██████████| 100/100 [00:00<00:00, 242.35it/s]
# 100%|██████████| 100/100 [00:00<00:00, 251.16it/s]
# 100%|██████████| 100/100 [00:00<00:00, 251.78it/s]
# 100%|██████████| 100/100 [00:00<00:00, 249.05it/s]
# 100%|██████████| 100/100 [00:00<00:00, 248.94it/s]
# 100%|██████████| 100/100 [00:00<00:00, 231.94it/s]
# 100%|██████████| 100/100 [00:00<00:00, 239.43it/s]
# 100%|██████████| 100/100 [00:00<00:00, 249.21it/s]
# 100%|██████████| 100/100 [00:00<00:00, 250.07it/s]
# 100%|██████████| 100/100 [00:00<00:00, 249.73it/s]
# 100%|██████████| 100/100 [00:00<00:00, 246.47it/s]
# 100%|██████████| 100/100 [00:00<00:00, 248.64it/s]
# 100%|██████████| 100/100 [00:00<00:00, 248.16it/s]
# 100%|██████████| 100/100 [00:00<00:00, 237.12it/s]
# 100%|██████████| 100/100 [00:00<00:00, 247.66it/s]
# 100%|██████████| 100/100 [00:00<00:00, 247.52it/s]
# 100%|██████████| 100/100 [00:00<00:00, 247.59it/s]
# 100%|██████████| 100/100 [00:00<00:00, 251.24it/s]
# 100%|██████████| 100/100 [00:00<00:00, 249.79it/s]
# 100%|██████████| 100/100 [00:00<00:00, 248.64it/s]
# 100%|██████████| 100/100 [00:00<00:00, 249.42it/s]
# 100%|██████████| 100/100 [00:00<00:00, 247.68it/s]
# 100%|██████████| 100/100 [00:00<00:00, 250.89it/s]
# 100%|██████████| 100/100 [00:00<00:00, 250.06it/s]
# 100%|██████████| 100/100 [00:00<00:00, 248.39it/s]
# 100%|██████████| 100/100 [00:00<00:00, 248.06it/s]
# 100%|██████████| 100/100 [00:00<00:00, 247.02it/s]
# 100%|██████████| 100/100 [00:00<00:00, 251.66it/s]
# 100%|██████████| 100/100 [00:00<00:00, 248.66it/s]
# 100%|██████████| 100/100 [00:00<00:00, 251.66it/s]
# 100%|██████████| 100/100 [00:00<00:00, 239.74it/s]
# 100%|██████████| 100/100 [00:00<00:00, 248.58it/s]
# 100%|██████████| 100/100 [00:00<00:00, 253.33it/s]
# 100%|██████████| 100/100 [00:00<00:00, 252.80it/s]
# 100%|██████████| 100/100 [00:00<00:00, 252.53it/s]
# 100%|██████████| 100/100 [00:00<00:00, 249.99it/s]
# 100%|██████████| 100/100 [00:00<00:00, 251.32it/s]
# 100%|██████████| 100/100 [00:00<00:00, 245.40it/s]
# 100%|██████████| 100/100 [00:00<00:00, 243.94it/s]
# 100%|██████████| 100/100 [00:00<00:00, 255.03it/s]
# 100%|██████████| 100/100 [00:00<00:00, 249.47it/s]
# 100%|██████████| 100/100 [00:00<00:00, 253.82it/s]
# 100%|██████████| 100/100 [00:00<00:00, 253.85it/s]
# 100%|██████████| 100/100 [00:00<00:00, 252.43it/s]
# 100%|██████████| 100/100 [00:00<00:00, 253.28it/s]
# 100%|██████████| 100/100 [00:00<00:00, 254.12it/s]
# Running loglikelihood requests: 100%|██████████| 22800/22800 [20:18<00:00, 18.71it/s]
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# hf ({'pretrained': 'EdgeCompress01/Qwen3-4B-SparseGPT', 'subfolder': 'Models/25', 'max_length': 2048, 'dtype': 'float16', 'parallelize': True}), gen_kwargs: ({}), limit: 100.0, num_fewshot: 2, batch_size: 3
# |                 Tasks                 |Version|Filter|n-shot|Metric|   |Value |   |Stderr|
# |---------------------------------------|------:|------|-----:|------|---|-----:|---|-----:|
# |mmlu                                   |      2|none  |      |acc   |↑  |0.6981|±  |0.0059|
# | - humanities                          |      2|none  |      |acc   |↑  |0.6946|±  |0.0123|
# |  - formal_logic                       |      1|none  |     2|acc   |↑  |0.5300|±  |0.0502|
# |  - high_school_european_history       |      1|none  |     2|acc   |↑  |0.7400|±  |0.0441|
# |  - high_school_us_history             |      1|none  |     2|acc   |↑  |0.8700|±  |0.0338|
# |  - high_school_world_history          |      1|none  |     2|acc   |↑  |0.8200|±  |0.0386|
# |  - international_law         Finished mmlu
#
# Starting evaluation for: arc_challenge
# 2026-03-27:12:31:10 WARNING  [config.evaluate_config:281] --limit SHOULD ONLY BE USED FOR TESTING. REAL METRICS SHOULD NOT BE COMPUTED USING LIMIT.
# 2026-03-27:12:31:15 INFO     [_cli.run:376] Selected Tasks: ['arc_challenge']
# Loading weights: 100%|██████████| 398/398 [00:02<00:00, 184.47it/s]
# Generating train split: 100%|██████████| 1119/1119 [00:00<00:00, 182212.37 examples/s]
# Generating test split: 100%|██████████| 1172/1172 [00:00<00:00, 268780.38 examples/s]
# Generating validation split: 100%|██████████| 299/299 [00:00<00:00, 111149.24 examples/s]
# 2026-03-27:12:31:29 WARNING  [evaluator:333] Overwriting default num_fewshot of arc_challenge from None to 0
# 100%|██████████| 100/100 [00:00<00:00, 484.71it/s]
# Running loglikelihood requests: 100%|██████████| 400/400 [00:12<00:00, 32.14it/s]
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# Finished arc_challenge
#
# Starting evaluation for: wikitext
# 2026-03-27:12:31:46 WARNING  [config.evaluate_config:281] --limit SHOULD ONLY BE USED FOR TESTING. REAL METRICS SHOULD NOT BE COMPUTED USING LIMIT.
# 2026-03-27:12:31:52 INFO     [_cli.run:376] Selected Tasks: ['wikitext']
# Loading weights: 100%|██████████| 398/398 [00:02<00:00, 188.03it/s]
# 2026-03-27:12:32:04 WARNING  [api.task:729] [Task: wikitext] metric word_perplexity is defined, but aggregation is not. using default aggregation=weighted_perplexity
# 2026-03-27:12:32:04 WARNING  [api.task:741] [Task: wikitext] metric word_perplexity is defined, but higher_is_better is not. using default higher_is_better=False
# 2026-03-27:12:32:04 WARNING  [api.task:729] [Task: wikitext] metric byte_perplexity is defined, but aggregation is not. using default aggregation=weighted_perplexity
# 2026-03-27:12:32:04 WARNING  [api.task:741] [Task: wikitext] metric byte_perplexity is defined, but higher_is_better is not. using default higher_is_better=False
# 2026-03-27:12:32:04 WARNING  [api.task:729] [Task: wikitext] metric bits_per_byte is defined, but aggregation is not. using default aggregation=bits_per_byte
# 2026-03-27:12:32:04 WARNING  [api.task:741] [Task: wikitext] metric bits_per_byte is defined, but higher_is_better is not. using default higher_is_better=False
# Generating train split: 100%|██████████| 629/629 [00:00<00:00, 8124.04 examples/s]
# Generating validation split: 100%|██████████| 60/60 [00:00<00:00, 9657.99 examples/s]
# Generating test split: 100%|██████████| 62/62 [00:00<00:00, 10674.72 examples/s]
# 2026-03-27:12:32:07 WARNING  [evaluator:333] Overwriting default num_fewshot of wikitext from None to 0
# 100%|██████████| 62/62 [00:00<00:00, 320.57it/s]
# 100%|██████████| 62/62 [00:00<00:00, 82.15it/s]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.63s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.54s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.59s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.62s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.60s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.56s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.53s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.52s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.52s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.52s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.53s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.55s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.56s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.57s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.55s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.55s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.54s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.53s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.53s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.54s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.55s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.55s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.55s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.55s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.55s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.54s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.54s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.54s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.52s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.55s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.55s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.54s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.55s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.55s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.55s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.54s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.54s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.54s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.55s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.54s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.54s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.54s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.55s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.55s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.54s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.56s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.55s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.56s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.54s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.54s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.53s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.53s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.55s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.53s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.54s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.55s/it]
# Running loglikelihood requests: 100%|██████████| 3/3 [00:07<00:00,  2.56s/it]
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# Finished wikitext

# %% [markdown]
# # Save reports

# %%
zip_path = shutil.make_archive(f"evaluation_results", 'zip', f"evaluation_results")
FileLink(zip_path)
# Out:
# /kaggle/working/evaluation_results.zip
